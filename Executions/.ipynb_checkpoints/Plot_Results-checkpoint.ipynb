# %%
import pandas as pd
import numpy as np
import sys, os , time
from tabulate import tabulate

def find_match(string,list_des):
    return [value for value in list_des if string in value]

def plot_files(file_name):
    print("\nFile to show: ",file_name)
    table = pd.read_csv(folder+file_name)
    print(tabulate(table, headers='keys', tablefmt='rst')) #latex

# %%
# !ls
# Out:
# CIFAR_tol3	    run_CIFAR.sh      simple_50		   simple_tol3_v2
# old_executions	    run_simple.sh     simple_tol3
# Plot_Results.ipynb  run_simple_v2.sh  simple_tol3_extense

# %%
# !ls simple_50
# Out:
# result_scenario1.txt		      synthetic_OursGlobal_trainAnn_s2.csv
# result_scenario2.txt		      synthetic_OursGlobal_trainAnn_s4.csv
# result_scenario3.txt		      synthetic_OursGlobal_trainAnn_s5.csv
# result_scenario4.txt		      synthetic_OursGlobal_trainAnn_s6.csv
# result_scenario5.txt		      synthetic_OursGlobal_trainAnn_s7.csv
# result_scenario6.txt		      synthetic_OursGlobal_train_s1.csv
# result_scenario7.txt		      synthetic_OursGlobal_train_s2.csv
# synthetic_DS_test_s1.csv	      synthetic_OursGlobal_train_s4.csv
# synthetic_DS_test_s2.csv	      synthetic_OursGlobal_train_s5.csv
# synthetic_DS_test_s4.csv	      synthetic_OursGlobal_train_s6.csv
# synthetic_DS_test_s5.csv	      synthetic_OursGlobal_train_s7.csv
# synthetic_DS_test_s6.csv	      synthetic_Raykar_test_s1.csv
# synthetic_DS_test_s7.csv	      synthetic_Raykar_test_s2.csv
# synthetic_DS_train_s1.csv	      synthetic_Raykar_test_s4.csv
# synthetic_DS_train_s2.csv	      synthetic_Raykar_test_s5.csv
# synthetic_DS_train_s4.csv	      synthetic_Raykar_test_s6.csv
# synthetic_DS_train_s5.csv	      synthetic_Raykar_test_s7.csv
# synthetic_DS_train_s6.csv	      synthetic_Raykar_trainAnn_s1.csv
# synthetic_DS_train_s7.csv	      synthetic_Raykar_trainAnn_s2.csv
# synthetic_hardMV_test_s1.csv	      synthetic_Raykar_trainAnn_s4.csv
# synthetic_hardMV_test_s2.csv	      synthetic_Raykar_trainAnn_s5.csv
# synthetic_hardMV_test_s4.csv	      synthetic_Raykar_trainAnn_s6.csv
# synthetic_hardMV_test_s5.csv	      synthetic_Raykar_trainAnn_s7.csv
# synthetic_hardMV_test_s6.csv	      synthetic_Raykar_train_s1.csv
# synthetic_hardMV_test_s7.csv	      synthetic_Raykar_train_s2.csv
# synthetic_hardMV_train_s1.csv	      synthetic_Raykar_train_s4.csv
# synthetic_hardMV_train_s2.csv	      synthetic_Raykar_train_s5.csv
# synthetic_hardMV_train_s4.csv	      synthetic_Raykar_train_s6.csv
# synthetic_hardMV_train_s5.csv	      synthetic_Raykar_train_s7.csv
# synthetic_hardMV_train_s6.csv	      synthetic_softMV_test_s1.csv
# synthetic_hardMV_train_s7.csv	      synthetic_softMV_test_s2.csv
# synthetic_OursGlobal_testAux_s1.csv   synthetic_softMV_test_s4.csv
# synthetic_OursGlobal_testAux_s2.csv   synthetic_softMV_test_s5.csv
# synthetic_OursGlobal_testAux_s4.csv   synthetic_softMV_test_s6.csv
# synthetic_OursGlobal_testAux_s5.csv   synthetic_softMV_test_s7.csv
# synthetic_OursGlobal_testAux_s6.csv   synthetic_softMV_train_s1.csv
# synthetic_OursGlobal_testAux_s7.csv   synthetic_softMV_train_s2.csv
# synthetic_OursGlobal_test_s1.csv      synthetic_softMV_train_s4.csv
# synthetic_OursGlobal_test_s2.csv      synthetic_softMV_train_s5.csv
# synthetic_OursGlobal_test_s4.csv      synthetic_softMV_train_s6.csv
# synthetic_OursGlobal_test_s5.csv      synthetic_softMV_train_s7.csv
# synthetic_OursGlobal_test_s6.csv      synthetic_UpperBound_test.csv
# synthetic_OursGlobal_test_s7.csv      synthetic_UpperBound_train.csv
# synthetic_OursGlobal_trainAnn_s1.csv

# %%
folder = "simple_tol3_v2//"
files = sorted(os.listdir(folder))

# %%
for s in range(1,10):
    print("\n****************************** Scenario "+str(s)+" ******************************")
    scenario_files = find_match("s"+str(s)+".csv",files)
    
    #all from softMV
    aux = find_match("softMV",scenario_files)
    for value in aux:
        plot_files(value)

    #all from hardMV
    aux = find_match("hardMV",scenario_files)
    for value in aux:
        plot_files(value)
        
    aux = find_match("DS",scenario_files)
    for value in aux:
        plot_files(value)
        
    aux = find_match("Raykar",scenario_files)
    for value in aux:
        plot_files(value)
        
    aux = find_match("Ours1",scenario_files)
    for value in aux:
        plot_files(value)        
    aux = find_match("Ours2",scenario_files)
    for value in aux:
        plot_files(value)
    aux = find_match("Ours3",scenario_files)
    for value in aux:
        plot_files(value)
# Out:
# ****************************** Scenario 1 ******************************
#
# File to show:  synthetic_softMV_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.662515      0.662515
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_train_s1.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.646072      0.646072    1.46406   0.174793     1.45768    0.174489
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_hardMV_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.685348      0.685348
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_train_s1.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.672039      0.672039    1.21339   0.183468     1.20806    0.183239
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_DS_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.942979      0.942979
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s1.csv
# ====  ============  ==========  ============  =========  ==========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  ==========  ==========  ==========
#    0  Global          0.930077      0.930077  0.0083941  0.00291665  0.00837058  0.00290923
# ====  ============  ==========  ============  =========  ==========  ==========  ==========
#
# File to show:  synthetic_Raykar_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.923565      0.923565
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s1.csv
# ====  ========================  ====================  =========================  =====================
#   ..    Mean ACC imiting Annot    Mean cross-entropy    Wmean ACC imiting Annot    wMean cross entropy
# ====  ========================  ====================  =========================  =====================
#    0                   0.66617                0.7377                   0.666386               0.737033
# ====  ========================  ====================  =========================  =====================
#
# File to show:  synthetic_Raykar_train_s1.csv
# ====  ============  ==========  ============  =========  ==========  ==========  ==========  ===========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Wmean KL    Wmean JS    Mean RMSE    Wmean RMSE
# ====  ============  ==========  ============  =========  ==========  ==========  ==========  ===========  ============
#    0  Global           0.91567       0.91567  0.0151863  0.00658035   0.0151479  0.00656482     0.169151       0.16897
# ====  ============  ==========  ============  =========  ==========  ==========  ==========  ===========  ============
#
# ****************************** Scenario 2 ******************************
#
# File to show:  synthetic_softMV_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.594017      0.594017
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_train_s2.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.569556      0.569556     1.9033   0.188136     1.90376    0.188157
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_hardMV_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.584371      0.584371
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_train_s2.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.553439      0.553439    2.25078   0.196564     2.25132     0.19659
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_DS_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.939194      0.939194
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s2.csv
# ====  ============  ==========  ============  =========  ==========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  ==========  ==========  ==========
#    0  Global           0.92617       0.92617  0.0106255  0.00363264   0.0105146  0.00359723
# ====  ============  ==========  ============  =========  ==========  ==========  ==========
#
# File to show:  synthetic_Raykar_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.910745      0.910745
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s2.csv
# ====  ========================  ====================  =========================  =====================
#   ..    Mean ACC imiting Annot    Mean cross-entropy    Wmean ACC imiting Annot    wMean cross entropy
# ====  ========================  ====================  =========================  =====================
#    0                   0.71655              0.665757                   0.716309               0.666018
# ====  ========================  ====================  =========================  =====================
#
# File to show:  synthetic_Raykar_train_s2.csv
# ====  ============  ==========  ============  =========  ==========  ==========  ==========  ===========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Wmean KL    Wmean JS    Mean RMSE    Wmean RMSE
# ====  ============  ==========  ============  =========  ==========  ==========  ==========  ===========  ============
#    0  Global          0.899349      0.899349  0.0174028  0.00748148   0.0173188  0.00744755     0.105791      0.106185
# ====  ============  ==========  ============  =========  ==========  ==========  ==========  ===========  ============
#
# ****************************** Scenario 3 ******************************
#
# File to show:  synthetic_softMV_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.653602      0.653602
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_train_s3.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.641229      0.641229    1.10472   0.113129     1.10177    0.112828
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_hardMV_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.741514      0.741514
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_train_s3.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global           0.74013       0.74013   0.385134   0.150192    0.384324    0.149983
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_DS_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.942979      0.942979
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s3.csv
# ====  ============  ==========  ============  =========  ==========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  ==========  ==========  ==========
#    0  Global          0.928042      0.928042  0.0239761  0.00460544    0.023659  0.00458309
# ====  ============  ==========  ============  =========  ==========  ==========  ==========
#
# File to show:  synthetic_Raykar_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.920024      0.920024
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s3.csv
# ====  ========================  ====================  =========================  =====================
#   ..    Mean ACC imiting Annot    Mean cross-entropy    Wmean ACC imiting Annot    wMean cross entropy
# ====  ========================  ====================  =========================  =====================
#    0                  0.629232               0.81677                   0.629388                0.81701
# ====  ========================  ====================  =========================  =====================
#
# File to show:  synthetic_Raykar_train_s3.csv
# ====  ============  ==========  ============  =========  ==========  ==========  ==========  ===========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Wmean KL    Wmean JS    Mean RMSE    Wmean RMSE
# ====  ============  ==========  ============  =========  ==========  ==========  ==========  ===========  ============
#    0  Global          0.912129      0.912129  0.0136987  0.00547667   0.0136693  0.00546275     0.106134      0.104938
# ====  ============  ==========  ============  =========  ==========  ==========  ==========  ===========  ============
#
# ****************************** Scenario 4 ******************************
#
# File to show:  synthetic_softMV_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.666422      0.666422
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.651486      0.651486    1.67788   0.181219     1.67725    0.181142
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_hardMV_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.711844      0.711844
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.704355      0.704355   0.512769   0.153689     0.51223    0.153595
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_DS_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global           0.93431       0.93431
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.924461      0.924461    1.96961   0.115499       1.787    0.105086
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_Raykar_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.902564      0.902564
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s4.csv
# ====  ========================  ====================  =========================  =====================
#   ..    Mean ACC imiting Annot    Mean cross-entropy    Wmean ACC imiting Annot    wMean cross entropy
# ====  ========================  ====================  =========================  =====================
#    0                  0.729115               0.79347                   0.723642               0.791628
# ====  ========================  ====================  =========================  =====================
#
# File to show:  synthetic_Raykar_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS    Mean RMSE    Wmean RMSE
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#    0  Global          0.900041      0.900041   0.214041  0.0905247    0.203052    0.086015     0.141241      0.141165
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#
# ****************************** Scenario 5 ******************************
#
# File to show:  synthetic_softMV_test_s5.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.645177      0.645177
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_train_s5.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.630077      0.630077    1.76418   0.180057     1.75709    0.179675
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_hardMV_test_s5.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global           0.71514       0.71514
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_train_s5.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.707611      0.707611   0.742873   0.177292     0.73941    0.177045
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_DS_test_s5.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.939072      0.939072
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s5.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.928897      0.928897    3.17568    0.53102     3.08039    0.403374
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_Raykar_test_s5.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.895238      0.895238
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s5.csv
# ====  ========================  ====================  =========================  =====================
#   ..    Mean ACC imiting Annot    Mean cross-entropy    Wmean ACC imiting Annot    wMean cross entropy
# ====  ========================  ====================  =========================  =====================
#    0                  0.799614              0.834494                   0.775977               0.829244
# ====  ========================  ====================  =========================  =====================
#
# File to show:  synthetic_Raykar_train_s5.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS    Mean RMSE    Wmean RMSE
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#    0  Global          0.888034      0.888034    0.33193   0.138526    0.308492    0.129113     0.132713      0.142271
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#
# ****************************** Scenario 6 ******************************
#
# File to show:  synthetic_softMV_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.560317      0.560317
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.534514      0.534514    1.48948   0.193712      1.4901    0.193868
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_hardMV_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.575336      0.575336
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.541677      0.541677    2.24496   0.198063     2.24527    0.198168
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_DS_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.790232      0.790232
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.779853      0.779853    2.09928   0.139405     1.94877    0.125849
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_Raykar_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.782662      0.782662
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s6.csv
# ====  ========================  ====================  =========================  =====================
#   ..    Mean ACC imiting Annot    Mean cross-entropy    Wmean ACC imiting Annot    wMean cross entropy
# ====  ========================  ====================  =========================  =====================
#    0                  0.748286              0.772878                   0.745063               0.768906
# ====  ========================  ====================  =========================  =====================
#
# File to show:  synthetic_Raykar_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS    Mean RMSE    Wmean RMSE
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#    0  Global          0.773667      0.773667   0.251633   0.105454    0.241229    0.101108     0.128543      0.127379
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#
# ****************************** Scenario 7 ******************************
#
# File to show:  synthetic_softMV_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.654335      0.654335
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.640456      0.640456    1.35715   0.129577     1.35999    0.129534
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_hardMV_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.767033      0.767033
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global          0.770045      0.770045   0.384935   0.148205    0.384604    0.147909
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_DS_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.918926      0.918926
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#    0  Global            0.9116        0.9116    2.41456   0.137457     2.19636    0.126011
# ====  ============  ==========  ============  =========  =========  ==========  ==========
#
# File to show:  synthetic_Raykar_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.912088      0.912088
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s7.csv
# ====  ========================  ====================  =========================  =====================
#   ..    Mean ACC imiting Annot    Mean cross-entropy    Wmean ACC imiting Annot    wMean cross entropy
# ====  ========================  ====================  =========================  =====================
#    0                  0.681697              0.850764                   0.675432               0.851298
# ====  ========================  ====================  =========================  =====================
#
# File to show:  synthetic_Raykar_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Wmean KL    Wmean JS    Mean RMSE    Wmean RMSE
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#    0  Global          0.902727      0.902727   0.184037  0.0738271     0.17499   0.0700911     0.145403       0.14386
# ====  ============  ==========  ============  =========  =========  ==========  ==========  ===========  ============
#
# ****************************** Scenario 8 ******************************
#
# ****************************** Scenario 9 ******************************

# %%
methods_list = ["Ann(tr)","softMV","hardMV", "DS", "Raykar", "OursGlobal", "Ours2", "Ours3"]
methods_list_aux = ["soft-MV","hard-MV", "D&S", "Raykar", "Ours Global","",""]

def calculate_aux(archivo,what_to_do="mv",model=""):
    try:
        f = open(folder+archivo)
        result_list = []
        for line in f.readlines():
            if what_to_do == "mv":
                if "ACC MV" in line: 
                    result_list.append(float(line.split(" ")[-1].strip()))
            elif what_to_do == 'epochs':
                if "Epochs to converge" in line and model in line: 
                    result_list.append(float(line.split(" ")[-1].strip()))
        f.close()
        return np.mean(result_list)
    except:
        return "-"

def compare_table(tipo,repre="normal"):
    t = pd.DataFrame()
    t["Methods"] = methods_list
    for s in range(1,10):
        t["Scenario "+str(s)] = ["-" for _ in range(len(methods_list))]
        if tipo == 'acc':
            t.loc[0,"Scenario "+str(s)] =  calculate_aux("result_scenario"+str(s)+".txt",what_to_do="mv")

        scenario_files = find_match("s"+str(s)+".csv",files)

        for k, method in enumerate(methods_list[1:]):
            aux = find_match(method,scenario_files)
            if tipo == "acc": #como normal?
                test_aux = find_match("_test_",aux)
                if len(test_aux) != 0:
                    t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+test_aux[0])["Accuracy"][0], 4)
                    
            elif tipo == 'kl' or tipo=='js':
                kl_aux = find_match("_train_",aux)
                if len(kl_aux) != 0:
                    if repre=="wmean":
                        to_extract = "Wmean "
                    elif repre=='mean':
                        to_extract="Mean "
                    if tipo == 'kl':
                        try:
                            t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+kl_aux[0])[to_extract+"KL"][0] ,4)
                        except:
                            pass
                    elif tipo=='js':
                        try:
                            t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+kl_aux[0])[to_extract+"JS"][0] ,4)
                        except:
                            pass
            elif tipo == 'accann':
                train_ann = find_match("_trainAnn_",aux)
                if len(train_ann) != 0:
                    if repre=="wmean":
                        to_extract = "Wmean "
                    elif repre=='mean':
                        to_extract="Mean "
                    t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+train_ann[0])[to_extract+"ACC imiting Annot"][0] ,4)
            elif tipo == 'rmse':
                train_aux = find_match("_train_",aux)
                if len(train_aux) != 0:
                    try:
                        t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+train_aux[0])["Average RMSE"][0] ,4)
                    except:
                        pass
            elif tipo == "epochs":
                t.loc[k+1,"Scenario "+str(s)]=calculate_aux("result_scenario"+str(s)+".txt",what_to_do="epochs",model=methods_list_aux[k])
    return t
t_acc = compare_table("acc","normal")
t_kl_mean = compare_table("kl","mean")
t_js_mean = compare_table("js","mean")
t_kl_wmean = compare_table("kl","wmean")
t_js_wmean = compare_table("js","wmean")
t_acc
# Out:
#       Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5  \
# 0     Ann(tr)   0.777371    0.61335    0.78022   0.771673   0.807082
# 1      softMV     0.6521     0.5745     0.6442     0.6438       0.63
# 2      hardMV     0.6901     0.5968      0.747     0.7297     0.7082
# 3          DS     0.9358     0.9435     0.9403     0.9295     0.9399
# 4      Raykar     0.9295     0.9192     0.9259     0.9211     0.9059
# 5  OursGlobal     0.9111     0.6866     0.9043     0.8999     0.9114
# 6       Ours2          -          -          -          -          -
# 7       Ours3          -          -          -          -          -
#
#   Scenario 6 Scenario 7 Scenario 8 Scenario 9
# 0   0.622711   0.782255          -          -
# 1     0.5811     0.6549          -          -
# 2     0.5944     0.7686          -          -
# 3     0.7963     0.9128          -          -
# 4     0.7564     0.9241          -          -
# 5      0.758     0.8455          -          -
# 6          -          -          -          -
# 7          -          -          -          -

# %%
t_acc #tol3 v2
# Out:
#       Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5  \
# 0     Ann(tr)   0.777371    0.61335    0.78022   0.771673   0.807082
# 1      softMV     0.6521     0.5745     0.6442     0.6438       0.63
# 2      hardMV     0.6901     0.5968      0.747     0.7297     0.7082
# 3          DS     0.9358     0.9435     0.9403     0.9295     0.9399
# 4      Raykar     0.9295     0.9192     0.9259     0.9211     0.9059
# 5  OursGlobal     0.9111     0.6866     0.9043     0.8999     0.9114
# 6       Ours2          -          -          -          -          -
# 7       Ours3          -          -          -          -          -
#
#   Scenario 6 Scenario 7 Scenario 8 Scenario 9
# 0   0.622711   0.782255          -          -
# 1     0.5811     0.6549          -          -
# 2     0.5944     0.7686          -          -
# 3     0.7963     0.9128          -          -
# 4     0.7564     0.9241          -          -
# 5      0.758     0.8455          -          -
# 6          -          -          -          -
# 7          -          -          -          -

# %%
t_acc #tol3 normal
# Out:
#       Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5  \
# 0     Ann(tr)   0.777371    0.61335    0.78022   0.771673   0.807082
# 1      softMV     0.6625      0.594     0.6536     0.6664     0.6452
# 2      hardMV     0.6853     0.5844     0.7415     0.7118     0.7151
# 3          DS      0.943     0.9392      0.943     0.9343     0.9391
# 4      Raykar     0.9236     0.9107       0.92     0.9026     0.8952
# 5  OursGlobal     0.8592     0.7748      0.873     0.8575     0.9131
# 6       Ours2          -          -          -          -          -
# 7       Ours3          -          -          -          -          -
#
#   Scenario 6 Scenario 7 Scenario 8 Scenario 9
# 0   0.622711   0.782255          -          -
# 1     0.5603     0.6543          -          -
# 2     0.5753      0.767          -          -
# 3     0.7902     0.9189          -          -
# 4     0.7827     0.9121          -          -
# 5     0.7601     0.9182          -          -
# 6          -          -          -          -
# 7          -          -          -          -

# %%
t_js_mean #tol3 normal
# Out:
#       Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5  \
# 0     Ann(tr)          -          -          -          -          -
# 1      softMV     0.1748     0.1881     0.1131     0.1812     0.1801
# 2      hardMV     0.1835     0.1966     0.1502     0.1537     0.1773
# 3          DS     0.0029     0.0036     0.0046     0.1155      0.531
# 4      Raykar     0.0066     0.0075     0.0055     0.0905     0.1385
# 5  OursGlobal     0.1511     0.1574     0.1466     0.1346     0.1181
# 6       Ours2          -          -          -          -          -
# 7       Ours3          -          -          -          -          -
#
#   Scenario 6 Scenario 7 Scenario 8 Scenario 9
# 0          -          -          -          -
# 1     0.1937     0.1296          -          -
# 2     0.1981     0.1482          -          -
# 3     0.1394     0.1375          -          -
# 4     0.1055     0.0738          -          -
# 5     0.1377     0.1271          -          -
# 6          -          -          -          -
# 7          -          -          -          -

# %%
t_js_mean #tol3 v2
# Out:
#       Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5  \
# 0     Ann(tr)          -          -          -          -          -
# 1      softMV     0.1733     0.1881     0.1332     0.2104     0.2147
# 2      hardMV      0.153     0.1966     0.1237     0.1829     0.1478
# 3          DS     0.0029     0.0036     0.0046     0.1155      0.531
# 4      Raykar     0.0066     0.0074     0.0054     0.0902     0.1386
# 5  OursGlobal     0.1057     0.1511     0.1323     0.1266     0.1257
# 6       Ours2          -          -          -          -          -
# 7       Ours3          -          -          -          -          -
#
#   Scenario 6 Scenario 7 Scenario 8 Scenario 9
# 0          -          -          -          -
# 1     0.2019     0.1524          -          -
# 2     0.2012     0.1188          -          -
# 3     0.1394     0.1375          -          -
# 4     0.1121      0.074          -          -
# 5     0.1486      0.114          -          -
# 6          -          -          -          -
# 7          -          -          -          -

# %%
t_accAnn_mean = compare_table("accann","mean")
t_accAnn_wmean = compare_table("accann","wmean")
t_rmseAnn = compare_table("rmse","normal")
t_accAnn_mean
# Out:
#       Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5  \
# 0     Ann(tr)          -          -          -          -          -
# 1      softMV          -          -          -          -          -
# 2      hardMV          -          -          -          -          -
# 3          DS          -          -          -          -          -
# 4      Raykar     0.6662     0.7165     0.6292     0.7291     0.7996
# 5  OursGlobal     0.6247     0.6199     0.6001     0.6979     0.7516
# 6       Ours2          -          -          -          -          -
# 7       Ours3          -          -          -          -          -
#
#   Scenario 6 Scenario 7 Scenario 8 Scenario 9
# 0          -          -          -          -
# 1          -          -          -          -
# 2          -          -          -          -
# 3          -          -          -          -
# 4     0.7483     0.6817          -          -
# 5     0.6993     0.6629          -          -
# 6          -          -          -          -
# 7          -          -          -          -

# %%
t_epochs = compare_table("epochs")
t_epochs
# Out:
#       Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5  \
# 0     Ann(tr)          -          -          -          -          -
# 1      softMV        5.6        5.6        6.3        6.5        6.4
# 2      hardMV       10.3        9.6       10.8        9.9       12.1
# 3          DS       14.1       13.7       11.4       11.7       14.5
# 4      Raykar       5.08       6.48       5.69      4.705          4
# 5  OursGlobal     34.345     32.245     32.955     34.115      40.17
# 6       Ours2    13.9657    13.5343    13.5578    13.4157    15.4647
# 7       Ours3    13.9657    13.5343    13.5578    13.4157    15.4647
#
#   Scenario 6 Scenario 7 Scenario 8 Scenario 9
# 0          -          -          -          -
# 1        4.9        5.6          -          -
# 2         10        9.7          -          -
# 3        9.9       11.1          -          -
# 4      5.205      4.005          -          -
# 5      32.76       33.2          -          -
# 6     12.601    12.7657          -          -
# 7     12.601    12.7657          -          -

# %%
print(tabulate(t_acc,headers='keys',tablefmt='latex'))
# Out:
# \begin{tabular}{rlrrrrllrll}
# \hline
#     & Methods   &   Scenario 1 &   Scenario 2 &   Scenario 3 &   Scenario 4 & Scenario 5   & Scenario 6         &   Scenario 7 & Scenario 8   & Scenario 9   \\
# \hline
#   0 & Ann(tr)   &     0.736088 &      0.63994 &     0.734682 &     0.860618 & -            & 0.92921            &     0.773474 & -            & -            \\
#   1 & softMV    &     0.50514  &      0.411   &     0.50312  &     0.54629  & -            & 0.55137            &     0.44988  & -            & -            \\
#   2 & hardMV    &     0.68797  &      0.61673 &     0.67775  &     0.76115  & -            & 0.8083499999999999 &     0.69982  & -            & -            \\
#   3 & DS        &     0.73433  &      0.70825 &     0.71054  &     0.7978   & -            & -                  &     0.77167  & -            & -            \\
#   4 & Raykar    &     0.76504  &      0.76543 &     0.75637  &     0.72907  & -            & -                  &     0.74361  & -            & -            \\
#   5 & Ours1     &     0.70187  &      0.65397 &     0.69528  &     0.72962  & -            & -                  &     0.62502  & -            & -            \\
#   6 & Ours2     &     0.71208  &      0.67341 &     0.70969  &     0.72946  & -            & -                  &     0.65994  & -            & -            \\
#   7 & Ours3     &     0.74322  &      0.66097 &     0.73005  &     0.76074  & -            & 0.7323999999999999 &     0.63891  & -            & -            \\
# \hline
# \end{tabular}

# %%
t_js_mean
# Out:
#       Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5  \
# 0     Ann(tr)          -          -          -          -          -
# 1      softMV     0.1748     0.1881     0.1131     0.1812     0.1801
# 2      hardMV     0.1835     0.1966     0.1502     0.1537     0.1773
# 3          DS     0.0029     0.0036     0.0046     0.1155      0.531
# 4      Raykar     0.0066     0.0075     0.0055     0.0905     0.1385
# 5  OursGlobal     0.1511     0.1574     0.1466     0.1346     0.1181
# 6       Ours2          -          -          -          -          -
# 7       Ours3          -          -          -          -          -
#
#   Scenario 6 Scenario 7 Scenario 8 Scenario 9
# 0          -          -          -          -
# 1     0.1937     0.1296          -          -
# 2     0.1981     0.1482          -          -
# 3     0.1394     0.1375          -          -
# 4     0.1055     0.0738          -          -
# 5     0.1377     0.1271          -          -
# 6          -          -          -          -
# 7          -          -          -          -

# %%
print(tabulate(t_js,headers='keys',tablefmt='latex'))
# Out:
# \begin{tabular}{rllllllllll}
# \hline
#     & Methods   & Scenario 1            & Scenario 2            & Scenario 3            & Scenario 4           & Scenario 5   & Scenario 6          & Scenario 7           & Scenario 8   & Scenario 9   \\
# \hline
#   0 & Ann(tr)   & -                     & -                     & -                     & -                    & -            & -                   & -                    & -            & -            \\
#   1 & softMV    & 0.05950674562562306   & 0.050221015434156566  & 0.0464438055596799    & 0.06008439775112365  & -            & -                   & 0.05270814033661828  & -            & -            \\
#   2 & hardMV    & 0.020995887868733132  & 0.02332643544245791   & 0.01641877942778385   & 0.020941518144649125 & -            & -                   & 0.022754271714284745 & -            & -            \\
#   3 & DS        & 0.0030529387533430176 & 0.0036232315811678796 & 0.0035185836491103835 & 0.027734659509510685 & -            & -                   & 0.030090635164642762 & -            & -            \\
#   4 & Raykar    & 0.002927220711785863  & 0.0032315487412953197 & 0.002849180546643681  & 0.021909906391642642 & -            & -                   & 0.022660941662491708 & -            & -            \\
#   5 & Ours1     & 0.05491425130342231   & 0.0556004753207321    & 0.044305405303445164  & 0.05791975756665664  & -            & -                   & 0.05925063236498172  & -            & -            \\
#   6 & Ours2     & 0.08897113067619779   & 0.08635660479650485   & 0.06757757207369068   & 0.08361031118942824  & -            & -                   & 0.12958117167140096  & -            & -            \\
#   7 & Ours3     & 0.08885640948565085   & 0.11156011363090483   & 0.07987275420720097   & 0.09815288307829276  & -            & 0.09800208925308994 & 0.11174892631537743  & -            & -            \\
# \hline
# \end{tabular}
