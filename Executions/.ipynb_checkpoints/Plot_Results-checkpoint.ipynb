# %%
import pandas as pd
import numpy as np
import sys, os , time
from tabulate import tabulate

def find_match(string,list_des):
    return [value for value in list_des if string in value]

def plot_files(file_name):
    print("\nFile to show: ",file_name)
    table = pd.read_csv(folder+file_name)
    print(tabulate(table, headers='keys', tablefmt='rst')) #latex

# %%
# !ls
# Out:
# aux.txt		 CIFAR_tol3	     run_CIFAR.sh      simple
# calculate_mv.py  new_CIFAR	     run_simple.sh     simple_tol2
# CIFAR		 Plot_Results.ipynb  run_simple_v2.sh  simple_tol3

# %%
# !ls CIFAR_tol3
# Out:
# result_scenario1.txt		simCIFAR_Ours2_trainAnn_s3.csv
# result_scenario2.txt		simCIFAR_Ours2_trainAnn_s4.csv
# result_scenario3.txt		simCIFAR_Ours2_trainAnn_s7.csv
# result_scenario4.txt		simCIFAR_Ours2_train_s1.csv
# result_scenario6.txt		simCIFAR_Ours2_train_s2.csv
# result_scenario7.txt		simCIFAR_Ours2_train_s3.csv
# simCIFAR_DS_test_s1.csv		simCIFAR_Ours2_train_s4.csv
# simCIFAR_DS_test_s2.csv		simCIFAR_Ours2_train_s7.csv
# simCIFAR_DS_test_s3.csv		simCIFAR_Ours3_testAux_s1.csv
# simCIFAR_DS_test_s4.csv		simCIFAR_Ours3_testAux_s2.csv
# simCIFAR_DS_test_s7.csv		simCIFAR_Ours3_testAux_s3.csv
# simCIFAR_DS_train_s1.csv	simCIFAR_Ours3_testAux_s4.csv
# simCIFAR_DS_train_s2.csv	simCIFAR_Ours3_testAux_s6.csv
# simCIFAR_DS_train_s3.csv	simCIFAR_Ours3_testAux_s7.csv
# simCIFAR_DS_train_s4.csv	simCIFAR_Ours3_test_s1.csv
# simCIFAR_DS_train_s7.csv	simCIFAR_Ours3_test_s2.csv
# simCIFAR_hardMV_test_s1.csv	simCIFAR_Ours3_test_s3.csv
# simCIFAR_hardMV_test_s2.csv	simCIFAR_Ours3_test_s4.csv
# simCIFAR_hardMV_test_s3.csv	simCIFAR_Ours3_test_s6.csv
# simCIFAR_hardMV_test_s4.csv	simCIFAR_Ours3_test_s7.csv
# simCIFAR_hardMV_test_s6.csv	simCIFAR_Ours3_trainAnn_s1.csv
# simCIFAR_hardMV_test_s7.csv	simCIFAR_Ours3_trainAnn_s2.csv
# simCIFAR_hardMV_trainG_s1.csv	simCIFAR_Ours3_trainAnn_s3.csv
# simCIFAR_hardMV_trainG_s2.csv	simCIFAR_Ours3_trainAnn_s4.csv
# simCIFAR_hardMV_trainG_s3.csv	simCIFAR_Ours3_trainAnn_s7.csv
# simCIFAR_hardMV_trainG_s4.csv	simCIFAR_Ours3_train_s1.csv
# simCIFAR_hardMV_trainG_s6.csv	simCIFAR_Ours3_train_s2.csv
# simCIFAR_hardMV_trainG_s7.csv	simCIFAR_Ours3_train_s3.csv
# simCIFAR_hardMV_train_s1.csv	simCIFAR_Ours3_train_s4.csv
# simCIFAR_hardMV_train_s2.csv	simCIFAR_Ours3_train_s6.csv
# simCIFAR_hardMV_train_s3.csv	simCIFAR_Ours3_train_s7.csv
# simCIFAR_hardMV_train_s4.csv	simCIFAR_Raykar_test_s1.csv
# simCIFAR_hardMV_train_s6.csv	simCIFAR_Raykar_test_s2.csv
# simCIFAR_hardMV_train_s7.csv	simCIFAR_Raykar_test_s3.csv
# simCIFAR_Ours1_testAux_s1.csv	simCIFAR_Raykar_test_s4.csv
# simCIFAR_Ours1_testAux_s2.csv	simCIFAR_Raykar_test_s7.csv
# simCIFAR_Ours1_testAux_s3.csv	simCIFAR_Raykar_trainAnn_s1.csv
# simCIFAR_Ours1_testAux_s4.csv	simCIFAR_Raykar_trainAnn_s2.csv
# simCIFAR_Ours1_testAux_s7.csv	simCIFAR_Raykar_trainAnn_s3.csv
# simCIFAR_Ours1_test_s1.csv	simCIFAR_Raykar_trainAnn_s4.csv
# simCIFAR_Ours1_test_s2.csv	simCIFAR_Raykar_trainAnn_s7.csv
# simCIFAR_Ours1_test_s3.csv	simCIFAR_Raykar_train_s1.csv
# simCIFAR_Ours1_test_s4.csv	simCIFAR_Raykar_train_s2.csv
# simCIFAR_Ours1_test_s7.csv	simCIFAR_Raykar_train_s3.csv
# simCIFAR_Ours1_trainAnn_s1.csv	simCIFAR_Raykar_train_s4.csv
# simCIFAR_Ours1_trainAnn_s2.csv	simCIFAR_Raykar_train_s7.csv
# simCIFAR_Ours1_trainAnn_s3.csv	simCIFAR_softMV_test_s1.csv
# simCIFAR_Ours1_trainAnn_s4.csv	simCIFAR_softMV_test_s2.csv
# simCIFAR_Ours1_trainAnn_s7.csv	simCIFAR_softMV_test_s3.csv
# simCIFAR_Ours1_train_s1.csv	simCIFAR_softMV_test_s4.csv
# simCIFAR_Ours1_train_s2.csv	simCIFAR_softMV_test_s6.csv
# simCIFAR_Ours1_train_s3.csv	simCIFAR_softMV_test_s7.csv
# simCIFAR_Ours1_train_s4.csv	simCIFAR_softMV_trainG_s1.csv
# simCIFAR_Ours1_train_s7.csv	simCIFAR_softMV_trainG_s2.csv
# simCIFAR_Ours2_testAux_s1.csv	simCIFAR_softMV_trainG_s3.csv
# simCIFAR_Ours2_testAux_s2.csv	simCIFAR_softMV_trainG_s4.csv
# simCIFAR_Ours2_testAux_s3.csv	simCIFAR_softMV_trainG_s6.csv
# simCIFAR_Ours2_testAux_s4.csv	simCIFAR_softMV_trainG_s7.csv
# simCIFAR_Ours2_testAux_s7.csv	simCIFAR_softMV_train_s1.csv
# simCIFAR_Ours2_test_s1.csv	simCIFAR_softMV_train_s2.csv
# simCIFAR_Ours2_test_s2.csv	simCIFAR_softMV_train_s3.csv
# simCIFAR_Ours2_test_s3.csv	simCIFAR_softMV_train_s4.csv
# simCIFAR_Ours2_test_s4.csv	simCIFAR_softMV_train_s6.csv
# simCIFAR_Ours2_test_s7.csv	simCIFAR_softMV_train_s7.csv
# simCIFAR_Ours2_trainAnn_s1.csv	simCIFAR_UpperBound_test.csv
# simCIFAR_Ours2_trainAnn_s2.csv	simCIFAR_UpperBound_train.csv

# %%
folder = "CIFAR_tol3/"
files = sorted(os.listdir(folder))

# %%
for s in range(1,10):
    print("\n****************************** Scenario "+str(s)+" ******************************")
    scenario_files = find_match("s"+str(s)+".csv",files)
    
    #all from softMV
    aux = find_match("softMV",scenario_files)
    for value in aux:
        plot_files(value)

    #all from hardMV
    aux = find_match("hardMV",scenario_files)
    for value in aux:
        plot_files(value)
        
    aux = find_match("DS",scenario_files)
    for value in aux:
        plot_files(value)
        
    aux = find_match("Raykar",scenario_files)
    for value in aux:
        plot_files(value)
        
    aux = find_match("Ours1",scenario_files)
    for value in aux:
        plot_files(value)        
    aux = find_match("Ours2",scenario_files)
    for value in aux:
        plot_files(value)
    aux = find_match("Ours3",scenario_files)
    for value in aux:
        plot_files(value)
# Out:
# ****************************** Scenario 1 ******************************
#
# File to show:  synthetic_softMV_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.513492      0.513492
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_trainG_s1.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.502035      0.502035    1.89579   0.156968            0.270283
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_softMV_train_s1.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.502035      0.502035   0.279557  0.0773767            0.938779
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.591514      0.591514
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_trainG_s1.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.580749      0.580749    2.23261   0.158736            0.329934
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_train_s1.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.580749      0.580749   0.239329  0.0673491              0.9533
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_DS_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.876801      0.876801
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s1.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.866789      0.866789  0.0106679  0.0024944            0.988758
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_Raykar_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.694322      0.694322
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s1.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.600746                0.844585
# ====  =======================  ======================
#
# File to show:  synthetic_Raykar_train_s1.csv
# ====  ============  ==========  ============  =========  ==========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  ==========  ==================  ==============
#    0  Global          0.689398      0.689398   0.016867  0.00497451            0.988626        0.141204
# ====  ============  ==========  ============  =========  ==========  ==================  ==============
#
# File to show:  synthetic_Ours1_testAux_s1.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.404429   39.95   0.397377     0.587369    1.36401       0.671029   0.254036    0.674725      0.674725
#    1         1  0.318958   31.45   0.393156     0.557126    1.33604       0.64954    0.223793    0.712332      0.712332
#    2         2  0.276613   27.05   0.389864     0.550622    1.39874       0.636356   0.217288    0.685043      0.685043
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours1_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.643834      0.643834
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours1_trainAnn_s1.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.669073                0.729851
# ====  =======================  ======================
#
# File to show:  synthetic_Ours1_train_s1.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.636528      0.636528   0.662798    0.10286            0.515401       0.0997595
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours2_testAux_s1.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.40174    39.7    0.315212     0.675113    1.1042        0.739147   0.341779    0.677656      0.677656
#    1         1  0.333015   32.75   0.325977     0.675665    1.02539       0.742185   0.342332    0.727778      0.727778
#    2         2  0.265245   26      0.347902     0.636097    1.12603       0.709002   0.302763    0.664591      0.664591
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours2_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global           0.72967       0.72967
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours2_trainAnn_s1.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.661205                0.747179
# ====  =======================  ======================
#
# File to show:  synthetic_Ours2_train_s1.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.722955      0.722955   0.693271  0.0967185            0.438028        0.103537
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours3_testAux_s1.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.38525    38      0.315057     0.691283   0.941249       0.75268    0.35795     0.659585      0.659585
#    1         1  0.276266   27.05   0.360775     0.762015   0.716442       0.823787   0.428681    0.768864      0.768864
#    2         2  0.338483   33.55   0.358266     0.801005   0.532452       0.861967   0.467672    0.741697      0.741697
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours3_test_s1.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global           0.76514       0.76514
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours3_trainAnn_s1.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.632223                0.805187
# ====  =======================  ======================
#
# File to show:  synthetic_Ours3_train_s1.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.757672      0.757672   0.636585   0.093879            0.388093        0.102332
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# ****************************** Scenario 2 ******************************
#
# File to show:  synthetic_softMV_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.469841      0.469841
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_trainG_s2.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.452605      0.452605    1.81948   0.163317            0.388143
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_softMV_train_s2.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.452605      0.452605   0.284603  0.0788086             0.90893
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.518926      0.518926
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_trainG_s2.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.496195      0.496195    1.99465   0.148086            0.438845
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_train_s2.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.496195      0.496195   0.256469  0.0715387             0.91277
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_DS_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.825092      0.825092
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s2.csv
# ====  ============  ==========  ============  =========  ==========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  ==========  ==================
#    0  Global          0.819434      0.819434  0.0170878  0.00330586            0.985139
# ====  ============  ==========  ============  =========  ==========  ==================
#
# File to show:  synthetic_Raykar_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.683089      0.683089
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s2.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.633164                0.792919
# ====  =======================  ======================
#
# File to show:  synthetic_Raykar_train_s2.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.677391      0.677391  0.0181716  0.0053482            0.990088        0.187746
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours1_testAux_s2.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.336476   33.1    0.356776     0.614397    1.4789        0.675523   0.281063    0.600244      0.600244
#    1         1  0.338068   33.3    0.437887     0.612177    1.2535        0.697458   0.278843    0.611355      0.611355
#    2         2  0.325457   31.95   0.449631     0.534929    1.44653       0.629428   0.201596    0.614408      0.614408
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours1_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.527717      0.527717
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours1_trainAnn_s2.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.674245                0.703054
# ====  =======================  ======================
#
# File to show:  synthetic_Ours1_train_s2.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.521754      0.521754   0.855122   0.114627            0.580888        0.174393
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours2_testAux_s2.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.366507   36.15   0.264044     0.632044   1.30848        0.68704    0.298711    0.614347      0.614347
#    1         1  0.301263   29.7    0.321226     0.750288   0.676531       0.811303   0.416954    0.697863      0.697863
#    2         2  0.33223    32.75   0.341388     0.683737   0.90989        0.755286   0.350403    0.691026      0.691026
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours2_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.683211      0.683211
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours2_trainAnn_s2.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.670355                0.705026
# ====  =======================  ======================
#
# File to show:  synthetic_Ours2_train_s2.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.675234      0.675234   0.689843  0.0968277            0.533382        0.182807
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours3_testAux_s2.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.364922   36      0.356395     0.697756   0.852488       0.770916   0.364423    0.671062      0.671062
#    1         1  0.296832   29.1    0.324088     0.686102   0.993548       0.746736   0.352769    0.651709      0.651709
#    2         2  0.338246   33.35   0.296501     0.622586   1.27181        0.681415   0.289252    0.600305      0.600305
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours3_test_s2.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.681441      0.681441
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours3_trainAnn_s2.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.649483                0.738406
# ====  =======================  ======================
#
# File to show:  synthetic_Ours3_train_s2.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.671551      0.671551   0.695406    0.10147            0.381021        0.202254
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# ****************************** Scenario 3 ******************************
#
# File to show:  synthetic_softMV_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.522405      0.522405
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_trainG_s3.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.513085      0.513085    1.74881   0.128732            0.463592
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_softMV_train_s3.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.513085      0.513085   0.236126   0.064226            0.833673
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.629609      0.629609
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_trainG_s3.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.624339      0.624339    1.21096   0.108788            0.426481
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_train_s3.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.624339      0.624339   0.200036  0.0553308            0.851795
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_DS_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.822344      0.822344
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s3.csv
# ====  ============  ==========  ============  =========  ==========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  ==========  ==================
#    0  Global          0.815812      0.815812  0.0243846  0.00356626            0.901047
# ====  ============  ==========  ============  =========  ==========  ==================
#
# File to show:  synthetic_Raykar_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.610684      0.610684
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s3.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.542438                0.927608
# ====  =======================  ======================
#
# File to show:  synthetic_Raykar_train_s3.csv
# ====  ============  ==========  ============  =========  ==========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL     Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  ==========  ==================  ==============
#    0  Global          0.608201      0.608201  0.0158455  0.00432362            0.889345        0.113779
# ====  ============  ==========  ============  =========  ==========  ==================  ==============
#
# File to show:  synthetic_Ours1_testAux_s3.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.345436   33.95   0.50399      0.567161    1.35027       0.666902   0.233827    0.648901      0.648901
#    1         1  0.382304   37.85   0.499758     0.575202    1.36964       0.672302   0.241869    0.668681      0.668681
#    2         2  0.272259   26.7    0.519579     0.570886    1.27874       0.672157   0.237552    0.636874      0.636874
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours1_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.633516      0.633516
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours1_trainAnn_s3.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.602598                0.825874
# ====  =======================  ======================
#
# File to show:  synthetic_Ours1_train_s3.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.622487      0.622487   0.787832    0.10851            0.446569        0.085482
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours2_testAux_s3.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.334506   32.85   0.385154     0.718449   0.855178       0.790741   0.385116    0.692186      0.692186
#    1         1  0.386846   38.15   0.374868     0.699705   0.924876       0.772366   0.366372    0.735287      0.735287
#    2         2  0.278648   27.35   0.421457     0.672885   0.944582       0.753985   0.339552    0.679365      0.679365
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours2_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global           0.70641       0.70641
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours2_trainAnn_s3.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                  0.62061                0.815855
# ====  =======================  ======================
#
# File to show:  synthetic_Ours2_train_s3.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.699939      0.699939   0.708684  0.0953397            0.548666       0.0705889
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours3_testAux_s3.csv
# ====  ========  =======  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups     Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  =======  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.34931   34.4    0.353441     0.697454   0.910336       0.763935   0.364121    0.711355      0.711355
#    1         1  0.24715   24.25   0.337712     0.729866   0.77729        0.795165   0.396533    0.69188       0.69188
#    2         2  0.40354   39.95   0.311052     0.731596   0.779447       0.796415   0.398262    0.811661      0.811661
# ====  ========  =======  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours3_test_s3.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global           0.74359       0.74359
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours3_trainAnn_s3.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.617915                0.823288
# ====  =======================  ======================
#
# File to show:  synthetic_Ours3_train_s3.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global           0.73258       0.73258   0.708979   0.098251            0.395374       0.0601607
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# ****************************** Scenario 4 ******************************
#
# File to show:  synthetic_softMV_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.514164      0.514164
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_trainG_s4.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.506634      0.506634    1.46782   0.150837             0.28245
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_softMV_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.506634      0.506634   0.352785  0.0845098            0.830018
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.650305      0.650305
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_trainG_s4.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.632173      0.632173    1.33851   0.128584            0.418966
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.632173      0.632173   0.293306  0.0700203            0.832068
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_DS_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.899328      0.899328
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.889683      0.889683   0.701156  0.0323024                 nan
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_Raykar_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.582662      0.582662
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s4.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.607896                0.871547
# ====  =======================  ======================
#
# File to show:  synthetic_Raykar_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.584575      0.584575   0.127352  0.0378273            0.860115        0.173433
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours1_testAux_s4.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.34283   685.15   0.520091     0.659197   0.882077       0.761683   0.325864    0.643529      0.643529
#    1         1  0.336151  671.8    0.519601     0.661898   0.865084       0.765023   0.328564    0.656777      0.656777
#    2         2  0.321019  641.65   0.508493     0.647511   0.913281       0.750331   0.314178    0.632051      0.632051
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours1_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.691514      0.691514
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours1_trainAnn_s4.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.608729                0.817023
# ====  =======================  ======================
#
# File to show:  synthetic_Ours1_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.679121      0.679121   0.636394  0.0896552            0.377351        0.172066
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours2_testAux_s4.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.346826   693.2   0.308282     0.817618   0.37645        0.878663   0.484285    0.739133      0.739133
#    1         1  0.331025   661.6   0.35603      0.792425   0.399245       0.863453   0.459091    0.68022       0.68022
#    2         2  0.32215    643.8   0.362712     0.751721   0.498748       0.828342   0.418388    0.662821      0.662821
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours2_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.820757      0.820757
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours2_trainAnn_s4.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.641599                0.779533
# ====  =======================  ======================
#
# File to show:  synthetic_Ours2_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.812495      0.812495   0.675278  0.0969987            0.279164        0.147176
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours3_testAux_s4.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.359127  717.65   0.284811     0.63071     1.50617       0.684573   0.297376    0.675458      0.675458
#    1         1  0.280503  560.5    0.338167     0.673848    1.17871       0.73591    0.340514    0.767643      0.767643
#    2         2  0.36037   720.2    0.343831     0.636542    1.31915       0.704983   0.303208    0.77442       0.77442
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours3_test_s4.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.654701      0.654701
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours3_trainAnn_s4.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.666574                0.750247
# ====  =======================  ======================
#
# File to show:  synthetic_Ours3_train_s4.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.644261      0.644261    1.03481    0.13855            0.355544        0.123862
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# ****************************** Scenario 5 ******************************
#
# ****************************** Scenario 6 ******************************
#
# File to show:  synthetic_softMV_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.500244      0.500244
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_trainG_s6.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.489092      0.489092    1.69731   0.153802            0.270879
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_softMV_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.489092      0.489092   0.949712   0.105741            0.696491
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.622894      0.622894
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_trainG_s6.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.609849      0.609849    1.46642   0.132608            0.380735
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.609849      0.609849   0.890334  0.0902732            0.691637
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_DS_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.909341      0.909341
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.897741      0.897741    2.17785   0.129999                 nan
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_Raykar_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.546337      0.546337
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s6.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.641649                0.886453
# ====  =======================  ======================
#
# File to show:  synthetic_Raykar_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.543081      0.543081   0.237757  0.0696283                 nan        0.213417
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours1_testAux_s6.csv
# ====  ========  ========  =======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob     T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  =======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.317419  3173.45   0.496911     0.558006    1.31079       0.667897   0.224673    0.639316      0.639316
#    1         1  0.320864  3207.85   0.498106     0.560183    1.30596       0.670021   0.226849    0.643407      0.643407
#    2         2  0.361717  3616.6    0.495375     0.556521    1.32839       0.666377   0.223188    0.634493      0.634493
# ====  ========  ========  =======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours1_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.619109      0.619109
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours1_trainAnn_s6.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.592639                 0.82937
# ====  =======================  ======================
#
# File to show:  synthetic_Ours1_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.609137      0.609137   0.944038   0.130522            0.239189        0.214914
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours2_testAux_s6.csv
# ====  ========  ========  =======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob     T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  =======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.323108  3230.35   0.375272     0.720497   0.926625       0.791004   0.387164    0.755006      0.755006
#    1         1  0.331411  3313.3    0.399227     0.685515   0.981034       0.767647   0.352182    0.645421      0.645421
#    2         2  0.345481  3454.15   0.385039     0.708377   0.906479       0.783383   0.375043    0.698291      0.698291
# ====  ========  ========  =======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours2_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.755495      0.755495
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours2_trainAnn_s6.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.635289                0.794457
# ====  =======================  ======================
#
# File to show:  synthetic_Ours2_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global           0.74941       0.74941   0.877379   0.116537            0.370253         0.18548
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours3_testAux_s6.csv
# ====  ========  ========  =======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob     T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  =======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.379466  3793.85   0.299169     0.638672   1.4453         0.698178   0.305338    0.65177       0.65177
#    1         1  0.267448  2673.7    0.326753     0.750134   0.903135       0.807188   0.416801    0.751282      0.751282
#    2         2  0.353087  3530      0.328949     0.771435   0.784515       0.834733   0.438102    0.859707      0.859707
# ====  ========  ========  =======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours3_test_s6.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.772894      0.772894
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours3_trainAnn_s6.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                  0.68319                0.736787
# ====  =======================  ======================
#
# File to show:  synthetic_Ours3_train_s6.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.758466      0.758466   0.827114   0.102502             0.41206        0.147493
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# ****************************** Scenario 7 ******************************
#
# File to show:  synthetic_softMV_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.450733      0.450733
# ====  ============  ==========  ============
#
# File to show:  synthetic_softMV_trainG_s7.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.432947      0.432947    2.00316   0.153975            0.333864
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_softMV_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.432947      0.432947   0.348064  0.0872869            0.809497
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.543834      0.543834
# ====  ============  ==========  ============
#
# File to show:  synthetic_hardMV_trainG_s7.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.517827      0.517827    2.07465   0.141724            0.443977
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_hardMV_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.517827      0.517827   0.342319   0.085598            0.801026
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_DS_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.760317      0.760317
# ====  ============  ==========  ============
#
# File to show:  synthetic_DS_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==================
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ============  ==========  ============  =========  =========  ==================
#    0  Global          0.750611      0.750611   0.877996  0.0391624                 nan
# ====  ============  ==========  ============  =========  =========  ==================
#
# File to show:  synthetic_Raykar_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.528755      0.528755
# ====  ============  ==========  ============
#
# File to show:  synthetic_Raykar_trainAnn_s7.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                   0.6126                 0.84877
# ====  =======================  ======================
#
# File to show:  synthetic_Raykar_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.519719      0.519719   0.163581  0.0480458            0.829613        0.209876
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours1_testAux_s7.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.293223  585.85   0.458507     0.442205    1.77726       0.547615   0.108872    0.548107      0.548107
#    1         1  0.382497  764.55   0.467037     0.498974    1.64706       0.598029   0.165641    0.608974      0.608974
#    2         2  0.324279  647.95   0.430871     0.422459    1.89754       0.522398   0.089126    0.539377      0.539377
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours1_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.550244      0.550244
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours1_trainAnn_s7.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.630608                0.737492
# ====  =======================  ======================
#
# File to show:  synthetic_Ours1_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global           0.54711       0.54711   0.916131    0.12964            0.332602        0.244444
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours2_testAux_s7.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.290104  579.75   0.377247     0.660291   0.862655       0.747464   0.326957    0.556227      0.556227
#    1         1  0.386723  773      0.37457      0.65619    0.895038       0.741575   0.322857    0.609829      0.609829
#    2         2  0.323173  645.85   0.359176     0.675002   0.850207       0.756769   0.341669    0.59884       0.59884
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours2_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.668926      0.668926
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours2_trainAnn_s7.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.648228                0.733243
# ====  =======================  ======================
#
# File to show:  synthetic_Ours2_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.657468      0.657468   0.754911    0.10443            0.363729        0.232075
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# File to show:  synthetic_Ours3_testAux_s7.csv
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.290053  579.65   0.323819     0.563526    1.54872       0.635217   0.230193    0.607448      0.607448
#    1         1  0.41807   835.7    0.288226     0.631902    1.34237       0.692391   0.298569    0.632906      0.632906
#    2         2  0.291876  583.3    0.299339     0.578756    1.41606       0.649152   0.245423    0.590415      0.590415
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#
# File to show:  synthetic_Ours3_test_s7.csv
# ====  ============  ==========  ============
#   ..  Unnamed: 0      Accuracy    F1 (micro)
# ====  ============  ==========  ============
#    0  Global          0.569414      0.569414
# ====  ============  ==========  ============
#
# File to show:  synthetic_Ours3_trainAnn_s7.csv
# ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.663262                0.723272
# ====  =======================  ======================
#
# File to show:  synthetic_Ours3_train_s7.csv
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#   ..  Unnamed: 0      Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#    0  Global          0.563268      0.563268   0.897971   0.126756            0.459468        0.217911
# ====  ============  ==========  ============  =========  =========  ==================  ==============
#
# ****************************** Scenario 8 ******************************
#
# ****************************** Scenario 9 ******************************

# %%
methods_list = ["Ann(tr)","softMV","hardMV", "DS", "Raykar", "Ours1", "Ours2", "Ours3"]

def calculate_mv_ann(archivo):
    try:
        f = open(folder+archivo)
        acc_mv_list = []
        for line in f.readlines():
            if "ACC MV" in line:
                acc_mv_list.append(float(line.split(" ")[-1].strip()))
        f.close()
        return np.mean(acc_mv_list)
    except:
        return "-"

def compare_table(tipo,repre="normal"):
    t = pd.DataFrame()
    t["Methods"] = methods_list
    for s in range(1,10):
        t["Scenario "+str(s)] = ["-" for _ in range(len(methods_list))]
        if tipo == 'acc':
            t.loc[0,"Scenario "+str(s)] =  calculate_mv_ann("result_scenario"+str(s)+".txt")

        scenario_files = find_match("s"+str(s)+".csv",files)

        for k, method in enumerate(methods_list[1:]):
            aux = find_match(method,scenario_files)
            if tipo == "acc": #como normal?
                test_aux = find_match("_test_",aux)
                if len(test_aux) != 0:
                    t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+test_aux[0])["Accuracy"][0], 4)
                    
            elif tipo == 'kl' or tipo=='js':
                if repre == "normal":
                    kl_aux = find_match("_train_",aux)
                elif repre== "global":
                    kl_aux = find_match("_trainG_",aux)
                if len(kl_aux) != 0:
                    if tipo == 'kl':
                        try:
                            t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+kl_aux[0])["Mean KL"][0] ,4)
                        except:
                            try:
                                t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+kl_aux[0])["Average KL"][0] ,4)
                            except:
                                pass
                    elif tipo=='js':
                        try:
                            t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+kl_aux[0])["Mean JS"][0] ,4)
                        except:
                            pass
            elif tipo == 'accann':
                train_ann = find_match("_trainAnn_",aux)
                if len(train_ann) != 0:
                    t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+train_ann[0])["ACC imiting Annotator"][0] ,4)
            elif tipo == 'rmse':
                train_aux = find_match("_train_",aux)
                if len(train_aux) != 0:
                    try:
                        t.loc[k+1,"Scenario "+str(s)] = round(pd.read_csv(folder+train_aux[0])["Average RMSE"][0] ,4)
                    except:
                        pass
    return t
t_acc = compare_table("acc","normal")
t_kl = compare_table("kl","normal")
t_js = compare_table("js","normal")

# %%
t_kl_g = compare_table("kl","global")
t_js_g = compare_table("js","global")

# %%
t_accAnn = compare_table("accann","normal")
t_rmseAnn = compare_table("rmse","normal")
t_rmseAnn
# Out:
#    Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5 Scenario 6  \
# 0  Ann(tr)          -          -          -          -          -          -
# 1   softMV          -          -          -          -          -          -
# 2   hardMV          -          -          -          -          -          -
# 3       DS          -          -          -          -          -          -
# 4   Raykar     0.0654     0.0538     0.0408      0.077          -          -
# 5    Ours1     0.0523     0.0503     0.0264     0.0423          -          -
# 6    Ours2     0.0421     0.0455      0.021     0.0372          -          -
# 7    Ours3     0.0286     0.0306      0.023     0.0272          -          -
#
#   Scenario 7 Scenario 8 Scenario 9
# 0          -          -          -
# 1          -          -          -
# 2          -          -          -
# 3          -          -          -
# 4     0.0634          -          -
# 5     0.0532          -          -
# 6     0.0368          -          -
# 7      0.035          -          -

# %%
t_accAnn
# Out:
#    Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5 Scenario 6  \
# 0  Ann(tr)          -          -          -          -          -          -
# 1   softMV          -          -          -          -          -          -
# 2   hardMV          -          -          -          -          -          -
# 3       DS          -          -          -          -          -          -
# 4   Raykar     0.3895      0.363     0.3595     0.3865          -          -
# 5    Ours1     0.3873     0.3607     0.3679      0.375          -          -
# 6    Ours2     0.3911      0.363     0.3734     0.3766          -          -
# 7    Ours3     0.3736     0.3402     0.3717     0.3738          -          -
#
#   Scenario 7 Scenario 8 Scenario 9
# 0          -          -          -
# 1          -          -          -
# 2          -          -          -
# 3          -          -          -
# 4     0.3681          -          -
# 5     0.3471          -          -
# 6     0.3505          -          -
# 7     0.3325          -          -

# %%
t_acc #tol3---ese
# Out:
#    Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5 Scenario 6  \
# 0  Ann(tr)   0.736088    0.63994   0.734682   0.860618          -    0.92921
# 1   softMV     0.5051      0.411     0.5031     0.5463          -     0.5514
# 2   hardMV      0.688     0.6167     0.6778     0.7612          -     0.8083
# 3       DS     0.7343     0.7083     0.7105     0.7978          -          -
# 4   Raykar      0.765     0.7654     0.7564     0.7291          -          -
# 5    Ours1     0.7019      0.654     0.6953     0.7296          -          -
# 6    Ours2     0.7121     0.6734     0.7097     0.7295          -          -
# 7    Ours3     0.7432      0.661     0.7301     0.7607          -     0.7324
#
#   Scenario 7 Scenario 8 Scenario 9
# 0   0.773474          -          -
# 1     0.4499          -          -
# 2     0.6998          -          -
# 3     0.7717          -          -
# 4     0.7436          -          -
# 5      0.625          -          -
# 6     0.6599          -          -
# 7     0.6389          -          -

# %%
print(tabulate(t_acc,headers='keys',tablefmt='latex'))
# Out:
# \begin{tabular}{rlrrrrllrll}
# \hline
#     & Methods   &   Scenario 1 &   Scenario 2 &   Scenario 3 &   Scenario 4 & Scenario 5   & Scenario 6         &   Scenario 7 & Scenario 8   & Scenario 9   \\
# \hline
#   0 & Ann(tr)   &     0.736088 &      0.63994 &     0.734682 &     0.860618 & -            & 0.92921            &     0.773474 & -            & -            \\
#   1 & softMV    &     0.50514  &      0.411   &     0.50312  &     0.54629  & -            & 0.55137            &     0.44988  & -            & -            \\
#   2 & hardMV    &     0.68797  &      0.61673 &     0.67775  &     0.76115  & -            & 0.8083499999999999 &     0.69982  & -            & -            \\
#   3 & DS        &     0.73433  &      0.70825 &     0.71054  &     0.7978   & -            & -                  &     0.77167  & -            & -            \\
#   4 & Raykar    &     0.76504  &      0.76543 &     0.75637  &     0.72907  & -            & -                  &     0.74361  & -            & -            \\
#   5 & Ours1     &     0.70187  &      0.65397 &     0.69528  &     0.72962  & -            & -                  &     0.62502  & -            & -            \\
#   6 & Ours2     &     0.71208  &      0.67341 &     0.70969  &     0.72946  & -            & -                  &     0.65994  & -            & -            \\
#   7 & Ours3     &     0.74322  &      0.66097 &     0.73005  &     0.76074  & -            & 0.7323999999999999 &     0.63891  & -            & -            \\
# \hline
# \end{tabular}

# %%
t_js
# Out:
#    Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5 Scenario 6  \
# 0  Ann(tr)          -          -          -          -          -          -
# 1   softMV     0.0595     0.0502     0.0464     0.0601          -          -
# 2   hardMV      0.021     0.0233     0.0164     0.0209          -          -
# 3       DS     0.0031     0.0036     0.0035     0.0277          -          -
# 4   Raykar     0.0029     0.0032     0.0028     0.0219          -          -
# 5    Ours1     0.0549     0.0556     0.0443     0.0579          -          -
# 6    Ours2      0.089     0.0864     0.0676     0.0836          -          -
# 7    Ours3     0.0889     0.1116     0.0799     0.0982          -      0.098
#
#   Scenario 7 Scenario 8 Scenario 9
# 0          -          -          -
# 1     0.0527          -          -
# 2     0.0228          -          -
# 3     0.0301          -          -
# 4     0.0227          -          -
# 5     0.0593          -          -
# 6     0.1296          -          -
# 7     0.1117          -          -

# %%
t_js_g
# Out:
#    Methods Scenario 1 Scenario 2 Scenario 3 Scenario 4 Scenario 5 Scenario 6  \
# 0  Ann(tr)          -          -          -          -          -          -
# 1   softMV     0.2892     0.2708     0.2207     0.2829          -     0.2812
# 2   hardMV     0.2621     0.2375     0.1993       0.26          -     0.2579
# 3       DS          -          -          -          -          -          -
# 4   Raykar          -          -          -          -          -          -
# 5    Ours1          -          -          -          -          -          -
# 6    Ours2          -          -          -          -          -          -
# 7    Ours3          -          -          -          -          -          -
#
#   Scenario 7 Scenario 8 Scenario 9
# 0          -          -          -
# 1     0.2724          -          -
# 2     0.2386          -          -
# 3          -          -          -
# 4          -          -          -
# 5          -          -          -
# 6          -          -          -
# 7          -          -          -

# %%
print(tabulate(t_js,headers='keys',tablefmt='latex'))
# Out:
# \begin{tabular}{rllllllllll}
# \hline
#     & Methods   & Scenario 1            & Scenario 2            & Scenario 3            & Scenario 4           & Scenario 5   & Scenario 6          & Scenario 7           & Scenario 8   & Scenario 9   \\
# \hline
#   0 & Ann(tr)   & -                     & -                     & -                     & -                    & -            & -                   & -                    & -            & -            \\
#   1 & softMV    & 0.05950674562562306   & 0.050221015434156566  & 0.0464438055596799    & 0.06008439775112365  & -            & -                   & 0.05270814033661828  & -            & -            \\
#   2 & hardMV    & 0.020995887868733132  & 0.02332643544245791   & 0.01641877942778385   & 0.020941518144649125 & -            & -                   & 0.022754271714284745 & -            & -            \\
#   3 & DS        & 0.0030529387533430176 & 0.0036232315811678796 & 0.0035185836491103835 & 0.027734659509510685 & -            & -                   & 0.030090635164642762 & -            & -            \\
#   4 & Raykar    & 0.002927220711785863  & 0.0032315487412953197 & 0.002849180546643681  & 0.021909906391642642 & -            & -                   & 0.022660941662491708 & -            & -            \\
#   5 & Ours1     & 0.05491425130342231   & 0.0556004753207321    & 0.044305405303445164  & 0.05791975756665664  & -            & -                   & 0.05925063236498172  & -            & -            \\
#   6 & Ours2     & 0.08897113067619779   & 0.08635660479650485   & 0.06757757207369068   & 0.08361031118942824  & -            & -                   & 0.12958117167140096  & -            & -            \\
#   7 & Ours3     & 0.08885640948565085   & 0.11156011363090483   & 0.07987275420720097   & 0.09815288307829276  & -            & 0.09800208925308994 & 0.11174892631537743  & -            & -            \\
# \hline
# \end{tabular}
