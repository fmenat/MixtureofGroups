# %% [markdown]
# Experimentation on the CIFAR simmulated annotators
# * batch = 128
# * delta convergence = 1e-2
# * Optimizer = ADAM
#
# * Our proposed: Pre-train base model with hard-MV (5 epochs?) as Rodrigues: https://github.com/fmpr/CrowdLayer/blob/master/demo-conll-ner-mturk.ipynb

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras, time, sys, os, gc

DTYPE_OP = 'float32'
keras.backend.set_floatx(DTYPE_OP)

if DTYPE_OP == 'float64':
    keras.backend.set_epsilon(np.finfo(np.float64).eps)
elif DTYPE_OP == 'float32':
    keras.backend.set_epsilon(np.finfo(np.float32).eps)
# Out:
# Using TensorFlow backend.

# %%
#GLOBAL Variables
BATCH_SIZE = 128
EPOCHS_BASE = 50
OPT = 'adam' #optimizer for neural network 
TOL = 1e-2 #tolerance for relative variation of parameters

# %% [markdown]
# ### Load Data and preprocess

# %%
X_train = np.loadtxt("../syntetic/simple/datasim_X_train.csv",delimiter=',')
Z_train = np.loadtxt("../syntetic/simple/datasim_Z_train.csv",dtype='int') #groudn truth

X_test = np.loadtxt("../syntetic/simple/datasim_X_test.csv",delimiter=',')
Z_test = np.loadtxt("../syntetic/simple/datasim_Z_test.csv",dtype='int') #groudn truth

print("Input shape:",X_train.shape)
# Out:
# Input shape: (2292, 2)

# %%
from sklearn.preprocessing import StandardScaler
std= StandardScaler(with_mean=True) #matrices sparse with_mean=False
std.fit(X_train)
Xstd_train = std.transform(X_train)
Xstd_test = std.transform(X_test)
Xstd_train.shape
# Out:
# (2457, 2)

# %% [markdown]
# ### Load annotations

# %%
opt = "datasim_normal"
#opt = "datasim_normal_badMV"
#opt = "datasim_normal_soft" 
#opt = "datasim_manyAnnot_v1" #npy
#opt = "datasim_manyAnnot_v2" #npy
#opt = "datasim_manyAnnot_v1_badMV" #npy

# %%
y_obs = np.loadtxt("../syntetic/simple/annotations_"+opt+".csv" ,delimiter=',',dtype='int')
#y_obs = np.load("../syntetic/simple/annotations_"+opt+".npy" )

groups_annot = np.loadtxt("../syntetic/simple/annotgroups_"+opt+".csv",delimiter=',')
#groups_annot = np.load("../syntetic/simple/annotgroups_"+opt+".npy")

load_matrix = np.loadtxt('../syntetic/simple/matrix_datasim_normal.csv',delimiter=',')
#load_matrix = np.loadtxt('../syntetic/simple/matrix_datasim_badMV.csv',delimiter=',')

rows,Kl = load_matrix.shape
real_conf_matrix = np.asarray([load_matrix[j-Kl:j] for j in np.arange(Kl,rows+1,Kl)])
if len(groups_annot.shape) ==1 or groups_annot.shape[1] ==  1: 
    groups_annot = keras.utils.to_categorical(groups_annot)  #only if it is hard clustering
    print("Done")
confe_matrix = np.tensordot(groups_annot,real_conf_matrix, axes=[[1],[0]])

N,T = y_obs.shape
K = np.max(y_obs)+1 # asumiendo que estan ordenadas
print("Shape (data,annotators): ",(N,T))
print("Classes: ",K)
# Out:
# Done
# Shape (data,annotators):  (2292, 100)
# Classes:  3

# %%
#delete unlabeled data
mask_labeled = np.sum(y_obs != -1,axis=1) != 0
Xstd_train = Xstd_train[mask_labeled]
Z_train = Z_train[mask_labeled]
y_obs = y_obs[mask_labeled]
print("Shape (data,annotators): ",(y_obs.shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c14773b9285b> in <module>()
#       1 #delete unlabeled data
#       2 mask_labeled = np.sum(y_obs != -1,axis=1) != 0
# ----> 3 Xstd_train = Xstd_train[mask_labeled]
#       4 Z_train = Z_train[mask_labeled]
#       5 y_obs = y_obs[mask_labeled]
#
# NameError: name 'Xstd_train' is not defined

# %%
from code.generate_data import SinteticData

folder = "."
X_train = np.loadtxt(folder+"/synthetic/simple/datasim_X_train.csv",delimiter=',')
Z_train = np.loadtxt(folder+"/synthetic/simple/datasim_Z_train.csv",dtype='int') #groudn truth

X_test = np.loadtxt(folder+"/synthetic/simple/datasim_X_test.csv",delimiter=',')
Z_test = np.loadtxt(folder+"/synthetic/simple/datasim_Z_test.csv",dtype='int') #groudn truth


GenerateData = SinteticData()
Tmax = 100
T_data = 10

GenerateData.set_probas(asfile=True,file_matrix=folder+'/synthetic/simple/matrix_datasim_normal.csv',file_groups =folder+'/synthetic/simple/groups_datasim_normal.csv')
#GenerateData.set_probas(asfile=True,file_matrix=folder+'/synthetic/simple/matrix_datasim_badMV.csv',file_groups =folder+'/synthetic/simple/groups_datasim_badMV.csv')

real_conf_matrix = GenerateData.conf_matrix.copy()

print("New Synthetic data is being generated...",flush=True,end='')
y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False)
print("Done! ")

if len(groups_annot.shape) ==1 or groups_annot.shape[1] ==  1: 
    groups_annot = keras.utils.to_categorical(groups_annot)  #only if it is hard clustering
confe_matrix = np.tensordot(groups_annot,real_conf_matrix, axes=[[1],[0]])

print("Accuracy of MV on train: ",np.mean(majority_voting(y_obs,repeats=False,onehot=False) == Z_train))

N,T = y_obs.shape
K = np.max(y_obs)+1 # asumiendo que estan ordenadas
print("Shape (data,annotators): ",(N,T))
print("Classes: ",K)
# Out:
# New Synthetic data is being generated...Done!
# Accuracy of MV on train:  0.7822547822547823
# Shape (data,annotators):  (2457, 100)
# Classes:  3

# %% [markdown]
# #### Delta Convergence criteria

# %%
from code.learning_models import LogisticRegression_Sklearn,LogisticRegression_Keras,MLP_Keras
#deep learning
from code.learning_models import default_CNN,default_RNN,default_RNNw_emb,CNN_simple, RNN_simple

from code.utils import EarlyStopRelative
ourCallback = EarlyStopRelative(monitor='loss',patience=1,min_delta=TOL)

# %% [markdown]
# ### Upper Bound Model

# %%
Z_train_onehot = keras.utils.to_categorical(Z_train)

model_UB = MLP_Keras(Xstd_train.shape[1:],Z_train_onehot.shape[1],8,1,BN=False,drop=0.2)
#model_UB = clone_model(raykarMC.base_model)

model_UB.compile(loss='categorical_crossentropy',optimizer=OPT)
model_UB.fit(Xstd_train,Z_train_onehot,epochs=EPOCHS_BASE,batch_size=BATCH_SIZE,verbose=0,callbacks=[ourCallback])

# %%
from code.representation import *
from code.utils import *

# %% [markdown]
# ### Infer Labels (without predictive model)

# %%
from code.baseline import LabelInference

label_I = LabelInference(y_obs,TOL,type_inf = 'all')
#label_I = LabelInference(y_obs_categorical,TOL, type_inf = 'all')

mv_onehot = label_I.mv_labels('onehot')
mv_probas = label_I.mv_labels('probas')

ds_labels,ds_conf_M = label_I.DS_labels()
# Out:
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18700.687233500248
# 2 	 -17485.773938720715 	0.4011	0.263120	0.064966
# 3 	 -17191.122293015942 	0.1046	0.207365	0.016851
# 4 	 -17103.107759029623 	0.0395	0.148308	0.005120
# 5 	 -17080.289316733273 	0.0169	0.095267	0.001334
# 6 	 -17072.765890991348 	0.0105	0.068634	0.000440
# 7 	 -17070.50667757563 	0.0069	0.050125	0.000132
# 8 	 -17069.804253866943 	0.0048	0.034780	0.000041
# 9 	 -17069.511120744028 	0.0034	0.021865	0.000017
# 10 	 -17069.364903300815 	0.0024	0.015788	0.000009
# 11 	 -17069.287043672517 	0.0018	0.011470	0.000005
# 12 	 -17069.243872754963 	0.0013	0.008088	0.000003
# Class marginals
# [0.35 0.34 0.32]

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
print("ACC D&S on train:",np.mean(ds_labels.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.7905759162303665
# ACC D&S on train: 0.9943280977312391

# %%
model_mvsoft = MLP_Keras(Xstd_train.shape[1:],mv_probas.shape[1],8,1,BN=False,drop=0.2)
model_mvsoft.compile(loss='categorical_crossentropy',optimizer=OPT)
model_mvsoft.fit(Xstd_train, mv_probas, epochs=EPOCHS_BASE,batch_size=BATCH_SIZE,verbose=0)
print("Trained model over soft-MV")
# Out:
# Trained model over soft-MV

# %%
model_mvhard = MLP_Keras(Xstd_train.shape[1:],mv_onehot.shape[1],8,1,BN=False,drop=0.2)
model_mvhard.compile(loss='categorical_crossentropy',optimizer=OPT)
model_mvhard.fit(Xstd_train, mv_onehot, epochs=EPOCHS_BASE,batch_size=BATCH_SIZE,verbose=0)
print("Trained model over hard-MV")
# Out:
# Trained model over hard-MV

# %%
model_ds = MLP_Keras(Xstd_train.shape[1:],ds_labels.shape[1],8,1,BN=False,drop=0.2)
model_ds.compile(loss='categorical_crossentropy',optimizer=OPT)
model_ds.fit(Xstd_train, ds_labels, epochs=EPOCHS_BASE,batch_size=BATCH_SIZE,verbose=0)
print("Trained model over D&S")
# Out:
# Trained model over D&S

# %%
from code.baseline import RaykarMC

#get representation needed for Raykar
#y_obs_categorical = label_I.y_obs_categ
y_obs_categorical = set_representation(y_obs,'onehot')

# %% [markdown]
# ### Raykar Model (joint predict model)

# %%
raykarMC = RaykarMC(Xstd_train.shape[1:],y_obs_categorical.shape[-1],T,epochs=1,optimizer=OPT,DTYPE_OP=DTYPE_OP)
raykarMC.define_model("mlp",8,1,BatchN=False,drop=0.2)

raykarMC.define_priors(np.ones((T,K))) #cada observador dijo al menos un dato
logL_hist = raykarMC.train(Xstd_train,y_obs_categorical,batch_size=BATCH_SIZE,max_iter=EPOCHS_BASE,tolerance=TOL
                           ,relative=True,val=False)
# Out:
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 2.05 sec)	logL: -19204.592
# Iter 2/50
# M step: done,  E step: done //  (in 0.24 sec)	logL: -17826.641	Tol1: 0.07175	Tol2: 0.26210
# Iter 3/50
# M step: done,  E step: done //  (in 0.17 sec)	logL: -17345.211	Tol1: 0.02701	Tol2: 0.12063
# Iter 4/50
# M step: done,  E step: done //  (in 0.18 sec)	logL: -17088.066	Tol1: 0.01483	Tol2: 0.06843
# Iter 5/50
# M step: done,  E step: done //  (in 0.15 sec)	logL: -16907.961	Tol1: 0.01054	Tol2: 0.03040
# Iter 6/50
# M step: done,  E step: done //  (in 0.19 sec)	logL: -16751.262	Tol1: 0.00927	Tol2: 0.01243
# Iter 7/50
# M step: done,  E step: done //  (in 0.17 sec)	logL: -16604.973	Tol1: 0.00873	Tol2: 0.00521
# Finished training!

# %%
plt.plot(range(len(logL_hist)),logL_hist,'bo-')
plt.show()

# %%
raykarMC = RaykarMC(Xstd_train.shape[1:],y_obs_categorical.shape[-1],T,epochs=1,optimizer=OPT,DTYPE_OP=DTYPE_OP)
#raykarMC.define_model("keras_shallow") 
raykarMC.define_model("mlp",8,1,BatchN=False,drop=0.2)

logL_hists,i = raykarMC.multiples_run(20,Xstd_train,y_obs_categorical,batch_size=BATCH_SIZE,max_iter=EPOCHS_BASE,
                                     tolerance=TOL)
# Out:
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.83 sec)	logL: -32323.252
# Iter 2/50
# M step: done,  E step: done //  (in 0.65 sec)	logL: -31587.340	Tol1: 0.02277	Tol2: 0.29136
# Iter 3/50
# M step: done,  E step: done //  (in 0.58 sec)	logL: -31546.770	Tol1: 0.00128	Tol2: 0.01912
# Iter 4/50
# M step: done,  E step: done //  (in 0.59 sec)	logL: -31510.746	Tol1: 0.00114	Tol2: 0.00712
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.83 sec)	logL: -32696.684
# Iter 2/50
# M step: done,  E step: done //  (in 0.60 sec)	logL: -31991.016	Tol1: 0.02158	Tol2: 0.29269
# Iter 3/50
# M step: done,  E step: done //  (in 0.58 sec)	logL: -31913.748	Tol1: 0.00242	Tol2: 0.01982
# Iter 4/50
# M step: done,  E step: done //  (in 0.59 sec)	logL: -31843.320	Tol1: 0.00221	Tol2: 0.00811
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.95 sec)	logL: -32146.305
# Iter 2/50
# M step: done,  E step: done //  (in 0.81 sec)	logL: -31365.383	Tol1: 0.02429	Tol2: 0.29181
# Iter 3/50
# M step: done,  E step: done //  (in 0.91 sec)	logL: -31307.834	Tol1: 0.00183	Tol2: 0.02016
# Iter 4/50
# M step: done,  E step: done //  (in 0.81 sec)	logL: -31261.641	Tol1: 0.00148	Tol2: 0.00790
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.46 sec)	logL: -32317.943
# Iter 2/50
# M step: done,  E step: done //  (in 0.56 sec)	logL: -31558.289	Tol1: 0.02351	Tol2: 0.29181
# Iter 3/50
# M step: done,  E step: done //  (in 0.63 sec)	logL: -31478.969	Tol1: 0.00251	Tol2: 0.02027
# Iter 4/50
# M step: done,  E step: done //  (in 0.63 sec)	logL: -31401.611	Tol1: 0.00246	Tol2: 0.00930
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.11 sec)	logL: -32230.266
# Iter 2/50
# M step: done,  E step: done //  (in 0.59 sec)	logL: -31473.641	Tol1: 0.02348	Tol2: 0.29140
# Iter 3/50
# M step: done,  E step: done //  (in 0.59 sec)	logL: -31422.367	Tol1: 0.00163	Tol2: 0.01906
# Iter 4/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31374.738	Tol1: 0.00152	Tol2: 0.00826
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.56 sec)	logL: -32402.480
# Iter 2/50
# M step: done,  E step: done //  (in 0.64 sec)	logL: -31643.039	Tol1: 0.02344	Tol2: 0.29284
# Iter 3/50
# M step: done,  E step: done //  (in 0.69 sec)	logL: -31573.971	Tol1: 0.00218	Tol2: 0.01973
# Iter 4/50
# M step: done,  E step: done //  (in 0.60 sec)	logL: -31515.449	Tol1: 0.00185	Tol2: 0.00864
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.11 sec)	logL: -32481.121
# Iter 2/50
# M step: done,  E step: done //  (in 0.63 sec)	logL: -31703.633	Tol1: 0.02394	Tol2: 0.29268
# Iter 3/50
# M step: done,  E step: done //  (in 0.62 sec)	logL: -31620.861	Tol1: 0.00261	Tol2: 0.02038
# Iter 4/50
# M step: done,  E step: done //  (in 0.60 sec)	logL: -31558.355	Tol1: 0.00198	Tol2: 0.00700
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.62 sec)	logL: -32090.926
# Iter 2/50
# M step: done,  E step: done //  (in 0.56 sec)	logL: -31256.555	Tol1: 0.02600	Tol2: 0.29313
# Iter 3/50
# M step: done,  E step: done //  (in 0.58 sec)	logL: -31205.773	Tol1: 0.00162	Tol2: 0.01893
# Iter 4/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31174.480	Tol1: 0.00100	Tol2: 0.00536
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.87 sec)	logL: -32180.908
# Iter 2/50
# M step: done,  E step: done //  (in 0.52 sec)	logL: -31409.066	Tol1: 0.02398	Tol2: 0.29146
# Iter 3/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31355.412	Tol1: 0.00171	Tol2: 0.02013
# Iter 4/50
# M step: done,  E step: done //  (in 0.59 sec)	logL: -31309.230	Tol1: 0.00147	Tol2: 0.00777
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.76 sec)	logL: -32363.531
# Iter 2/50
# M step: done,  E step: done //  (in 0.67 sec)	logL: -31591.500	Tol1: 0.02385	Tol2: 0.29261
# Iter 3/50
# M step: done,  E step: done //  (in 0.62 sec)	logL: -31530.230	Tol1: 0.00194	Tol2: 0.02004
# Iter 4/50
# M step: done,  E step: done //  (in 0.61 sec)	logL: -31484.410	Tol1: 0.00145	Tol2: 0.00675
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.78 sec)	logL: -32274.484
# Iter 2/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31467.008	Tol1: 0.02502	Tol2: 0.29274
# Iter 3/50
# M step: done,  E step: done //  (in 0.56 sec)	logL: -31393.438	Tol1: 0.00234	Tol2: 0.02006
# Iter 4/50
# M step: done,  E step: done //  (in 0.54 sec)	logL: -31339.354	Tol1: 0.00172	Tol2: 0.00690
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.52 sec)	logL: -32239.379
# Iter 2/50
# M step: done,  E step: done //  (in 0.54 sec)	logL: -31401.707	Tol1: 0.02598	Tol2: 0.29352
# Iter 3/50
# M step: done,  E step: done //  (in 0.55 sec)	logL: -31322.156	Tol1: 0.00253	Tol2: 0.01973
# Iter 4/50
# M step: done,  E step: done //  (in 0.55 sec)	logL: -31263.312	Tol1: 0.00188	Tol2: 0.00652
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.69 sec)	logL: -32319.941
# Iter 2/50
# M step: done,  E step: done //  (in 0.54 sec)	logL: -31539.566	Tol1: 0.02415	Tol2: 0.29182
# Iter 3/50
# M step: done,  E step: done //  (in 0.55 sec)	logL: -31444.686	Tol1: 0.00301	Tol2: 0.02122
# Iter 4/50
# M step: done,  E step: done //  (in 0.56 sec)	logL: -31359.547	Tol1: 0.00271	Tol2: 0.01036
# Iter 5/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31287.363	Tol1: 0.00230	Tol2: 0.00820
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.57 sec)	logL: -32520.102
# Iter 2/50
# M step: done,  E step: done //  (in 0.53 sec)	logL: -31778.602	Tol1: 0.02280	Tol2: 0.29260
# Iter 3/50
# M step: done,  E step: done //  (in 0.55 sec)	logL: -31703.865	Tol1: 0.00235	Tol2: 0.01918
# Iter 4/50
# M step: done,  E step: done //  (in 0.53 sec)	logL: -31639.469	Tol1: 0.00203	Tol2: 0.00826
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.78 sec)	logL: -32060.270
# Iter 2/50
# M step: done,  E step: done //  (in 0.54 sec)	logL: -31266.117	Tol1: 0.02477	Tol2: 0.29201
# Iter 3/50
# M step: done,  E step: done //  (in 0.56 sec)	logL: -31235.945	Tol1: 0.00097	Tol2: 0.01916
# Iter 4/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31218.848	Tol1: 0.00055	Tol2: 0.00572
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.83 sec)	logL: -32294.051
# Iter 2/50
# M step: done,  E step: done //  (in 0.54 sec)	logL: -31434.656	Tol1: 0.02661	Tol2: 0.29447
# Iter 3/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31368.342	Tol1: 0.00211	Tol2: 0.01886
# Iter 4/50
# M step: done,  E step: done //  (in 0.58 sec)	logL: -31331.836	Tol1: 0.00116	Tol2: 0.00504
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 20.99 sec)	logL: -32306.094
# Iter 2/50
# M step: done,  E step: done //  (in 0.56 sec)	logL: -31522.488	Tol1: 0.02426	Tol2: 0.29237
# Iter 3/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31457.758	Tol1: 0.00205	Tol2: 0.01989
# Iter 4/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31416.371	Tol1: 0.00132	Tol2: 0.00671
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.08 sec)	logL: -32302.234
# Iter 2/50
# M step: done,  E step: done //  (in 0.54 sec)	logL: -31507.711	Tol1: 0.02460	Tol2: 0.29212
# Iter 3/50
# M step: done,  E step: done //  (in 0.59 sec)	logL: -31432.465	Tol1: 0.00239	Tol2: 0.02004
# Iter 4/50
# M step: done,  E step: done //  (in 0.58 sec)	logL: -31376.441	Tol1: 0.00178	Tol2: 0.00616
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.19 sec)	logL: -32221.404
# Iter 2/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31430.225	Tol1: 0.02455	Tol2: 0.29254
# Iter 3/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31379.523	Tol1: 0.00161	Tol2: 0.01981
# Iter 4/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -31342.805	Tol1: 0.00117	Tol2: 0.00676
# Finished training!
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2292, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 21.28 sec)	logL: -32530.041
# Iter 2/50
# M step: done,  E step: done //  (in 0.55 sec)	logL: -31766.119	Tol1: 0.02348	Tol2: 0.29181
# Iter 3/50
# M step: done,  E step: done //  (in 0.60 sec)	logL: -31649.555	Tol1: 0.00367	Tol2: 0.02082
# Iter 4/50
# M step: done,  E step: done //  (in 0.58 sec)	logL: -31546.777	Tol1: 0.00325	Tol2: 0.00794
# Finished training!

# %% [markdown]
# ### Our Proposed

# %%
from code.MixtureofGroups import GroupMixtureOpt
#get our representation 
r_obs = set_representation(y_obs_categorical,"repeat")
#r_obs = set_representation(y_obs,"repeat")
print("vector of repeats:\n",r_obs)
print("shape:",r_obs.shape)
# Out:
# vector of repeats:
#  [[ 2  1 10]
#  [ 0  4  4]
#  [ 1  1  4]
#  ...
#  [ 0  0  7]
#  [ 9  0  3]
#  [10  0  2]]
# shape: (2457, 3)

# %%
# %%time

#pre analysis
from code.MixtureofGroups import project_and_cluster,clusterize_annotators
annotators_pca = project_and_cluster(y_obs_categorical,DTYPE_OP=DTYPE_OP)[0]
print("Annotators PCA of annotations shape: ",annotators_pca.shape)

mv_soft = majority_voting(r_obs,repeats=True,probas=True) 
aux = []
for example in mv_soft:
    aux.append(entropy(example)/np.log(K))
print("Normalized entropy (0-1) of repeats annotations:",np.mean(aux))
# Out:
# Bayesian gaussian mixture say is 6 clusters
# DBSCAN say is 1 clusters
# Affinity Propagation say is 3 clusters
# Annotators PCA of annotations shape:  (100, 4)
# Normalized entropy (0-1) of repeats annotations: 0.6084968211432953
# CPU times: user 815 ms, sys: 64.3 ms, total: 880 ms
# Wall time: 747 ms

# %%
from sklearn.decomposition import TruncatedSVD

# %%
plt.scatter(annotators_pca[:,0],annotators_pca[:,1],c=groups_annot.argmax(axis=1))
plt.show()

std = StandardScaler()
annotators_pca2 = std.fit_transform(annotators_pca)
plt.scatter(annotators_pca2[:,0],annotators_pca2[:,1])
plt.show()

# %%
M_seted = 3

# %%
gMixture1 = GroupMixtureOpt(Xstd_train.shape[1:],Kl=r_obs.shape[1],M=M_seted,epochs=1,pre_init=5,optimizer=OPT,dtype_op=DTYPE_OP) 
gMixture1.define_model("mlp",8,1,BatchN=False,drop=0.2)
gMixture1.lambda_random = False #lambda=1     
logL_hists,i = gMixture1.multiples_run(20,Xstd_train,r_obs,batch_size=BATCH_SIZE,max_iter=EPOCHS_BASE,tolerance=TOL*2
                                   ,cluster=True,bulk_annotators=[y_obs_categorical,annotators_pca])
# Out:
# Needed params (units,deep,drop,BatchN?)
# Clustering Done!
# Get init alphas in 0.001092 mins
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [1. 1. 1.]
# Alphas:  (3,)
# MV init:  (2457, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2457, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.31 sec)	logL: -24860.433
# Iter 2/50
# M step: done,  E step: done //  (in 0.27 sec)	logL: -24322.173	Tol1: 0.02165	Tol2: 0.15723	Tol3: 0.01684
# Iter 3/50
# M step: done,  E step: done //  (in 0.24 sec)	logL: -23888.409	Tol1: 0.01783	Tol2: 0.12780	Tol3: 0.00372
# Iter 4/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -23453.898	Tol1: 0.01819	Tol2: 0.11795	Tol3: 0.00520
# Iter 5/50
# M step: done,  E step: done //  (in 0.23 sec)	logL: -23018.506	Tol1: 0.01856	Tol2: 0.11575	Tol3: 0.00485
# Iter 6/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -22622.846	Tol1: 0.01719	Tol2: 0.11729	Tol3: 0.00418
# Iter 7/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -22267.243	Tol1: 0.01572	Tol2: 0.11822	Tol3: 0.00323
# Iter 8/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -21954.050	Tol1: 0.01407	Tol2: 0.11723	Tol3: 0.00187
# Iter 9/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -21666.803	Tol1: 0.01308	Tol2: 0.11342	Tol3: 0.00091
# Iter 10/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -21425.513	Tol1: 0.01114	Tol2: 0.10764	Tol3: 0.00147
# Iter 11/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -21196.258	Tol1: 0.01070	Tol2: 0.09996	Tol3: 0.00119
# Iter 12/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -21001.314	Tol1: 0.00920	Tol2: 0.08989	Tol3: 0.00143
# Iter 13/50
# M step: done,  E step: done //  (in 0.23 sec)	logL: -20825.242	Tol1: 0.00838	Tol2: 0.07829	Tol3: 0.00117
# Iter 14/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -20670.079	Tol1: 0.00745	Tol2: 0.06586	Tol3: 0.00132
# Iter 15/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -20538.516	Tol1: 0.00636	Tol2: 0.05390	Tol3: 0.00080
# Iter 16/50
# M step: done,  E step: done //  (in 0.26 sec)	logL: -20438.342	Tol1: 0.00488	Tol2: 0.04643	Tol3: 0.00091
# Iter 17/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -20358.466	Tol1: 0.00391	Tol2: 0.04118	Tol3: 0.00064
# Iter 18/50
# M step: done,  E step: done //  (in 0.26 sec)	logL: -20313.160	Tol1: 0.00223	Tol2: 0.03711	Tol3: 0.00094
# Iter 19/50
# M step: done,  E step: done //  (in 0.25 sec)	logL: -20277.168	Tol1: 0.00177	Tol2: 0.03672	Tol3: 0.00164
# Iter 20/50
# M step: done,  E step: done //  (in 0.24 sec)	logL: -20241.706	Tol1: 0.00175	Tol2: 0.03484	Tol3: 0.00135
# Iter 21/50
# M step: done,  E step: done //  (in 0.24 sec)	logL: -20213.778	Tol1: 0.00138	Tol2: 0.03371	Tol3: 0.00093
# Iter 22/50
# M step: done,  E step: done //  (in 0.27 sec)	logL: -20192.401	Tol1: 0.00106	Tol2: 0.03323	Tol3: 0.00163
# Iter 23/50
# M step: done,  E step: done //  (in 0.28 sec)	logL: -20181.485	Tol1: 0.00054	Tol2: 0.03309	Tol3: 0.00152
# Iter 24/50
# M step: done,  E step: done //  (in 0.25 sec)	logL: -20169.061	Tol1: 0.00062	Tol2: 0.03386	Tol3: 0.00254
# Iter 25/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -20158.380	Tol1: 0.00053	Tol2: 0.03520	Tol3: 0.00354
# Iter 26/50
# M step: done,  E step: done //  (in 0.27 sec)	logL: -20146.230	Tol1: 0.00060	Tol2: 0.03125	Tol3: 0.00232
# Iter 27/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -20139.847	Tol1: 0.00032	Tol2: 0.03200	Tol3: 0.00264
# Iter 28/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -20128.745	Tol1: 0.00055	Tol2: 0.03112	Tol3: 0.00280
# Iter 29/50
# M step: done,  E step: done //  (in 0.24 sec)	logL: -20121.781	Tol1: 0.00035	Tol2: 0.03101	Tol3: 0.00227
# Iter 30/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -20113.780	Tol1: 0.00040	Tol2: 0.02979	Tol3: 0.00274
# Iter 31/50
# M step: done,  E step: done //  (in 0.27 sec)	logL: -20113.425	Tol1: 0.00002	Tol2: 0.02990	Tol3: 0.00244
# Iter 32/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -20110.435	Tol1: 0.00015	Tol2: 0.03133	Tol3: 0.00365
# Iter 33/50
# M step: done,  E step: done //  (in 0.28 sec)	logL: -20099.063	Tol1: 0.00057	Tol2: 0.02798	Tol3: 0.00287
# Iter 34/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -20097.770	Tol1: 0.00006	Tol2: 0.02941	Tol3: 0.00307
# Iter 35/50
# M step: done,  E step: done //  (in 0.24 sec)	logL: -20095.725	Tol1: 0.00010	Tol2: 0.02931	Tol3: 0.00342
# Iter 36/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -20093.746	Tol1: 0.00010	Tol2: 0.02693	Tol3: 0.00300
# Iter 37/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -20088.305	Tol1: 0.00027	Tol2: 0.02594	Tol3: 0.00303
# Iter 38/50
# M step: done,  E step: done //  (in 0.23 sec)	logL: -20086.824	Tol1: 0.00007	Tol2: 0.02710	Tol3: 0.00306
# Iter 39/50
# M step: done,  E step: done //  (in 0.24 sec)	logL: -20079.986	Tol1: 0.00034	Tol2: 0.02510	Tol3: 0.00315
# Iter 40/50
# M step: done,  E step: done //  (in 0.21 sec)	logL: -20075.245	Tol1: 0.00024	Tol2: 0.02610	Tol3: 0.00313
# Iter 41/50
# M step: done,  E step: done //  (in 0.24 sec)	logL: -20069.524	Tol1: 0.00028	Tol2: 0.02499	Tol3: 0.00342
# Iter 42/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -20067.490	Tol1: 0.00010	Tol2: 0.02471	Tol3: 0.00320
# Iter 43/50
# M step: done,  E step: done //  (in 0.24 sec)	logL: -20061.474	Tol1: 0.00030	Tol2: 0.02454	Tol3: 0.00276
# Iter 44/50
# M step: done,  E step: done //  (in 0.26 sec)	logL: -20064.061	Tol1: 0.00013	Tol2: 0.02576	Tol3: 0.00299
# Iter 45/50
# M step: done,  E step: done //  (in 0.23 sec)	logL: -20057.490	Tol1: 0.00033	Tol2: 0.02604	Tol3: 0.00345
# Iter 46/50
# M step: done,  E step: done //  (in 0.23 sec)	logL: -20055.604	Tol1: 0.00009	Tol2: 0.02413	Tol3: 0.00262
# Iter 47/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -20051.903	Tol1: 0.00018	Tol2: 0.02313	Tol3: 0.00287
# Iter 48/50
# M step: done,  E step: done //  (in 0.26 sec)	logL: -20051.974	Tol1: 0.00000	Tol2: 0.02302	Tol3: 0.00295
# Iter 49/50
# M step: done,  E step: done //  (in 0.27 sec)	logL: -20050.981	Tol1: 0.00005	Tol2: 0.02263	Tol3: 0.00358
# Iter 50/50
# M step: done,  E step: done //  (in 0.22 sec)	logL: -20045.807	Tol1: 0.00026	Tol2: 0.02020	Tol3: 0.00315
# Finished training!

# %%
gMixture2 = GroupMixtureOpt(Xstd_train.shape[1:],Kl=r_obs.shape[1],M=M_seted,epochs=1,pre_init=5,optimizer=OPT,dtype_op=DTYPE_OP) 
gMixture2.define_model("mlp",8,1,BatchN=False,drop=0.2)
gMixture2.lambda_random = True #lambda random
logL_hists,i = gMixture2.multiples_run(20,Xstd_train,r_obs,batch_size=BATCH_SIZE,max_iter=EPOCHS_BASE,tolerance=TOL*2
                                   ,cluster=True,bulk_annotators=[y_obs_categorical,annotators_pca])
# Out:
# Needed params (units,deep,drop,BatchN?)
# Clustering Done!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.1917401  0.26428646 0.2554183 ]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.49 sec)	logL: -20783.336
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -20016.988	Tol1: 0.03687	Tol2: 0.27807	Tol3: 0.06337
# Iter 3/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -19627.503	Tol1: 0.01946	Tol2: 0.15028	Tol3: 0.02028
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19326.629	Tol1: 0.01533	Tol2: 0.10838	Tol3: 0.00492
# Iter 5/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -19064.013	Tol1: 0.01359	Tol2: 0.08999	Tol3: 0.00258
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18824.344	Tol1: 0.01257	Tol2: 0.08129	Tol3: 0.00276
# Iter 7/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18602.050	Tol1: 0.01181	Tol2: 0.07683	Tol3: 0.00297
# Iter 8/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18396.473	Tol1: 0.01105	Tol2: 0.06784	Tol3: 0.00307
# Iter 9/50
# M step: done,  E step: done //  (in 0.13 sec)	logL: -18203.936	Tol1: 0.01047	Tol2: 0.05598	Tol3: 0.00305
# Iter 10/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18030.375	Tol1: 0.00953	Tol2: 0.04525	Tol3: 0.00316
# Iter 11/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17869.613	Tol1: 0.00892	Tol2: 0.03528	Tol3: 0.00312
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17715.552	Tol1: 0.00862	Tol2: 0.02758	Tol3: 0.00317
# Iter 13/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17566.877	Tol1: 0.00839	Tol2: 0.02315	Tol3: 0.00321
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17431.390	Tol1: 0.00771	Tol2: 0.01939	Tol3: 0.00326
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.852665   0.06535901 0.5169175 ]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.52 sec)	logL: -21080.003
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -20513.088	Tol1: 0.02689	Tol2: 0.30543	Tol3: 0.01467
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20007.454	Tol1: 0.02465	Tol2: 0.17674	Tol3: 0.00816
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19572.908	Tol1: 0.02172	Tol2: 0.13687	Tol3: 0.00405
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19199.821	Tol1: 0.01906	Tol2: 0.11852	Tol3: 0.00036
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18867.946	Tol1: 0.01729	Tol2: 0.10833	Tol3: 0.00372
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18545.155	Tol1: 0.01711	Tol2: 0.10498	Tol3: 0.00699
# Iter 8/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18242.569	Tol1: 0.01632	Tol2: 0.10628	Tol3: 0.00977
# Iter 9/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17953.150	Tol1: 0.01587	Tol2: 0.10516	Tol3: 0.01134
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17684.442	Tol1: 0.01497	Tol2: 0.10260	Tol3: 0.01262
# Iter 11/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17462.553	Tol1: 0.01255	Tol2: 0.09638	Tol3: 0.01261
# Iter 12/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17265.719	Tol1: 0.01127	Tol2: 0.08745	Tol3: 0.01175
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17111.106	Tol1: 0.00895	Tol2: 0.07870	Tol3: 0.01099
# Iter 14/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16975.651	Tol1: 0.00792	Tol2: 0.06993	Tol3: 0.01007
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16868.094	Tol1: 0.00634	Tol2: 0.06482	Tol3: 0.00895
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16778.026	Tol1: 0.00534	Tol2: 0.05351	Tol3: 0.00772
# Iter 17/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16697.245	Tol1: 0.00481	Tol2: 0.04434	Tol3: 0.00753
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16626.137	Tol1: 0.00426	Tol2: 0.03782	Tol3: 0.00711
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16563.650	Tol1: 0.00376	Tol2: 0.03274	Tol3: 0.00663
# Iter 20/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16513.782	Tol1: 0.00301	Tol2: 0.02971	Tol3: 0.00647
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16470.022	Tol1: 0.00265	Tol2: 0.02595	Tol3: 0.00639
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16426.410	Tol1: 0.00265	Tol2: 0.02855	Tol3: 0.00670
# Iter 23/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16384.836	Tol1: 0.00253	Tol2: 0.02785	Tol3: 0.00642
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16350.960	Tol1: 0.00207	Tol2: 0.02739	Tol3: 0.00616
# Iter 25/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16324.125	Tol1: 0.00164	Tol2: 0.02650	Tol3: 0.00625
# Iter 26/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16297.652	Tol1: 0.00162	Tol2: 0.02424	Tol3: 0.00623
# Iter 27/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16276.197	Tol1: 0.00132	Tol2: 0.02689	Tol3: 0.00618
# Iter 28/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16255.390	Tol1: 0.00128	Tol2: 0.02348	Tol3: 0.00601
# Iter 29/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16240.459	Tol1: 0.00092	Tol2: 0.02848	Tol3: 0.00628
# Iter 30/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16221.541	Tol1: 0.00116	Tol2: 0.03046	Tol3: 0.00682
# Iter 31/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16209.659	Tol1: 0.00073	Tol2: 0.02599	Tol3: 0.00610
# Iter 32/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16197.501	Tol1: 0.00075	Tol2: 0.02348	Tol3: 0.00645
# Iter 33/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16186.291	Tol1: 0.00069	Tol2: 0.02191	Tol3: 0.00610
# Iter 34/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16177.739	Tol1: 0.00053	Tol2: 0.02229	Tol3: 0.00605
# Iter 35/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16165.398	Tol1: 0.00076	Tol2: 0.02431	Tol3: 0.00655
# Iter 36/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16155.002	Tol1: 0.00064	Tol2: 0.02452	Tol3: 0.00601
# Iter 37/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16148.414	Tol1: 0.00041	Tol2: 0.02327	Tol3: 0.00565
# Iter 38/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16141.316	Tol1: 0.00044	Tol2: 0.02105	Tol3: 0.00600
# Iter 39/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16128.928	Tol1: 0.00077	Tol2: 0.02188	Tol3: 0.00623
# Iter 40/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16125.059	Tol1: 0.00024	Tol2: 0.01960	Tol3: 0.00559
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.6182094 0.4535738 0.6936803]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.54 sec)	logL: -21702.798
# Iter 2/50
# M step: done,  E step: done //  (in 0.07 sec)	logL: -21364.306	Tol1: 0.01560	Tol2: 0.22934	Tol3: 0.00626
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20985.761	Tol1: 0.01772	Tol2: 0.14046	Tol3: 0.00313
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20587.312	Tol1: 0.01899	Tol2: 0.10588	Tol3: 0.00413
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20197.535	Tol1: 0.01893	Tol2: 0.09194	Tol3: 0.00492
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19833.313	Tol1: 0.01803	Tol2: 0.09443	Tol3: 0.00532
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19516.271	Tol1: 0.01599	Tol2: 0.09665	Tol3: 0.00538
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19216.901	Tol1: 0.01534	Tol2: 0.09441	Tol3: 0.00592
# Iter 9/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18936.438	Tol1: 0.01459	Tol2: 0.09073	Tol3: 0.00666
# Iter 10/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18673.729	Tol1: 0.01387	Tol2: 0.08509	Tol3: 0.00660
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18429.586	Tol1: 0.01307	Tol2: 0.07731	Tol3: 0.00670
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18199.358	Tol1: 0.01249	Tol2: 0.06719	Tol3: 0.00704
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17999.737	Tol1: 0.01097	Tol2: 0.05779	Tol3: 0.00707
# Iter 14/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17815.747	Tol1: 0.01022	Tol2: 0.05046	Tol3: 0.00679
# Iter 15/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17649.335	Tol1: 0.00934	Tol2: 0.04410	Tol3: 0.00650
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17492.810	Tol1: 0.00887	Tol2: 0.03854	Tol3: 0.00703
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17350.104	Tol1: 0.00816	Tol2: 0.03343	Tol3: 0.00628
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17225.029	Tol1: 0.00721	Tol2: 0.02856	Tol3: 0.00681
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17118.295	Tol1: 0.00620	Tol2: 0.02324	Tol3: 0.00625
# Iter 20/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17021.236	Tol1: 0.00567	Tol2: 0.02049	Tol3: 0.00691
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16930.830	Tol1: 0.00531	Tol2: 0.01703	Tol3: 0.00676
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.76989144 0.547976   0.87282073]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.57 sec)	logL: -21684.492
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -21342.190	Tol1: 0.01579	Tol2: 0.24435	Tol3: 0.00299
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20934.926	Tol1: 0.01908	Tol2: 0.15184	Tol3: 0.00543
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20475.818	Tol1: 0.02193	Tol2: 0.11927	Tol3: 0.00777
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19983.209	Tol1: 0.02406	Tol2: 0.10795	Tol3: 0.01018
# Iter 6/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -19472.720	Tol1: 0.02555	Tol2: 0.11203	Tol3: 0.01164
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18960.441	Tol1: 0.02631	Tol2: 0.11557	Tol3: 0.01188
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18448.283	Tol1: 0.02701	Tol2: 0.11506	Tol3: 0.01214
# Iter 9/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17962.826	Tol1: 0.02631	Tol2: 0.11064	Tol3: 0.01129
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17530.034	Tol1: 0.02409	Tol2: 0.10276	Tol3: 0.01071
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17182.252	Tol1: 0.01984	Tol2: 0.09327	Tol3: 0.01060
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16908.947	Tol1: 0.01591	Tol2: 0.08067	Tol3: 0.01001
# Iter 13/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16715.273	Tol1: 0.01145	Tol2: 0.06785	Tol3: 0.00961
# Iter 14/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16575.477	Tol1: 0.00836	Tol2: 0.05380	Tol3: 0.00867
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16481.104	Tol1: 0.00569	Tol2: 0.04355	Tol3: 0.00795
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16412.855	Tol1: 0.00414	Tol2: 0.04089	Tol3: 0.00764
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16363.542	Tol1: 0.00300	Tol2: 0.03730	Tol3: 0.00695
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16333.939	Tol1: 0.00181	Tol2: 0.03497	Tol3: 0.00680
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16319.831	Tol1: 0.00086	Tol2: 0.03120	Tol3: 0.00622
# Iter 20/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16300.223	Tol1: 0.00120	Tol2: 0.03025	Tol3: 0.00641
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16291.653	Tol1: 0.00053	Tol2: 0.02733	Tol3: 0.00640
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16282.971	Tol1: 0.00053	Tol2: 0.02261	Tol3: 0.00583
# Iter 23/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16268.955	Tol1: 0.00086	Tol2: 0.02251	Tol3: 0.00603
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16265.837	Tol1: 0.00019	Tol2: 0.02175	Tol3: 0.00596
# Iter 25/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16265.506	Tol1: 0.00002	Tol2: 0.02489	Tol3: 0.00662
# Iter 26/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16251.916	Tol1: 0.00084	Tol2: 0.02401	Tol3: 0.00662
# Iter 27/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16247.600	Tol1: 0.00027	Tol2: 0.02051	Tol3: 0.00644
# Iter 28/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16244.873	Tol1: 0.00017	Tol2: 0.02237	Tol3: 0.00672
# Iter 29/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16244.602	Tol1: 0.00002	Tol2: 0.02255	Tol3: 0.00683
# Iter 30/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16242.506	Tol1: 0.00013	Tol2: 0.02226	Tol3: 0.00713
# Iter 31/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16241.127	Tol1: 0.00008	Tol2: 0.02502	Tol3: 0.00776
# Iter 32/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16235.046	Tol1: 0.00037	Tol2: 0.02148	Tol3: 0.00728
# Iter 33/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16230.429	Tol1: 0.00028	Tol2: 0.02234	Tol3: 0.00780
# Iter 34/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16231.521	Tol1: 0.00007	Tol2: 0.01735	Tol3: 0.00737
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.32112208 0.43791562 0.19597536]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.59 sec)	logL: -18982.328
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -18565.812	Tol1: 0.02194	Tol2: 0.19954	Tol3: 0.01311
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18231.126	Tol1: 0.01803	Tol2: 0.13338	Tol3: 0.00513
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17952.770	Tol1: 0.01527	Tol2: 0.10352	Tol3: 0.00592
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17712.047	Tol1: 0.01341	Tol2: 0.08417	Tol3: 0.00666
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17513.076	Tol1: 0.01123	Tol2: 0.07538	Tol3: 0.00666
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17351.039	Tol1: 0.00925	Tol2: 0.07045	Tol3: 0.00653
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17206.048	Tol1: 0.00836	Tol2: 0.06571	Tol3: 0.00671
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17090.177	Tol1: 0.00673	Tol2: 0.05755	Tol3: 0.00586
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16988.133	Tol1: 0.00597	Tol2: 0.05073	Tol3: 0.00582
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16902.123	Tol1: 0.00506	Tol2: 0.04243	Tol3: 0.00584
# Iter 12/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16828.213	Tol1: 0.00437	Tol2: 0.03527	Tol3: 0.00623
# Iter 13/50
# M step: done,  E step: done //  (in 0.13 sec)	logL: -16763.970	Tol1: 0.00382	Tol2: 0.02797	Tol3: 0.00570
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16708.705	Tol1: 0.00330	Tol2: 0.02351	Tol3: 0.00597
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16664.121	Tol1: 0.00267	Tol2: 0.02085	Tol3: 0.00631
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16622.002	Tol1: 0.00253	Tol2: 0.02038	Tol3: 0.00693
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16578.235	Tol1: 0.00263	Tol2: 0.01883	Tol3: 0.00688
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.15315479 0.00606739 0.80697125]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.62 sec)	logL: -20156.865
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -19591.094	Tol1: 0.02807	Tol2: 0.27226	Tol3: 0.02955
# Iter 3/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -19213.706	Tol1: 0.01926	Tol2: 0.14736	Tol3: 0.00689
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18886.598	Tol1: 0.01702	Tol2: 0.11352	Tol3: 0.00597
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18586.519	Tol1: 0.01589	Tol2: 0.09620	Tol3: 0.00578
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18321.108	Tol1: 0.01428	Tol2: 0.08300	Tol3: 0.00642
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18086.419	Tol1: 0.01281	Tol2: 0.07190	Tol3: 0.00667
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17879.641	Tol1: 0.01143	Tol2: 0.06012	Tol3: 0.00612
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17706.089	Tol1: 0.00971	Tol2: 0.05064	Tol3: 0.00563
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17551.648	Tol1: 0.00872	Tol2: 0.04368	Tol3: 0.00491
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17428.221	Tol1: 0.00703	Tol2: 0.03937	Tol3: 0.00473
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17308.736	Tol1: 0.00686	Tol2: 0.03864	Tol3: 0.00531
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17203.700	Tol1: 0.00607	Tol2: 0.03558	Tol3: 0.00433
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17111.963	Tol1: 0.00533	Tol2: 0.03345	Tol3: 0.00404
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17035.422	Tol1: 0.00447	Tol2: 0.03070	Tol3: 0.00406
# Iter 16/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16966.285	Tol1: 0.00406	Tol2: 0.03064	Tol3: 0.00477
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16899.191	Tol1: 0.00395	Tol2: 0.02909	Tol3: 0.00499
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16841.737	Tol1: 0.00340	Tol2: 0.02497	Tol3: 0.00451
# Iter 19/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16791.183	Tol1: 0.00300	Tol2: 0.02326	Tol3: 0.00484
# Iter 20/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16743.310	Tol1: 0.00285	Tol2: 0.02321	Tol3: 0.00529
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16703.277	Tol1: 0.00239	Tol2: 0.02099	Tol3: 0.00557
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16659.760	Tol1: 0.00261	Tol2: 0.02454	Tol3: 0.00651
# Iter 23/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16618.536	Tol1: 0.00247	Tol2: 0.02248	Tol3: 0.00603
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16587.403	Tol1: 0.00187	Tol2: 0.01680	Tol3: 0.00540
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.96025974 0.70267403 0.11101807]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.65 sec)	logL: -21839.291
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -21658.346	Tol1: 0.00829	Tol2: 0.25847	Tol3: 0.01786
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -21431.454	Tol1: 0.01048	Tol2: 0.14268	Tol3: 0.01523
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -21160.891	Tol1: 0.01262	Tol2: 0.11312	Tol3: 0.01376
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20860.060	Tol1: 0.01422	Tol2: 0.10153	Tol3: 0.01259
# Iter 6/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -20542.808	Tol1: 0.01521	Tol2: 0.09632	Tol3: 0.01132
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20230.898	Tol1: 0.01518	Tol2: 0.09261	Tol3: 0.00989
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19932.292	Tol1: 0.01476	Tol2: 0.08845	Tol3: 0.00833
# Iter 9/50
# M step: done,  E step: done //  (in 0.14 sec)	logL: -19649.627	Tol1: 0.01418	Tol2: 0.08464	Tol3: 0.00691
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19388.334	Tol1: 0.01330	Tol2: 0.08510	Tol3: 0.00570
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19130.924	Tol1: 0.01328	Tol2: 0.08274	Tol3: 0.00475
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18866.790	Tol1: 0.01381	Tol2: 0.08201	Tol3: 0.00396
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18598.065	Tol1: 0.01424	Tol2: 0.08473	Tol3: 0.00315
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18297.884	Tol1: 0.01614	Tol2: 0.08823	Tol3: 0.00370
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17980.949	Tol1: 0.01732	Tol2: 0.09386	Tol3: 0.00439
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17680.431	Tol1: 0.01671	Tol2: 0.09869	Tol3: 0.00551
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17411.941	Tol1: 0.01519	Tol2: 0.09789	Tol3: 0.00636
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17205.717	Tol1: 0.01184	Tol2: 0.09048	Tol3: 0.00661
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17042.636	Tol1: 0.00948	Tol2: 0.08067	Tol3: 0.00685
# Iter 20/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16915.155	Tol1: 0.00748	Tol2: 0.06934	Tol3: 0.00650
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16801.781	Tol1: 0.00670	Tol2: 0.05782	Tol3: 0.00616
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16710.938	Tol1: 0.00541	Tol2: 0.04840	Tol3: 0.00597
# Iter 23/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16633.507	Tol1: 0.00463	Tol2: 0.04063	Tol3: 0.00559
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16571.793	Tol1: 0.00371	Tol2: 0.03465	Tol3: 0.00570
# Iter 25/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16519.014	Tol1: 0.00318	Tol2: 0.02686	Tol3: 0.00530
# Iter 26/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16479.175	Tol1: 0.00241	Tol2: 0.02295	Tol3: 0.00528
# Iter 27/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16445.405	Tol1: 0.00205	Tol2: 0.02118	Tol3: 0.00542
# Iter 28/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16410.084	Tol1: 0.00215	Tol2: 0.01932	Tol3: 0.00586
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.36683738 0.17532411 0.99378467]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.67 sec)	logL: -20798.499
# Iter 2/50
# M step: done,  E step: done //  (in 0.07 sec)	logL: -20356.140	Tol1: 0.02127	Tol2: 0.24325	Tol3: 0.01136
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20028.528	Tol1: 0.01609	Tol2: 0.16796	Tol3: 0.01085
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19766.731	Tol1: 0.01307	Tol2: 0.12870	Tol3: 0.00937
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19562.428	Tol1: 0.01034	Tol2: 0.10184	Tol3: 0.00747
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19400.891	Tol1: 0.00826	Tol2: 0.08400	Tol3: 0.00582
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19280.126	Tol1: 0.00622	Tol2: 0.07100	Tol3: 0.00512
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19183.831	Tol1: 0.00499	Tol2: 0.06027	Tol3: 0.00450
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19109.228	Tol1: 0.00389	Tol2: 0.05167	Tol3: 0.00415
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19045.201	Tol1: 0.00335	Tol2: 0.04501	Tol3: 0.00393
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18989.452	Tol1: 0.00293	Tol2: 0.04127	Tol3: 0.00384
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18935.231	Tol1: 0.00286	Tol2: 0.03814	Tol3: 0.00384
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18879.227	Tol1: 0.00296	Tol2: 0.03528	Tol3: 0.00385
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18813.999	Tol1: 0.00345	Tol2: 0.03697	Tol3: 0.00426
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18733.299	Tol1: 0.00429	Tol2: 0.03925	Tol3: 0.00479
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18635.024	Tol1: 0.00525	Tol2: 0.04218	Tol3: 0.00534
# Iter 17/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18520.803	Tol1: 0.00613	Tol2: 0.04573	Tol3: 0.00592
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18380.159	Tol1: 0.00759	Tol2: 0.04926	Tol3: 0.00684
# Iter 19/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18219.160	Tol1: 0.00876	Tol2: 0.05318	Tol3: 0.00766
# Iter 20/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18043.734	Tol1: 0.00963	Tol2: 0.05648	Tol3: 0.00850
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17860.298	Tol1: 0.01017	Tol2: 0.05987	Tol3: 0.00907
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17684.991	Tol1: 0.00982	Tol2: 0.06178	Tol3: 0.00957
# Iter 23/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17519.382	Tol1: 0.00936	Tol2: 0.06141	Tol3: 0.00954
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17370.066	Tol1: 0.00852	Tol2: 0.06134	Tol3: 0.00965
# Iter 25/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17236.781	Tol1: 0.00767	Tol2: 0.05687	Tol3: 0.00958
# Iter 26/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17123.327	Tol1: 0.00658	Tol2: 0.05462	Tol3: 0.00862
# Iter 27/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17027.506	Tol1: 0.00560	Tol2: 0.04890	Tol3: 0.00841
# Iter 28/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16941.618	Tol1: 0.00504	Tol2: 0.04085	Tol3: 0.00837
# Iter 29/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16872.886	Tol1: 0.00406	Tol2: 0.03626	Tol3: 0.00813
# Iter 30/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16819.440	Tol1: 0.00317	Tol2: 0.03167	Tol3: 0.00832
# Iter 31/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16760.170	Tol1: 0.00352	Tol2: 0.02469	Tol3: 0.00851
# Iter 32/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16716.588	Tol1: 0.00260	Tol2: 0.02409	Tol3: 0.00798
# Iter 33/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16679.731	Tol1: 0.00220	Tol2: 0.02251	Tol3: 0.00812
# Iter 34/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16643.796	Tol1: 0.00215	Tol2: 0.02250	Tol3: 0.00842
# Iter 35/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16612.299	Tol1: 0.00189	Tol2: 0.02240	Tol3: 0.00825
# Iter 36/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16579.982	Tol1: 0.00195	Tol2: 0.02139	Tol3: 0.00785
# Iter 37/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16552.413	Tol1: 0.00166	Tol2: 0.02214	Tol3: 0.00756
# Iter 38/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16529.121	Tol1: 0.00141	Tol2: 0.02183	Tol3: 0.00750
# Iter 39/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16510.521	Tol1: 0.00113	Tol2: 0.02221	Tol3: 0.00758
# Iter 40/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16491.443	Tol1: 0.00116	Tol2: 0.02002	Tol3: 0.00795
# Iter 41/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16480.175	Tol1: 0.00068	Tol2: 0.01987	Tol3: 0.00792
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.03643925 0.41378883 0.2574039 ]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.70 sec)	logL: -21194.899
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -20420.231	Tol1: 0.03655	Tol2: 0.28020	Tol3: 0.07953
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19824.254	Tol1: 0.02919	Tol2: 0.16884	Tol3: 0.05547
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19348.629	Tol1: 0.02399	Tol2: 0.12062	Tol3: 0.03534
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18955.794	Tol1: 0.02030	Tol2: 0.09140	Tol3: 0.02054
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18619.947	Tol1: 0.01772	Tol2: 0.06797	Tol3: 0.01001
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18324.054	Tol1: 0.01589	Tol2: 0.05325	Tol3: 0.00335
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18054.765	Tol1: 0.01470	Tol2: 0.04383	Tol3: 0.00255
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17819.019	Tol1: 0.01306	Tol2: 0.03640	Tol3: 0.00319
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17614.565	Tol1: 0.01147	Tol2: 0.03082	Tol3: 0.00492
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17430.162	Tol1: 0.01047	Tol2: 0.02607	Tol3: 0.00648
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17265.216	Tol1: 0.00946	Tol2: 0.02330	Tol3: 0.00790
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17122.174	Tol1: 0.00828	Tol2: 0.01941	Tol3: 0.00765
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.51188654 0.14270243 0.8263707 ]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.73 sec)	logL: -21479.878
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -21002.476	Tol1: 0.02223	Tol2: 0.25339	Tol3: 0.01578
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20567.963	Tol1: 0.02069	Tol2: 0.16144	Tol3: 0.01772
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20162.696	Tol1: 0.01970	Tol2: 0.12546	Tol3: 0.01652
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19788.885	Tol1: 0.01854	Tol2: 0.10617	Tol3: 0.01404
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19454.133	Tol1: 0.01692	Tol2: 0.09656	Tol3: 0.01127
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19146.344	Tol1: 0.01582	Tol2: 0.08888	Tol3: 0.01022
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18866.460	Tol1: 0.01462	Tol2: 0.08159	Tol3: 0.01112
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18596.634	Tol1: 0.01430	Tol2: 0.08129	Tol3: 0.01164
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18338.278	Tol1: 0.01389	Tol2: 0.08480	Tol3: 0.01277
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18089.344	Tol1: 0.01357	Tol2: 0.08766	Tol3: 0.01333
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17862.040	Tol1: 0.01257	Tol2: 0.08861	Tol3: 0.01430
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17650.576	Tol1: 0.01184	Tol2: 0.08817	Tol3: 0.01514
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17462.063	Tol1: 0.01068	Tol2: 0.08513	Tol3: 0.01526
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17300.501	Tol1: 0.00925	Tol2: 0.08042	Tol3: 0.01490
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17156.550	Tol1: 0.00832	Tol2: 0.07382	Tol3: 0.01422
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17028.369	Tol1: 0.00747	Tol2: 0.06681	Tol3: 0.01383
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16920.407	Tol1: 0.00634	Tol2: 0.06101	Tol3: 0.01275
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16826.242	Tol1: 0.00557	Tol2: 0.05477	Tol3: 0.01170
# Iter 20/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16747.292	Tol1: 0.00469	Tol2: 0.04675	Tol3: 0.01051
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16682.190	Tol1: 0.00389	Tol2: 0.04132	Tol3: 0.00965
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16626.670	Tol1: 0.00333	Tol2: 0.04051	Tol3: 0.00907
# Iter 23/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16573.391	Tol1: 0.00320	Tol2: 0.03479	Tol3: 0.00854
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16525.270	Tol1: 0.00290	Tol2: 0.02991	Tol3: 0.00785
# Iter 25/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16485.762	Tol1: 0.00239	Tol2: 0.02708	Tol3: 0.00735
# Iter 26/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16456.464	Tol1: 0.00178	Tol2: 0.02396	Tol3: 0.00695
# Iter 27/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16430.629	Tol1: 0.00157	Tol2: 0.02578	Tol3: 0.00700
# Iter 28/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16403.977	Tol1: 0.00162	Tol2: 0.02947	Tol3: 0.00684
# Iter 29/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16382.160	Tol1: 0.00133	Tol2: 0.02410	Tol3: 0.00674
# Iter 30/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16364.250	Tol1: 0.00109	Tol2: 0.02409	Tol3: 0.00654
# Iter 31/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16348.342	Tol1: 0.00097	Tol2: 0.02453	Tol3: 0.00641
# Iter 32/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16331.650	Tol1: 0.00102	Tol2: 0.02396	Tol3: 0.00649
# Iter 33/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16318.982	Tol1: 0.00078	Tol2: 0.02349	Tol3: 0.00637
# Iter 34/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16310.629	Tol1: 0.00051	Tol2: 0.02220	Tol3: 0.00665
# Iter 35/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16294.656	Tol1: 0.00098	Tol2: 0.02310	Tol3: 0.00666
# Iter 36/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16286.302	Tol1: 0.00051	Tol2: 0.01909	Tol3: 0.00669
# Finished training!

# %%
gMixture3 = GroupMixtureOpt(Xstd_train.shape[1:],Kl=r_obs.shape[1],M=M_seted,epochs=1,pre_init=5,optimizer=OPT,dtype_op=DTYPE_OP) 
gMixture3.define_model("mlp",8,1,BatchN=False,drop=0.2)
gMixture3.lambda_random = True #with lambda random --necessary
logL_hists,i = gMixture3.multiples_run(20,Xstd_train,r_obs,batch_size=BATCH_SIZE,max_iter=EPOCHS_BASE,tolerance=TOL*2
                                   ,cluster=True)
# Out:
# Needed params (units,deep,drop,BatchN?)
# Clustering Done!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.6041986  0.5255313  0.32005224]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.77 sec)	logL: -21348.361
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -21015.371	Tol1: 0.01560	Tol2: 0.16956	Tol3: 0.01734
# Iter 3/50
# M step: done,  E step: done //  (in 0.11 sec)	logL: -20641.109	Tol1: 0.01781	Tol2: 0.12761	Tol3: 0.01488
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20236.356	Tol1: 0.01961	Tol2: 0.12051	Tol3: 0.01350
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19810.868	Tol1: 0.02103	Tol2: 0.12231	Tol3: 0.01362
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19388.437	Tol1: 0.02132	Tol2: 0.12903	Tol3: 0.01371
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18991.575	Tol1: 0.02047	Tol2: 0.13477	Tol3: 0.01281
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18628.323	Tol1: 0.01913	Tol2: 0.13498	Tol3: 0.01197
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18313.787	Tol1: 0.01688	Tol2: 0.12908	Tol3: 0.01044
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18053.460	Tol1: 0.01421	Tol2: 0.11744	Tol3: 0.00917
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17834.577	Tol1: 0.01212	Tol2: 0.10061	Tol3: 0.00774
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17655.232	Tol1: 0.01006	Tol2: 0.08276	Tol3: 0.00686
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17506.516	Tol1: 0.00842	Tol2: 0.06576	Tol3: 0.00557
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17370.868	Tol1: 0.00775	Tol2: 0.05253	Tol3: 0.00484
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17260.475	Tol1: 0.00636	Tol2: 0.04304	Tol3: 0.00401
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17157.476	Tol1: 0.00597	Tol2: 0.03607	Tol3: 0.00401
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17060.991	Tol1: 0.00562	Tol2: 0.03176	Tol3: 0.00360
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16982.040	Tol1: 0.00463	Tol2: 0.02567	Tol3: 0.00312
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16906.968	Tol1: 0.00442	Tol2: 0.02086	Tol3: 0.00309
# Iter 20/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16845.944	Tol1: 0.00361	Tol2: 0.01716	Tol3: 0.00314
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.617859   0.22271347 0.39102635]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.80 sec)	logL: -20397.638
# Iter 2/50
# M step: done,  E step: done //  (in 0.12 sec)	logL: -19968.285	Tol1: 0.02105	Tol2: 0.23814	Tol3: 0.02381
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19614.930	Tol1: 0.01770	Tol2: 0.15746	Tol3: 0.01828
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19281.869	Tol1: 0.01698	Tol2: 0.13804	Tol3: 0.01567
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18964.174	Tol1: 0.01648	Tol2: 0.13382	Tol3: 0.01450
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18654.486	Tol1: 0.01633	Tol2: 0.13242	Tol3: 0.01405
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18363.687	Tol1: 0.01559	Tol2: 0.13048	Tol3: 0.01358
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18080.460	Tol1: 0.01542	Tol2: 0.12991	Tol3: 0.01360
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17805.412	Tol1: 0.01521	Tol2: 0.12776	Tol3: 0.01460
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17555.312	Tol1: 0.01405	Tol2: 0.12263	Tol3: 0.01484
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17347.972	Tol1: 0.01181	Tol2: 0.11355	Tol3: 0.01348
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17176.152	Tol1: 0.00990	Tol2: 0.10134	Tol3: 0.01280
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17046.956	Tol1: 0.00752	Tol2: 0.08857	Tol3: 0.01066
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16941.666	Tol1: 0.00618	Tol2: 0.07535	Tol3: 0.00862
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16861.299	Tol1: 0.00474	Tol2: 0.06301	Tol3: 0.00729
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16802.463	Tol1: 0.00349	Tol2: 0.05421	Tol3: 0.00538
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16744.349	Tol1: 0.00346	Tol2: 0.04147	Tol3: 0.00573
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16696.451	Tol1: 0.00286	Tol2: 0.03398	Tol3: 0.00560
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16657.270	Tol1: 0.00235	Tol2: 0.02842	Tol3: 0.00495
# Iter 20/50
# M step: done,  E step: done //  (in 0.11 sec)	logL: -16621.316	Tol1: 0.00216	Tol2: 0.02361	Tol3: 0.00495
# Iter 21/50
# M step: done,  E step: done //  (in 0.12 sec)	logL: -16583.446	Tol1: 0.00228	Tol2: 0.02011	Tol3: 0.00476
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16554.834	Tol1: 0.00173	Tol2: 0.01822	Tol3: 0.00371
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.6237201  0.67230415 0.84172404]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.82 sec)	logL: -21477.840
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -21024.963	Tol1: 0.02109	Tol2: 0.21859	Tol3: 0.00483
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20569.609	Tol1: 0.02166	Tol2: 0.15858	Tol3: 0.00435
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20124.329	Tol1: 0.02165	Tol2: 0.13826	Tol3: 0.00496
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19722.654	Tol1: 0.01996	Tol2: 0.12734	Tol3: 0.00456
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19378.327	Tol1: 0.01746	Tol2: 0.11723	Tol3: 0.00369
# Iter 7/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -19098.288	Tol1: 0.01445	Tol2: 0.10835	Tol3: 0.00231
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18871.470	Tol1: 0.01188	Tol2: 0.10129	Tol3: 0.00138
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18679.200	Tol1: 0.01019	Tol2: 0.09363	Tol3: 0.00238
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18498.992	Tol1: 0.00965	Tol2: 0.08948	Tol3: 0.00415
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18318.113	Tol1: 0.00978	Tol2: 0.08818	Tol3: 0.00686
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18128.727	Tol1: 0.01034	Tol2: 0.09067	Tol3: 0.00968
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17927.090	Tol1: 0.01112	Tol2: 0.09381	Tol3: 0.01210
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17708.473	Tol1: 0.01219	Tol2: 0.09628	Tol3: 0.01446
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17495.846	Tol1: 0.01201	Tol2: 0.09552	Tol3: 0.01486
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17298.090	Tol1: 0.01130	Tol2: 0.09355	Tol3: 0.01511
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17124.020	Tol1: 0.01006	Tol2: 0.08882	Tol3: 0.01412
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16981.870	Tol1: 0.00830	Tol2: 0.08058	Tol3: 0.01201
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16869.428	Tol1: 0.00662	Tol2: 0.07233	Tol3: 0.01049
# Iter 20/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16774.939	Tol1: 0.00560	Tol2: 0.06097	Tol3: 0.00884
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16701.227	Tol1: 0.00439	Tol2: 0.04652	Tol3: 0.00697
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16640.229	Tol1: 0.00365	Tol2: 0.03511	Tol3: 0.00680
# Iter 23/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16586.090	Tol1: 0.00325	Tol2: 0.02537	Tol3: 0.00555
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16546.380	Tol1: 0.00239	Tol2: 0.01973	Tol3: 0.00575
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.7499605  0.83720416 0.49906743]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.86 sec)	logL: -20613.733
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -20248.074	Tol1: 0.01774	Tol2: 0.22568	Tol3: 0.01864
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19901.657	Tol1: 0.01711	Tol2: 0.16394	Tol3: 0.01583
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19598.305	Tol1: 0.01524	Tol2: 0.14385	Tol3: 0.01364
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19338.851	Tol1: 0.01324	Tol2: 0.13388	Tol3: 0.01199
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19113.382	Tol1: 0.01166	Tol2: 0.12770	Tol3: 0.01042
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18925.216	Tol1: 0.00984	Tol2: 0.12622	Tol3: 0.00895
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18758.668	Tol1: 0.00880	Tol2: 0.12288	Tol3: 0.00784
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18614.724	Tol1: 0.00767	Tol2: 0.11766	Tol3: 0.00658
# Iter 10/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18482.433	Tol1: 0.00711	Tol2: 0.11025	Tol3: 0.00630
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18353.950	Tol1: 0.00695	Tol2: 0.10019	Tol3: 0.00530
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18229.750	Tol1: 0.00677	Tol2: 0.08800	Tol3: 0.00528
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18109.529	Tol1: 0.00659	Tol2: 0.07427	Tol3: 0.00518
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17990.143	Tol1: 0.00659	Tol2: 0.06049	Tol3: 0.00534
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17875.337	Tol1: 0.00638	Tol2: 0.04758	Tol3: 0.00482
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17752.988	Tol1: 0.00684	Tol2: 0.03886	Tol3: 0.00517
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17631.751	Tol1: 0.00683	Tol2: 0.03060	Tol3: 0.00499
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17521.107	Tol1: 0.00628	Tol2: 0.02488	Tol3: 0.00505
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17408.988	Tol1: 0.00640	Tol2: 0.02305	Tol3: 0.00665
# Iter 20/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17293.705	Tol1: 0.00662	Tol2: 0.02147	Tol3: 0.00723
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17189.072	Tol1: 0.00605	Tol2: 0.01827	Tol3: 0.00685
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.4567239  0.48463294 0.30207902]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.87 sec)	logL: -21062.430
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -20636.803	Tol1: 0.02021	Tol2: 0.19823	Tol3: 0.02256
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20187.720	Tol1: 0.02176	Tol2: 0.15144	Tol3: 0.01694
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19725.369	Tol1: 0.02290	Tol2: 0.14367	Tol3: 0.01554
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19264.612	Tol1: 0.02336	Tol2: 0.14292	Tol3: 0.01469
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18832.359	Tol1: 0.02244	Tol2: 0.14636	Tol3: 0.01360
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18439.484	Tol1: 0.02086	Tol2: 0.14858	Tol3: 0.01274
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18099.843	Tol1: 0.01842	Tol2: 0.14519	Tol3: 0.01155
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17800.132	Tol1: 0.01656	Tol2: 0.13523	Tol3: 0.01104
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17543.647	Tol1: 0.01441	Tol2: 0.12021	Tol3: 0.00970
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17325.429	Tol1: 0.01244	Tol2: 0.10189	Tol3: 0.00908
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17139.185	Tol1: 0.01075	Tol2: 0.08311	Tol3: 0.00890
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16983.172	Tol1: 0.00910	Tol2: 0.06771	Tol3: 0.00901
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16857.074	Tol1: 0.00742	Tol2: 0.05528	Tol3: 0.00910
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16748.564	Tol1: 0.00644	Tol2: 0.04540	Tol3: 0.00914
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16651.485	Tol1: 0.00580	Tol2: 0.03796	Tol3: 0.00848
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16573.751	Tol1: 0.00467	Tol2: 0.03016	Tol3: 0.00792
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16511.439	Tol1: 0.00376	Tol2: 0.02496	Tol3: 0.00726
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16459.800	Tol1: 0.00313	Tol2: 0.02287	Tol3: 0.00735
# Iter 20/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16419.424	Tol1: 0.00245	Tol2: 0.02059	Tol3: 0.00695
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16387.456	Tol1: 0.00195	Tol2: 0.01684	Tol3: 0.00606
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.7007957  0.67847246 0.6342211 ]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.90 sec)	logL: -20898.172
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -20450.064	Tol1: 0.02144	Tol2: 0.21046	Tol3: 0.01126
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19993.796	Tol1: 0.02231	Tol2: 0.16121	Tol3: 0.01270
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19551.132	Tol1: 0.02214	Tol2: 0.15011	Tol3: 0.01111
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19151.141	Tol1: 0.02046	Tol2: 0.14752	Tol3: 0.01234
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18789.495	Tol1: 0.01888	Tol2: 0.14640	Tol3: 0.01330
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18475.384	Tol1: 0.01672	Tol2: 0.14365	Tol3: 0.01606
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18199.815	Tol1: 0.01492	Tol2: 0.14194	Tol3: 0.02069
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17951.639	Tol1: 0.01364	Tol2: 0.13995	Tol3: 0.02451
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17735.541	Tol1: 0.01204	Tol2: 0.13755	Tol3: 0.02726
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17537.620	Tol1: 0.01116	Tol2: 0.13409	Tol3: 0.02704
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17353.340	Tol1: 0.01051	Tol2: 0.12765	Tol3: 0.02707
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17195.850	Tol1: 0.00908	Tol2: 0.12077	Tol3: 0.02589
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17052.361	Tol1: 0.00834	Tol2: 0.10884	Tol3: 0.02242
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16925.912	Tol1: 0.00742	Tol2: 0.09632	Tol3: 0.01910
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16814.275	Tol1: 0.00660	Tol2: 0.07959	Tol3: 0.01545
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16723.272	Tol1: 0.00541	Tol2: 0.06967	Tol3: 0.01344
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16645.525	Tol1: 0.00465	Tol2: 0.05420	Tol3: 0.01047
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16580.487	Tol1: 0.00391	Tol2: 0.04165	Tol3: 0.00746
# Iter 20/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16521.438	Tol1: 0.00356	Tol2: 0.03488	Tol3: 0.00564
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16471.723	Tol1: 0.00301	Tol2: 0.03207	Tol3: 0.00471
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16431.756	Tol1: 0.00243	Tol2: 0.03124	Tol3: 0.00439
# Iter 23/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16397.799	Tol1: 0.00207	Tol2: 0.02820	Tol3: 0.00275
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16366.636	Tol1: 0.00190	Tol2: 0.02798	Tol3: 0.00273
# Iter 25/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16339.555	Tol1: 0.00165	Tol2: 0.02862	Tol3: 0.00250
# Iter 26/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16316.791	Tol1: 0.00139	Tol2: 0.02863	Tol3: 0.00141
# Iter 27/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16296.303	Tol1: 0.00126	Tol2: 0.02879	Tol3: 0.00147
# Iter 28/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16278.931	Tol1: 0.00107	Tol2: 0.02902	Tol3: 0.00124
# Iter 29/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16263.924	Tol1: 0.00092	Tol2: 0.02730	Tol3: 0.00109
# Iter 30/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16249.351	Tol1: 0.00090	Tol2: 0.03076	Tol3: 0.00119
# Iter 31/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16235.776	Tol1: 0.00084	Tol2: 0.02410	Tol3: 0.00023
# Iter 32/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16222.050	Tol1: 0.00085	Tol2: 0.02338	Tol3: 0.00101
# Iter 33/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16208.476	Tol1: 0.00084	Tol2: 0.02251	Tol3: 0.00071
# Iter 34/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16198.522	Tol1: 0.00061	Tol2: 0.02242	Tol3: 0.00049
# Iter 35/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16188.032	Tol1: 0.00065	Tol2: 0.02166	Tol3: 0.00019
# Iter 36/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16178.732	Tol1: 0.00057	Tol2: 0.01881	Tol3: 0.00082
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.5615494  0.21696548 0.92454773]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.94 sec)	logL: -21990.501
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -21799.768	Tol1: 0.00867	Tol2: 0.13542	Tol3: 0.01230
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -21620.974	Tol1: 0.00820	Tol2: 0.08831	Tol3: 0.00819
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -21421.993	Tol1: 0.00920	Tol2: 0.07788	Tol3: 0.01020
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -21197.505	Tol1: 0.01048	Tol2: 0.07874	Tol3: 0.01080
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20941.614	Tol1: 0.01207	Tol2: 0.08346	Tol3: 0.01122
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20659.486	Tol1: 0.01347	Tol2: 0.08992	Tol3: 0.01119
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20352.626	Tol1: 0.01485	Tol2: 0.09643	Tol3: 0.01122
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20033.627	Tol1: 0.01567	Tol2: 0.10669	Tol3: 0.01099
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19698.498	Tol1: 0.01673	Tol2: 0.11713	Tol3: 0.00982
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19355.010	Tol1: 0.01744	Tol2: 0.12619	Tol3: 0.00807
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18996.108	Tol1: 0.01854	Tol2: 0.13498	Tol3: 0.00919
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18652.229	Tol1: 0.01810	Tol2: 0.14166	Tol3: 0.00932
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18318.133	Tol1: 0.01791	Tol2: 0.14480	Tol3: 0.01158
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18014.494	Tol1: 0.01658	Tol2: 0.14264	Tol3: 0.01339
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17758.405	Tol1: 0.01422	Tol2: 0.13586	Tol3: 0.01390
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17531.775	Tol1: 0.01276	Tol2: 0.12471	Tol3: 0.01479
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17347.524	Tol1: 0.01051	Tol2: 0.11029	Tol3: 0.01411
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17200.266	Tol1: 0.00849	Tol2: 0.09515	Tol3: 0.01335
# Iter 20/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17071.144	Tol1: 0.00751	Tol2: 0.07979	Tol3: 0.01285
# Iter 21/50
# M step: done,  E step: done //  (in 0.13 sec)	logL: -16965.168	Tol1: 0.00621	Tol2: 0.06746	Tol3: 0.01155
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16875.620	Tol1: 0.00528	Tol2: 0.05488	Tol3: 0.01011
# Iter 23/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16789.791	Tol1: 0.00509	Tol2: 0.04380	Tol3: 0.00920
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16714.746	Tol1: 0.00447	Tol2: 0.03448	Tol3: 0.00880
# Iter 25/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16652.214	Tol1: 0.00374	Tol2: 0.02958	Tol3: 0.00762
# Iter 26/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16597.854	Tol1: 0.00326	Tol2: 0.02371	Tol3: 0.00757
# Iter 27/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16540.581	Tol1: 0.00345	Tol2: 0.01812	Tol3: 0.00732
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.28150398 0.09215066 0.56077564]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 0.95 sec)	logL: -21318.963
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -20963.887	Tol1: 0.01666	Tol2: 0.16845	Tol3: 0.01452
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20617.564	Tol1: 0.01652	Tol2: 0.12261	Tol3: 0.01032
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20249.527	Tol1: 0.01785	Tol2: 0.11761	Tol3: 0.00977
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19853.169	Tol1: 0.01957	Tol2: 0.12010	Tol3: 0.00973
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19442.150	Tol1: 0.02070	Tol2: 0.12426	Tol3: 0.00968
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19034.794	Tol1: 0.02095	Tol2: 0.13257	Tol3: 0.01119
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18642.804	Tol1: 0.02059	Tol2: 0.13773	Tol3: 0.01280
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18288.784	Tol1: 0.01899	Tol2: 0.13854	Tol3: 0.01373
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17971.796	Tol1: 0.01733	Tol2: 0.13422	Tol3: 0.01380
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17701.277	Tol1: 0.01505	Tol2: 0.12497	Tol3: 0.01376
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17469.009	Tol1: 0.01312	Tol2: 0.11224	Tol3: 0.01333
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17278.626	Tol1: 0.01090	Tol2: 0.09681	Tol3: 0.01219
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17124.670	Tol1: 0.00891	Tol2: 0.07930	Tol3: 0.01101
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17003.208	Tol1: 0.00709	Tol2: 0.06249	Tol3: 0.01097
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16904.023	Tol1: 0.00583	Tol2: 0.04893	Tol3: 0.01042
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16819.709	Tol1: 0.00499	Tol2: 0.03880	Tol3: 0.00989
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16750.227	Tol1: 0.00413	Tol2: 0.03024	Tol3: 0.00909
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16696.806	Tol1: 0.00319	Tol2: 0.02481	Tol3: 0.00844
# Iter 20/50
# M step: done,  E step: done //  (in 0.11 sec)	logL: -16651.525	Tol1: 0.00271	Tol2: 0.02204	Tol3: 0.00782
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16618.460	Tol1: 0.00199	Tol2: 0.02058	Tol3: 0.00728
# Iter 22/50
# M step: done,  E step: done //  (in 0.11 sec)	logL: -16586.299	Tol1: 0.00194	Tol2: 0.01975	Tol3: 0.00649
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.39755654 0.7000071  0.47991863]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 1.13 sec)	logL: -21405.021
# Iter 2/50
# M step: done,  E step: done //  (in 0.09 sec)	logL: -21101.818	Tol1: 0.01417	Tol2: 0.16346	Tol3: 0.01073
# Iter 3/50
# M step: done,  E step: done //  (in 0.12 sec)	logL: -20752.394	Tol1: 0.01656	Tol2: 0.12102	Tol3: 0.00326
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -20379.522	Tol1: 0.01797	Tol2: 0.11192	Tol3: 0.00472
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19993.401	Tol1: 0.01895	Tol2: 0.11247	Tol3: 0.00652
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19599.157	Tol1: 0.01972	Tol2: 0.11693	Tol3: 0.00859
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19224.720	Tol1: 0.01910	Tol2: 0.12679	Tol3: 0.01075
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18869.392	Tol1: 0.01848	Tol2: 0.13345	Tol3: 0.01168
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18546.958	Tol1: 0.01709	Tol2: 0.13497	Tol3: 0.01118
# Iter 10/50
# M step: done,  E step: done //  (in 0.11 sec)	logL: -18270.894	Tol1: 0.01488	Tol2: 0.13150	Tol3: 0.01081
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18033.525	Tol1: 0.01299	Tol2: 0.12249	Tol3: 0.01036
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17829.262	Tol1: 0.01133	Tol2: 0.10925	Tol3: 0.00912
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17655.235	Tol1: 0.00976	Tol2: 0.09228	Tol3: 0.00827
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17514.964	Tol1: 0.00794	Tol2: 0.07405	Tol3: 0.00808
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17392.289	Tol1: 0.00700	Tol2: 0.05559	Tol3: 0.00694
# Iter 16/50
# M step: done,  E step: done //  (in 0.14 sec)	logL: -17288.106	Tol1: 0.00599	Tol2: 0.04053	Tol3: 0.00610
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17204.112	Tol1: 0.00486	Tol2: 0.03009	Tol3: 0.00584
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17134.237	Tol1: 0.00406	Tol2: 0.02337	Tol3: 0.00560
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17068.482	Tol1: 0.00384	Tol2: 0.01982	Tol3: 0.00552
# Finished training!
# Initializing new EM...
# Pre-train network on 5 epochs... Done!
# Lambda by group:  [0.20013225 0.26853737 0.64517397]
# Alphas:  (3,)
# MV init:  (2292, 3)
# Betas:  (3, 3, 3)
# Q estimate:  (2292, 3, 3, 3)
# Iter 1/50
# M step: done,  E step: done //  (in 1.02 sec)	logL: -20671.533
# Iter 2/50
# M step: done,  E step: done //  (in 0.08 sec)	logL: -20179.271	Tol1: 0.02381	Tol2: 0.20719	Tol3: 0.01640
# Iter 3/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19833.119	Tol1: 0.01715	Tol2: 0.12962	Tol3: 0.00630
# Iter 4/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19559.596	Tol1: 0.01379	Tol2: 0.10832	Tol3: 0.00459
# Iter 5/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19336.135	Tol1: 0.01142	Tol2: 0.09679	Tol3: 0.00302
# Iter 6/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19157.940	Tol1: 0.00922	Tol2: 0.08852	Tol3: 0.00258
# Iter 7/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -19015.170	Tol1: 0.00745	Tol2: 0.08073	Tol3: 0.00337
# Iter 8/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18903.143	Tol1: 0.00589	Tol2: 0.07566	Tol3: 0.00454
# Iter 9/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18805.728	Tol1: 0.00515	Tol2: 0.07135	Tol3: 0.00539
# Iter 10/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18716.159	Tol1: 0.00476	Tol2: 0.06835	Tol3: 0.00637
# Iter 11/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18630.118	Tol1: 0.00460	Tol2: 0.06702	Tol3: 0.00810
# Iter 12/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18543.068	Tol1: 0.00467	Tol2: 0.06735	Tol3: 0.00964
# Iter 13/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18449.801	Tol1: 0.00503	Tol2: 0.06859	Tol3: 0.01133
# Iter 14/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18354.304	Tol1: 0.00518	Tol2: 0.07109	Tol3: 0.01302
# Iter 15/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18249.865	Tol1: 0.00569	Tol2: 0.07358	Tol3: 0.01455
# Iter 16/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18136.328	Tol1: 0.00622	Tol2: 0.07626	Tol3: 0.01616
# Iter 17/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -18015.328	Tol1: 0.00667	Tol2: 0.07947	Tol3: 0.01764
# Iter 18/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17886.227	Tol1: 0.00717	Tol2: 0.08173	Tol3: 0.01822
# Iter 19/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17748.465	Tol1: 0.00770	Tol2: 0.08176	Tol3: 0.01813
# Iter 20/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17608.340	Tol1: 0.00790	Tol2: 0.08191	Tol3: 0.01753
# Iter 21/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17467.185	Tol1: 0.00802	Tol2: 0.08170	Tol3: 0.01612
# Iter 22/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17328.402	Tol1: 0.00795	Tol2: 0.07929	Tol3: 0.01465
# Iter 23/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17202.289	Tol1: 0.00728	Tol2: 0.07651	Tol3: 0.01261
# Iter 24/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17085.310	Tol1: 0.00680	Tol2: 0.07032	Tol3: 0.01033
# Iter 25/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16983.582	Tol1: 0.00595	Tol2: 0.06444	Tol3: 0.00849
# Iter 26/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16889.193	Tol1: 0.00556	Tol2: 0.05750	Tol3: 0.00683
# Iter 27/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16809.278	Tol1: 0.00473	Tol2: 0.04959	Tol3: 0.00574
# Iter 28/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16741.000	Tol1: 0.00406	Tol2: 0.04344	Tol3: 0.00470
# Iter 29/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16683.504	Tol1: 0.00343	Tol2: 0.03745	Tol3: 0.00397
# Iter 30/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16634.445	Tol1: 0.00294	Tol2: 0.03305	Tol3: 0.00326
# Iter 31/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16590.073	Tol1: 0.00267	Tol2: 0.03223	Tol3: 0.00254
# Iter 32/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16553.310	Tol1: 0.00222	Tol2: 0.02809	Tol3: 0.00204
# Iter 33/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16512.293	Tol1: 0.00248	Tol2: 0.02873	Tol3: 0.00159
# Iter 34/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16486.569	Tol1: 0.00156	Tol2: 0.02230	Tol3: 0.00148
# Iter 35/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16462.544	Tol1: 0.00146	Tol2: 0.02115	Tol3: 0.00114
# Iter 36/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16441.548	Tol1: 0.00128	Tol2: 0.02103	Tol3: 0.00094
# Iter 37/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16423.242	Tol1: 0.00111	Tol2: 0.02029	Tol3: 0.00078
# Iter 38/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16411.686	Tol1: 0.00070	Tol2: 0.02093	Tol3: 0.00077
# Iter 39/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16394.435	Tol1: 0.00105	Tol2: 0.02390	Tol3: 0.00049
# Iter 40/50
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16379.798	Tol1: 0.00089	Tol2: 0.01888	Tol3: 0.00039
# Finished training!

# %%
plt.plot(range(len(logL_hists[i])),logL_hists[i],'bo-')
plt.show()

# %% [markdown]
# ### Compare trained models

# %%
#Import it:
from code.evaluation import Evaluation_metrics
from sklearn.metrics import confusion_matrix

# %%
evaluate = Evaluation_metrics(model_UB,'keras',Xstd_train.shape[0])
print("*** Upper bound (Train with GT) ***")

print("Train")
Z_train_pred = evaluate.tested_model.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = evaluate.tested_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a68605ad9260> in <module>()
# ----> 1 evaluate = Evaluation_metrics(model_UB,'keras',Xstd_train.shape[0])
#       2 print("*** Upper bound (Train with GT) ***")
#       3
#       4 print("Train")
#       5 Z_train_pred = evaluate.tested_model.predict_classes(Xstd_train)
#
# NameError: name 'model_UB' is not defined

# %% [markdown]
# #### 1st configuration: Normal ($T$ = 100, $T_{max}$ = 10 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.7905759162303665

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Soft-Majority (Train with softMV) ***
# Train
# KL divergence: 0.1807	Pearson Correlation between diagonals: 0.5824
# KL divergence: 0.1218	Pearson Correlation between diagonals: 0.9900
# KL divergence: 0.0691	Pearson Correlation between diagonals: 0.9584
# KL divergence: 0.1122	Pearson Correlation between diagonals: 0.9768
# KL divergence: 0.1256	Pearson Correlation between diagonals: 0.9725
# KL divergence: 0.0410	Pearson Correlation between diagonals: 0.9653
# KL divergence: 0.1184	Pearson Correlation between diagonals: 0.9997
# KL divergence: 0.1119	Pearson Correlation between diagonals: 0.9807
# KL divergence: 0.1125	Pearson Correlation between diagonals: 0.9925
# KL divergence: 0.1381	Pearson Correlation between diagonals: 0.9530
# KL divergence: 0.0455	Pearson Correlation between diagonals: 0.9578
# KL divergence: 0.1409	Pearson Correlation between diagonals: 0.9862
# KL divergence: 0.1536	Pearson Correlation between diagonals: 0.9379
# KL divergence: 0.1335	Pearson Correlation between diagonals: 0.9804
# KL divergence: 0.1311	Pearson Correlation between diagonals: 0.9253
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |
# |----+--------+------------+--------------+--------------+-----------------------|
# |  0 | Global |   0.636549 |     0.636549 |     0.116628 |              0.946624 |
# +----+--------+------------+--------------+--------------+-----------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.659341 |     0.659341 |
# +----+--------+------------+--------------+

# %%
print("*** Soft-Majority (Train with softMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)
# Out:
# *** Soft-Majority (Train with softMV) ***
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# KL divergence: 0.4278	Pearson Correlation between diagonals: 0.7071
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# KL divergence: 0.4278	Pearson Correlation between diagonals: 0.7071
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# KL divergence: 0.4278	Pearson Correlation between diagonals: 0.7071
# KL divergence: 0.4278	Pearson Correlation between diagonals: 0.7071
# KL divergence: 1.3479	Pearson Correlation between diagonals: -0.6744
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# KL divergence: 0.1817	Pearson Correlation between diagonals: 0.8092
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |
# |----+--------+------------+--------------+--------------+-----------------------|
# |  0 | Global |   0.636549 |     0.636549 |     0.394196 |              0.581081 |
# +----+--------+------------+--------------+--------------+-----------------------+

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Hard-Majority (Train with hardMV) ***
# Train
# KL divergence: 0.1434	Pearson Correlation between diagonals: 0.8352
# KL divergence: 0.0757	Pearson Correlation between diagonals: 0.9893
# KL divergence: 0.0869	Pearson Correlation between diagonals: 0.9989
# KL divergence: 0.0489	Pearson Correlation between diagonals: 0.9532
# KL divergence: 0.0779	Pearson Correlation between diagonals: 0.9964
# KL divergence: 0.0746	Pearson Correlation between diagonals: 0.9942
# KL divergence: 0.0545	Pearson Correlation between diagonals: 0.9726
# KL divergence: 0.0857	Pearson Correlation between diagonals: 0.9988
# KL divergence: 0.0562	Pearson Correlation between diagonals: 0.9474
# KL divergence: 0.0787	Pearson Correlation between diagonals: 0.9249
# KL divergence: 0.1131	Pearson Correlation between diagonals: 0.9904
# KL divergence: 0.0989	Pearson Correlation between diagonals: 0.9525
# KL divergence: 0.0877	Pearson Correlation between diagonals: 0.9050
# KL divergence: 0.0897	Pearson Correlation between diagonals: 0.9622
# KL divergence: 0.1002	Pearson Correlation between diagonals: 0.9871
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |
# |----+--------+------------+--------------+--------------+-----------------------|
# |  0 | Global |   0.631665 |     0.631665 |    0.0910533 |              0.971834 |
# +----+--------+------------+--------------+--------------+-----------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.653236 |     0.653236 |
# +----+--------+------------+--------------+

# %%
print("*** Hard-Majority (Train with hardMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)
# Out:
# *** Hard-Majority (Train with hardMV) ***
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 6.0199	Pearson Correlation between diagonals: -0.6640
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 0.2927	Pearson Correlation between diagonals: 0.7170
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 6.0199	Pearson Correlation between diagonals: -0.6640
# KL divergence: 6.0199	Pearson Correlation between diagonals: -0.6640
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 2.3243	Pearson Correlation between diagonals: 0.8009
# KL divergence: 6.0199	Pearson Correlation between diagonals: -0.6640
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |
# |----+--------+------------+--------------+--------------+-----------------------|
# |  0 | Global |   0.631665 |     0.631665 |      2.43538 |              0.579021 |
# +----+--------+------------+--------------+--------------+-----------------------+

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf_M,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Dawid and Skene model (Train with D&S) ***
# Train
# KL divergence: 0.0002	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0048	Pearson Correlation between diagonals: 0.9974
# KL divergence: 0.0022	Pearson Correlation between diagonals: 0.9994
# KL divergence: 0.0130	Pearson Correlation between diagonals: 0.9996
# KL divergence: 0.0167	Pearson Correlation between diagonals: 0.9438
# KL divergence: 0.0150	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0211	Pearson Correlation between diagonals: 0.9894
# KL divergence: 0.0045	Pearson Correlation between diagonals: 0.9848
# KL divergence: 0.0058	Pearson Correlation between diagonals: 0.9967
# KL divergence: 0.0149	Pearson Correlation between diagonals: 0.9853
# KL divergence: 0.0158	Pearson Correlation between diagonals: 0.9901
# KL divergence: 0.0083	Pearson Correlation between diagonals: 0.9836
# KL divergence: 0.0048	Pearson Correlation between diagonals: 0.9993
# KL divergence: 0.0030	Pearson Correlation between diagonals: 0.9969
# KL divergence: 0.0064	Pearson Correlation between diagonals: 0.9967
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |
# |----+--------+------------+--------------+--------------+-----------------------|
# |  0 | Global |   0.937322 |     0.937322 |    0.0101059 |              0.987132 |
# +----+--------+------------+--------------+--------------+-----------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.946276 |     0.946276 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model ***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model ***
# Train
# KL divergence: 0.0261	Pearson Correlation between diagonals: 0.9233
# KL divergence: 0.0178	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0102	Pearson Correlation between diagonals: 0.9993
# KL divergence: 0.0229	Pearson Correlation between diagonals: 0.9771
# KL divergence: 0.0155	Pearson Correlation between diagonals: 0.9991
# KL divergence: 0.0144	Pearson Correlation between diagonals: 0.9835
# KL divergence: 0.0201	Pearson Correlation between diagonals: 0.9997
# KL divergence: 0.0297	Pearson Correlation between diagonals: 0.9977
# KL divergence: 0.0166	Pearson Correlation between diagonals: 0.9818
# KL divergence: 0.0172	Pearson Correlation between diagonals: 0.9981
# KL divergence: 0.0149	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0152	Pearson Correlation between diagonals: 0.9996
# KL divergence: 0.0218	Pearson Correlation between diagonals: 0.9916
# KL divergence: 0.0124	Pearson Correlation between diagonals: 0.9987
# KL divergence: 0.0450	Pearson Correlation between diagonals: 0.9967
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |      0.407 |        0.407 |    0.0182532 |              0.991418 |       0.136343 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.641349 |               0.868337 |
# +----+-------------------------+------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |    0.39072 |      0.39072 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.0161	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0130	Pearson Correlation between diagonals: 0.9818
# KL divergence: 0.0184	Pearson Correlation between diagonals: 0.9976
# KL divergence: 0.0213	Pearson Correlation between diagonals: 0.9994
# KL divergence: 0.0213	Pearson Correlation between diagonals: 0.9998
# KL divergence: 0.0105	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0168	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0184	Pearson Correlation between diagonals: 0.9976
# KL divergence: 0.0095	Pearson Correlation between diagonals: 0.9957
# KL divergence: 0.0094	Pearson Correlation between diagonals: 0.9997
# KL divergence: 0.0211	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0142	Pearson Correlation between diagonals: 0.9991
# KL divergence: 0.0240	Pearson Correlation between diagonals: 0.9956
# KL divergence: 0.0191	Pearson Correlation between diagonals: 0.9996
# KL divergence: 0.0074	Pearson Correlation between diagonals: 0.9989
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.895288 |     0.895288 |    0.0172657 |              0.992196 |       0.132332 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+------------------------------+-----------------------------------+
# |    |   Accuracy imiting Annotator |   Cross-entropy imiting Annotator |
# |----+------------------------------+-----------------------------------|
# |  0 |                     0.756944 |                          0.687978 |
# +----+------------------------------+-----------------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.888889 |     0.888889 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (1) multiples runs***
# Train
# KL divergence: 0.4231	Pearson Correlation between diagonals: 0.8517
# KL divergence: 0.4969	Pearson Correlation between diagonals: 0.7781
# KL divergence: 0.4969	Pearson Correlation between diagonals: 0.7781
# KL divergence: 0.4231	Pearson Correlation between diagonals: 0.8519
# KL divergence: 0.3072	Pearson Correlation between diagonals: 0.9013
# KL divergence: 0.3072	Pearson Correlation between diagonals: 0.9013
# KL divergence: 0.3072	Pearson Correlation between diagonals: 0.9013
# KL divergence: 0.4231	Pearson Correlation between diagonals: 0.8519
# KL divergence: 0.4231	Pearson Correlation between diagonals: 0.8519
# KL divergence: 0.3072	Pearson Correlation between diagonals: 0.9013
# KL divergence: 0.4969	Pearson Correlation between diagonals: 0.7781
# KL divergence: 0.4969	Pearson Correlation between diagonals: 0.7781
# KL divergence: 0.4969	Pearson Correlation between diagonals: 0.7781
# KL divergence: 0.3072	Pearson Correlation between diagonals: 0.9013
# KL divergence: 0.3072	Pearson Correlation between diagonals: 0.9013
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |    0.90232 |      0.90232 |     0.408445 |              0.849187 |      0.0935501 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.654315 |               0.746397 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.09205053901920716
# A result
#  +----+----------+----------+------------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |     Prob |   T groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+----------+------------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 | 0.286609 |         28 |  0.225798 |    0.94562  | 0.0563878 |           0.972097 |   0.899878 |     0.899878 |
# |  1 |        1 | 0.538757 |         53 |  0.264179 |    0.924085 | 0.0807225 |           0.960354 |   0.821734 |     0.821734 |
# |  2 |        2 | 0.174634 |         17 |  0.305627 |    0.65062  | 0.848148  |           0.717888 |   0.639805 |     0.639805 |
# +----+----------+----------+------------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.908425 |     0.908425 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (2) multiples runs***
# Train
# KL divergence: 1.1224	Pearson Correlation between diagonals: 0.8390
# KL divergence: 1.1224	Pearson Correlation between diagonals: 0.8390
# KL divergence: 0.0440	Pearson Correlation between diagonals: 0.9529
# KL divergence: 0.3691	Pearson Correlation between diagonals: 0.2314
# KL divergence: 0.2958	Pearson Correlation between diagonals: 0.1912
# KL divergence: 0.3014	Pearson Correlation between diagonals: 0.1941
# KL divergence: 1.1224	Pearson Correlation between diagonals: 0.8390
# KL divergence: 0.3582	Pearson Correlation between diagonals: 0.2251
# KL divergence: 0.0824	Pearson Correlation between diagonals: 0.9576
# KL divergence: 0.3606	Pearson Correlation between diagonals: 0.2265
# KL divergence: 0.3458	Pearson Correlation between diagonals: 0.2182
# KL divergence: 0.0440	Pearson Correlation between diagonals: 0.9527
# KL divergence: 0.2990	Pearson Correlation between diagonals: 0.1927
# KL divergence: 0.2935	Pearson Correlation between diagonals: 0.1890
# KL divergence: 0.2940	Pearson Correlation between diagonals: 0.1894
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.896597 |     0.896597 |     0.390277 |              0.482194 |       0.042371 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                 0.66464 |               0.678071 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.06449716188944876
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.285473 |    0.90655  |  0.101399 |           0.950495 |   0.877124 |     0.877124 |
# |  1 |        1 |  0.399035 |    0.824705 |  0.207945 |           0.90136  |   0.807843 |     0.807843 |
# |  2 |        2 |  0.509679 |    0.608345 |  0.698066 |           0.72292  |   0.614379 |     0.614379 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.898039 |     0.898039 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture3,'our1') 
aux = gMixture3.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (3) multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture3.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture3.get_confusionM()
y_o_groups = gMixture3.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture3.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (3) multiples runs***
# Train
# KL divergence: 0.1440	Pearson Correlation between diagonals: -0.1600
# KL divergence: 0.2096	Pearson Correlation between diagonals: 0.9913
# KL divergence: 0.2118	Pearson Correlation between diagonals: 0.9912
# KL divergence: 0.2059	Pearson Correlation between diagonals: 0.9916
# KL divergence: 0.1828	Pearson Correlation between diagonals: 0.9946
# KL divergence: 0.1865	Pearson Correlation between diagonals: 0.9935
# KL divergence: 1.3588	Pearson Correlation between diagonals: 0.5331
# KL divergence: 0.1977	Pearson Correlation between diagonals: 0.9922
# KL divergence: 0.1985	Pearson Correlation between diagonals: 0.9921
# KL divergence: 0.1846	Pearson Correlation between diagonals: 0.9957
# KL divergence: 0.2105	Pearson Correlation between diagonals: 0.9913
# KL divergence: 0.2071	Pearson Correlation between diagonals: 0.9915
# KL divergence: 0.2111	Pearson Correlation between diagonals: 0.9912
# KL divergence: 0.1874	Pearson Correlation between diagonals: 0.9962
# KL divergence: 0.1936	Pearson Correlation between diagonals: 0.9926
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.936736 |     0.936736 |     0.370716 |              0.688981 |      0.0528811 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.668251 |                0.69475 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.08106997329741716
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.302278 |    0.903248 |  0.110042 |           0.947068 |   0.915033 |     0.915033 |
# |  1 |        1 |  0.321652 |    0.655811 |  1.43281  |           0.676771 |   0.616993 |     0.616993 |
# |  2 |        2 |  0.33149  |    0.875725 |  0.149862 |           0.929293 |   0.91634  |     0.91634  |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.930719 |     0.930719 |
# +----+--------+------------+--------------+

# %% [markdown]
# #### 2) configuration: very bad MV ($T$ = 100, $T_{max}$ = 10 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.6208551483420593

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Soft-Majority (Train with softMV) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.462042 |     0.462042 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.453595 |     0.453595 |
# +----+--------+------------+--------------+

# %%
print("*** Soft-Majority (Train with softMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Hard-Majority (Train with hardMV) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.572426 |     0.572426 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.573856 |     0.573856 |
# +----+--------+------------+--------------+

# %%
print("*** Hard-Majority (Train with hardMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf_M,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Dawid and Skene model (Train with D&S) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.945462 |     0.945462 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.945098 |     0.945098 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model ***")

print("Train")
Z_train_pred = evaluate.tested_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = evaluate.tested_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model ***
# Train
# KL divergence: 0.0199	Pearson Correlation between diagonals: 0.8477
# KL divergence: 0.0132	Pearson Correlation between diagonals: 0.9588
# KL divergence: 0.0191	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0129	Pearson Correlation between diagonals: 0.9991
# KL divergence: 0.0198	Pearson Correlation between diagonals: 0.9815
# KL divergence: 0.0065	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0156	Pearson Correlation between diagonals: 0.9969
# KL divergence: 0.0124	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0120	Pearson Correlation between diagonals: 0.9889
# KL divergence: 0.0186	Pearson Correlation between diagonals: 0.9904
# KL divergence: 0.0236	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0096	Pearson Correlation between diagonals: 0.9998
# KL divergence: 0.0116	Pearson Correlation between diagonals: 0.9901
# KL divergence: 0.0142	Pearson Correlation between diagonals: 0.9945
# KL divergence: 0.0139	Pearson Correlation between diagonals: 0.9852
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.904014 |     0.904014 |    0.0172159 |              0.978584 |       0.138445 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+------------------------------+-----------------------------------+
# |    |   Accuracy imiting Annotator |   Cross-entropy imiting Annotator |
# |----+------------------------------+-----------------------------------|
# |  0 |                     0.571256 |                          0.845189 |
# +----+------------------------------+-----------------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.886275 |     0.886275 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.0208	Pearson Correlation between diagonals: 0.9592
# KL divergence: 0.0210	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0191	Pearson Correlation between diagonals: 0.8566
# KL divergence: 0.0182	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0164	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0278	Pearson Correlation between diagonals: 0.8053
# KL divergence: 0.0208	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0117	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0128	Pearson Correlation between diagonals: 0.9950
# KL divergence: 0.0177	Pearson Correlation between diagonals: 0.9997
# KL divergence: 0.0098	Pearson Correlation between diagonals: 0.9990
# KL divergence: 0.0140	Pearson Correlation between diagonals: 0.9853
# KL divergence: 0.0192	Pearson Correlation between diagonals: 0.8884
# KL divergence: 0.0270	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0323	Pearson Correlation between diagonals: 0.9497
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.937609 |     0.937609 |    0.0171666 |              0.978929 |       0.130713 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+------------------------------+-----------------------------------+
# |    |   Accuracy imiting Annotator |   Cross-entropy imiting Annotator |
# |----+------------------------------+-----------------------------------|
# |  0 |                     0.594826 |                          0.829137 |
# +----+------------------------------+-----------------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.938562 |     0.938562 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (1) multiples runs***
# Train
# KL divergence: 0.8191	Pearson Correlation between diagonals: 0.6187
# KL divergence: 0.3089	Pearson Correlation between diagonals: 0.9952
# KL divergence: 0.3527	Pearson Correlation between diagonals: 0.5437
# KL divergence: 0.3092	Pearson Correlation between diagonals: 0.9958
# KL divergence: 0.3530	Pearson Correlation between diagonals: 0.5418
# KL divergence: 0.8191	Pearson Correlation between diagonals: 0.6187
# KL divergence: 0.3089	Pearson Correlation between diagonals: 0.9952
# KL divergence: 0.3526	Pearson Correlation between diagonals: 0.5450
# KL divergence: 0.8191	Pearson Correlation between diagonals: 0.6187
# KL divergence: 0.3535	Pearson Correlation between diagonals: 0.5375
# KL divergence: 0.3091	Pearson Correlation between diagonals: 0.9956
# KL divergence: 0.3533	Pearson Correlation between diagonals: 0.5391
# KL divergence: 0.3090	Pearson Correlation between diagonals: 0.9955
# KL divergence: 0.3528	Pearson Correlation between diagonals: 0.5434
# KL divergence: 0.8191	Pearson Correlation between diagonals: 0.6187
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.811518 |     0.811518 |     0.406222 |              0.676317 |       0.116598 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.581522 |               0.816666 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.06470905197784305
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.436847 |    0.847319 |  0.170389 |           0.917554 |   0.545098 |     0.545098 |
# |  1 |        1 |  0.44411  |    0.846018 |  0.171337 |           0.917012 |   0.545098 |     0.545098 |
# |  2 |        2 |  0.563047 |    0.632923 |  0.699663 |           0.733364 |   0.363399 |     0.363399 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.792157 |     0.792157 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (2) multiples runs***
# Train
# KL divergence: 0.5447	Pearson Correlation between diagonals: 0.9140
# KL divergence: 0.2189	Pearson Correlation between diagonals: 0.9945
# KL divergence: 0.3358	Pearson Correlation between diagonals: 0.8816
# KL divergence: 0.4667	Pearson Correlation between diagonals: 0.7768
# KL divergence: 0.2225	Pearson Correlation between diagonals: 0.9934
# KL divergence: 0.5051	Pearson Correlation between diagonals: 0.8487
# KL divergence: 0.2151	Pearson Correlation between diagonals: 0.9956
# KL divergence: 0.4623	Pearson Correlation between diagonals: 0.7682
# KL divergence: 0.5613	Pearson Correlation between diagonals: 0.9370
# KL divergence: 0.2242	Pearson Correlation between diagonals: 0.9928
# KL divergence: 0.5340	Pearson Correlation between diagonals: 0.8977
# KL divergence: 1.5246	Pearson Correlation between diagonals: 0.5547
# KL divergence: 0.5719	Pearson Correlation between diagonals: 0.9500
# KL divergence: 1.5246	Pearson Correlation between diagonals: 0.5547
# KL divergence: 0.2431	Pearson Correlation between diagonals: 0.9845
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.842932 |     0.842932 |     0.575574 |              0.834427 |      0.0706584 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.542183 |               0.824472 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.09083747211843729
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.446232 |    0.818332 |  0.210108 |           0.899486 |   0.500654 |     0.500654 |
# |  1 |        1 |  0.404119 |    0.656614 |  0.905881 |           0.713379 |   0.452288 |     0.452288 |
# |  2 |        2 |  0.309366 |    0.905541 |  0.101072 |           0.950443 |   0.640523 |     0.640523 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.822222 |     0.822222 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture3,'our1') 
aux = gMixture3.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (3) multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture3.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture3.get_confusionM()
y_o_groups = gMixture3.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture3.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (3) multiples runs***
# Train
# KL divergence: 0.1336	Pearson Correlation between diagonals: 0.9889
# KL divergence: 0.9438	Pearson Correlation between diagonals: 0.9603
# KL divergence: 0.1336	Pearson Correlation between diagonals: 0.9889
# KL divergence: 0.4336	Pearson Correlation between diagonals: 0.5777
# KL divergence: 0.1364	Pearson Correlation between diagonals: 0.9892
# KL divergence: 0.9431	Pearson Correlation between diagonals: 0.9604
# KL divergence: 0.1351	Pearson Correlation between diagonals: 0.9891
# KL divergence: 0.9431	Pearson Correlation between diagonals: 0.9604
# KL divergence: 0.2393	Pearson Correlation between diagonals: 0.6886
# KL divergence: 0.1338	Pearson Correlation between diagonals: 0.9889
# KL divergence: 0.1372	Pearson Correlation between diagonals: 0.9893
# KL divergence: 0.2162	Pearson Correlation between diagonals: 0.7046
# KL divergence: 0.1566	Pearson Correlation between diagonals: 0.9913
# KL divergence: 0.1336	Pearson Correlation between diagonals: 0.9889
# KL divergence: 0.2096	Pearson Correlation between diagonals: 0.7096
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.906195 |     0.906195 |     0.294791 |               0.89651 |        0.12239 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.558361 |               0.856256 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.097741017350927
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.411819 |    0.869491 |  0.142274 |           0.930643 |   0.738562 |     0.738562 |
# |  1 |        1 |  0.454669 |    0.481844 |  1.01388  |           0.611729 |   0.322876 |     0.322876 |
# |  2 |        2 |  0.648664 |    0.728034 |  0.32858  |           0.845097 |   0.449673 |     0.449673 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.882353 |     0.882353 |
# +----+--------+------------+--------------+

# %% [markdown]
# #### 3) configuration: normal soft ($T$ = 100, $T_{max}$ = 10, soft clustering )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.81282722513089

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Soft-Majority (Train with softMV) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.725131 |     0.725131 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |    0.71634 |      0.71634 |
# +----+--------+------------+--------------+

# %%
print("*** Soft-Majority (Train with softMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Hard-Majority (Train with hardMV) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.808464 |     0.808464 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |    0.80915 |      0.80915 |
# +----+--------+------------+--------------+

# %%
print("*** Hard-Majority (Train with hardMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf_M,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Dawid and Skene model (Train with D&S) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.946335 |     0.946335 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.942484 |     0.942484 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model ***")

print("Train")
Z_train_pred = evaluate.tested_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = evaluate.tested_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model ***
# Train
# KL divergence: 0.0206	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0071	Pearson Correlation between diagonals: 0.9997
# KL divergence: 0.0130	Pearson Correlation between diagonals: 0.9957
# KL divergence: 0.0183	Pearson Correlation between diagonals: 0.9916
# KL divergence: 0.0221	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0206	Pearson Correlation between diagonals: 0.9996
# KL divergence: 0.0084	Pearson Correlation between diagonals: 0.9935
# KL divergence: 0.0197	Pearson Correlation between diagonals: 0.9992
# KL divergence: 0.0066	Pearson Correlation between diagonals: 0.9975
# KL divergence: 0.0105	Pearson Correlation between diagonals: 0.9997
# KL divergence: 0.0198	Pearson Correlation between diagonals: 0.9997
# KL divergence: 0.0052	Pearson Correlation between diagonals: 0.9840
# KL divergence: 0.0038	Pearson Correlation between diagonals: 0.9996
# KL divergence: 0.0170	Pearson Correlation between diagonals: 0.9964
# KL divergence: 0.0113	Pearson Correlation between diagonals: 1.0000
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.927574 |     0.927574 |    0.0134671 |              0.993623 |      0.0812075 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+------------------------------+-----------------------------------+
# |    |   Accuracy imiting Annotator |   Cross-entropy imiting Annotator |
# |----+------------------------------+-----------------------------------|
# |  0 |                     0.666435 |                          0.791672 |
# +----+------------------------------+-----------------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.921569 |     0.921569 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.0195	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0074	Pearson Correlation between diagonals: 0.9995
# KL divergence: 0.0186	Pearson Correlation between diagonals: 0.9923
# KL divergence: 0.0119	Pearson Correlation between diagonals: 0.9968
# KL divergence: 0.0176	Pearson Correlation between diagonals: 0.9995
# KL divergence: 0.0198	Pearson Correlation between diagonals: 0.9997
# KL divergence: 0.0083	Pearson Correlation between diagonals: 0.9980
# KL divergence: 0.0072	Pearson Correlation between diagonals: 0.9958
# KL divergence: 0.0105	Pearson Correlation between diagonals: 0.9271
# KL divergence: 0.0058	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0102	Pearson Correlation between diagonals: 0.9939
# KL divergence: 0.0235	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.0124	Pearson Correlation between diagonals: 0.9973
# KL divergence: 0.0065	Pearson Correlation between diagonals: 0.9978
# KL divergence: 0.0105	Pearson Correlation between diagonals: 0.9996
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.922339 |     0.922339 |    0.0131962 |              0.993913 |      0.0946202 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+------------------------------+-----------------------------------+
# |    |   Accuracy imiting Annotator |   Cross-entropy imiting Annotator |
# |----+------------------------------+-----------------------------------|
# |  0 |                     0.664752 |                          0.798222 |
# +----+------------------------------+-----------------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.930719 |     0.930719 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (1) multiples runs***
# Train
# KL divergence: 0.3082	Pearson Correlation between diagonals: 0.5562
# KL divergence: 0.6010	Pearson Correlation between diagonals: -0.0748
# KL divergence: 0.1025	Pearson Correlation between diagonals: 0.9984
# KL divergence: 0.2892	Pearson Correlation between diagonals: 0.1997
# KL divergence: 0.4342	Pearson Correlation between diagonals: 0.7988
# KL divergence: 1.1285	Pearson Correlation between diagonals: 0.7658
# KL divergence: 0.4090	Pearson Correlation between diagonals: 0.0350
# KL divergence: 0.1941	Pearson Correlation between diagonals: 0.6416
# KL divergence: 0.3571	Pearson Correlation between diagonals: 0.0912
# KL divergence: 0.3965	Pearson Correlation between diagonals: 0.4538
# KL divergence: 0.5501	Pearson Correlation between diagonals: 0.3472
# KL divergence: 0.7558	Pearson Correlation between diagonals: -0.1224
# KL divergence: 0.2494	Pearson Correlation between diagonals: 0.2969
# KL divergence: 0.5466	Pearson Correlation between diagonals: -0.0570
# KL divergence: 0.3536	Pearson Correlation between diagonals: 0.4044
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |    0.89267 |      0.89267 |       0.5065 |              0.235142 |       0.044841 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.657884 |               0.697329 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.00285352435457753
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.305345 |    0.892468 |  0.119342 |           0.942156 |   0.860131 |     0.860131 |
# |  1 |        1 |  0.390524 |    0.846823 |  0.176214 |           0.915582 |   0.606536 |     0.606536 |
# |  2 |        2 |  0.269038 |    0.907335 |  0.102107 |           0.950395 |   0.866667 |     0.866667 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.895425 |     0.895425 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (2) multiples runs***
# Train
# KL divergence: 0.2391	Pearson Correlation between diagonals: 0.7401
# KL divergence: 0.4105	Pearson Correlation between diagonals: 0.2201
# KL divergence: 0.4400	Pearson Correlation between diagonals: 0.5581
# KL divergence: 0.3701	Pearson Correlation between diagonals: 0.9111
# KL divergence: 0.5899	Pearson Correlation between diagonals: 0.1490
# KL divergence: 0.5330	Pearson Correlation between diagonals: 0.7387
# KL divergence: 0.3076	Pearson Correlation between diagonals: 0.2981
# KL divergence: 0.1544	Pearson Correlation between diagonals: 0.8249
# KL divergence: 0.2659	Pearson Correlation between diagonals: 0.3555
# KL divergence: 0.4418	Pearson Correlation between diagonals: 0.5578
# KL divergence: 0.5744	Pearson Correlation between diagonals: 0.1683
# KL divergence: 0.4136	Pearson Correlation between diagonals: 0.2152
# KL divergence: 0.2787	Pearson Correlation between diagonals: 0.5538
# KL divergence: 0.5941	Pearson Correlation between diagonals: 0.1438
# KL divergence: 0.3605	Pearson Correlation between diagonals: 0.5104
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.903141 |     0.903141 |     0.391811 |              0.469568 |      0.0406863 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.657838 |               0.688176 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.005769655283074826
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.328478 |    0.881282 |  0.131811 |           0.936105 |   0.84183  |     0.84183  |
# |  1 |        1 |  0.410847 |    0.810386 |  0.227167 |           0.892596 |   0.720261 |     0.720261 |
# |  2 |        2 |  0.281032 |    0.904995 |  0.103624 |           0.949492 |   0.864052 |     0.864052 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.903268 |     0.903268 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture3,'our1') 
aux = gMixture3.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (3) multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture3.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture3.get_confusionM()
y_o_groups = gMixture3.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture3.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (3) multiples runs***
# Train
# KL divergence: 0.4492	Pearson Correlation between diagonals: 0.8463
# KL divergence: 1.5327	Pearson Correlation between diagonals: 0.9983
# KL divergence: 0.4352	Pearson Correlation between diagonals: 0.9419
# KL divergence: 0.4265	Pearson Correlation between diagonals: 0.8263
# KL divergence: 0.4340	Pearson Correlation between diagonals: 0.8328
# KL divergence: 0.4291	Pearson Correlation between diagonals: 0.9453
# KL divergence: 0.4425	Pearson Correlation between diagonals: 0.8403
# KL divergence: 1.5157	Pearson Correlation between diagonals: 0.9965
# KL divergence: 0.4380	Pearson Correlation between diagonals: 0.9403
# KL divergence: 0.4431	Pearson Correlation between diagonals: 0.8408
# KL divergence: 0.4502	Pearson Correlation between diagonals: 0.8472
# KL divergence: 1.4929	Pearson Correlation between diagonals: 0.9932
# KL divergence: 0.4511	Pearson Correlation between diagonals: 0.8479
# KL divergence: 0.4430	Pearson Correlation between diagonals: 0.9374
# KL divergence: 1.4535	Pearson Correlation between diagonals: 0.9860
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.883072 |     0.883072 |     0.591899 |              0.890642 |      0.0642503 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.547132 |               0.862627 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.12279508542269468
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.329843 |    0.902199 |  0.103719 |           0.949011 |   0.746405 |     0.746405 |
# |  1 |        1 |  0.394027 |    0.871747 |  0.139701 |           0.931875 |   0.688889 |     0.688889 |
# |  2 |        2 |  0.433454 |    0.508892 |  1.11847  |           0.616762 |   0.322876 |     0.322876 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.860131 |     0.860131 |
# +----+--------+------------+--------------+

# %% [markdown]
# #### 4) configuration: Manny annot v1 ($T$ = 2000, $T_{max}$ = 20 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.8538394415357766

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
print("*** Soft-Majority (Train with softMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Hard-Majority (Train with hardMV) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.888307 |     0.888307 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.888889 |     0.888889 |
# +----+--------+------------+--------------+

# %%
print("*** Hard-Majority (Train with hardMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf_M,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Dawid and Skene model (Train with D&S) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.933682 |     0.933682 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.933333 |     0.933333 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model ***")

print("Train")
Z_train_pred = evaluate.tested_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = evaluate.tested_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model ***
# Train
# KL divergence: 0.1547	Pearson Correlation between diagonals: 0.9967
# KL divergence: 0.1802	Pearson Correlation between diagonals: 0.3776
# KL divergence: 0.1491	Pearson Correlation between diagonals: 0.9695
# KL divergence: 0.0901	Pearson Correlation between diagonals: 0.9884
# KL divergence: 0.1242	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.1128	Pearson Correlation between diagonals: 0.9363
# KL divergence: 0.1614	Pearson Correlation between diagonals: 0.9987
# KL divergence: 0.0935	Pearson Correlation between diagonals: 0.9969
# KL divergence: 0.0927	Pearson Correlation between diagonals: 0.9977
# KL divergence: 0.2355	Pearson Correlation between diagonals: 0.7503
# KL divergence: 0.1001	Pearson Correlation between diagonals: 0.9702
# KL divergence: 0.1290	Pearson Correlation between diagonals: 0.9655
# KL divergence: 0.2289	Pearson Correlation between diagonals: 0.9971
# KL divergence: 0.1453	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.0964	Pearson Correlation between diagonals: 0.9913
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |    0.38918 |      0.38918 |     0.147233 |              0.857617 |       0.295673 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+------------------------------+-----------------------------------+
# |    |   Accuracy imiting Annotator |   Cross-entropy imiting Annotator |
# |----+------------------------------+-----------------------------------|
# |  0 |                     0.483967 |                          0.934478 |
# +----+------------------------------+-----------------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.398693 |     0.398693 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.0928	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.2019	Pearson Correlation between diagonals: 0.7364
# KL divergence: 0.1802	Pearson Correlation between diagonals: 0.3775
# KL divergence: 0.1284	Pearson Correlation between diagonals: 0.9271
# KL divergence: 0.1700	Pearson Correlation between diagonals: 0.9995
# KL divergence: 0.1242	Pearson Correlation between diagonals: 0.9999
# KL divergence: 0.1128	Pearson Correlation between diagonals: 0.9363
# KL divergence: 0.0941	Pearson Correlation between diagonals: 0.9968
# KL divergence: 0.0927	Pearson Correlation between diagonals: 0.9977
# KL divergence: 0.1132	Pearson Correlation between diagonals: 0.9802
# KL divergence: 0.1001	Pearson Correlation between diagonals: 0.9702
# KL divergence: 0.2289	Pearson Correlation between diagonals: 0.9971
# KL divergence: 0.0789	Pearson Correlation between diagonals: 0.9933
# KL divergence: 0.1519	Pearson Correlation between diagonals: 0.9948
# KL divergence: 0.2164	Pearson Correlation between diagonals: 0.9268
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.822426 |     0.822426 |     0.147153 |              0.857683 |       0.208163 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+------------------------------+-----------------------------------+
# |    |   Accuracy imiting Annotator |   Cross-entropy imiting Annotator |
# |----+------------------------------+-----------------------------------|
# |  0 |                      0.68203 |                          0.792556 |
# +----+------------------------------+-----------------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.810458 |     0.810458 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (1) multiples runs***
# Train
# KL divergence: 0.7561	Pearson Correlation between diagonals: 0.9623
# KL divergence: 0.6163	Pearson Correlation between diagonals: 0.6581
# KL divergence: 0.6075	Pearson Correlation between diagonals: 0.6924
# KL divergence: 0.1494	Pearson Correlation between diagonals: 0.7350
# KL divergence: 0.5830	Pearson Correlation between diagonals: 0.8212
# KL divergence: 0.5882	Pearson Correlation between diagonals: 0.7776
# KL divergence: 0.6164	Pearson Correlation between diagonals: 0.6587
# KL divergence: 0.1579	Pearson Correlation between diagonals: 0.6938
# KL divergence: 0.6050	Pearson Correlation between diagonals: 0.7034
# KL divergence: 0.6128	Pearson Correlation between diagonals: 0.6739
# KL divergence: 0.7763	Pearson Correlation between diagonals: 0.9653
# KL divergence: 0.6047	Pearson Correlation between diagonals: 0.7010
# KL divergence: 0.6030	Pearson Correlation between diagonals: 0.7097
# KL divergence: 0.5973	Pearson Correlation between diagonals: 0.7362
# KL divergence: 0.7579	Pearson Correlation between diagonals: 0.9626
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.921466 |     0.921466 |     0.514718 |              0.762218 |      0.0919809 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.688129 |               0.652776 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.009807251335587353
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.464797 |    0.728612 |  0.351644 |           0.838201 |   0.620915 |     0.620915 |
# |  1 |        1 |  0.354827 |    0.861781 |  0.154598 |           0.925215 |   0.869281 |     0.869281 |
# |  2 |        2 |  0.403172 |    0.828732 |  0.197224 |           0.905472 |   0.843137 |     0.843137 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.920261 |     0.920261 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (2) multiples runs***
# Train
# KL divergence: 1.6851	Pearson Correlation between diagonals: 0.6812
# KL divergence: 0.4902	Pearson Correlation between diagonals: -0.0420
# KL divergence: 0.0532	Pearson Correlation between diagonals: 0.9979
# KL divergence: 1.7017	Pearson Correlation between diagonals: 0.6978
# KL divergence: 0.5056	Pearson Correlation between diagonals: 0.0495
# KL divergence: 0.5100	Pearson Correlation between diagonals: 0.0787
# KL divergence: 0.5095	Pearson Correlation between diagonals: 0.0725
# KL divergence: 0.5085	Pearson Correlation between diagonals: 0.0689
# KL divergence: 0.4884	Pearson Correlation between diagonals: -0.0587
# KL divergence: 1.6957	Pearson Correlation between diagonals: 0.6928
# KL divergence: 0.4980	Pearson Correlation between diagonals: 0.0050
# KL divergence: 0.5148	Pearson Correlation between diagonals: 0.1062
# KL divergence: 0.5028	Pearson Correlation between diagonals: 0.0342
# KL divergence: 1.7424	Pearson Correlation between diagonals: 0.7246
# KL divergence: 1.6995	Pearson Correlation between diagonals: 0.6975
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.880454 |     0.880454 |     0.575932 |              0.359152 |      0.0778175 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.661815 |                0.68421 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.004195076442556456
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.200926 |    0.946471 | 0.0559347 |           0.972382 |   0.847059 |     0.847059 |
# |  1 |        1 |  0.289992 |    0.89202  | 0.122364  |           0.941079 |   0.779085 |     0.779085 |
# |  2 |        2 |  0.288891 |    0.902538 | 0.107521  |           0.947782 |   0.793464 |     0.793464 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.878431 |     0.878431 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture3,'our1') 
aux = gMixture3.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (3) multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture3.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture3.get_confusionM()
y_o_groups = gMixture3.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture3.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (3) multiples runs***
# Train
# KL divergence: 0.5981	Pearson Correlation between diagonals: 0.0618
# KL divergence: 0.0794	Pearson Correlation between diagonals: 0.9902
# KL divergence: 0.6424	Pearson Correlation between diagonals: -0.0310
# KL divergence: 0.6441	Pearson Correlation between diagonals: -0.0347
# KL divergence: 0.6978	Pearson Correlation between diagonals: -0.1290
# KL divergence: 0.0982	Pearson Correlation between diagonals: 0.9941
# KL divergence: 0.7452	Pearson Correlation between diagonals: -0.1942
# KL divergence: 0.6677	Pearson Correlation between diagonals: -0.0789
# KL divergence: 1.0584	Pearson Correlation between diagonals: 0.8729
# KL divergence: 0.7476	Pearson Correlation between diagonals: -0.1970
# KL divergence: 0.6702	Pearson Correlation between diagonals: -0.0830
# KL divergence: 1.0546	Pearson Correlation between diagonals: 0.8739
# KL divergence: 0.7186	Pearson Correlation between diagonals: -0.1597
# KL divergence: 0.0830	Pearson Correlation between diagonals: 0.9985
# KL divergence: 0.6819	Pearson Correlation between diagonals: -0.1033
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.883508 |     0.883508 |      0.58468 |              0.337614 |      0.0695661 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.671146 |               0.665688 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.017402511090040207
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.194189 |    0.93742  | 0.0677826 |           0.96689  |   0.879739 |     0.879739 |
# |  1 |        1 |  0.40521  |    0.812372 | 0.224733  |           0.893745 |   0.679739 |     0.679739 |
# |  2 |        2 |  0.210053 |    0.929269 | 0.0774615 |           0.962291 |   0.877124 |     0.877124 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |    0.88366 |      0.88366 |
# +----+--------+------------+--------------+

# %% [markdown]
# #### 5) configuration: Manny annot v2 ($T=5000, T_{data}=40$)

# %% [markdown]
# #### 6) configuration: Manny annot v3 ($T$ = 10000, $T_{data}$ = 40 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.9101221640488656

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Soft-Majority (Train with softMV) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.821117 |     0.821117 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.820915 |     0.820915 |
# +----+--------+------------+--------------+

# %%
print("*** Soft-Majority (Train with softMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Hard-Majority (Train with hardMV) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.910995 |     0.910995 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.915033 |     0.915033 |
# +----+--------+------------+--------------+

# %%
print("*** Hard-Majority (Train with hardMV) ***")
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf_M,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Dawid and Skene model (Train with D&S) ***
# Train
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.937609 |     0.937609 |
# +----+--------+------------+--------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.941176 |     0.941176 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model ***")

print("Train")
Z_train_pred = evaluate.tested_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = evaluate.tested_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model ***
# Train
# KL divergence: 0.2347	Pearson Correlation between diagonals: 0.8480
# KL divergence: 0.2410	Pearson Correlation between diagonals: 0.9987
# KL divergence: 0.1587	Pearson Correlation between diagonals: 0.9970
# KL divergence: 0.4860	Pearson Correlation between diagonals: -0.7598
# KL divergence: 0.2041	Pearson Correlation between diagonals: 0.9816
# KL divergence: 0.2195	Pearson Correlation between diagonals: 0.9846
# KL divergence: 0.3508	Pearson Correlation between diagonals: 0.8396
# KL divergence: 0.1633	Pearson Correlation between diagonals: 0.9486
# KL divergence: 0.1793	Pearson Correlation between diagonals: 0.9978
# KL divergence: 0.3735	Pearson Correlation between diagonals: -0.4015
# KL divergence: 0.2021	Pearson Correlation between diagonals: 0.9983
# KL divergence: 0.1565	Pearson Correlation between diagonals: 0.7665
# KL divergence: 0.2801	Pearson Correlation between diagonals: 0.8480
# KL divergence: 0.2198	Pearson Correlation between diagonals: 0.9935
# KL divergence: 0.3582	Pearson Correlation between diagonals: 0.9984
# /home/casapanshop/anaconda2/envs/py3/lib/python3.5/site-packages/scipy/stats/stats.py:3003: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.113874 |     0.113874 |     0.292311 |                   nan |       0.323055 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+------------------------------+-----------------------------------+
# |    |   Accuracy imiting Annotator |   Cross-entropy imiting Annotator |
# |----+------------------------------+-----------------------------------|
# |  0 |                     0.526329 |                          0.962369 |
# +----+------------------------------+-----------------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.132026 |     0.132026 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.3709	Pearson Correlation between diagonals: -0.0248
# KL divergence: 0.2347	Pearson Correlation between diagonals: 0.8480
# KL divergence: 0.2410	Pearson Correlation between diagonals: 0.9987
# KL divergence: 0.1530	Pearson Correlation between diagonals: 0.9982
# KL divergence: 0.2465	Pearson Correlation between diagonals: 0.9945
# KL divergence: 0.2041	Pearson Correlation between diagonals: 0.9816
# KL divergence: 0.3508	Pearson Correlation between diagonals: 0.8396
# KL divergence: 0.3074	Pearson Correlation between diagonals: 1.0000
# KL divergence: 0.2407	Pearson Correlation between diagonals: -0.9794
# KL divergence: 0.2236	Pearson Correlation between diagonals: 0.9164
# KL divergence: 0.3735	Pearson Correlation between diagonals: -0.4015
# KL divergence: 0.1565	Pearson Correlation between diagonals: 0.7665
# KL divergence: 0.1766	Pearson Correlation between diagonals: 0.9573
# KL divergence: 0.1689	Pearson Correlation between diagonals: 0.9698
# KL divergence: 0.3163	Pearson Correlation between diagonals: 0.1408
# /home/casapanshop/anaconda2/envs/py3/lib/python3.5/site-packages/scipy/stats/stats.py:3003: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.328098 |     0.328098 |      0.29227 |                   nan |       0.276417 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+------------------------------+-----------------------------------+
# |    |   Accuracy imiting Annotator |   Cross-entropy imiting Annotator |
# |----+------------------------------+-----------------------------------|
# |  0 |                     0.591467 |                          0.888117 |
# +----+------------------------------+-----------------------------------+
# Test
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.312418 |     0.312418 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (1) multiples runs***
# Train
# KL divergence: 0.5236	Pearson Correlation between diagonals: 0.1895
# KL divergence: 0.5238	Pearson Correlation between diagonals: 0.1876
# KL divergence: 0.5239	Pearson Correlation between diagonals: 0.1870
# KL divergence: 0.5237	Pearson Correlation between diagonals: 0.1885
# KL divergence: 0.5233	Pearson Correlation between diagonals: 0.1925
# KL divergence: 0.5238	Pearson Correlation between diagonals: 0.1873
# KL divergence: 0.1137	Pearson Correlation between diagonals: 0.9656
# KL divergence: 0.1095	Pearson Correlation between diagonals: 0.9683
# KL divergence: 0.5236	Pearson Correlation between diagonals: 0.1899
# KL divergence: 0.1126	Pearson Correlation between diagonals: 0.9663
# KL divergence: 0.5238	Pearson Correlation between diagonals: 0.1873
# KL divergence: 0.1164	Pearson Correlation between diagonals: 0.9641
# KL divergence: 0.5239	Pearson Correlation between diagonals: 0.1868
# KL divergence: 0.5239	Pearson Correlation between diagonals: 0.1864
# KL divergence: 0.1132	Pearson Correlation between diagonals: 0.9657
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.903578 |     0.903578 |     0.535437 |              0.483006 |      0.0933207 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.664985 |               0.685675 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.0006646502733929083
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.327247 |    0.877618 |  0.136993 |           0.933766 |   0.862745 |     0.862745 |
# |  1 |        1 |  0.334756 |    0.869936 |  0.147471 |           0.928997 |   0.853595 |     0.853595 |
# |  2 |        2 |  0.363132 |    0.849224 |  0.173523 |           0.916847 |   0.83268  |     0.83268  |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.901961 |     0.901961 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (2) multiples runs***
# Train
# KL divergence: 0.0927	Pearson Correlation between diagonals: 0.9949
# KL divergence: 0.6877	Pearson Correlation between diagonals: -0.1752
# KL divergence: 0.6893	Pearson Correlation between diagonals: -0.1759
# KL divergence: 0.0927	Pearson Correlation between diagonals: 0.9949
# KL divergence: 0.6894	Pearson Correlation between diagonals: -0.1759
# KL divergence: 0.6889	Pearson Correlation between diagonals: -0.1757
# KL divergence: 0.0927	Pearson Correlation between diagonals: 0.9949
# KL divergence: 0.6872	Pearson Correlation between diagonals: -0.1750
# KL divergence: 0.6861	Pearson Correlation between diagonals: -0.1746
# KL divergence: 0.6897	Pearson Correlation between diagonals: -0.1760
# KL divergence: 0.6882	Pearson Correlation between diagonals: -0.1754
# KL divergence: 0.0927	Pearson Correlation between diagonals: 0.9949
# KL divergence: 0.0896	Pearson Correlation between diagonals: 0.9950
# KL divergence: 0.6889	Pearson Correlation between diagonals: -0.1757
# KL divergence: 0.0928	Pearson Correlation between diagonals: 0.9949
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.855148 |     0.855148 |     0.680976 |              0.234342 |      0.0923628 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                 0.66303 |               0.689337 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.0005245272914180532
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.300799 |    0.875978 |  0.144653 |           0.931004 |   0.83268  |     0.83268  |
# |  1 |        1 |  0.2637   |    0.899264 |  0.11435  |           0.944965 |   0.854902 |     0.854902 |
# |  2 |        2 |  0.267616 |    0.893484 |  0.122003 |           0.941452 |   0.845752 |     0.845752 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.853595 |     0.853595 |
# +----+--------+------------+--------------+

# %%
evaluate = Evaluation_metrics(gMixture3,'our1') 
aux = gMixture3.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (3) multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture3.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture3.get_confusionM()
y_o_groups = gMixture3.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture3.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (3) multiples runs***
# Train
# KL divergence: 0.7662	Pearson Correlation between diagonals: 0.2859
# KL divergence: 0.8253	Pearson Correlation between diagonals: 0.3113
# KL divergence: 0.8515	Pearson Correlation between diagonals: 0.2088
# KL divergence: 0.8174	Pearson Correlation between diagonals: 0.3489
# KL divergence: 0.1412	Pearson Correlation between diagonals: 0.9621
# KL divergence: 0.1403	Pearson Correlation between diagonals: 0.9663
# KL divergence: 0.6205	Pearson Correlation between diagonals: 0.7691
# KL divergence: 0.1464	Pearson Correlation between diagonals: 0.9664
# KL divergence: 0.1251	Pearson Correlation between diagonals: 0.9532
# KL divergence: 0.6363	Pearson Correlation between diagonals: 0.7418
# KL divergence: 0.6256	Pearson Correlation between diagonals: 0.7916
# KL divergence: 0.8633	Pearson Correlation between diagonals: 0.2122
# KL divergence: 0.8392	Pearson Correlation between diagonals: 0.1813
# KL divergence: 0.4275	Pearson Correlation between diagonals: 0.9675
# KL divergence: 0.8690	Pearson Correlation between diagonals: 0.2060
# A result
#  +----+--------+------------+--------------+--------------+-----------------------+----------------+
# |    |        |   Accuracy |   F1 (micro) |   Average KL |   Average PearsonCorr |   Average RMSE |
# |----+--------+------------+--------------+--------------+-----------------------+----------------|
# |  0 | Global |   0.924956 |     0.924956 |     0.562815 |              0.638957 |       0.150251 |
# +----+--------+------------+--------------+--------------+-----------------------+----------------+
# A result
#  +----+-------------------------+------------------------+
# |    |   ACC imiting Annotator |   CE imiting Annotator |
# |----+-------------------------+------------------------|
# |  0 |                0.766692 |                0.58654 |
# +----+-------------------------+------------------------+
# Test
# Inertia: 0.1073835778515786
# A result
#  +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# |    |   Groups |   Entropy |   Diag Mean |   KL to I |   I similar % (JS) |   Accuracy |   F1 (micro) |
# |----+----------+-----------+-------------+-----------+--------------------+------------+--------------|
# |  0 |        0 |  0.368183 |    0.845515 | 0.178813  |           0.914489 |   0.839216 |     0.839216 |
# |  1 |        1 |  0.146661 |    0.963101 | 0.0380235 |           0.981149 |   0.920261 |     0.920261 |
# |  2 |        2 |  0.41336  |    0.528281 | 0.862691  |           0.65927  |   0.321569 |     0.321569 |
# +----+----------+-----------+-------------+-----------+--------------------+------------+--------------+
# A result
#  +----+--------+------------+--------------+
# |    |        |   Accuracy |   F1 (micro) |
# |----+--------+------------+--------------|
# |  0 | Global |   0.921569 |     0.921569 |
# +----+--------+------------+--------------+

# %% [markdown]
# #### 6) configuration: Manny annot v1 bad MV ($T$ = 2000, $T_{max}$ = 20 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.6295811518324608
