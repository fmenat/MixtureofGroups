# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras, time, sys, os, gc
from code.generate_data import SinteticData
from code.representation import *
from code.utils import *
from code.learning_models import *
from code.baseline import RaykarMC,LabelInference
from code.MixtureofGroups import GroupMixtureGlo, GroupMixtureInd

import matplotlib
font = {'family' : 'normal',
        'size'   : 15}
matplotlib.rc('font', **font)

matplotlib.rc('axes', titlesize=25)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=25)    # fontsize of the x and y labels
#plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
#plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
ms = 10 #markersize

to_check = [100,2000,5000,10000,15000,25000,40000]
to_check
# Out:
# Using TensorFlow backend.
# [100, 2000, 5000, 10000, 15000, 25000, 40000]

# %%
memory_cons = []
N = 50000
K = 10
T_i = 20
for t in to_check:
    print(t)
    a = np.zeros((N,t,K),dtype='float32') #int8
    memory_cons.append(a.nbytes/(1024*1024)) #MB
    del a
    gc.collect()

ours_consume = np.zeros((N,K),dtype='float32').nbytes/(1024*1024) #global
ours_consume2 = np.zeros((N,T_i,K),dtype='float32').nbytes/(1024*1024) #annotation
ours_consume2 += np.zeros((N,T_i,K),dtype='float32').nbytes/(1024*1024) #identity

print("CIFAR example 50k exaples, 10 classes -- memory consume of representation")

plt.figure(figsize=(15,7))
plt.plot(to_check,memory_cons,'bo-',label="Individual consume", markersize=ms)
plt.plot(to_check,np.tile(ours_consume,len(to_check)),'g*-',label="Global consume", markersize=ms)
plt.plot(to_check,np.tile(ours_consume2,len(to_check)),'mX-',label="Individual-identity consume", markersize=ms)

#plt.hlines(16000,0,to_check[-1], color='r', label="Our memory limit")

plt.xticks(to_check)
plt.ylabel("MB")
plt.xlabel("Annotators (T)")
plt.legend()
plt.show()
# Out:
# 100
# 2000
# 5000
# 10000
# 15000
# 25000
# 40000
# CIFAR example 50k exaples, 10 classes -- memory consume of representation
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
folder = "."
X_train = np.loadtxt(folder+"/synthetic/simple/datasim_X_train.csv",delimiter=',')
Z_train = np.loadtxt(folder+"/synthetic/simple/datasim_Z_train.csv",dtype='int') #groudn truth

X_test = np.loadtxt(folder+"/synthetic/simple/datasim_X_test.csv",delimiter=',')
Z_test = np.loadtxt(folder+"/synthetic/simple/datasim_Z_test.csv",dtype='int') #groudn truth
N = Z_train.shape[0]
GenerateData = SinteticData(state=None)

#CONFUSION MATRIX CHOOSE
GenerateData.set_probas(asfile=True,file_matrix='./synthetic/simple/matrix_datasim_normal.csv',file_groups ='./synthetic/simple/groups_datasim_normal.csv')

#GenerateData.set_probas(asfile=True,file_matrix=path+'/synthetic/simple/matrix_datasim_badMV.csv',file_groups =path+'/synthetic/simple/groups_datasim_badMV.csv')

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
to_check = [100,2000,5000,10000,15000,25000,40000]
T_data = 10 
M_seted = 5
BATCH_SIZE= 64

annot_acc = []
raykar_exec = []
raykar_init = []
ourglobal_exec = []
ourglobal_init = []
ourindiv1_exec = []
ourindiv1_init = []
ourindiv2_exec = []
ourindiv2_init = []
ourindiv3_exec = []
ourindiv3_init = []
mv_exec = []
ds_exec = []
for Tmax in to_check:
    aux_annot_acc = []
    aux_raykar_exec = []
    aux_raykar_init = []
    aux_ourglobal_exec = []
    aux_ourglobal_init = []
    aux_ourindiv1_exec = []
    aux_ourindiv1_init = []
    aux_ourindiv2_exec = []
    aux_ourindiv2_init = []
    aux_ourindiv3_exec = []
    aux_ourindiv3_init = []
    aux_mv_exec = []
    aux_ds_exec = []
    for _ in range(10):
        y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False,hard=True)
        T = y_obs.shape[1]
        #annot_acc.append(np.mean(GenerateData.yo_label == Z_train))

        #----------------------------RAYKAR---------------------------#
        y_obs_categorical = set_representation(y_obs,'onehot') 
        raykarMC = RaykarMC(X_train.shape[1:],y_obs_categorical.shape[-1],Tmax,epochs=1)
        raykarMC.define_model("mlp",16,1,BatchN=False,drop=0.2)
        logL_hists,i = raykarMC.multiples_run(1,X_train,y_obs_categorical,max_iter=3,batch_size=BATCH_SIZE)

        aux_raykar_exec.append(raykarMC.current_exectime)
        aux_raykar_init.append(raykarMC.init_exectime)

        del raykarMC
        gc.collect()
        keras.backend.clear_session()
        #----------------------------RAYKAR---------------------------#

        #----------------------------Ours Global---------------------------#
        r_obs = set_representation(y_obs,"repeat")
        K = r_obs.shape[1]
        gMixture_Global = GroupMixtureGlo(X_train.shape[1:],Kl=r_obs.shape[1],M=M_seted,epochs=1,pre_init=0) 
        gMixture_Global.define_model("mlp",16,1,BatchN=False,drop=0.2)
        logL_hists,i_r = gMixture_Global.multiples_run(1,X_train,r_obs,max_iter=3, batch_size=BATCH_SIZE)

        aux_ourglobal_exec.append(gMixture_Global.current_exectime)
        aux_ourglobal_init.append(gMixture_Global.init_exectime)
    
        del gMixture_Global
        gc.collect()
        keras.backend.clear_session()
        #----------------------------Ours Global---------------------------#
        
        #----------------------------Ours Individual---------------------------#
        Y_ann_train, T_idx = set_representation(y_obs,"onehotvar")
        T_idx_unique = np.arange(T).reshape(-1,1)
        A = keras.utils.to_categorical(np.arange(T), num_classes=T) #fast way
        A_rep = np.zeros((T, K))
        for i in range(N):
            for l, t_idx in enumerate(T_idx[i]):
                obs_t = Y_ann_train[i][l].argmax(axis=-1)
                A_rep[t_idx, obs_t] += 1
        gMixture_Ind = GroupMixtureInd(X_train.shape[1:],Kl=K,M=M_seted,epochs=1,pre_init=15) 
        gMixture_Ind.define_model("mlp",16,1,BatchN=False,drop=0.2)
        gMixture_Ind.define_model_group("mlp", T, M_seted, 1, BatchN=False, embed=True, embed_M=A)
        gMixture_Ind.pre_init_z = 3
        logL_hists,i = gMixture_Ind.multiples_run(1,X_train,Y_ann_train, T_idx, A=[],max_iter=3,batch_size=BATCH_SIZE)
        
        aux_ourindiv1_exec.append(gMixture_Ind.current_exectime)
        aux_ourindiv1_init.append(gMixture_Ind.init_exectime)
        
        del gMixture_Ind
        gc.collect()
        keras.backend.clear_session()

        gMixture_Ind = GroupMixtureInd(X_train.shape[1:],Kl=K,M=M_seted,epochs=1,pre_init=1) 
        gMixture_Ind.define_model("mlp",16,1,BatchN=False,drop=0.2) 
        gMixture_Ind.pre_init_z = 3 
        logL_hists,i_r = gMixture_Ind.multiples_run(1,X_train,Y_ann_train, T_idx, A=[], batch_size=BATCH_SIZE,max_iter=3)
        
        aux_ourindiv2_exec.append(gMixture_Ind.current_exectime)
        aux_ourindiv2_init.append(gMixture_Ind.init_exectime)
        
        del gMixture_Ind
        gc.collect()
        keras.backend.clear_session()

        gMixture_Ind = GroupMixtureInd(X_train.shape[1:],Kl=K,M=M_seted,epochs=1,pre_init=15) 
        gMixture_Ind.define_model("mlp",16,1,BatchN=False,drop=0.2) 
        gMixture_Ind.define_model_group("mlp", T, K*M_seted, 1, BatchN=False, embed=True, embed_M=A_rep)
        gMixture_Ind.pre_init_z = 3 
        logL_hists,i_r = gMixture_Ind.multiples_run(1,X_train,Y_ann_train, T_idx, A=[], batch_size=BATCH_SIZE,max_iter=3)
        
        aux_ourindiv3_exec.append(gMixture_Ind.current_exectime)
        aux_ourindiv3_init.append(gMixture_Ind.init_exectime)
        
        del gMixture_Ind
        gc.collect()
        keras.backend.clear_session()
        #----------------------------Ours Individual---------------------------#
        
        #----------------------------Majority Voting---------------------------#
        mv_soft = majority_voting(r_obs,repeats=True,probas=True) 
        time_callback = TimeHistory()
        model_mvsoft = MLP_Keras(X_train.shape[1:],mv_soft.shape[1],16,1,BN=False,drop=0.2)
        model_mvsoft.compile(loss='categorical_crossentropy',optimizer='adam')
        model_mvsoft.fit(X_train, mv_soft, epochs=3,batch_size=BATCH_SIZE,verbose=1,callbacks=[time_callback])
        times = time_callback.times
        aux_mv_exec.append(times[-1])
        del model_mvsoft
        gc.collect()
        keras.backend.clear_session()
        #----------------------------Majority Voting---------------------------#
        
        #----------------------------Dawid and Skene---------------------------#
        label_I = LabelInference(y_obs,1e-10, type_inf = 'ds', max_iter=3)
        ds_labels,ds_conf = label_I.DS_labels()
        aux_ds_exec.append(label_I.DS_current_exectime)
        del label_I
        gc.collect()
        #----------------------------Dawid and Skene---------------------------#
        
    raykar_exec.append(np.mean(aux_raykar_exec))
    raykar_init.append(np.mean(aux_raykar_init))
    ourglobal_exec.append(np.mean(aux_ourglobal_exec))
    ourglobal_init.append(np.mean(aux_ourglobal_init))
    ourindiv1_exec.append(np.mean(aux_ourindiv1_exec))
    ourindiv1_init.append(np.mean(aux_ourindiv1_init))
    ourindiv2_exec.append(np.mean(aux_ourindiv2_exec))
    ourindiv2_init.append(np.mean(aux_ourindiv2_init))
    ourindiv3_exec.append(np.mean(aux_ourindiv3_exec))
    ourindiv3_init.append(np.mean(aux_ourindiv3_init))
    mv_exec.append(np.mean(aux_mv_exec))
    ds_exec.append(np.mean(aux_ds_exec))
    
raykar_exec = np.asarray(raykar_exec)
raykar_init = np.asarray(raykar_init)
ourglobal_exec = np.asarray(ourglobal_exec)
ourglobal_init = np.asarray(ourglobal_init)
ourindiv1_exec = np.asarray(ourindiv1_exec)
ourindiv1_init = np.asarray(ourindiv1_init)
ourindiv2_exec = np.asarray(ourindiv2_exec)
ourindiv2_init = np.asarray(ourindiv2_init)
ourindiv3_exec = np.asarray(ourindiv3_exec)
ourindiv3_init = np.asarray(ourindiv3_init)
mv_exec = np.asarray(mv_exec)
ds_exec = np.asarray(ds_exec)
print("Done")
# Out:
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.55 sec)	logL: -18827.842
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -17217.539	Tol1: 0.08553	Tol2: 0.27994
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -16691.041	Tol1: 0.03058	Tol2: 0.10428
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002399 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.55 sec)	logL: -25814.808
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -25042.387	Tol1: 0.02992	Tol2: 0.42074	Tol3: 0.02988
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -24547.572	Tol1: 0.01976	Tol2: 0.18113	Tol3: 0.01710
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001374 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24616, 5, 3)
# Iter 1/3
# M step:M step en 1.071699 sec
#  done,  E step:E step en 0.136155 sec
#  done //  (in 1.21 sec)	logL: -21192.393
# Iter 2/3
# M step:M step en 0.235854 sec
#  done,  E step:E step en 0.051570 sec
#  done //  (in 0.29 sec)	logL: -20171.837	Tol1: 0.04816	Tol2: 0.18109
# Iter 3/3
# M step:M step en 0.208653 sec
#  done,  E step:E step en 0.066366 sec
#  done //  (in 0.28 sec)	logL: -19296.985	Tol1: 0.04337	Tol2: 0.17786
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001426 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24616, 5, 3)
# Iter 1/3
# M step:M step en 0.579589 sec
#  done,  E step:E step en 0.128992 sec
#  done //  (in 0.71 sec)	logL: -20198.574
# Iter 2/3
# M step:M step en 0.104015 sec
#  done,  E step:E step en 0.042656 sec
#  done //  (in 0.15 sec)	logL: -19054.325	Tol1: 0.05665	Tol2: 0.20174
# Iter 3/3
# M step:M step en 0.096437 sec
#  done,  E step:E step en 0.043572 sec
#  done //  (in 0.14 sec)	logL: -18178.394	Tol1: 0.04597	Tol2: 0.19292
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001259 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24616, 5, 3)
# Iter 1/3
# M step:M step en 1.165093 sec
#  done,  E step:E step en 0.150151 sec
#  done //  (in 1.32 sec)	logL: -27168.400
# Iter 2/3
# M step:M step en 0.220663 sec
#  done,  E step:E step en 0.049612 sec
#  done //  (in 0.27 sec)	logL: -22648.673	Tol1: 0.16636	Tol2: 3.87299
# Iter 3/3
# M step:M step en 0.219779 sec
#  done,  E step:E step en 0.050339 sec
#  done //  (in 0.27 sec)	logL: -21353.408	Tol1: 0.05719	Tol2: 0.14465
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 86us/step - loss: 1.0939
# Epoch 2/3
# 2457/2457 [==============================] - 0s 24us/step - loss: 1.0194
# Epoch 3/3
# 2457/2457 [==============================] - 0s 23us/step - loss: 0.9564
# Representation for DS in 0.050110 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18852.845663134114
# 2 	 -17575.804700553133 	0.3133	0.284335	0.067737
# 3 	 -17340.057380834416 	0.0743	0.206255	0.013413
# 4 	 -17293.88823339918 	0.0362	0.140946	0.002663
# Class marginals
# [0.37 0.34 0.3 ]
# Estimation for DS in 1.180479 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -18474.676
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -16878.729	Tol1: 0.08639	Tol2: 0.27812
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -16399.789	Tol1: 0.02838	Tol2: 0.10356
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002078 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -24561.325
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23766.222	Tol1: 0.03237	Tol2: 0.51277	Tol3: 0.08395
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23113.457	Tol1: 0.02747	Tol2: 0.24012	Tol3: 0.04771
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001157 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24512, 5, 3)
# Iter 1/3
# M step:M step en 1.190737 sec
#  done,  E step:E step en 0.164885 sec
#  done //  (in 1.36 sec)	logL: -20503.303
# Iter 2/3
# M step:M step en 0.216861 sec
#  done,  E step:E step en 0.050409 sec
#  done //  (in 0.27 sec)	logL: -19454.218	Tol1: 0.05117	Tol2: 0.21515
# Iter 3/3
# M step:M step en 0.238375 sec
#  done,  E step:E step en 0.064650 sec
#  done //  (in 0.30 sec)	logL: -18624.632	Tol1: 0.04264	Tol2: 0.20948
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001336 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24512, 5, 3)
# Iter 1/3
# M step:M step en 0.581643 sec
#  done,  E step:E step en 0.150517 sec
#  done //  (in 0.73 sec)	logL: -20054.132
# Iter 2/3
# M step:M step en 0.098293 sec
#  done,  E step:E step en 0.050567 sec
#  done //  (in 0.15 sec)	logL: -19046.803	Tol1: 0.05023	Tol2: 0.20142
# Iter 3/3
# M step:M step en 0.104007 sec
#  done,  E step:E step en 0.045337 sec
#  done //  (in 0.15 sec)	logL: -18211.504	Tol1: 0.04386	Tol2: 0.19829
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001330 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24512, 5, 3)
# Iter 1/3
# M step:M step en 1.045902 sec
#  done,  E step:E step en 0.178893 sec
#  done //  (in 1.23 sec)	logL: -22507.553
# Iter 2/3
# M step:M step en 0.229020 sec
#  done,  E step:E step en 0.056280 sec
#  done //  (in 0.29 sec)	logL: -21234.500	Tol1: 0.05656	Tol2: 33.71975
# Iter 3/3
# M step:M step en 0.205597 sec
#  done,  E step:E step en 0.047206 sec
#  done //  (in 0.25 sec)	logL: -20346.786	Tol1: 0.04181	Tol2: 0.07219
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 80us/step - loss: 1.0291
# Epoch 2/3
# 2457/2457 [==============================] - 0s 21us/step - loss: 0.9539
# Epoch 3/3
# 2457/2457 [==============================] - 0s 21us/step - loss: 0.9052
# Representation for DS in 0.050778 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18595.93326505213
# 2 	 -17323.504786826998 	0.3418	0.280682	0.068425
# 3 	 -17058.779617367745 	0.0828	0.211201	0.015281
# 4 	 -17002.93681769362 	0.0378	0.150823	0.003274
# Class marginals
# [0.36 0.33 0.31]
# Estimation for DS in 1.185227 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -18413.641
# Iter 2/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -17036.465	Tol1: 0.07479	Tol2: 0.26561
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -16570.945	Tol1: 0.02732	Tol2: 0.09851
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002062 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -24244.204
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23073.639	Tol1: 0.04828	Tol2: 0.47406	Tol3: 0.07893
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -22344.970	Tol1: 0.03158	Tol2: 0.24158	Tol3: 0.02576
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001200 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24549, 5, 3)
# Iter 1/3
# M step:M step en 1.079794 sec
#  done,  E step:E step en 0.118024 sec
#  done //  (in 1.20 sec)	logL: -21999.171
# Iter 2/3
# M step:M step en 0.196436 sec
#  done,  E step:E step en 0.079221 sec
#  done //  (in 0.28 sec)	logL: -21126.562	Tol1: 0.03967	Tol2: 0.18938
# Iter 3/3
# M step:M step en 0.246309 sec
#  done,  E step:E step en 0.051841 sec
#  done //  (in 0.30 sec)	logL: -20291.885	Tol1: 0.03951	Tol2: 0.16602
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001378 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24549, 5, 3)
# Iter 1/3
# M step:M step en 0.528033 sec
#  done,  E step:E step en 0.073597 sec
#  done //  (in 0.60 sec)	logL: -20195.338
# Iter 2/3
# M step:M step en 0.083429 sec
#  done,  E step:E step en 0.037250 sec
#  done //  (in 0.12 sec)	logL: -19164.233	Tol1: 0.05106	Tol2: 0.20771
# Iter 3/3
# M step:M step en 0.082017 sec
#  done,  E step:E step en 0.036596 sec
#  done //  (in 0.12 sec)	logL: -18237.167	Tol1: 0.04837	Tol2: 0.20439
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001356 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24549, 5, 3)
# Iter 1/3
# M step:M step en 0.988734 sec
#  done,  E step:E step en 0.143963 sec
#  done //  (in 1.13 sec)	logL: -33892.354
# Iter 2/3
# M step:M step en 0.211610 sec
#  done,  E step:E step en 0.058650 sec
#  done //  (in 0.27 sec)	logL: -21388.932	Tol1: 0.36892	Tol2: 8.83695
# Iter 3/3
# M step:M step en 0.218272 sec
#  done,  E step:E step en 0.053035 sec
#  done //  (in 0.27 sec)	logL: -20489.010	Tol1: 0.04207	Tol2: 0.08665
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 102us/step - loss: 1.0494
# Epoch 2/3
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9803
# Epoch 3/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9321
# Representation for DS in 0.059286 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18690.13837519402
# 2 	 -17482.631659906037 	0.3350	0.281447	0.064607
# 3 	 -17229.980266531144 	0.0904	0.209823	0.014452
# 4 	 -17166.98159723816 	0.0316	0.151669	0.003656
# Class marginals
# [0.35 0.33 0.32]
# Estimation for DS in 1.197063 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -18161.957
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -16733.797	Tol1: 0.07863	Tol2: 0.28912
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -16151.309	Tol1: 0.03481	Tol2: 0.10844
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002744 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.49 sec)	logL: -25767.962
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24309.022	Tol1: 0.05662	Tol2: 0.46487	Tol3: 0.09964
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23690.261	Tol1: 0.02545	Tol2: 0.20983	Tol3: 0.02677
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001220 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24651, 5, 3)
# Iter 1/3
# M step:M step en 1.014565 sec
#  done,  E step:E step en 0.113640 sec
#  done //  (in 1.13 sec)	logL: -20517.666
# Iter 2/3
# M step:M step en 0.204907 sec
#  done,  E step:E step en 0.056496 sec
#  done //  (in 0.26 sec)	logL: -19619.600	Tol1: 0.04377	Tol2: 0.16758
# Iter 3/3
# M step:M step en 0.210314 sec
#  done,  E step:E step en 0.058235 sec
#  done //  (in 0.27 sec)	logL: -18847.163	Tol1: 0.03937	Tol2: 0.17268
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001411 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24651, 5, 3)
# Iter 1/3
# M step:M step en 0.563607 sec
#  done,  E step:E step en 0.099882 sec
#  done //  (in 0.67 sec)	logL: -19936.420
# Iter 2/3
# M step:M step en 0.089718 sec
#  done,  E step:E step en 0.037803 sec
#  done //  (in 0.13 sec)	logL: -19024.423	Tol1: 0.04575	Tol2: 0.18943
# Iter 3/3
# M step:M step en 0.084914 sec
#  done,  E step:E step en 0.051356 sec
#  done //  (in 0.14 sec)	logL: -18153.149	Tol1: 0.04580	Tol2: 0.19420
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001244 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24651, 5, 3)
# Iter 1/3
# M step:M step en 1.125977 sec
#  done,  E step:E step en 0.166133 sec
#  done //  (in 1.29 sec)	logL: -22989.325
# Iter 2/3
# M step:M step en 0.242616 sec
#  done,  E step:E step en 0.064633 sec
#  done //  (in 0.31 sec)	logL: -20967.386	Tol1: 0.08795	Tol2: 48.01840
# Iter 3/3
# M step:M step en 0.225857 sec
#  done,  E step:E step en 0.047779 sec
#  done //  (in 0.28 sec)	logL: -20165.116	Tol1: 0.03826	Tol2: 0.08492
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 90us/step - loss: 1.1546
# Epoch 2/3
# 2457/2457 [==============================] - 0s 32us/step - loss: 1.0488
# Epoch 3/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9773
# Representation for DS in 0.058262 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18318.68150935668
# 2 	 -17112.829090765365 	0.3963	0.258410	0.065826
# 3 	 -16797.816075061128 	0.0991	0.196843	0.018408
# 4 	 -16704.594457829575 	0.0472	0.148778	0.005550
# Class marginals
# [0.38 0.33 0.29]
# Estimation for DS in 1.197583 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -17796.256
# Iter 2/3
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16191.473	Tol1: 0.09018	Tol2: 0.28859
# Iter 3/3
# M step: done,  E step: done //  (in 0.11 sec)	logL: -15659.572	Tol1: 0.03285	Tol2: 0.10725
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002638 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.51 sec)	logL: -25512.702
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -24502.248	Tol1: 0.03961	Tol2: 0.40360	Tol3: 0.05858
# Iter 3/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -23848.262	Tol1: 0.02669	Tol2: 0.19232	Tol3: 0.01861
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001302 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24457, 5, 3)
# Iter 1/3
# M step:M step en 1.047667 sec
#  done,  E step:E step en 0.132778 sec
#  done //  (in 1.18 sec)	logL: -20471.706
# Iter 2/3
# M step:M step en 0.216376 sec
#  done,  E step:E step en 0.058939 sec
#  done //  (in 0.28 sec)	logL: -19341.776	Tol1: 0.05519	Tol2: 0.21159
# Iter 3/3
# M step:M step en 0.217455 sec
#  done,  E step:E step en 0.067890 sec
#  done //  (in 0.29 sec)	logL: -18408.928	Tol1: 0.04823	Tol2: 0.20122
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001488 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24457, 5, 3)
# Iter 1/3
# M step:M step en 0.488175 sec
#  done,  E step:E step en 0.072697 sec
#  done //  (in 0.56 sec)	logL: -19882.233
# Iter 2/3
# M step:M step en 0.085390 sec
#  done,  E step:E step en 0.049925 sec
#  done //  (in 0.14 sec)	logL: -18778.881	Tol1: 0.05549	Tol2: 0.19098
# Iter 3/3
# M step:M step en 0.089671 sec
#  done,  E step:E step en 0.043094 sec
#  done //  (in 0.13 sec)	logL: -17858.586	Tol1: 0.04901	Tol2: 0.19792
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001334 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24457, 5, 3)
# Iter 1/3
# M step:M step en 1.165354 sec
#  done,  E step:E step en 0.110605 sec
#  done //  (in 1.28 sec)	logL: -27795.573
# Iter 2/3
# M step:M step en 0.178961 sec
#  done,  E step:E step en 0.038923 sec
#  done //  (in 0.22 sec)	logL: -22173.551	Tol1: 0.20226	Tol2: 13.14728
# Iter 3/3
# M step:M step en 0.198308 sec
#  done,  E step:E step en 0.058845 sec
#  done //  (in 0.26 sec)	logL: -21401.294	Tol1: 0.03483	Tol2: 0.06873
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 88us/step - loss: 1.0734
# Epoch 2/3
# 2457/2457 [==============================] - 0s 23us/step - loss: 0.9786
# Epoch 3/3
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9173
# Representation for DS in 0.056675 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18081.40594610808
# 2 	 -16799.474979152794 	0.3520	0.286668	0.070898
# 3 	 -16523.893618213035 	0.0820	0.209467	0.016404
# 4 	 -16454.501641047435 	0.0387	0.146554	0.004199
# Class marginals
# [0.36 0.33 0.31]
# Estimation for DS in 1.210673 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.46 sec)	logL: -18319.324
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -16652.676	Tol1: 0.09098	Tol2: 0.28217
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -16089.516	Tol1: 0.03382	Tol2: 0.11424
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002013 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -25448.455
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24821.936	Tol1: 0.02462	Tol2: 0.38361	Tol3: 0.05516
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24331.726	Tol1: 0.01975	Tol2: 0.17435	Tol3: 0.01895
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001220 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24532, 5, 3)
# Iter 1/3
# M step:M step en 1.232421 sec
#  done,  E step:E step en 0.178795 sec
#  done //  (in 1.41 sec)	logL: -22299.844
# Iter 2/3
# M step:M step en 0.242381 sec
#  done,  E step:E step en 0.068818 sec
#  done //  (in 0.31 sec)	logL: -21611.209	Tol1: 0.03088	Tol2: 0.16480
# Iter 3/3
# M step:M step en 0.235366 sec
#  done,  E step:E step en 0.067117 sec
#  done //  (in 0.30 sec)	logL: -20877.347	Tol1: 0.03396	Tol2: 0.14011
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001414 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24532, 5, 3)
# Iter 1/3
# M step:M step en 0.553501 sec
#  done,  E step:E step en 0.126795 sec
#  done //  (in 0.68 sec)	logL: -20656.849
# Iter 2/3
# M step:M step en 0.091919 sec
#  done,  E step:E step en 0.043223 sec
#  done //  (in 0.14 sec)	logL: -19724.266	Tol1: 0.04515	Tol2: 0.14730
# Iter 3/3
# M step:M step en 0.092145 sec
#  done,  E step:E step en 0.042840 sec
#  done //  (in 0.14 sec)	logL: -18842.651	Tol1: 0.04470	Tol2: 0.14769
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001459 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24532, 5, 3)
# Iter 1/3
# M step:M step en 1.161240 sec
#  done,  E step:E step en 0.128778 sec
#  done //  (in 1.29 sec)	logL: -24006.152
# Iter 2/3
# M step:M step en 0.244868 sec
#  done,  E step:E step en 0.069732 sec
#  done //  (in 0.32 sec)	logL: -22196.636	Tol1: 0.07538	Tol2: 46.36003
# Iter 3/3
# M step:M step en 0.219929 sec
#  done,  E step:E step en 0.060613 sec
#  done //  (in 0.28 sec)	logL: -21529.227	Tol1: 0.03007	Tol2: 0.03535
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 112us/step - loss: 1.1556
# Epoch 2/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 1.0546
# Epoch 3/3
# 2457/2457 [==============================] - 0s 29us/step - loss: 0.9902
# Representation for DS in 0.057205 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18045.218125814463
# 2 	 -16825.084798220756 	0.3825	0.265583	0.067615
# 3 	 -16549.613632514684 	0.0849	0.196033	0.016373
# 4 	 -16466.61514189536 	0.0508	0.139163	0.005015
# Class marginals
# [0.39 0.33 0.28]
# Estimation for DS in 1.205985 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.53 sec)	logL: -18707.539
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -17056.133	Tol1: 0.08827	Tol2: 0.27684
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -16517.146	Tol1: 0.03160	Tol2: 0.10868
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002273 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.50 sec)	logL: -24951.545
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -24181.485	Tol1: 0.03086	Tol2: 0.36645	Tol3: 0.05406
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -23587.431	Tol1: 0.02457	Tol2: 0.17773	Tol3: 0.01648
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001329 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24612, 5, 3)
# Iter 1/3
# M step:M step en 1.205023 sec
#  done,  E step:E step en 0.158533 sec
#  done //  (in 1.37 sec)	logL: -20816.999
# Iter 2/3
# M step:M step en 0.249845 sec
#  done,  E step:E step en 0.066468 sec
#  done //  (in 0.32 sec)	logL: -19708.526	Tol1: 0.05325	Tol2: 0.21742
# Iter 3/3
# M step:M step en 0.241340 sec
#  done,  E step:E step en 0.075557 sec
#  done //  (in 0.32 sec)	logL: -18895.597	Tol1: 0.04125	Tol2: 0.18077
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001394 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24612, 5, 3)
# Iter 1/3
# M step:M step en 0.634497 sec
#  done,  E step:E step en 0.098386 sec
#  done //  (in 0.73 sec)	logL: -20932.736
# Iter 2/3
# M step:M step en 0.097191 sec
#  done,  E step:E step en 0.037964 sec
#  done //  (in 0.14 sec)	logL: -20040.296	Tol1: 0.04263	Tol2: 0.14583
# Iter 3/3
# M step:M step en 0.082559 sec
#  done,  E step:E step en 0.036890 sec
#  done //  (in 0.12 sec)	logL: -19171.131	Tol1: 0.04337	Tol2: 0.15239
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001172 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24612, 5, 3)
# Iter 1/3
# M step:M step en 1.014650 sec
#  done,  E step:E step en 0.108895 sec
#  done //  (in 1.13 sec)	logL: -41306.913
# Iter 2/3
# M step:M step en 0.194953 sec
#  done,  E step:E step en 0.061330 sec
#  done //  (in 0.26 sec)	logL: -22721.836	Tol1: 0.44993	Tol2: 24.85611
# Iter 3/3
# M step:M step en 0.220389 sec
#  done,  E step:E step en 0.058240 sec
#  done //  (in 0.28 sec)	logL: -21822.766	Tol1: 0.03957	Tol2: 0.04662
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 92us/step - loss: 1.2215
# Epoch 2/3
# 2457/2457 [==============================] - 0s 31us/step - loss: 1.0979
# Epoch 3/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 1.0226
# Representation for DS in 0.059049 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18753.13628861776
# 2 	 -17467.74675914059 	0.3622	0.279770	0.068543
# 3 	 -17185.003824404375 	0.0886	0.210875	0.016187
# 4 	 -17116.12864400372 	0.0353	0.154305	0.004008
# Class marginals
# [0.37 0.33 0.3 ]
# Estimation for DS in 1.236004 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.49 sec)	logL: -18884.203
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -17255.926	Tol1: 0.08622	Tol2: 0.26517
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -16616.232	Tol1: 0.03707	Tol2: 0.11893
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002742 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -25827.044
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24756.210	Tol1: 0.04146	Tol2: 0.41410	Tol3: 0.07134
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24147.124	Tol1: 0.02460	Tol2: 0.18907	Tol3: 0.02063
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001208 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24520, 5, 3)
# Iter 1/3
# M step:M step en 1.118956 sec
#  done,  E step:E step en 0.156564 sec
#  done //  (in 1.28 sec)	logL: -20551.932
# Iter 2/3
# M step:M step en 0.223367 sec
#  done,  E step:E step en 0.088387 sec
#  done //  (in 0.31 sec)	logL: -19436.085	Tol1: 0.05429	Tol2: 0.22288
# Iter 3/3
# M step:M step en 0.258853 sec
#  done,  E step:E step en 0.079445 sec
#  done //  (in 0.34 sec)	logL: -18534.498	Tol1: 0.04639	Tol2: 0.17413
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001394 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24520, 5, 3)
# Iter 1/3
# M step:M step en 0.552779 sec
#  done,  E step:E step en 0.127040 sec
#  done //  (in 0.68 sec)	logL: -20221.606
# Iter 2/3
# M step:M step en 0.110925 sec
#  done,  E step:E step en 0.043000 sec
#  done //  (in 0.15 sec)	logL: -19241.556	Tol1: 0.04847	Tol2: 0.16050
# Iter 3/3
# M step:M step en 0.093167 sec
#  done,  E step:E step en 0.037958 sec
#  done //  (in 0.13 sec)	logL: -18440.547	Tol1: 0.04163	Tol2: 0.14715
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001360 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24520, 5, 3)
# Iter 1/3
# M step:M step en 1.075101 sec
#  done,  E step:E step en 0.116144 sec
#  done //  (in 1.19 sec)	logL: -28244.405
# Iter 2/3
# M step:M step en 0.224476 sec
#  done,  E step:E step en 0.072169 sec
#  done //  (in 0.30 sec)	logL: -23360.625	Tol1: 0.17291	Tol2: 44.76918
# Iter 3/3
# M step:M step en 0.202006 sec
#  done,  E step:E step en 0.043994 sec
#  done //  (in 0.25 sec)	logL: -22660.259	Tol1: 0.02998	Tol2: 0.02727
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 102us/step - loss: 1.0523
# Epoch 2/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9861
# Epoch 3/3
# 2457/2457 [==============================] - 0s 32us/step - loss: 0.9384
# Representation for DS in 0.057536 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18143.416243903648
# 2 	 -16924.614615806804 	0.3921	0.266500	0.067176
# 3 	 -16634.687967179798 	0.0889	0.201713	0.017130
# 4 	 -16554.17995468174 	0.0487	0.135453	0.004840
# Class marginals
# [0.38 0.33 0.29]
# Estimation for DS in 1.244615 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -18160.875
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -16650.262	Tol1: 0.08318	Tol2: 0.27675
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -16081.084	Tol1: 0.03418	Tol2: 0.11256
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002482 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.50 sec)	logL: -23371.545
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -22498.449	Tol1: 0.03736	Tol2: 0.40593	Tol3: 0.04399
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -21865.337	Tol1: 0.02814	Tol2: 0.22979	Tol3: 0.02743
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001212 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24553, 5, 3)
# Iter 1/3
# M step:M step en 1.165444 sec
#  done,  E step:E step en 0.127865 sec
#  done //  (in 1.30 sec)	logL: -20695.016
# Iter 2/3
# M step:M step en 0.229395 sec
#  done,  E step:E step en 0.056153 sec
#  done //  (in 0.29 sec)	logL: -19653.698	Tol1: 0.05032	Tol2: 0.19409
# Iter 3/3
# M step:M step en 0.230739 sec
#  done,  E step:E step en 0.058980 sec
#  done //  (in 0.29 sec)	logL: -18826.322	Tol1: 0.04210	Tol2: 0.17746
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001377 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24553, 5, 3)
# Iter 1/3
# M step:M step en 0.531995 sec
#  done,  E step:E step en 0.157229 sec
#  done //  (in 0.69 sec)	logL: -19474.828
# Iter 2/3
# M step:M step en 0.114223 sec
#  done,  E step:E step en 0.077425 sec
#  done //  (in 0.19 sec)	logL: -18429.543	Tol1: 0.05367	Tol2: 0.20429
# Iter 3/3
# M step:M step en 0.114784 sec
#  done,  E step:E step en 0.083915 sec
#  done //  (in 0.20 sec)	logL: -17634.749	Tol1: 0.04313	Tol2: 0.19353
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001163 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24553, 5, 3)
# Iter 1/3
# M step:M step en 1.057106 sec
#  done,  E step:E step en 0.185575 sec
#  done //  (in 1.24 sec)	logL: -23205.338
# Iter 2/3
# M step:M step en 0.232688 sec
#  done,  E step:E step en 0.057815 sec
#  done //  (in 0.29 sec)	logL: -21314.996	Tol1: 0.08146	Tol2: 44.56025
# Iter 3/3
# M step:M step en 0.218760 sec
#  done,  E step:E step en 0.047580 sec
#  done //  (in 0.27 sec)	logL: -20489.518	Tol1: 0.03873	Tol2: 0.07705
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 86us/step - loss: 1.0551
# Epoch 2/3
# 2457/2457 [==============================] - 0s 22us/step - loss: 0.9746
# Epoch 3/3
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9240
# Representation for DS in 0.058589 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18238.99369715117
# 2 	 -17069.99033475379 	0.3837	0.262065	0.064094
# 3 	 -16782.02624126042 	0.0922	0.198836	0.016870
# 4 	 -16686.790151184046 	0.0458	0.144313	0.005675
# Class marginals
# [0.37 0.33 0.29]
# Estimation for DS in 1.249536 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.52 sec)	logL: -17946.885
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -16510.430	Tol1: 0.08004	Tol2: 0.27376
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -15908.041	Tol1: 0.03649	Tol2: 0.10706
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002383 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -23926.267
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -22889.449	Tol1: 0.04333	Tol2: 0.44412	Tol3: 0.04834
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -22163.712	Tol1: 0.03171	Tol2: 0.24970	Tol3: 0.02710
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001228 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24438, 5, 3)
# Iter 1/3
# M step:M step en 1.133204 sec
#  done,  E step:E step en 0.159785 sec
#  done //  (in 1.30 sec)	logL: -20337.474
# Iter 2/3
# M step:M step en 0.224134 sec
#  done,  E step:E step en 0.047280 sec
#  done //  (in 0.27 sec)	logL: -19169.422	Tol1: 0.05743	Tol2: 0.18846
# Iter 3/3
# M step:M step en 0.216498 sec
#  done,  E step:E step en 0.046783 sec
#  done //  (in 0.26 sec)	logL: -18261.699	Tol1: 0.04735	Tol2: 0.16635
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001436 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24438, 5, 3)
# Iter 1/3
# M step:M step en 0.585763 sec
#  done,  E step:E step en 0.101723 sec
#  done //  (in 0.69 sec)	logL: -20755.648
# Iter 2/3
# M step:M step en 0.089622 sec
#  done,  E step:E step en 0.043528 sec
#  done //  (in 0.13 sec)	logL: -19923.643	Tol1: 0.04009	Tol2: 0.12494
# Iter 3/3
# M step:M step en 0.099964 sec
#  done,  E step:E step en 0.069863 sec
#  done //  (in 0.17 sec)	logL: -19079.349	Tol1: 0.04238	Tol2: 0.13585
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001467 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24438, 5, 3)
# Iter 1/3
# M step:M step en 1.022571 sec
#  done,  E step:E step en 0.151952 sec
#  done //  (in 1.18 sec)	logL: -23699.391
# Iter 2/3
# M step:M step en 0.205705 sec
#  done,  E step:E step en 0.043311 sec
#  done //  (in 0.25 sec)	logL: -21750.128	Tol1: 0.08225	Tol2: 45.05263
# Iter 3/3
# M step:M step en 0.191772 sec
#  done,  E step:E step en 0.049913 sec
#  done //  (in 0.24 sec)	logL: -20808.324	Tol1: 0.04330	Tol2: 0.08670
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 115us/step - loss: 0.9888
# Epoch 2/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9257
# Epoch 3/3
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.8864
# Representation for DS in 0.059813 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18029.405630354428
# 2 	 -16817.73320489425 	0.4034	0.263132	0.067205
# 3 	 -16516.11136269457 	0.0956	0.197139	0.017935
# 4 	 -16430.039187712784 	0.0469	0.134834	0.005211
# Class marginals
# [0.38 0.33 0.28]
# Estimation for DS in 1.189416 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.57 sec)	logL: -19840.771
# Iter 2/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18026.316	Tol1: 0.09145	Tol2: 0.12843
# Iter 3/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17170.211	Tol1: 0.04749	Tol2: 0.06591
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002077 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -24239.624
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23464.115	Tol1: 0.03199	Tol2: 0.42118	Tol3: 0.04008
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -22831.986	Tol1: 0.02694	Tol2: 0.22632	Tol3: 0.01733
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001390 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24589, 5, 3)
# Iter 1/3
# M step:M step en 1.143348 sec
#  done,  E step:E step en 0.187616 sec
#  done //  (in 1.33 sec)	logL: -21060.715
# Iter 2/3
# M step:M step en 0.310439 sec
#  done,  E step:E step en 0.102497 sec
#  done //  (in 0.41 sec)	logL: -19973.203	Tol1: 0.05164	Tol2: 0.22215
# Iter 3/3
# M step:M step en 0.324056 sec
#  done,  E step:E step en 0.112104 sec
#  done //  (in 0.44 sec)	logL: -19103.499	Tol1: 0.04354	Tol2: 0.20958
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001657 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24589, 5, 3)
# Iter 1/3
# M step:M step en 0.736696 sec
#  done,  E step:E step en 0.080022 sec
#  done //  (in 0.82 sec)	logL: -20022.149
# Iter 2/3
# M step:M step en 0.296824 sec
#  done,  E step:E step en 0.043621 sec
#  done //  (in 0.34 sec)	logL: -18960.606	Tol1: 0.05302	Tol2: 0.19266
# Iter 3/3
# M step:M step en 0.279924 sec
#  done,  E step:E step en 0.037954 sec
#  done //  (in 0.32 sec)	logL: -18033.735	Tol1: 0.04888	Tol2: 0.19811
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001382 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24589, 5, 3)
# Iter 1/3
# M step:M step en 1.048041 sec
#  done,  E step:E step en 0.119879 sec
#  done //  (in 1.17 sec)	logL: -20569.858
# Iter 2/3
# M step:M step en 0.209000 sec
#  done,  E step:E step en 0.114561 sec
#  done //  (in 0.33 sec)	logL: -19526.054	Tol1: 0.05074	Tol2: 0.23525
# Iter 3/3
# M step:M step en 0.244788 sec
#  done,  E step:E step en 0.060016 sec
#  done //  (in 0.31 sec)	logL: -18724.084	Tol1: 0.04107	Tol2: 0.20097
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 96us/step - loss: 1.0671
# Epoch 2/3
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9811
# Epoch 3/3
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9266
# Representation for DS in 0.080418 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15789.443923029807
# 2 	 -13473.194666031699 	0.3645	0.346839	0.146696
# 3 	 -13001.55657814152 	0.0406	0.280886	0.035006
# 4 	 -12856.038950256849 	0.0192	1408.729614	0.011192
# Class marginals
# [0.37 0.31 0.32]
# Estimation for DS in 7.242859 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.58 sec)	logL: -19996.758
# Iter 2/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -18407.242	Tol1: 0.07949	Tol2: 0.12987
# Iter 3/3
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17748.906	Tol1: 0.03577	Tol2: 0.05331
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002063 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -27309.391
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -25715.186	Tol1: 0.05838	Tol2: 0.43965	Tol3: 0.11593
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -25054.960	Tol1: 0.02567	Tol2: 0.20239	Tol3: 0.02586
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001465 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24677, 5, 3)
# Iter 1/3
# M step:M step en 1.138774 sec
#  done,  E step:E step en 0.190539 sec
#  done //  (in 1.33 sec)	logL: -21025.651
# Iter 2/3
# M step:M step en 0.311340 sec
#  done,  E step:E step en 0.147883 sec
#  done //  (in 0.46 sec)	logL: -19980.729	Tol1: 0.04970	Tol2: 0.20510
# Iter 3/3
# M step:M step en 0.393020 sec
#  done,  E step:E step en 0.159367 sec
#  done //  (in 0.56 sec)	logL: -19136.310	Tol1: 0.04226	Tol2: 0.19946
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001628 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24677, 5, 3)
# Iter 1/3
# M step:M step en 0.821496 sec
#  done,  E step:E step en 0.073394 sec
#  done //  (in 0.90 sec)	logL: -20523.964
# Iter 2/3
# M step:M step en 0.278256 sec
#  done,  E step:E step en 0.037080 sec
#  done //  (in 0.32 sec)	logL: -19596.794	Tol1: 0.04518	Tol2: 0.17100
# Iter 3/3
# M step:M step en 0.270557 sec
#  done,  E step:E step en 0.037426 sec
#  done //  (in 0.31 sec)	logL: -18680.916	Tol1: 0.04674	Tol2: 0.18102
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001413 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24677, 5, 3)
# Iter 1/3
# M step:M step en 1.116505 sec
#  done,  E step:E step en 0.130753 sec
#  done //  (in 1.25 sec)	logL: -20103.349
# Iter 2/3
# M step:M step en 0.214335 sec
#  done,  E step:E step en 0.049245 sec
#  done //  (in 0.26 sec)	logL: -18957.458	Tol1: 0.05700	Tol2: 0.25494
# Iter 3/3
# M step:M step en 0.228750 sec
#  done,  E step:E step en 0.073485 sec
#  done //  (in 0.30 sec)	logL: -18175.758	Tol1: 0.04123	Tol2: 0.21033
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 97us/step - loss: 0.9869
# Epoch 2/3
# 2457/2457 [==============================] - 0s 34us/step - loss: 0.9264
# Epoch 3/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.8908
# Representation for DS in 0.085039 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15877.497925191592
# 2 	 -13558.087518894004 	0.3454	0.347723	0.146082
# 3 	 -13079.487924697043 	0.0385	370.651489	0.035300
# 4 	 -12937.821386383517 	0.0165	1296.461182	0.010831
# Class marginals
# [0.38 0.3  0.31]
# Estimation for DS in 8.182416 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.58 sec)	logL: -20201.652
# Iter 2/3
# M step: done,  E step: done //  (in 0.12 sec)	logL: -18536.980	Tol1: 0.08240	Tol2: 0.12472
# Iter 3/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17773.277	Tol1: 0.04120	Tol2: 0.05857
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002142 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -25236.078
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24116.044	Tol1: 0.04438	Tol2: 0.41978	Tol3: 0.06693
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23413.068	Tol1: 0.02915	Tol2: 0.20889	Tol3: 0.01212
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# ...
# Representation for DS in 0.278919 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3950.6040922178922
# 2 	 -3179.0711143423882 	0.1310	0.077378	0.195295
# 3 	 -2857.742913611728 	0.0945	1201.491211	0.101076
# 4 	 -2712.4596424913475 	0.0357	28074.166016	0.050838
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 56.284983 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.24 sec)	logL: -20576.559
# Iter 2/3
# M step: done,  E step: done //  (in 0.44 sec)	logL: -19582.193	Tol1: 0.04833	Tol2: 0.03809
# Iter 3/3
# M step: done,  E step: done //  (in 0.45 sec)	logL: -18798.166	Tol1: 0.04004	Tol2: 0.02574
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002068 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -24907.225
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23883.090	Tol1: 0.04112	Tol2: 0.41700	Tol3: 0.05452
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23184.484	Tol1: 0.02925	Tol2: 0.20456	Tol3: 0.01702
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001591 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24415, 5, 3)
# Iter 1/3
# M step:M step en 1.525927 sec
#  done,  E step:E step en 1.549814 sec
#  done //  (in 3.08 sec)	logL: -18539.053
# Iter 2/3
# M step:M step en 0.731628 sec
#  done,  E step:E step en 1.443307 sec
#  done //  (in 2.18 sec)	logL: -17428.394	Tol1: 0.05991	Tol2: 0.26044
# Iter 3/3
# M step:M step en 0.732790 sec
#  done,  E step:E step en 1.052408 sec
#  done //  (in 1.79 sec)	logL: -16475.310	Tol1: 0.05469	Tol2: 0.24956
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001838 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24415, 5, 3)
# Iter 1/3
# M step:M step en 2.352464 sec
#  done,  E step:E step en 0.076580 sec
#  done //  (in 2.43 sec)	logL: -12510.785
# Iter 2/3
# M step:M step en 1.831994 sec
#  done,  E step:E step en 0.043069 sec
#  done //  (in 1.88 sec)	logL: -11967.441	Tol1: 0.04343	Tol2: 0.16406
# Iter 3/3
# M step:M step en 1.825896 sec
#  done,  E step:E step en 0.039336 sec
#  done //  (in 1.87 sec)	logL: -11587.486	Tol1: 0.03175	Tol2: 0.13268
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001632 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24415, 5, 3)
# Iter 1/3
# M step:M step en 0.970947 sec
#  done,  E step:E step en 0.147111 sec
#  done //  (in 1.12 sec)	logL: -10876.894
# Iter 2/3
# M step:M step en 0.187481 sec
#  done,  E step:E step en 0.112526 sec
#  done //  (in 0.30 sec)	logL: -8212.901	Tol1: 0.24492	Tol2: 0.52122
# Iter 3/3
# M step:M step en 0.195801 sec
#  done,  E step:E step en 0.123281 sec
#  done //  (in 0.32 sec)	logL: -7378.714	Tol1: 0.10157	Tol2: 0.38448
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 93us/step - loss: 1.1490
# Epoch 2/3
# 2457/2457 [==============================] - 0s 27us/step - loss: 1.0413
# Epoch 3/3
# 2457/2457 [==============================] - 0s 29us/step - loss: 0.9683
# Representation for DS in 0.310314 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3973.959376560162
# 2 	 -3199.47502674118 	0.1356	0.077568	0.194890
# 3 	 -2863.21988012222 	0.0892	243.295425	0.105097
# 4 	 -2724.574182098389 	0.0301	34422.414062	0.048423
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 55.465924 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.30 sec)	logL: -20707.781
# Iter 2/3
# M step: done,  E step: done //  (in 0.52 sec)	logL: -19805.301	Tol1: 0.04358	Tol2: 0.03435
# Iter 3/3
# M step: done,  E step: done //  (in 0.46 sec)	logL: -19030.801	Tol1: 0.03911	Tol2: 0.02507
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002055 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -24878.922
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23873.239	Tol1: 0.04042	Tol2: 0.38415	Tol3: 0.05225
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23184.007	Tol1: 0.02887	Tol2: 0.18427	Tol3: 0.01776
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.002555 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24495, 5, 3)
# Iter 1/3
# M step:M step en 1.634590 sec
#  done,  E step:E step en 1.566095 sec
#  done //  (in 3.20 sec)	logL: -19887.244
# Iter 2/3
# M step:M step en 0.724728 sec
#  done,  E step:E step en 1.470053 sec
#  done //  (in 2.20 sec)	logL: -18893.772	Tol1: 0.04996	Tol2: 0.20728
# Iter 3/3
# M step:M step en 0.708025 sec
#  done,  E step:E step en 1.443300 sec
#  done //  (in 2.15 sec)	logL: -18111.706	Tol1: 0.04139	Tol2: 0.20387
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.002916 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24495, 5, 3)
# Iter 1/3
# M step:M step en 2.529855 sec
#  done,  E step:E step en 0.074593 sec
#  done //  (in 2.61 sec)	logL: -14675.642
# Iter 2/3
# M step:M step en 1.852810 sec
#  done,  E step:E step en 0.042090 sec
#  done //  (in 1.90 sec)	logL: -14016.629	Tol1: 0.04491	Tol2: 0.19689
# Iter 3/3
# M step:M step en 1.817509 sec
#  done,  E step:E step en 0.038858 sec
#  done //  (in 1.86 sec)	logL: -13626.365	Tol1: 0.02784	Tol2: 0.11346
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.002545 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24495, 5, 3)
# Iter 1/3
# M step:M step en 1.142465 sec
#  done,  E step:E step en 0.176590 sec
#  done //  (in 1.32 sec)	logL: -12480.472
# Iter 2/3
# M step:M step en 0.215396 sec
#  done,  E step:E step en 0.114075 sec
#  done //  (in 0.33 sec)	logL: -9451.788	Tol1: 0.24267	Tol2: 0.47703
# Iter 3/3
# M step:M step en 0.224630 sec
#  done,  E step:E step en 0.094403 sec
#  done //  (in 0.32 sec)	logL: -8036.802	Tol1: 0.14971	Tol2: 0.38406
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 78us/step - loss: 1.0867
# Epoch 2/3
# 2457/2457 [==============================] - 0s 20us/step - loss: 1.0005
# Epoch 3/3
# 2457/2457 [==============================] - 0s 20us/step - loss: 0.9380
# Representation for DS in 0.401824 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3935.883991554196
# 2 	 -3174.6651390173047 	0.1217	0.080310	0.193405
# 3 	 -2843.245665159248 	0.0924	445.966675	0.104395
# 4 	 -2692.033688069623 	0.0348	30870.990234	0.053183
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 55.216226 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.24 sec)	logL: -20790.588
# Iter 2/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -19956.016	Tol1: 0.04014	Tol2: 0.03234
# Iter 3/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -19192.441	Tol1: 0.03826	Tol2: 0.02473
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002044 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.50 sec)	logL: -24710.910
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -23731.291	Tol1: 0.03964	Tol2: 0.45871	Tol3: 0.03407
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -23076.932	Tol1: 0.02757	Tol2: 0.20312	Tol3: 0.01873
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001594 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24540, 5, 3)
# Iter 1/3
# M step:M step en 1.662676 sec
#  done,  E step:E step en 1.318120 sec
#  done //  (in 2.98 sec)	logL: -21274.242
# Iter 2/3
# M step:M step en 0.725193 sec
#  done,  E step:E step en 1.410538 sec
#  done //  (in 2.14 sec)	logL: -20583.128	Tol1: 0.03249	Tol2: 0.16601
# Iter 3/3
# M step:M step en 0.749780 sec
#  done,  E step:E step en 1.096162 sec
#  done //  (in 1.85 sec)	logL: -19924.048	Tol1: 0.03202	Tol2: 0.17426
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001845 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24540, 5, 3)
# Iter 1/3
# M step:M step en 2.339487 sec
#  done,  E step:E step en 0.073842 sec
#  done //  (in 2.41 sec)	logL: -11997.903
# Iter 2/3
# M step:M step en 1.864217 sec
#  done,  E step:E step en 0.044361 sec
#  done //  (in 1.91 sec)	logL: -11332.710	Tol1: 0.05544	Tol2: 0.21787
# Iter 3/3
# M step:M step en 1.887389 sec
#  done,  E step:E step en 0.038153 sec
#  done //  (in 1.93 sec)	logL: -10905.517	Tol1: 0.03770	Tol2: 0.17383
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001637 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24540, 5, 3)
# Iter 1/3
# M step:M step en 1.112340 sec
#  done,  E step:E step en 0.165169 sec
#  done //  (in 1.28 sec)	logL: -10927.992
# Iter 2/3
# M step:M step en 0.220510 sec
#  done,  E step:E step en 0.123157 sec
#  done //  (in 0.35 sec)	logL: -8793.523	Tol1: 0.19532	Tol2: 0.47061
# Iter 3/3
# M step:M step en 0.214226 sec
#  done,  E step:E step en 0.103968 sec
#  done //  (in 0.32 sec)	logL: -7919.445	Tol1: 0.09940	Tol2: 0.34654
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 95us/step - loss: 1.0458
# Epoch 2/3
# 2457/2457 [==============================] - 0s 29us/step - loss: 0.9689
# Epoch 3/3
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9172
# Representation for DS in 0.385813 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3934.0579573476134
# 2 	 -3153.799330665078 	0.1389	0.078885	0.198334
# 3 	 -2815.9479228487403 	0.1012	926.615662	0.107125
# 4 	 -2675.3358088782666 	0.0372	34621.464844	0.049934
# Class marginals
# [0.38 0.27 0.35]
# Estimation for DS in 55.994477 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.25 sec)	logL: -20973.316
# Iter 2/3
# M step: done,  E step: done //  (in 0.45 sec)	logL: -20153.988	Tol1: 0.03907	Tol2: 0.03236
# Iter 3/3
# M step: done,  E step: done //  (in 0.45 sec)	logL: -19449.291	Tol1: 0.03497	Tol2: 0.02360
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# Doing clustering...Done!
# Get init alphas in 0.002035 mins
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -25326.270
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23968.196	Tol1: 0.05362	Tol2: 0.49721	Tol3: 0.06366
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23212.087	Tol1: 0.03155	Tol2: 0.20417	Tol3: 0.02829
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001613 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24617, 5, 3)
# Iter 1/3
# M step:M step en 1.552341 sec
#  done,  E step:E step en 1.820242 sec
#  done //  (in 3.37 sec)	logL: -22634.511
# Iter 2/3
# M step:M step en 0.818080 sec
#  done,  E step:E step en 1.580122 sec
#  done //  (in 2.40 sec)	logL: -21865.324	Tol1: 0.03398	Tol2: 0.20786
# Iter 3/3
# M step:M step en 0.765953 sec
#  done,  E step:E step en 1.059571 sec
#  done //  (in 1.83 sec)	logL: -21148.742	Tol1: 0.03277	Tol2: 0.19573
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001685 mins
# Pre-train networks over *z* and over *g* on 1 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24617, 5, 3)
# Iter 1/3
# M step:M step en 2.415151 sec
#  done,  E step:E step en 0.082812 sec
#  done //  (in 2.50 sec)	logL: -13117.826
# Iter 2/3
# M step:M step en 1.935024 sec
#  done,  E step:E step en 0.039224 sec
#  done //  (in 1.98 sec)	logL: -12569.390	Tol1: 0.04181	Tol2: 0.17687
# Iter 3/3
# M step:M step en 1.952124 sec
#  done,  E step:E step en 0.043422 sec
#  done //  (in 2.00 sec)	logL: -12215.838	Tol1: 0.02813	Tol2: 0.14298
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Lambda by group:  [1. 1. 1. 1. 1.]
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001619 mins
# Pre-train networks over *z* and over *g* on 15 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24617, 5, 3)
# Iter 1/3
# M step:M step en 1.056436 sec
#  done,  E step:E step en 0.151376 sec
#  done //  (in 1.21 sec)	logL: -10838.243
# Iter 2/3
# M step:M step en 0.183583 sec
#  done,  E step:E step en 0.125459 sec
#  done //  (in 0.31 sec)	logL: -8133.553	Tol1: 0.24955	Tol2: 0.50864
# Iter 3/3
# M step:M step en 0.204354 sec
#  done,  E step:E step en 0.087518 sec
#  done //  (in 0.29 sec)	logL: -7272.832	Tol1: 0.10582	Tol2: 0.37131
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 87us/step - loss: 1.2587
# Epoch 2/3
# 2457/2457 [==============================] - 0s 23us/step - loss: 1.1206
# Epoch 3/3
# 2457/2457 [==============================] - 0s 24us/step - loss: 1.0414
# Representation for DS in 0.222813 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3973.6880463494413
# 2 	 -3189.6904906423133 	0.1445	0.076135	0.197297
# 3 	 -2854.4025132192996 	0.0945	160.721268	0.105116
# 4 	 -2704.9067008740103 	0.0340	34909.867188	0.052374
# Class marginals
# [0.38 0.27 0.35]
# Estimation for DS in 56.271269 sec
# Done

# %%
import pandas as pd
df = pd.DataFrame({"Raykar exec": raykar_exec, "Raykar init": raykar_init, "Our exec": ourglobal_exec,
                  "Our init": ourglobal_init, "MV exec": mv_exec, "DS exec": ds_exec, 
                   "Our Indiv1 exec" : ourindiv1_exec,  "Our Indiv1 init" : ourindiv1_init,
                  "Our Indiv2 exec" : ourindiv2_exec,  "Our Indiv2 init" : ourindiv2_init,
                  "Our Indiv3 exec" : ourindiv3_exec,  "Our Indiv3 init" : ourindiv3_init,})
df.to_csv("time_comparison_plus.csv",index=False)
df.head()
# Out:
#     DS exec   MV exec  Our Indiv1 exec  Our Indiv1 init  Our Indiv2 exec  \
# 0  0.131501  0.068240         0.295761         3.566552         0.144277
# 1  1.061336  0.065058         0.462007         4.732461         0.312182
# 2  2.145961  0.071563         0.739320         5.800849         0.606844
# 3  3.832257  0.069230         1.085166         7.760564         1.037356
# 4  4.998328  0.070282         1.425617         8.546283         1.301346
#
#    Our Indiv2 init  Our Indiv3 exec  Our Indiv3 init  Our exec  Our init  \
# 0         1.007254         0.265527         3.270630  0.068053  0.146089
# 1         0.943943         0.266526         3.249624  0.066924  0.136033
# 2         1.026803         0.279378         3.190988  0.066043  0.145369
# 3         1.045055         0.295901         3.262086  0.068581  0.131737
# 4         1.071177         0.297749         3.443405  0.073685  0.148885
#
#    Raykar exec  Raykar init
# 0     0.061153     0.005502
# 1     0.102139     0.094507
# 2     0.168260     0.231528
# 3     0.263229     0.426500
# 4     0.349428     0.564266

# %%
import pandas as pd
aux = pd.read_csv("time_comparison_plus.csv")
raykar_exec = aux["Raykar exec"]
raykar_init = aux["Raykar init"]
ourglobal_exec = aux["Our exec"]
ourglobal_init = aux["Our init"]
mv_exec = aux["MV exec"]
ds_exec = aux["DS exec"]
ourindiv1_exec = aux["Our Indiv1 exec"]
ourindiv1_init = aux["Our Indiv1 init"]
ourindiv2_exec = aux["Our Indiv2 exec"]
ourindiv2_init = aux["Our Indiv2 init"]
ourindiv3_exec = aux["Our Indiv3 exec"]
ourindiv3_init = aux["Our Indiv3 init"]

# %% [markdown]
# ### Comparison between Ours Global (CMM) and Raykar

# %%
plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
#plt.plot(to_check,mv_exec,'cs-',label="MV iter exec", markersize=ms)
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
#plt.legend()
plt.show()

plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
plt.plot(to_check,mv_exec,'cs-',label="MV iter exec", markersize=ms)
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Comparison between Alls -- Ours Global (CMM), Ours Individual and Raykar

# %%
plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
plt.plot(to_check,mv_exec,'cs-',label="MV iter exec", markersize=ms)
plt.plot(to_check,ds_exec,'v-',label="DS inference iter exec", color='orange', markersize=ms)

plt.plot(to_check,ourindiv1_exec,'X-',label="Ours-Indiv (model-T) iter exec", color='purple', markersize=ms)
plt.plot(to_check,ourindiv2_exec,'X-',label="Ours-Indiv (param-T) iter exec", color='magenta',markersize=ms)
plt.plot(to_check,ourindiv3_exec,'X-',label="Ours-Indiv (model-K) iter exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()


plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)

plt.plot(to_check,ourindiv1_exec,'X-',label="Ours-Indiv (model-T) iter exec", color='purple', markersize=ms)
plt.plot(to_check,ourindiv2_exec,'X-',label="Ours-Indiv (param-T) iter exec", color='magenta',markersize=ms)
plt.plot(to_check,ourindiv3_exec,'X-',label="Ours-Indiv (model-K) iter exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()

plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
plt.plot(to_check,ourindiv3_exec,'X-',label="Ours-Indiv (model-K) iter exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
#plt.legend()
plt.show()
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Initiation time Comparison

# %% [markdown]
# > Revisar.. mejorar...

# %%
plt.figure(figsize=(10,7))
plt.plot(to_check,raykar_init,'bo-',label="Raykar init exec", markersize=ms)
plt.plot(to_check,ourglobal_init,'g*-',label="Our-Global init exec", markersize=ms)
plt.plot(to_check,ourindiv1_init,'X-',label="Ours-Indiv (model-T) init exec", color='purple', markersize=ms)
plt.plot(to_check,ourindiv2_init,'X-',label="Ours-Indiv (param-T) init exec", color='magenta', markersize=ms)
plt.plot(to_check,ourindiv3_init,'X-',label="Ours-Indiv (model-K) init exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()

plt.figure(figsize=(10,7))
plt.plot(to_check,raykar_init,'bo-',label="Raykar init exec", markersize=ms)
plt.plot(to_check,ourglobal_init,'g*-',label="Our-Global init exec", markersize=ms)
plt.plot(to_check,ourindiv2_init,'X-',label="Ours-Indiv (param-T) init exec", color='magenta', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# falta por el numero de iteraciones (El nuestro tiene mas)
R_iter = 15
Our_iter = 25
Our_iter2 = 20

plt.figure(figsize=(10,7))
plt.plot(to_check,raykar_init+raykar_exec*R_iter,'bo-',label="Raykar to conv", markersize=ms)
plt.plot(to_check,ourglobal_init+ourglobal_exec*Our_iter,'g*-',label="Our-Global to conv + groups", markersize=ms) 

plt.plot(to_check,ourindiv1_init+ourindiv1_exec*Our_iter2,'X-',label="Ours-Indiv (model-T) init exec", color='purple', markersize=ms)
plt.plot(to_check,ourindiv2_init+ourindiv2_exec*Our_iter2,'X-',label="Ours-Indiv (param-T) init exec", color='magenta', markersize=ms)
plt.plot(to_check,ourindiv3_init+ourindiv3_exec*Our_iter2,'X-',label="Ours-Indiv (model-K) init exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# falta por el numero de iteraciones (El nuestro tiene mas)
R_iter = 40
Our_iter = 40

plt.figure(figsize=(8,5))
plt.plot(to_check,raykar_init+raykar_exec*R_iter,'o-',label="Raykar init exec")
plt.plot(to_check,ourglobal_init+0.0021*60+ourglobal_exec*Our_iter,'o-',label="Our-Global init exec + groups")
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()

# %% [markdown]
# ### Future comparison
# ---

# %%
to_check = [100,500,2000,5000,10000,15000]
print("Simple Data")
N = 2500

T_data_test = np.arange(1,15,2)

plt.figure(figsize=(15,5))
for T_data in T_data_test:
    #fixint T_data
    D_t = [N*T_data/T for T in to_check]
    plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()

print("CIFAR Data")
N = 50000

T_data_test = np.arange(1,15,2)

plt.figure(figsize=(15,5))
for T_data in T_data_test:
    #fixint T_data
    D_t = [N*T_data/T for T in to_check]
    plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# Simple Data
# CIFAR Data

# %%
to_check = [100,500,1500,3500,6000,10000]
print("Simple Data")
N = 2500

plt.figure(figsize=(15,5))
T_data = 5 #5 para llegar solo a 10k o 10 para llegar a 15k
D_t = [N*T_data/T for T in to_check]
plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.ylim(0,20)

plt.show()

print("CIFAR Data")
N = 50000
T_data = 3 #para poder ver sparness factor mas bajos..
plt.figure(figsize=(15,5))
D_t = [N*T_data/T for T in to_check]
plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.ylim(0,100)
plt.show()
# Out:
# Simple Data
# CIFAR Data

# %%
np.linspace(100,10000,6)
# Out:
# array([  100.,  2080.,  4060.,  6040.,  8020., 10000.])

# %%
to_check = [25,100,500,2000,5000,10000]

# %%
N = Z_train.shape[0]
#fixing T_d
T_data = 5
print("T_d=",T_data)
D_t = np.asarray([N*T_data/T for T in to_check])

annot_acc = []
for Tmax in to_check:
    aux = []
    for _ in range(10):
        y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False,hard=True)
        aux.append(np.mean(GenerateData.yo_label == Z_train))
    annot_acc.append(np.mean(aux))
    
plt.figure(figsize=(8,5))
plt.plot(to_check,D_t/N,'o-',label="Sparseness factor")
plt.plot(to_check,annot_acc,'o-',label="Acc annotators")
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# T_d= 5
