# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras, time, sys, os, gc
from code.generate_data import SinteticData
from code.representation import *
from code.utils import *
from code.learning_models import *
from code.baseline import RaykarMC,LabelInference
from code.MixtureofGroups import GroupMixtureGlo, GroupMixtureInd

import matplotlib
font = {'family' : 'normal',
        'size'   : 15}
matplotlib.rc('font', **font)

matplotlib.rc('axes', titlesize=25)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=25)    # fontsize of the x and y labels
#plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
#plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
ms = 10 #markersize

to_check = [100,2000,5000,10000,15000,25000,40000]
to_check
# Out:
# [100, 2000, 5000, 10000, 15000, 25000, 40000]

# %%
memory_cons = []
N = 50000
K = 10
T_i = 5
for t in to_check:
    print(t)
    a = np.zeros((N,t,K),dtype='float32') #int8
    memory_cons.append(a.nbytes/(1024*1024)) #MB
    del a
    gc.collect()

ours_consume = np.zeros((N,K),dtype='float32').nbytes/(1024*1024) #global
ours_consume2 = np.zeros((N,T_i,K),dtype='float32').nbytes/(1024*1024) #global

print("CIFAR example 50k exaples, 10 classes -- memory consume of representation")

plt.figure(figsize=(15,7))
plt.plot(to_check,memory_cons,'bo-',label="Individual consume", markersize=ms)
plt.plot(to_check,np.tile(ours_consume,len(to_check)),'g*-',label="Global consume", markersize=ms)
plt.plot(to_check,np.tile(ours_consume2,len(to_check)),'mD-',label="Individual-identity consume", markersize=ms)

#plt.hlines(16000,0,to_check[-1], color='r', label="Our memory limit")

plt.xticks(to_check)
plt.ylabel("MB")
plt.xlabel("Annotators (T)")
#plt.legend()
plt.show()
# Out:
# 100
# 2000
# 5000
# 10000
# 15000
# 25000
# 40000
# CIFAR example 50k exaples, 10 classes
# /home/casapanshop/anaconda2/envs/py3/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
folder = "."
X_train = np.loadtxt(folder+"/synthetic/simple/datasim_X_train.csv",delimiter=',')
Z_train = np.loadtxt(folder+"/synthetic/simple/datasim_Z_train.csv",dtype='int') #groudn truth

X_test = np.loadtxt(folder+"/synthetic/simple/datasim_X_test.csv",delimiter=',')
Z_test = np.loadtxt(folder+"/synthetic/simple/datasim_Z_test.csv",dtype='int') #groudn truth
N = Z_train.shape[0]
GenerateData = SinteticData(state=None)

#CONFUSION MATRIX CHOOSE
GenerateData.set_probas(asfile=True,file_matrix='./synthetic/simple/matrix_datasim_normal.csv',file_groups ='./synthetic/simple/groups_datasim_normal.csv')

#GenerateData.set_probas(asfile=True,file_matrix=path+'/synthetic/simple/matrix_datasim_badMV.csv',file_groups =path+'/synthetic/simple/groups_datasim_badMV.csv')

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
to_check = [100,2000,5000,10000,15000,25000,40000]
T_data = 10 

annot_acc = []
raykar_exec = []
raykar_init = []
ourglobal_exec = []
ourglobal_init = []
mv_exec = []
ds_exec = []
for Tmax in to_check:
    aux_annot_acc = []
    aux_raykar_exec = []
    aux_raykar_init = []
    aux_ourglobal_exec = []
    aux_ourglobal_init = []
    aux_mv_exec = []
    aux_ds_exec = []
    for _ in range(10):

        y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False,hard=True)

        #annot_acc.append(np.mean(GenerateData.yo_label == Z_train))

        #get representation needed for Raykar
        y_obs_categorical = set_representation(y_obs,'onehot') 

        raykarMC = RaykarMC(X_train.shape[1:],y_obs_categorical.shape[-1],Tmax,epochs=1)
        raykarMC.define_model("mlp",16,1,BatchN=False,drop=0.2)
        logL_hists,i = raykarMC.multiples_run(1,X_train,y_obs_categorical,max_iter=2)

        aux_raykar_exec.append(raykarMC.current_exectime)
        aux_raykar_init.append(raykarMC.init_exectime)

        del raykarMC
        gc.collect()
        keras.backend.clear_session()

        r_obs = set_representation(y_obs,"repeat")
        gMixture_Global = GroupMixtureOpt(X_train.shape[1:],Kl=r_obs.shape[1],M=5,epochs=1,pre_init=0) 
        gMixture_Global.define_model("mlp",16,1,BatchN=False,drop=0.2)
        gMixture_Global.lambda_random = True #with lambda random --necessary
        logL_hists,i_r = gMixture_Global.multiples_run(1,X_train,r_obs,max_iter=2,cluster=True)

        aux_ourglobal_exec.append(gMixture_Global.current_exectime)
        aux_ourglobal_init.append(gMixture_Global.init_exectime)
    
        del gMixture_Global
        gc.collect()
        keras.backend.clear_session()
        
        mv_soft = majority_voting(r_obs,repeats=True,probas=True) 
        time_callback = TimeHistory()
        model_mvsoft = MLP_Keras(X_train.shape[1:],mv_soft.shape[1],16,1,BN=False,drop=0.2)
        model_mvsoft.compile(loss='categorical_crossentropy',optimizer='adam')
        model_mvsoft.fit(X_train, mv_soft, epochs=2,batch_size=64,verbose=1,callbacks=[time_callback])
        times = time_callback.times
        aux_mv_exec.append(times[-1])
        
        #AND DS???????
        label_I = LabelInference(y_obs,1e-10, type_inf = 'ds', max_iter=3)
        ds_labels,ds_conf = label_I.DS_labels()
        aux_ds_exec.append(label_I.DS_current_exectime)
        
    raykar_exec.append(np.mean(aux_raykar_exec))
    raykar_init.append(np.mean(aux_raykar_init))
    ourglobal_exec.append(np.mean(aux_ourglobal_exec))
    ourglobal_init.append(np.mean(aux_ourglobal_init))
    mv_exec.append(np.mean(aux_mv_exec))
    ds_exec.append(np.mean(aux_ds_exec))
    
raykar_exec = np.asarray(raykar_exec)
raykar_init = np.asarray(raykar_init)
ourglobal_exec = np.asarray(ourglobal_exec)
ourglobal_init = np.asarray(ourglobal_init)
mv_exec = np.asarray(mv_exec)
ds_exec = np.asarray(ds_exec)
print("Done")
# Out:
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.74 sec)	logL: -18577.355
# Iter 2/2
# M step: done,  E step: done //  (in 0.11 sec)	logL: -16798.623	Tol1: 0.09575	Tol2: 0.27453
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003415 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.6509898  0.61469805 0.29725298 0.6307546  0.4925987 ]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.65 sec)	logL: -24047.180
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -22984.371	Tol1: 0.04420	Tol2: 0.41593	Tol3: 0.03393
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 106us/step - loss: 1.0903
# Epoch 2/2
# 2457/2457 [==============================] - 0s 24us/step - loss: 0.9953
# Representation for DS in 0.469012 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18381.20770880311
# 2 	 -17211.803934803083 	0.3560	0.269535	0.063620
# 3 	 -16956.141091920737 	0.0867	0.198721	0.014854
# 4 	 -16874.93360559513 	0.0400	0.136885	0.004789
# Class marginals
# [0.37 0.33 0.3 ]
# Estimation for DS in 1.355880 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.72 sec)	logL: -18930.215
# Iter 2/2
# M step: done,  E step: done //  (in 0.08 sec)	logL: -17210.449	Tol1: 0.09085	Tol2: 0.28687
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002254 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.32 0.95 0.91 0.49 0.64]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -25672.520
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24228.421	Tol1: 0.05625	Tol2: 0.66321	Tol3: 0.14420
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 120us/step - loss: 1.1024
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 1.0177
# Representation for DS in 0.456299 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -19044.730162934808
# 2 	 -17717.334525069204 	0.3017	0.304691	0.069699
# 3 	 -17522.29196763897 	0.0705	0.211126	0.011009
# 4 	 -17488.47216638541 	0.0211	0.141796	0.001930
# Class marginals
# [0.35 0.33 0.32]
# Estimation for DS in 1.271793 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -18159.039
# Iter 2/2
# M step: done,  E step: done //  (in 0.08 sec)	logL: -16386.930	Tol1: 0.09759	Tol2: 0.28896
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002247 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.95 0.06 0.71 0.09 0.69]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.63 sec)	logL: -24783.204
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23460.164	Tol1: 0.05338	Tol2: 0.47188	Tol3: 0.07213
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 91us/step - loss: 1.1146
# Epoch 2/2
# 2457/2457 [==============================] - 0s 25us/step - loss: 1.0176
# Representation for DS in 0.475461 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18433.08392442408
# 2 	 -17187.090095601667 	0.3188	0.284639	0.067596
# 3 	 -16927.116136267083 	0.0776	0.203404	0.015126
# 4 	 -16858.706755265965 	0.0422	0.148325	0.004041
# Class marginals
# [0.36 0.33 0.31]
# Estimation for DS in 1.270276 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.63 sec)	logL: -18139.590
# Iter 2/2
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16641.586	Tol1: 0.08258	Tol2: 0.28794
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002282 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.09 0.68 0.96 0.79 0.9 ]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.65 sec)	logL: -24990.337
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23687.285	Tol1: 0.05214	Tol2: 0.40288	Tol3: 0.10393
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 110us/step - loss: 1.1143
# Epoch 2/2
# 2457/2457 [==============================] - 0s 29us/step - loss: 1.0053
# Representation for DS in 0.473768 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18385.333180396512
# 2 	 -17136.131609552667 	0.3760	0.272209	0.067946
# 3 	 -16850.68452795755 	0.0820	0.205041	0.016658
# 4 	 -16777.278802569617 	0.0467	0.142782	0.004356
# Class marginals
# [0.37 0.33 0.29]
# Estimation for DS in 1.298274 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.68 sec)	logL: -18801.904
# Iter 2/2
# M step: done,  E step: done //  (in 0.12 sec)	logL: -17107.750	Tol1: 0.09011	Tol2: 0.28080
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002603 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.89 0.72 0.36 0.44 0.39]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.69 sec)	logL: -27329.134
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24770.933	Tol1: 0.09361	Tol2: 0.62922	Tol3: 0.20626
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 95us/step - loss: 1.1273
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 1.0275
# Representation for DS in 0.473176 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18939.90544617857
# 2 	 -17636.729989115167 	0.2774	0.306659	0.068806
# 3 	 -17437.63782422021 	0.0689	0.218122	0.011288
# 4 	 -17405.012991135056 	0.0207	0.145151	0.001871
# Class marginals
# [0.34 0.33 0.33]
# Estimation for DS in 1.384799 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.74 sec)	logL: -17999.295
# Iter 2/2
# M step: done,  E step: done //  (in 0.09 sec)	logL: -16387.729	Tol1: 0.08953	Tol2: 0.28950
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002521 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.74 0.13 0.06 0.64 0.23]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.69 sec)	logL: -25032.711
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23666.305	Tol1: 0.05458	Tol2: 0.46819	Tol3: 0.09050
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 101us/step - loss: 1.1739
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 1.0688
# Representation for DS in 0.487121 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18409.09234782668
# 2 	 -17147.451291336067 	0.3403	0.277003	0.068534
# 3 	 -16908.580849770347 	0.0689	0.201697	0.013930
# 4 	 -16852.363557610995 	0.0460	0.136644	0.003325
# Class marginals
# [0.38 0.33 0.29]
# Estimation for DS in 1.298179 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.62 sec)	logL: -18732.461
# Iter 2/2
# M step: done,  E step: done //  (in 0.08 sec)	logL: -17328.289	Tol1: 0.07496	Tol2: 0.28131
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002918 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.75 0.42 0.75 0.78 0.33]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.62 sec)	logL: -24742.537
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23845.114	Tol1: 0.03627	Tol2: 0.39997	Tol3: 0.03549
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 122us/step - loss: 1.0549
# Epoch 2/2
# 2457/2457 [==============================] - 0s 32us/step - loss: 0.9702
# Representation for DS in 0.503067 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18586.915101171373
# 2 	 -17358.05070889201 	0.3670	0.275009	0.066114
# 3 	 -17064.167087763446 	0.0967	0.210623	0.016931
# 4 	 -16985.17184973084 	0.0366	0.153748	0.004629
# Class marginals
# [0.35 0.33 0.32]
# Estimation for DS in 1.288141 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.57 sec)	logL: -18573.398
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -16939.223	Tol1: 0.08798	Tol2: 0.28395
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002262 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.3  0.74 0.31 0.74 0.64]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.63 sec)	logL: -25780.268
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -24290.885	Tol1: 0.05777	Tol2: 0.42547	Tol3: 0.07042
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 94us/step - loss: 1.1032
# Epoch 2/2
# 2457/2457 [==============================] - 0s 29us/step - loss: 1.0096
# Representation for DS in 0.491176 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18700.779259633317
# 2 	 -17342.412608199767 	0.3143	0.294036	0.072637
# 3 	 -17102.716099309244 	0.0666	0.204343	0.013821
# 4 	 -17053.04698585072 	0.0428	0.137354	0.002904
# Class marginals
# [0.36 0.34 0.3 ]
# Estimation for DS in 1.299496 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.74 sec)	logL: -18289.131
# Iter 2/2
# M step: done,  E step: done //  (in 0.10 sec)	logL: -16656.895	Tol1: 0.08925	Tol2: 0.27559
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002613 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.75 0.26 0.38 0.58 0.61]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -24273.758
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23180.122	Tol1: 0.04505	Tol2: 0.45482	Tol3: 0.05595
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 91us/step - loss: 1.0906
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 1.0261
# Representation for DS in 0.503513 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18159.893342091244
# 2 	 -16950.337139733292 	0.3584	0.272332	0.066606
# 3 	 -16683.45600717665 	0.0865	0.202281	0.015745
# 4 	 -16613.75122077537 	0.0423	0.137914	0.004178
# Class marginals
# [0.37 0.33 0.29]
# Estimation for DS in 1.450765 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.62 sec)	logL: -18265.078
# Iter 2/2
# M step: done,  E step: done //  (in 0.08 sec)	logL: -16723.223	Tol1: 0.08442	Tol2: 0.27466
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002302 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.51 0.69 0.81 0.25 0.76]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.70 sec)	logL: -24261.872
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23348.453	Tol1: 0.03765	Tol2: 0.41224	Tol3: 0.04747
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 94us/step - loss: 1.0337
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9609
# Representation for DS in 0.473831 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18516.104118826788
# 2 	 -17347.187324297967 	0.3898	0.260684	0.063130
# 3 	 -17053.247011663152 	0.1008	0.195786	0.016945
# 4 	 -16952.83281524721 	0.0379	0.152020	0.005888
# Class marginals
# [0.38 0.33 0.29]
# Estimation for DS in 1.279430 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.91 sec)	logL: -19393.293
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -17561.477	Tol1: 0.09446	Tol2: 0.14059
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002644 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.23 0.73 0.19 0.72 0.27]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.65 sec)	logL: -26776.561
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -24559.243	Tol1: 0.08281	Tol2: 0.59027	Tol3: 0.15380
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 91us/step - loss: 1.2870
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.1433
# Representation for DS in 8.085878 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15748.361632599243
# 2 	 -13397.495487229795 	0.3475	0.353310	0.149277
# 3 	 -12919.830359965756 	0.0356	0.284796	0.035653
# 4 	 -12781.893317699065 	0.0193	928.080750	0.010676
# Class marginals
# [0.37 0.3  0.32]
# Estimation for DS in 7.411208 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.88 sec)	logL: -20003.174
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -18243.172	Tol1: 0.08799	Tol2: 0.12696
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002641 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.94 0.04 0.4  0.57 0.16]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.71 sec)	logL: -28190.454
# Iter 2/2
# M step: done,  E step: done //  (in 0.16 sec)	logL: -25355.857	Tol1: 0.10055	Tol2: 0.68338	Tol3: 0.19374
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 106us/step - loss: 1.1467
# Epoch 2/2
# 2457/2457 [==============================] - 0s 29us/step - loss: 1.0439
# Representation for DS in 8.332299 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15943.764403923582
# 2 	 -13608.867739168682 	0.3542	0.348339	0.146446
# 3 	 -13159.513191173646 	0.0403	0.279670	0.033019
# 4 	 -13029.207649346798 	0.0127	1111.260620	0.009902
# Class marginals
# [0.38 0.31 0.31]
# Estimation for DS in 7.949293 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.84 sec)	logL: -19659.648
# Iter 2/2
# M step: done,  E step: done //  (in 0.12 sec)	logL: -17918.330	Tol1: 0.08857	Tol2: 0.13326
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002315 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.23 0.28 0.1  0.45 0.21]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.64 sec)	logL: -25816.206
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23492.559	Tol1: 0.09001	Tol2: 0.61870	Tol3: 0.19091
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 91us/step - loss: 1.1910
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 1.0750
# Representation for DS in 8.050637 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15798.247883283766
# 2 	 -13501.250132483096 	0.3419	0.343930	0.145396
# 3 	 -13013.88381830682 	0.0425	0.282761	0.036098
# 4 	 -12871.710235232516 	0.0177	1481.630615	0.010925
# Class marginals
# [0.37 0.31 0.33]
# Estimation for DS in 7.482275 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.87 sec)	logL: -19753.922
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -18022.551	Tol1: 0.08765	Tol2: 0.13848
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002598 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.3  0.7  0.24 0.21 0.7 ]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -26770.315
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -25125.211	Tol1: 0.06145	Tol2: 0.51429	Tol3: 0.09740
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 106us/step - loss: 1.0171
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9567
# Representation for DS in 8.215087 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15660.948750234798
# 2 	 -13345.918160264047 	0.3405	0.346049	0.147822
# 3 	 -12872.080243807599 	0.0400	370.653534	0.035504
# 4 	 -12750.796059651322 	0.0133	1852.072021	0.009422
# Class marginals
# [0.38 0.31 0.31]
# Estimation for DS in 7.893659 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.80 sec)	logL: -19859.641
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -18040.293	Tol1: 0.09161	Tol2: 0.13993
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002250 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.38 0.71 0.26 0.19 0.93]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.62 sec)	logL: -25596.349
# Iter 2/2
# M step: done,  E step: done //  (in 0.17 sec)	logL: -24109.668	Tol1: 0.05808	Tol2: 0.46745	Tol3: 0.05803
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 108us/step - loss: 1.2367
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.1274
# Representation for DS in 8.275598 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -16078.691939575898
# 2 	 -13660.47601485452 	0.3443	0.357480	0.150399
# 3 	 -13206.731039654815 	0.0354	0.286155	0.033216
# 4 	 -13094.467615817759 	0.0155	1858.286621	0.008500
# Class marginals
# [0.38 0.31 0.31]
# Estimation for DS in 7.466868 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.86 sec)	logL: -19857.051
# Iter 2/2
# M step: done,  E step: done //  (in 0.12 sec)	logL: -18361.059	Tol1: 0.07534	Tol2: 0.11573
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002238 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.85 0.94 0.12 0.43 0.71]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.68 sec)	logL: -25408.597
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23982.051	Tol1: 0.05614	Tol2: 0.44995	Tol3: 0.08902
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 96us/step - loss: 1.1491
# Epoch 2/2
# 2457/2457 [==============================] - 0s 24us/step - loss: 1.0602
# Representation for DS in 8.193109 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15540.339039518796
# 2 	 -13274.223351271567 	0.3580	0.338218	0.145822
# 3 	 -12785.64293969073 	0.0435	370.649902	0.036807
# 4 	 -12643.983691764337 	0.0237	1296.450684	0.011080
# Class marginals
# [0.37 0.31 0.32]
# Estimation for DS in 7.903665 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.85 sec)	logL: -19738.184
# Iter 2/2
# M step: done,  E step: done //  (in 0.12 sec)	logL: -17934.672	Tol1: 0.09137	Tol2: 0.14243
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002656 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.53 0.5  0.93 0.96 0.22]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.70 sec)	logL: -25641.981
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24302.764	Tol1: 0.05223	Tol2: 0.41715	Tol3: 0.10780
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 98us/step - loss: 1.0762
# Epoch 2/2
# 2457/2457 [==============================] - 0s 25us/step - loss: 0.9918
# Representation for DS in 8.299892 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15785.52140189139
# 2 	 -13484.741935977574 	0.3509	0.342822	0.145753
# 3 	 -13008.947693646654 	0.0357	0.280454	0.035284
# 4 	 -12878.411940517062 	0.0206	2963.114258	0.010034
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 7.876370 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.80 sec)	logL: -19450.986
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -17693.844	Tol1: 0.09034	Tol2: 0.13609
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002277 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.57 0.9  0.15 0.55 0.37]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.62 sec)	logL: -27115.699
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -24942.504	Tol1: 0.08015	Tol2: 0.50602	Tol3: 0.20833
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 90us/step - loss: 1.0490
# Epoch 2/2
# 2457/2457 [==============================] - 0s 24us/step - loss: 0.9875
# Representation for DS in 8.368552 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15679.634638082412
# 2 	 -13353.103633890205 	0.3358	0.349039	0.148379
# 3 	 -12900.20091600118 	0.0343	741.022400	0.033917
# 4 	 -12791.696617509906 	0.0128	3333.479004	0.008411
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 8.213616 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.82 sec)	logL: -19870.002
# Iter 2/2
# M step: done,  E step: done //  (in 0.12 sec)	logL: -18081.215	Tol1: 0.09002	Tol2: 0.13250
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002377 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.98 0.43 0.55 0.63 0.78]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.64 sec)	logL: -23598.130
# Iter 2/2
# M step: done,  E step: done //  (in 0.19 sec)	logL: -22600.592	Tol1: 0.04227	Tol2: 0.39026	Tol3: 0.04156
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 89us/step - loss: 1.1204
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.0259
# Representation for DS in 8.416953 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -16056.577926845184
# 2 	 -13718.392551662337 	0.3387	0.352632	0.145622
# 3 	 -13253.02733886179 	0.0405	1111.397095	0.033923
# 4 	 -13118.998686011215 	0.0179	740.891785	0.010113
# Class marginals
# [0.37 0.31 0.33]
# Estimation for DS in 7.791624 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.94 sec)	logL: -19515.281
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -17775.055	Tol1: 0.08917	Tol2: 0.13579
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002246 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.08 0.5  0.71 0.08 0.18]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.64 sec)	logL: -25472.116
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23777.145	Tol1: 0.06654	Tol2: 0.50542	Tol3: 0.11743
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 116us/step - loss: 1.0275
# Epoch 2/2
# 2457/2457 [==============================] - 0s 24us/step - loss: 0.9694
# Representation for DS in 8.345502 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15532.199597424262
# 2 	 -13219.769368126035 	0.3559	0.344403	0.148880
# 3 	 -12749.422169310614 	0.0429	0.282206	0.035579
# 4 	 -12620.871896803126 	0.0182	1667.389526	0.010083
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 7.932315 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.05 sec)	logL: -20091.430
# Iter 2/2
# M step: done,  E step: done //  (in 0.22 sec)	logL: -18744.139	Tol1: 0.06706	Tol2: 0.07828
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002739 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.33 0.04 0.4  0.6  0.38]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -24357.963
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -22726.851	Tol1: 0.06696	Tol2: 0.59939	Tol3: 0.13405
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 95us/step - loss: 0.9788
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9321
# Representation for DS in 20.425717 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12459.545697625646
# 2 	 -9812.875551510551 	0.3418	0.267912	0.212421
# 3 	 -9197.845397530795 	0.0336	7909.028320	0.062676
# 4 	 -9001.351639339024 	0.0170	55251.269531	0.021363
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 17.013800 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.02 sec)	logL: -20048.514
# Iter 2/2
# M step: done,  E step: done //  (in 0.19 sec)	logL: -18677.012	Tol1: 0.06841	Tol2: 0.07792
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002613 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.84 0.44 0.74 0.26 0.45]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.69 sec)	logL: -24876.099
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23466.243	Tol1: 0.05668	Tol2: 0.69760	Tol3: 0.10846
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 105us/step - loss: 1.2107
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.1017
# Representation for DS in 20.222223 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12210.33175120159
# 2 	 -9546.764854123518 	0.3364	0.265733	0.218140
# 3 	 -8948.105042078585 	0.0296	9099.130859	0.062708
# 4 	 -8772.158078532253 	0.0139	50667.378906	0.019663
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 16.828382 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.06 sec)	logL: -20197.988
# Iter 2/2
# M step: done,  E step: done //  (in 0.22 sec)	logL: -18788.088	Tol1: 0.06980	Tol2: 0.08355
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002832 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.56 0.49 0.79 0.34 0.69]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.73 sec)	logL: -26503.697
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -24781.171	Tol1: 0.06499	Tol2: 0.48374	Tol3: 0.11117
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 99us/step - loss: 1.0748
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 0.9898
# Representation for DS in 20.229615 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12510.308864137698
# 2 	 -9766.249972899006 	0.3451	0.274195	0.219344
# 3 	 -9177.13012690474 	0.0348	8473.205078	0.060322
# 4 	 -8980.707495650815 	0.0182	57512.625000	0.021403
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 16.879460 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.06 sec)	logL: -20206.355
# Iter 2/2
# M step: done,  E step: done //  (in 0.22 sec)	logL: -18849.348	Tol1: 0.06716	Tol2: 0.07738
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002306 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.55 0.66 0.32 0.47 0.47]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.70 sec)	logL: -25054.455
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23983.313	Tol1: 0.04275	Tol2: 0.42359	Tol3: 0.06222
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 89us/step - loss: 1.0142
# Epoch 2/2
# 2457/2457 [==============================] - 0s 24us/step - loss: 0.9479
# Representation for DS in 19.933414 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12286.72141304834
# 2 	 -9658.1790814531 	0.3625	0.260079	0.213934
# 3 	 -9037.680637399935 	0.0345	7450.842285	0.064246
# 4 	 -8848.014234637983 	0.0146	49145.117188	0.020986
# Class marginals
# [0.38 0.3  0.33]
# Estimation for DS in 17.089565 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.02 sec)	logL: -20315.951
# Iter 2/2
# M step: done,  E step: done //  (in 0.24 sec)	logL: -19021.143	Tol1: 0.06373	Tol2: 0.07552
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002719 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.78 0.02 0.46 0.85 0.58]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -25828.373
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24064.282	Tol1: 0.06830	Tol2: 0.69565	Tol3: 0.19942
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 97us/step - loss: 1.0434
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9709
# Representation for DS in 20.567589 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12382.27778680451
# 2 	 -9721.989857071674 	0.3563	0.270416	0.214846
# 3 	 -9143.737904635762 	0.0279	6636.672363	0.059479
# 4 	 -8975.981033700808 	0.0152	49333.890625	0.018347
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 17.363474 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.08 sec)	logL: -20319.973
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -18994.953	Tol1: 0.06521	Tol2: 0.07591
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002411 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.15 0.78 0.5  0.56 0.06]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -25869.871
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -24526.035	Tol1: 0.05195	Tol2: 0.49979	Tol3: 0.09115
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 93us/step - loss: 1.1539
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.0498
# Representation for DS in 19.893869 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12253.37127394471
# 2 	 -9576.719161235666 	0.3600	0.268843	0.218442
# 3 	 -8991.400696469982 	0.0279	6650.053711	0.061119
# 4 	 -8820.501793630952 	0.0159	43972.246094	0.019007
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 16.805225 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.98 sec)	logL: -20257.840
# Iter 2/2
# M step: done,  E step: done //  (in 0.21 sec)	logL: -18948.436	Tol1: 0.06464	Tol2: 0.07495
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002709 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.99 0.16 0.05 0.53 0.19]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.62 sec)	logL: -27047.284
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23962.425	Tol1: 0.11405	Tol2: 0.73934	Tol3: 0.25187
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 96us/step - loss: 1.1897
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.0678
# Representation for DS in 20.494905 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12432.210478040037
# 2 	 -9758.42569314873 	0.3539	0.268764	0.215069
# 3 	 -9150.774866609745 	0.0362	10462.664062	0.062269
# 4 	 -8990.644130161563 	0.0169	50490.199219	0.017499
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 17.444249 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.07 sec)	logL: -20183.113
# Iter 2/2
# M step: done,  E step: done //  (in 0.19 sec)	logL: -18815.988	Tol1: 0.06774	Tol2: 0.07886
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002293 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.31 0.3  0.28 0.76 0.35]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -26038.568
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24433.720	Tol1: 0.06163	Tol2: 0.56337	Tol3: 0.12075
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 112us/step - loss: 1.0908
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 1.0105
# Representation for DS in 20.395783 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12447.058833805828
# 2 	 -9787.467067499405 	0.3589	0.269126	0.213672
# 3 	 -9170.377320762254 	0.0333	6490.097168	0.063049
# 4 	 -8978.944844854559 	0.0176	49863.292969	0.020875
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 17.001462 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.96 sec)	logL: -20638.684
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -19297.418	Tol1: 0.06499	Tol2: 0.07497
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002735 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.14 0.14 0.9  0.11 0.82]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -24561.720
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23205.236	Tol1: 0.05523	Tol2: 0.44344	Tol3: 0.10443
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 90us/step - loss: 1.1423
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 1.0492
# Representation for DS in 20.936353 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12693.611187203765
# 2 	 -9956.80475946352 	0.3551	0.273162	0.215605
# 3 	 -9365.388409504898 	0.0273	8866.464844	0.059398
# 4 	 -9193.492523657384 	0.0114	49211.273438	0.018354
# Class marginals
# [0.38 0.29 0.33]
# Estimation for DS in 17.757499 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.02 sec)	logL: -20443.869
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -18994.070	Tol1: 0.07092	Tol2: 0.08336
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002325 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.66 0.31 0.96 0.82 0.54]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.63 sec)	logL: -25727.565
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24375.583	Tol1: 0.05255	Tol2: 0.37771	Tol3: 0.08650
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 114us/step - loss: 1.1434
# Epoch 2/2
# 2457/2457 [==============================] - 0s 30us/step - loss: 1.0528
# Representation for DS in 20.353849 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12543.771047907849
# 2 	 -9848.537317877974 	0.3633	0.270327	0.214866
# 3 	 -9261.747374214478 	0.0300	7214.278809	0.059581
# 4 	 -9097.49968876266 	0.0132	51946.078125	0.017734
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 16.975746 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.15 sec)	logL: -20622.857
# Iter 2/2
# M step: done,  E step: done //  (in 0.29 sec)	logL: -19385.660	Tol1: 0.05999	Tol2: 0.05596
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002717 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.1  0.25 0.99 0.05 0.13]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -24652.725
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23442.317	Tol1: 0.04910	Tol2: 0.40786	Tol3: 0.04033
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 102us/step - loss: 1.0159
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9426
# Representation for DS in 37.101252 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9189.546346966596
# 2 	 -6984.1553380688765 	0.3421	0.156573	0.239989
# 3 	 -6451.240128149117 	0.0419	12164.698242	0.076303
# 4 	 -6265.002904345251 	0.0149	104155.335938	0.028868
# Class marginals
# [0.39 0.29 0.32]
# Estimation for DS in 30.182457 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.14 sec)	logL: -20584.961
# Iter 2/2
# M step: done,  E step: done //  (in 0.28 sec)	logL: -19480.953	Tol1: 0.05363	Tol2: 0.05418
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002606 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.4  0.87 0.23 0.51 0.46]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -23954.554
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -22820.011	Tol1: 0.04736	Tol2: 0.42230	Tol3: 0.06871
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 112us/step - loss: 1.0447
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9827
# Representation for DS in 37.874198 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9056.637247184959
# 2 	 -6852.355610400533 	0.3427	0.155948	0.243389
# 3 	 -6276.585319383241 	0.0377	13047.648438	0.084025
# 4 	 -6057.14038623111 	0.0193	104861.484375	0.034962
# Class marginals
# [0.38 0.3  0.33]
# Estimation for DS in 29.899256 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.13 sec)	logL: -20463.045
# Iter 2/2
# M step: done,  E step: done //  (in 0.28 sec)	logL: -19355.555	Tol1: 0.05412	Tol2: 0.05223
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002598 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.63 0.54 0.2  0.44 0.97]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.65 sec)	logL: -26097.706
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -24958.356	Tol1: 0.04366	Tol2: 0.46906	Tol3: 0.06583
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 107us/step - loss: 1.1439
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 1.0701
# Representation for DS in 37.430568 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -8975.931130981775
# 2 	 -6768.867934484841 	0.3262	0.155386	0.245887
# 3 	 -6225.837598358229 	0.0399	10555.364258	0.080225
# 4 	 -6031.587242589173 	0.0148	109693.195312	0.031201
# Class marginals
# [0.38 0.3  0.33]
# Estimation for DS in 31.163000 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.13 sec)	logL: -20645.754
# Iter 2/2
# M step: done,  E step: done //  (in 0.28 sec)	logL: -19599.822	Tol1: 0.05066	Tol2: 0.05238
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002687 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.46 0.52 0.64 0.09 0.53]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -25437.372
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24107.601	Tol1: 0.05228	Tol2: 0.47638	Tol3: 0.08932
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 102us/step - loss: 1.0988
# Epoch 2/2
# 2457/2457 [==============================] - 0s 30us/step - loss: 1.0163
# Representation for DS in 38.443089 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9145.52519506656
# 2 	 -6944.499110225161 	0.3503	0.158214	0.240667
# 3 	 -6357.439048482724 	0.0420	10972.271484	0.084536
# 4 	 -6140.647327244641 	0.0179	102505.148438	0.034100
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 30.537068 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.22 sec)	logL: -20108.301
# Iter 2/2
# M step: done,  E step: done //  (in 0.32 sec)	logL: -18899.242	Tol1: 0.06013	Tol2: 0.05632
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002599 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.58 0.98 0.43 0.86 0.27]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -23142.334
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -22281.152	Tol1: 0.03721	Tol2: 0.43305	Tol3: 0.09007
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 108us/step - loss: 1.1428
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.0421
# Representation for DS in 36.528810 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -8934.980893994614
# 2 	 -6770.699467320969 	0.3476	0.150162	0.242226
# 3 	 -6223.819830532569 	0.0399	9079.234375	0.080772
# 4 	 -6031.95715989377 	0.0197	99469.726562	0.030827
# Class marginals
# [0.38 0.3  0.33]
# Estimation for DS in 30.315113 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.16 sec)	logL: -20512.648
# Iter 2/2
# M step: done,  E step: done //  (in 0.29 sec)	logL: -19348.379	Tol1: 0.05676	Tol2: 0.05540
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002952 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.22 0.57 0.23 0.66 0.81]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.70 sec)	logL: -24267.758
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23325.201	Tol1: 0.03884	Tol2: 0.41106	Tol3: 0.07955
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 101us/step - loss: 1.0653
# Epoch 2/2
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9926
# Representation for DS in 36.972133 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9270.792198931014
# 2 	 -6987.024184133902 	0.3436	0.160090	0.246340
# 3 	 -6389.1862365318375 	0.0374	11428.061523	0.085564
# 4 	 -6194.7783463516735 	0.0177	107348.687500	0.030428
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 30.524052 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.14 sec)	logL: -20436.859
# Iter 2/2
# M step: done,  E step: done //  (in 0.31 sec)	logL: -19328.471	Tol1: 0.05423	Tol2: 0.05371
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002648 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.4  0.36 0.4  0.76 0.95]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -23098.754
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -22224.701	Tol1: 0.03784	Tol2: 0.46248	Tol3: 0.05829
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 113us/step - loss: 1.1658
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.0461
# Representation for DS in 37.166070 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9074.25611616449
# ...
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -5566.330073686729
# 2 	 -4334.6159229155555 	0.2257	0.076584	0.221279
# 3 	 -3867.7075895190424 	0.0762	4383.138672	0.107716
# 4 	 -3671.878690927238 	0.0173	73083.179688	0.050632
# Class marginals
# [0.38 0.28 0.34]
# Estimation for DS in 51.368895 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (25000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.40 sec)	logL: -20663.266
# Iter 2/2
# M step: done,  E step: done //  (in 0.49 sec)	logL: -19660.766	Tol1: 0.04852	Tol2: 0.03967
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002263 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.66 0.64 0.98 0.15 0.52]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -25362.779
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23978.709	Tol1: 0.05457	Tol2: 0.41954	Tol3: 0.04565
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 96us/step - loss: 1.0488
# Epoch 2/2
# 2457/2457 [==============================] - 0s 25us/step - loss: 0.9669
# Representation for DS in 63.160087 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -5510.659867554606
# 2 	 -4275.5424553567045 	0.2464	0.080582	0.224132
# 3 	 -3833.627276194467 	0.0919	2692.111572	0.103359
# 4 	 -3659.062751511965 	0.0224	69563.335938	0.045535
# Class marginals
# [0.38 0.29 0.32]
# Estimation for DS in 50.348717 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (25000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.45 sec)	logL: -21170.387
# Iter 2/2
# M step: done,  E step: done //  (in 0.42 sec)	logL: -20304.131	Tol1: 0.04092	Tol2: 0.03663
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002934 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.77 0.55 0.81 0.03 0.38]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.58 sec)	logL: -24841.693
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23924.751	Tol1: 0.03691	Tol2: 0.41381	Tol3: 0.05381
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 100us/step - loss: 1.2272
# Epoch 2/2
# 2457/2457 [==============================] - 0s 29us/step - loss: 1.0809
# Representation for DS in 65.113127 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -5522.528636868736
# 2 	 -4303.244003163562 	0.2220	0.079201	0.220784
# 3 	 -3864.7658030578746 	0.0780	2359.552734	0.101895
# 4 	 -3692.154703164964 	0.0174	66634.742188	0.044663
# Class marginals
# [0.38 0.28 0.34]
# Estimation for DS in 50.103163 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.44 sec)	logL: -21096.861
# Iter 2/2
# M step: done,  E step: done //  (in 0.48 sec)	logL: -20250.617	Tol1: 0.04011	Tol2: 0.03565
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002709 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.65 0.8  0.6  0.61 0.27]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.64 sec)	logL: -24869.717
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23351.462	Tol1: 0.06105	Tol2: 0.40952	Tol3: 0.07981
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 103us/step - loss: 1.0689
# Epoch 2/2
# 2457/2457 [==============================] - 0s 25us/step - loss: 0.9914
# Representation for DS in 75.614541 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3969.313087163968
# 2 	 -3194.6451319389603 	0.1448	0.076354	0.195164
# 3 	 -2871.342570932143 	0.0997	927.771851	0.101201
# 4 	 -2732.5145166914695 	0.0360	32995.343750	0.048350
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 58.610887 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.58 sec)	logL: -21125.789
# Iter 2/2
# M step: done,  E step: done //  (in 0.53 sec)	logL: -20144.148	Tol1: 0.04647	Tol2: 0.03960
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003126 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.4  0.02 0.51 0.31 0.64]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.68 sec)	logL: -26315.637
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24945.312	Tol1: 0.05207	Tol2: 0.39091	Tol3: 0.06876
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 102us/step - loss: 1.2364
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 1.1042
# Representation for DS in 74.147945 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -4003.4136882368975
# 2 	 -3191.9309195189103 	0.1564	0.079463	0.202698
# 3 	 -2844.841128044801 	0.0981	1325.292725	0.108740
# 4 	 -2692.649876737354 	0.0288	35060.378906	0.053497
# Class marginals
# [0.39 0.26 0.35]
# Estimation for DS in 58.425970 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.44 sec)	logL: -20714.301
# Iter 2/2
# M step: done,  E step: done //  (in 0.50 sec)	logL: -19612.484	Tol1: 0.05319	Tol2: 0.04159
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002582 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.86 0.24 0.56 1.   0.05]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.64 sec)	logL: -26616.123
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -24206.699	Tol1: 0.09052	Tol2: 0.61598	Tol3: 0.25552
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 93us/step - loss: 1.2129
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 1.0804
# Representation for DS in 74.966448 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -4009.97611640233
# 2 	 -3222.4697234091777 	0.1409	0.078208	0.196387
# 3 	 -2874.451433021748 	0.0957	202.485748	0.107997
# 4 	 -2730.1168136910887 	0.0349	33426.675781	0.050213
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 58.905128 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.56 sec)	logL: -20885.836
# Iter 2/2
# M step: done,  E step: done //  (in 0.44 sec)	logL: -20175.590	Tol1: 0.03401	Tol2: 0.03105
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002582 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.54 0.41 0.19 0.77 0.97]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -24991.311
# Iter 2/2
# M step: done,  E step: done //  (in 0.16 sec)	logL: -23748.746	Tol1: 0.04972	Tol2: 0.40795	Tol3: 0.11115
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 94us/step - loss: 1.0643
# Epoch 2/2
# 2457/2457 [==============================] - 0s 29us/step - loss: 0.9711
# Representation for DS in 76.033422 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3876.6703690871614
# 2 	 -3120.8538788263077 	0.1263	0.078703	0.194965
# 3 	 -2798.0272013066365 	0.0978	732.026917	0.103442
# 4 	 -2654.12814034514 	0.0375	28649.603516	0.051429
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 58.687217 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.45 sec)	logL: -21123.676
# Iter 2/2
# M step: done,  E step: done //  (in 0.48 sec)	logL: -20290.832	Tol1: 0.03943	Tol2: 0.03262
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002620 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.99 0.58 0.96 1.   0.43]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.63 sec)	logL: -25273.330
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -24469.211	Tol1: 0.03182	Tol2: 0.36073	Tol3: 0.03907
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 94us/step - loss: 1.0839
# Epoch 2/2
# 2457/2457 [==============================] - 0s 25us/step - loss: 1.0064
# Representation for DS in 75.059471 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -4094.012011733738
# 2 	 -3269.0820757969664 	0.1413	0.080929	0.201497
# 3 	 -2940.3586111529694 	0.0877	560.169189	0.100555
# 4 	 -2800.3213596878927 	0.0312	33912.308594	0.047626
# Class marginals
# [0.38 0.25 0.36]
# Estimation for DS in 60.915715 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.39 sec)	logL: -21143.109
# Iter 2/2
# M step: done,  E step: done //  (in 0.48 sec)	logL: -20425.051	Tol1: 0.03396	Tol2: 0.03019
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002990 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.16 0.1  0.49 0.43 0.54]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.68 sec)	logL: -25853.016
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24038.006	Tol1: 0.07020	Tol2: 0.51604	Tol3: 0.16476
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 109us/step - loss: 1.0609
# Epoch 2/2
# 2457/2457 [==============================] - 0s 23us/step - loss: 0.9759
# Representation for DS in 75.636775 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3971.8743516362633
# 2 	 -3225.5224238021938 	0.1332	0.078993	0.187909
# 3 	 -2888.743377023799 	0.1037	763.929443	0.104411
# 4 	 -2737.108156265121 	0.0348	34213.832031	0.052492
# Class marginals
# [0.38 0.27 0.35]
# Estimation for DS in 58.105282 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.38 sec)	logL: -20537.408
# Iter 2/2
# M step: done,  E step: done //  (in 0.45 sec)	logL: -19492.678	Tol1: 0.05087	Tol2: 0.03899
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003245 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.3  0.54 0.57 0.19 0.91]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.64 sec)	logL: -25716.297
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -24305.336	Tol1: 0.05487	Tol2: 0.44536	Tol3: 0.09610
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 94us/step - loss: 0.9947
# Epoch 2/2
# 2457/2457 [==============================] - 0s 24us/step - loss: 0.9333
# Representation for DS in 75.328005 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3843.4467223231577
# 2 	 -3078.3965416040837 	0.1295	0.078682	0.199053
# 3 	 -2757.8603153976896 	0.0985	445.478302	0.104124
# 4 	 -2625.0932630615875 	0.0352	27340.964844	0.048141
# Class marginals
# [0.38 0.27 0.35]
# Estimation for DS in 59.507103 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.43 sec)	logL: -20903.764
# Iter 2/2
# M step: done,  E step: done //  (in 0.52 sec)	logL: -20065.289	Tol1: 0.04011	Tol2: 0.03434
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002529 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.2  0.2  0.64 0.74 0.43]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -24558.213
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23442.302	Tol1: 0.04544	Tol2: 0.41371	Tol3: 0.05060
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 91us/step - loss: 1.1426
# Epoch 2/2
# 2457/2457 [==============================] - 0s 25us/step - loss: 1.0372
# Representation for DS in 75.077794 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3937.7079080598887
# 2 	 -3144.122697199443 	0.1419	0.078798	0.201535
# 3 	 -2810.783377664458 	0.0945	201.308365	0.106020
# 4 	 -2660.472102037932 	0.0346	35606.003906	0.053477
# Class marginals
# [0.38 0.27 0.35]
# Estimation for DS in 58.820235 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.42 sec)	logL: -21206.344
# Iter 2/2
# M step: done,  E step: done //  (in 0.46 sec)	logL: -20493.289	Tol1: 0.03362	Tol2: 0.03095
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002531 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.18 0.59 0.05 0.72 0.71]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.63 sec)	logL: -24803.032
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -23539.356	Tol1: 0.05095	Tol2: 0.45151	Tol3: 0.06870
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 100us/step - loss: 1.0103
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 0.9403
# Representation for DS in 75.126117 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3996.2048539318444
# 2 	 -3209.6722508505973 	0.1414	0.081280	0.196820
# 3 	 -2883.5564327183674 	0.0926	1565.739136	0.101604
# 4 	 -2738.7355024080334 	0.0275	26135.343750	0.050223
# Class marginals
# [0.39 0.26 0.35]
# Estimation for DS in 60.561031 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.51 sec)	logL: -20807.742
# Iter 2/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -19925.502	Tol1: 0.04240	Tol2: 0.03548
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003396 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.94 0.1  0.13 0.75 0.84]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.69 sec)	logL: -24568.600
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23589.206	Tol1: 0.03986	Tol2: 0.40759	Tol3: 0.08745
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 106us/step - loss: 1.0564
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 0.9884
# Representation for DS in 75.831283 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3928.557034210948
# 2 	 -3169.432851441476 	0.1242	0.082215	0.193232
# 3 	 -2839.7929488048 	0.0972	121.349556	0.104006
# 4 	 -2691.84500168703 	0.0356	26684.193359	0.052098
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 57.956345 sec
# Done

# %%
import pandas as pd
df = pd.DataFrame({"Raykar exec": raykar_exec, "Raykar init": raykar_init, "Our exec": ourglobal_exec,
                  "Our init": ourglobal_init, "MV exec": mv_exec, "DS exec": ds_exec})
df.to_csv("time_comparison.csv",index=False)
df.head()
# Out:
#     DS exec   MV exec  Our exec  Our init  Raykar exec  Raykar init
# 0  0.149213  0.068083  0.144551  0.004793     0.099068     0.005901
# 1  1.079853  0.064119  0.155140  0.004566     0.129765     0.105036
# 2  2.325447  0.066128  0.145056  0.004490     0.209314     0.261032
# 3  4.215830  0.067410  0.147432  0.004879     0.294403     0.481122
# 4  5.521846  0.066169  0.142852  0.004922     0.370990     0.653070

# %%
import pandas as pd
aux = pd.read_csv("time_comparison.csv")
raykar_exec = aux["Raykar exec"]
raykar_init = aux["Raykar init"]
ourglobal_exec = aux["Our exec"]
ourglobal_init = aux["Our init"]
mv_exec = aux["MV exec"]
ds_exec = aux["DS exec"]

# %%
plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# /home/casapanshop/anaconda2/envs/py3/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
plt.plot(to_check,mv_exec,'cs-',label="MV iter exec", markersize=ms)
plt.plot(to_check,ds_exec,'v-',label="DS inference iter exec", color='orange', markersize=ms)
#plt.plot(to_check,ds_exec+mv_exec,'p-',label="DS utility iter exec", color='orange')

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# /home/casapanshop/anaconda2/envs/py3/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(10,7))
plt.plot(to_check,raykar_init,'bo-',label="Raykar init exec", markersize=ms)
plt.plot(to_check,ourglobal_init,'g*-',label="Our-Global init exec", markersize=ms)
plt.plot(to_check,ourglobal_init+0.0021*60,'m*-',label="Our-Global init exec + groups", markersize=ms) #datacenter time
#plt.plot(to_check,ourglobal_init+0.0041*60,'m*-',label="Our-Global init exec + groups", markersize=ms)# pc-casa time
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()

# %%
# falta por el numero de iteraciones (El nuestro tiene mas)
R_iter = 10
Our_iter = 25

plt.figure(figsize=(10,7))
plt.plot(to_check,raykar_init+raykar_exec*R_iter,'bo-',label="Raykar to conv", markersize=ms)
#plt.plot(to_check,ourglobal_init+ourglobal_exec*Our_iter,'o-',label="Our-Global to conv", markersize=ms)
plt.plot(to_check,ourglobal_init+0.0021*60+ourglobal_exec*Our_iter,'go-',label="Our-Global to conv + groups", markersize=ms) #datacenter
#plt.plot(to_check,ourglobal_init+0.0041*60+ourglobal_exec*Our_iter,'g*-',label="Our-Global to conv + groups", markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()

# %%
# falta por el numero de iteraciones (El nuestro tiene mas)
R_iter = 40
Our_iter = 40

plt.figure(figsize=(8,5))
plt.plot(to_check,raykar_init+raykar_exec*R_iter,'o-',label="Raykar init exec")
plt.plot(to_check,ourglobal_init+0.0021*60+ourglobal_exec*Our_iter,'o-',label="Our-Global init exec + groups")
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()

# %% [markdown]
# ### Future comparison
# ---

# %%
to_check = [100,500,2000,5000,10000,15000]
print("Simple Data")
N = 2500

T_data_test = np.arange(1,15,2)

plt.figure(figsize=(15,5))
for T_data in T_data_test:
    #fixint T_data
    D_t = [N*T_data/T for T in to_check]
    plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()

print("CIFAR Data")
N = 50000

T_data_test = np.arange(1,15,2)

plt.figure(figsize=(15,5))
for T_data in T_data_test:
    #fixint T_data
    D_t = [N*T_data/T for T in to_check]
    plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# Simple Data
# CIFAR Data

# %%
to_check = [100,500,1500,3500,6000,10000]
print("Simple Data")
N = 2500

plt.figure(figsize=(15,5))
T_data = 5 #5 para llegar solo a 10k o 10 para llegar a 15k
D_t = [N*T_data/T for T in to_check]
plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.ylim(0,20)

plt.show()

print("CIFAR Data")
N = 50000
T_data = 3 #para poder ver sparness factor mas bajos..
plt.figure(figsize=(15,5))
D_t = [N*T_data/T for T in to_check]
plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.ylim(0,100)
plt.show()
# Out:
# Simple Data
# CIFAR Data

# %%
np.linspace(100,10000,6)
# Out:
# array([  100.,  2080.,  4060.,  6040.,  8020., 10000.])

# %%
to_check = [25,100,500,2000,5000,10000]

# %%
N = Z_train.shape[0]
#fixing T_d
T_data = 5
print("T_d=",T_data)
D_t = np.asarray([N*T_data/T for T in to_check])

annot_acc = []
for Tmax in to_check:
    aux = []
    for _ in range(10):
        y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False,hard=True)
        aux.append(np.mean(GenerateData.yo_label == Z_train))
    annot_acc.append(np.mean(aux))
    
plt.figure(figsize=(8,5))
plt.plot(to_check,D_t/N,'o-',label="Sparseness factor")
plt.plot(to_check,annot_acc,'o-',label="Acc annotators")
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# T_d= 5
