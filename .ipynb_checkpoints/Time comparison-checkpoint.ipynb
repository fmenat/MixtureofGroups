# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras, time, sys, os, gc
from code.generate_data import SinteticData
from code.representation import *
from code.utils import *
from code.learning_models import *
from code.baseline import RaykarMC,LabelInference
from code.MixtureofGroups import GroupMixtureGlo, GroupMixtureInd

import matplotlib
font = {'family' : 'normal',
        'size'   : 15}
matplotlib.rc('font', **font)

matplotlib.rc('axes', titlesize=25)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=25)    # fontsize of the x and y labels
#plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
#plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
ms = 10 #markersize

to_check = [100,2000,5000,10000,15000,25000,40000]
to_check
# Out:
# Using TensorFlow backend.
# [100, 2000, 5000, 10000, 15000, 25000, 40000]

# %%
memory_cons = []
N = 50000
K = 10
T_i = 20
for t in to_check:
    print(t)
    a = np.zeros((N,t,K),dtype='float32') #int8
    memory_cons.append(a.nbytes/(1024*1024)) #MB
    del a
    gc.collect()

ours_consume = np.zeros((N,K),dtype='float32').nbytes/(1024*1024) #global
ours_consume2 = np.zeros((N,T_i,K),dtype='float32').nbytes/(1024*1024) #annotation
ours_consume2 += np.zeros((N,T_i,K),dtype='float32').nbytes/(1024*1024) #identity

print("CIFAR example 50k exaples, 10 classes -- memory consume of representation")

plt.figure(figsize=(15,7))
plt.plot(to_check,memory_cons,'bo-',label="Individual consume", markersize=ms)
plt.plot(to_check,np.tile(ours_consume,len(to_check)),'g*-',label="Global consume", markersize=ms)
plt.plot(to_check,np.tile(ours_consume2,len(to_check)),'mX-',label="Individual-identity consume", markersize=ms)

#plt.hlines(16000,0,to_check[-1], color='r', label="Our memory limit")

plt.xticks(to_check)
plt.ylabel("MB")
plt.xlabel("Annotators (T)")
plt.legend()
plt.show()
# Out:
# 100
# 2000
# 5000
# 10000
# 15000
# 25000
# 40000
# CIFAR example 50k exaples, 10 classes -- memory consume of representation
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
folder = "."
X_train = np.loadtxt(folder+"/synthetic/simple/datasim_X_train.csv",delimiter=',')
Z_train = np.loadtxt(folder+"/synthetic/simple/datasim_Z_train.csv",dtype='int') #groudn truth

X_test = np.loadtxt(folder+"/synthetic/simple/datasim_X_test.csv",delimiter=',')
Z_test = np.loadtxt(folder+"/synthetic/simple/datasim_Z_test.csv",dtype='int') #groudn truth
N = Z_train.shape[0]
GenerateData = SinteticData(state=None)

#CONFUSION MATRIX CHOOSE
GenerateData.set_probas(asfile=True,file_matrix='./synthetic/simple/matrix_datasim_normal.csv',file_groups ='./synthetic/simple/groups_datasim_normal.csv')

#GenerateData.set_probas(asfile=True,file_matrix=path+'/synthetic/simple/matrix_datasim_badMV.csv',file_groups =path+'/synthetic/simple/groups_datasim_badMV.csv')

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
to_check = [100,2000,5000,10000,15000,25000,40000]
T_data = 10 
M_seted = 5
BATCH_SIZE= 64

annot_acc = []
raykar_exec = []
raykar_init = []
ourglobal_exec = []
ourglobal_init = []
ourindiv1_exec = []
ourindiv1_init = []
ourindiv2_exec = []
ourindiv2_init = []
ourindiv3_exec = []
ourindiv3_init = []
mv_exec = []
ds_exec = []
for Tmax in to_check:
    aux_annot_acc = []
    aux_raykar_exec = []
    aux_raykar_init = []
    aux_ourglobal_exec = []
    aux_ourglobal_init = []
    aux_ourindiv1_exec = []
    aux_ourindiv1_init = []
    aux_ourindiv2_exec = []
    aux_ourindiv2_init = []
    aux_ourindiv3_exec = []
    aux_ourindiv3_init = []
    aux_mv_exec = []
    aux_ds_exec = []
    for _ in range(10):
        y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False,hard=True)
        T = y_obs.shape[1]
        #annot_acc.append(np.mean(GenerateData.yo_label == Z_train))

        #----------------------------RAYKAR---------------------------#
        y_obs_categorical = set_representation(y_obs,'onehot') 
        raykarMC = RaykarMC(X_train.shape[1:],y_obs_categorical.shape[-1],Tmax,epochs=1)
        raykarMC.define_model("mlp",16,1,BatchN=False,drop=0.2)
        logL_hists,i = raykarMC.multiples_run(1,X_train,y_obs_categorical,max_iter=3,batch_size=BATCH_SIZE)

        aux_raykar_exec.append(raykarMC.current_exectime)
        aux_raykar_init.append(raykarMC.init_exectime)

        del raykarMC
        gc.collect()
        keras.backend.clear_session()
        #----------------------------RAYKAR---------------------------#

        #----------------------------Ours Global---------------------------#
        r_obs = set_representation(y_obs,"repeat")
        K = r_obs.shape[1]
        gMixture_Global = GroupMixtureGlo(X_train.shape[1:],Kl=r_obs.shape[1],M=M_seted,epochs=1) 
        gMixture_Global.define_model("mlp",16,1,BatchN=False,drop=0.2)
        logL_hists,i_r = gMixture_Global.multiples_run(1,X_train,r_obs,max_iter=3, batch_size=BATCH_SIZE)

        aux_ourglobal_exec.append(gMixture_Global.current_exectime)
        aux_ourglobal_init.append(gMixture_Global.init_exectime)
    
        del gMixture_Global
        gc.collect()
        keras.backend.clear_session()
        #----------------------------Ours Global---------------------------#
        
        #----------------------------Ours Individual---------------------------#
        Y_ann_train, T_idx = set_representation(y_obs,"onehotvar")
        T_idx_unique = np.arange(T).reshape(-1,1)
        A = keras.utils.to_categorical(np.arange(T), num_classes=T) #fast way
        A_rep = np.zeros((T, K))
        for i in range(N):
            for l, t_idx in enumerate(T_idx[i]):
                obs_t = Y_ann_train[i][l].argmax(axis=-1)
                A_rep[t_idx, obs_t] += 1
        gMixture_Ind = GroupMixtureInd(X_train.shape[1:],Kl=K,M=M_seted,epochs=1) 
        gMixture_Ind.define_model("mlp",16,1,BatchN=False,drop=0.2)
        gMixture_Ind.define_model_group("mlp", T, M_seted, 1, BatchN=False, embed=True, embed_M=A)
        logL_hists,i = gMixture_Ind.multiples_run(1,X_train,Y_ann_train, T_idx, A=[],max_iter=3,
                                                  pre_init_g=15, pre_init_z= 3, batch_size=BATCH_SIZE)
        
        aux_ourindiv1_exec.append(gMixture_Ind.current_exectime)
        aux_ourindiv1_init.append(gMixture_Ind.init_exectime)
        
        del gMixture_Ind
        gc.collect()
        keras.backend.clear_session()

        gMixture_Ind = GroupMixtureInd(X_train.shape[1:],Kl=K,M=M_seted,epochs=1) 
        gMixture_Ind.define_model("mlp",16,1,BatchN=False,drop=0.2) 
        logL_hists,i_r = gMixture_Ind.multiples_run(1,X_train,Y_ann_train, T_idx, A=[],
                                                    pre_init_z=3,batch_size=BATCH_SIZE,max_iter=3)
        
        aux_ourindiv2_exec.append(gMixture_Ind.current_exectime)
        aux_ourindiv2_init.append(gMixture_Ind.init_exectime)
        
        del gMixture_Ind
        gc.collect()
        keras.backend.clear_session()

        gMixture_Ind = GroupMixtureInd(X_train.shape[1:],Kl=K,M=M_seted,epochs=1) 
        gMixture_Ind.define_model("mlp",16,1,BatchN=False,drop=0.2) 
        gMixture_Ind.define_model_group("mlp", T, K*M_seted, 1, BatchN=False, embed=True, embed_M=A_rep)
        logL_hists,i_r = gMixture_Ind.multiples_run(1,X_train,Y_ann_train, T_idx, A=[],
                                                    pre_init_g=15, pre_init_z=3, batch_size=BATCH_SIZE,max_iter=3)
        
        aux_ourindiv3_exec.append(gMixture_Ind.current_exectime)
        aux_ourindiv3_init.append(gMixture_Ind.init_exectime)
        
        del gMixture_Ind
        gc.collect()
        keras.backend.clear_session()
        #----------------------------Ours Individual---------------------------#
        
        #----------------------------Majority Voting---------------------------#
        mv_soft = majority_voting(r_obs,repeats=True,probas=True) 
        time_callback = TimeHistory()
        model_mvsoft = MLP_Keras(X_train.shape[1:],mv_soft.shape[1],16,1,BN=False,drop=0.2)
        model_mvsoft.compile(loss='categorical_crossentropy',optimizer='adam')
        model_mvsoft.fit(X_train, mv_soft, epochs=3,batch_size=BATCH_SIZE,verbose=1,callbacks=[time_callback])
        times = time_callback.times
        aux_mv_exec.append(times[-1])
        del model_mvsoft
        gc.collect()
        keras.backend.clear_session()
        #----------------------------Majority Voting---------------------------#
        
        #----------------------------Dawid and Skene---------------------------#
        label_I = LabelInference(y_obs,1e-10, type_inf = 'ds', max_iter=3)
        ds_labels,ds_conf = label_I.DS_labels()
        aux_ds_exec.append(label_I.DS_current_exectime)
        del label_I
        gc.collect()
        #----------------------------Dawid and Skene---------------------------#
        
    raykar_exec.append(np.mean(aux_raykar_exec))
    raykar_init.append(np.mean(aux_raykar_init))
    ourglobal_exec.append(np.mean(aux_ourglobal_exec))
    ourglobal_init.append(np.mean(aux_ourglobal_init))
    ourindiv1_exec.append(np.mean(aux_ourindiv1_exec))
    ourindiv1_init.append(np.mean(aux_ourindiv1_init))
    ourindiv2_exec.append(np.mean(aux_ourindiv2_exec))
    ourindiv2_init.append(np.mean(aux_ourindiv2_init))
    ourindiv3_exec.append(np.mean(aux_ourindiv3_exec))
    ourindiv3_init.append(np.mean(aux_ourindiv3_init))
    mv_exec.append(np.mean(aux_mv_exec))
    ds_exec.append(np.mean(aux_ds_exec))
    
raykar_exec = np.asarray(raykar_exec)
raykar_init = np.asarray(raykar_init)
ourglobal_exec = np.asarray(ourglobal_exec)
ourglobal_init = np.asarray(ourglobal_init)
ourindiv1_exec = np.asarray(ourindiv1_exec)
ourindiv1_init = np.asarray(ourindiv1_init)
ourindiv2_exec = np.asarray(ourindiv2_exec)
ourindiv2_init = np.asarray(ourindiv2_init)
ourindiv3_exec = np.asarray(ourindiv3_exec)
ourindiv3_init = np.asarray(ourindiv3_init)
mv_exec = np.asarray(mv_exec)
ds_exec = np.asarray(ds_exec)
print("Done")
# Out:
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.66 sec)	logL: -18261.717
# Iter 2/3
# M step: done,  E step: done //  (in 0.12 sec)	logL: -16700.822	Tol1: 0.08547	Tol2: 0.27995
# Iter 3/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -16060.925	Tol1: 0.03832	Tol2: 0.11691
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.003805 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.57 sec)	logL: -25344.448
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -24567.913	Tol1: 0.03064	Tol2: 0.40229	Tol3: 0.05948
# Iter 3/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -24230.060	Tol1: 0.01375	Tol2: 0.18084	Tol3: 0.01342
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001364 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24636, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.30 sec)	logL: -20279.032
# Iter 2/3
# M step: done,  E step: done //  (in 0.27 sec)	logL: -19299.452	Tol1: 0.04831	Tol2: 0.25122
# Iter 3/3
# M step: done,  E step: done //  (in 0.34 sec)	logL: -18561.257	Tol1: 0.03825	Tol2: 0.20392
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001367 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24636, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.70 sec)	logL: -19791.845
# Iter 2/3
# M step: done,  E step: done //  (in 0.15 sec)	logL: -18786.465	Tol1: 0.05080	Tol2: 0.17726
# Iter 3/3
# M step: done,  E step: done //  (in 0.14 sec)	logL: -17889.998	Tol1: 0.04772	Tol2: 0.17750
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001184 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24636, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.09 sec)	logL: -39009.994
# Iter 2/3
# M step: done,  E step: done //  (in 0.24 sec)	logL: -20900.320	Tol1: 0.46423	Tol2: 26.43479
# Iter 3/3
# M step: done,  E step: done //  (in 0.25 sec)	logL: -20027.685	Tol1: 0.04175	Tol2: 0.28794
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 86us/step - loss: 1.0750
# Epoch 2/3
# 2457/2457 [==============================] - 0s 23us/step - loss: 0.9868
# Epoch 3/3
# 2457/2457 [==============================] - 0s 21us/step - loss: 0.9287
# Representation for DS in 0.051300 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18116.196700280216
# 2 	 -16967.81951945046 	0.4019	0.256103	0.063390
# 3 	 -16659.8425714252 	0.1019	0.191723	0.018151
# 4 	 -16546.86441169874 	0.0506	0.140550	0.006781
# Class marginals
# [0.38 0.33 0.29]
# Estimation for DS in 1.179889 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -18729.910
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -17015.102	Tol1: 0.09155	Tol2: 0.27925
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -16530.133	Tol1: 0.02850	Tol2: 0.09936
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002309 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.49 sec)	logL: -24654.246
# Iter 2/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -23789.917	Tol1: 0.03506	Tol2: 0.40344	Tol3: 0.02972
# Iter 3/3
# M step: done,  E step: done //  (in 0.10 sec)	logL: -23020.370	Tol1: 0.03235	Tol2: 0.22412	Tol3: 0.02615
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001299 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24490, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.19 sec)	logL: -20702.474
# Iter 2/3
# M step: done,  E step: done //  (in 0.29 sec)	logL: -19598.516	Tol1: 0.05332	Tol2: 0.19807
# Iter 3/3
# M step: done,  E step: done //  (in 0.28 sec)	logL: -18700.524	Tol1: 0.04582	Tol2: 0.20005
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001247 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24490, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.67 sec)	logL: -20291.434
# Iter 2/3
# M step: done,  E step: done //  (in 0.17 sec)	logL: -19165.755	Tol1: 0.05548	Tol2: 0.20873
# Iter 3/3
# M step: done,  E step: done //  (in 0.13 sec)	logL: -18260.987	Tol1: 0.04721	Tol2: 0.20313
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001113 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24490, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.12 sec)	logL: -20457.538
# Iter 2/3
# M step: done,  E step: done //  (in 0.23 sec)	logL: -19344.153	Tol1: 0.05442	Tol2: 0.78079
# Iter 3/3
# M step: done,  E step: done //  (in 0.27 sec)	logL: -18409.640	Tol1: 0.04831	Tol2: 0.11710
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 101us/step - loss: 1.0724
# Epoch 2/3
# 2457/2457 [==============================] - 0s 34us/step - loss: 0.9890
# Epoch 3/3
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9317
# Representation for DS in 0.060348 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18861.787464503628
# 2 	 -17572.792717974728 	0.2922	0.296308	0.068339
# 3 	 -17361.866730725804 	0.0665	0.210681	0.012003
# 4 	 -17323.990956779886 	0.0346	0.140932	0.002182
# Class marginals
# [0.34 0.34 0.32]
# Estimation for DS in 1.244115 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.50 sec)	logL: -18697.572
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -16880.762	Tol1: 0.09717	Tol2: 0.28849
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -16380.895	Tol1: 0.02961	Tol2: 0.09938
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002410 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.49 sec)	logL: -24987.909
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -24145.918	Tol1: 0.03370	Tol2: 0.39761	Tol3: 0.04633
# Iter 3/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -23450.293	Tol1: 0.02881	Tol2: 0.20391	Tol3: 0.01666
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001281 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24722, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.12 sec)	logL: -21050.048
# Iter 2/3
# M step: done,  E step: done //  (in 0.23 sec)	logL: -19975.594	Tol1: 0.05104	Tol2: 0.20164
# Iter 3/3
# M step: done,  E step: done //  (in 0.26 sec)	logL: -19120.983	Tol1: 0.04278	Tol2: 0.19017
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001457 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24722, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.71 sec)	logL: -20176.155
# Iter 2/3
# M step: done,  E step: done //  (in 0.15 sec)	logL: -19001.107	Tol1: 0.05824	Tol2: 0.21034
# Iter 3/3
# M step: done,  E step: done //  (in 0.12 sec)	logL: -18075.678	Tol1: 0.04870	Tol2: 0.20764
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001121 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24722, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.14 sec)	logL: -23489.102
# Iter 2/3
# M step: done,  E step: done //  (in 0.21 sec)	logL: -21899.797	Tol1: 0.06766	Tol2: 32.69728
# Iter 3/3
# M step: done,  E step: done //  (in 0.25 sec)	logL: -21176.259	Tol1: 0.03304	Tol2: 0.03954
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 95us/step - loss: 1.0314
# Epoch 2/3
# 2457/2457 [==============================] - 0s 29us/step - loss: 0.9643
# Epoch 3/3
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9178
# Representation for DS in 0.058278 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18748.74167521896
# 2 	 -17455.304420283937 	0.3454	0.283719	0.068988
# 3 	 -17178.011863806154 	0.0834	0.213356	0.015886
# 4 	 -17121.23735635851 	0.0354	0.146788	0.003305
# Class marginals
# [0.35 0.33 0.32]
# Estimation for DS in 1.263993 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -17855.662
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -16387.553	Tol1: 0.08222	Tol2: 0.29837
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -15930.242	Tol1: 0.02791	Tol2: 0.10417
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002379 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.49 sec)	logL: -25162.640
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24383.921	Tol1: 0.03095	Tol2: 0.40900	Tol3: 0.03861
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23782.345	Tol1: 0.02467	Tol2: 0.21123	Tol3: 0.01560
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001185 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24533, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.19 sec)	logL: -21226.597
# Iter 2/3
# M step: done,  E step: done //  (in 0.26 sec)	logL: -20295.496	Tol1: 0.04386	Tol2: 0.18461
# Iter 3/3
# M step: done,  E step: done //  (in 0.27 sec)	logL: -19424.093	Tol1: 0.04294	Tol2: 0.17972
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001353 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24533, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.57 sec)	logL: -20335.854
# Iter 2/3
# M step: done,  E step: done //  (in 0.12 sec)	logL: -19274.309	Tol1: 0.05220	Tol2: 0.18059
# Iter 3/3
# M step: done,  E step: done //  (in 0.12 sec)	logL: -18223.858	Tol1: 0.05450	Tol2: 0.19105
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001190 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24533, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.11 sec)	logL: -28335.717
# Iter 2/3
# M step: done,  E step: done //  (in 0.23 sec)	logL: -23402.237	Tol1: 0.17411	Tol2: 43.59253
# Iter 3/3
# M step: done,  E step: done //  (in 0.23 sec)	logL: -22510.367	Tol1: 0.03811	Tol2: 0.03256
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 83us/step - loss: 1.1194
# Epoch 2/3
# 2457/2457 [==============================] - 0s 23us/step - loss: 1.0155
# Epoch 3/3
# 2457/2457 [==============================] - 0s 22us/step - loss: 0.9540
# Representation for DS in 0.050540 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18302.30226184235
# 2 	 -17024.54696599766 	0.3652	0.274468	0.069814
# 3 	 -16761.071634250748 	0.0697	0.202479	0.015476
# 4 	 -16688.964076997418 	0.0564	0.135230	0.004302
# Class marginals
# [0.39 0.33 0.27]
# Estimation for DS in 1.178765 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -18059.246
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -16419.846	Tol1: 0.09078	Tol2: 0.28152
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -15872.572	Tol1: 0.03333	Tol2: 0.10993
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002082 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -25022.978
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23748.091	Tol1: 0.05095	Tol2: 0.72196	Tol3: 0.11473
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23092.990	Tol1: 0.02759	Tol2: 0.27562	Tol3: 0.05586
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001157 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24565, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.13 sec)	logL: -20817.327
# Iter 2/3
# M step: done,  E step: done //  (in 0.28 sec)	logL: -19825.630	Tol1: 0.04764	Tol2: 0.17152
# Iter 3/3
# M step: done,  E step: done //  (in 0.25 sec)	logL: -18966.348	Tol1: 0.04334	Tol2: 0.17186
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001295 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24565, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.62 sec)	logL: -20289.284
# Iter 2/3
# M step: done,  E step: done //  (in 0.12 sec)	logL: -19346.586	Tol1: 0.04646	Tol2: 0.17997
# Iter 3/3
# M step: done,  E step: done //  (in 0.13 sec)	logL: -18457.188	Tol1: 0.04597	Tol2: 0.19207
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001320 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24565, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.12 sec)	logL: -22157.968
# Iter 2/3
# M step: done,  E step: done //  (in 0.25 sec)	logL: -20998.959	Tol1: 0.05231	Tol2: 39.62637
# Iter 3/3
# M step: done,  E step: done //  (in 0.23 sec)	logL: -20315.152	Tol1: 0.03256	Tol2: 0.07420
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 85us/step - loss: 1.0476
# Epoch 2/3
# 2457/2457 [==============================] - 0s 21us/step - loss: 0.9631
# Epoch 3/3
# 2457/2457 [==============================] - 0s 22us/step - loss: 0.9157
# Representation for DS in 0.051426 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18360.11353779148
# 2 	 -17063.56687667296 	0.3654	0.276239	0.070618
# 3 	 -16764.219513172528 	0.0889	0.210837	0.017543
# 4 	 -16704.64283117137 	0.0429	0.150508	0.003554
# Class marginals
# [0.35 0.33 0.32]
# Estimation for DS in 1.187471 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -18147.629
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -16555.066	Tol1: 0.08776	Tol2: 0.28750
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -16040.596	Tol1: 0.03108	Tol2: 0.10970
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002320 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.51 sec)	logL: -23576.575
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -22598.034	Tol1: 0.04150	Tol2: 0.41860	Tol3: 0.06396
# Iter 3/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -21884.259	Tol1: 0.03159	Tol2: 0.23989	Tol3: 0.03679
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001264 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24475, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.14 sec)	logL: -21195.274
# Iter 2/3
# M step: done,  E step: done //  (in 0.28 sec)	logL: -20237.041	Tol1: 0.04521	Tol2: 0.17015
# Iter 3/3
# M step: done,  E step: done //  (in 0.28 sec)	logL: -19429.630	Tol1: 0.03990	Tol2: 0.15752
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001280 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24475, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.68 sec)	logL: -20514.289
# Iter 2/3
# M step: done,  E step: done //  (in 0.12 sec)	logL: -19737.710	Tol1: 0.03786	Tol2: 0.14739
# Iter 3/3
# M step: done,  E step: done //  (in 0.12 sec)	logL: -19025.520	Tol1: 0.03608	Tol2: 0.15082
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001285 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24475, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.08 sec)	logL: -20905.507
# Iter 2/3
# M step: done,  E step: done //  (in 0.21 sec)	logL: -20049.363	Tol1: 0.04095	Tol2: 16.28657
# Iter 3/3
# M step: done,  E step: done //  (in 0.22 sec)	logL: -19206.122	Tol1: 0.04206	Tol2: 0.12080
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 91us/step - loss: 1.0986
# Epoch 2/3
# 2457/2457 [==============================] - 0s 24us/step - loss: 1.0227
# Epoch 3/3
# 2457/2457 [==============================] - 0s 24us/step - loss: 0.9690
# Representation for DS in 0.058028 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18397.65132593997
# 2 	 -17115.13954329791 	0.3559	0.278651	0.069711
# 3 	 -16824.626492426705 	0.0864	0.212752	0.016974
# 4 	 -16760.65149316527 	0.0368	0.148209	0.003802
# Class marginals
# [0.37 0.33 0.3 ]
# Estimation for DS in 1.182787 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -18894.855
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -17390.389	Tol1: 0.07962	Tol2: 0.28277
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -16929.494	Tol1: 0.02650	Tol2: 0.09845
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002245 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -26459.714
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -25357.512	Tol1: 0.04166	Tol2: 0.38943	Tol3: 0.08658
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24805.079	Tol1: 0.02179	Tol2: 0.17999	Tol3: 0.02055
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001147 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24671, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.25 sec)	logL: -22229.679
# Iter 2/3
# M step: done,  E step: done //  (in 0.30 sec)	logL: -21463.891	Tol1: 0.03445	Tol2: 0.17886
# Iter 3/3
# M step: done,  E step: done //  (in 0.31 sec)	logL: -20673.959	Tol1: 0.03680	Tol2: 0.12454
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001315 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24671, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.57 sec)	logL: -20361.020
# Iter 2/3
# M step: done,  E step: done //  (in 0.13 sec)	logL: -19276.948	Tol1: 0.05324	Tol2: 0.17700
# Iter 3/3
# M step: done,  E step: done //  (in 0.13 sec)	logL: -18398.142	Tol1: 0.04559	Tol2: 0.17315
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001214 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24671, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.09 sec)	logL: -23067.512
# Iter 2/3
# M step: done,  E step: done //  (in 0.26 sec)	logL: -21659.666	Tol1: 0.06103	Tol2: 33.68881
# Iter 3/3
# M step: done,  E step: done //  (in 0.28 sec)	logL: -20971.897	Tol1: 0.03175	Tol2: 0.03879
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 94us/step - loss: 1.0606
# Epoch 2/3
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9866
# Epoch 3/3
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9444
# Representation for DS in 0.061438 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18716.90886934125
# 2 	 -17441.021004801278 	0.3513	0.281202	0.068168
# 3 	 -17179.902480737885 	0.0854	0.207295	0.014972
# 4 	 -17124.516726433445 	0.0342	0.146880	0.003224
# Class marginals
# [0.36 0.33 0.31]
# Estimation for DS in 1.199719 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.51 sec)	logL: -18601.689
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -17070.078	Tol1: 0.08234	Tol2: 0.27535
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -16525.172	Tol1: 0.03192	Tol2: 0.10158
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002380 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.53 sec)	logL: -23779.277
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -23001.022	Tol1: 0.03273	Tol2: 0.43266	Tol3: 0.05459
# Iter 3/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -22466.750	Tol1: 0.02323	Tol2: 0.24302	Tol3: 0.03428
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001318 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24672, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.16 sec)	logL: -21021.149
# Iter 2/3
# M step: done,  E step: done //  (in 0.26 sec)	logL: -19953.345	Tol1: 0.05080	Tol2: 0.17853
# Iter 3/3
# M step: done,  E step: done //  (in 0.28 sec)	logL: -19013.315	Tol1: 0.04711	Tol2: 0.18786
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001299 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24672, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.62 sec)	logL: -20373.061
# Iter 2/3
# M step: done,  E step: done //  (in 0.14 sec)	logL: -19358.043	Tol1: 0.04982	Tol2: 0.20111
# Iter 3/3
# M step: done,  E step: done //  (in 0.14 sec)	logL: -18474.972	Tol1: 0.04562	Tol2: 0.20490
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001339 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24672, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.11 sec)	logL: -27469.799
# Iter 2/3
# M step: done,  E step: done //  (in 0.23 sec)	logL: -21907.508	Tol1: 0.20249	Tol2: 30.62331
# Iter 3/3
# M step: done,  E step: done //  (in 0.25 sec)	logL: -21075.749	Tol1: 0.03797	Tol2: 0.04048
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 94us/step - loss: 1.1416
# Epoch 2/3
# 2457/2457 [==============================] - 0s 28us/step - loss: 1.0451
# Epoch 3/3
# 2457/2457 [==============================] - 0s 27us/step - loss: 0.9870
# Representation for DS in 0.059826 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18652.12623834591
# 2 	 -17411.975347024534 	0.3422	0.285152	0.066488
# 3 	 -17164.146197657166 	0.0843	0.208801	0.014233
# 4 	 -17099.912737424504 	0.0302	0.148740	0.003742
# Class marginals
# [0.36 0.33 0.31]
# Estimation for DS in 1.195042 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -18878.264
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -17301.994	Tol1: 0.08350	Tol2: 0.26964
# Iter 3/3
# M step: done,  E step: done //  (in 0.05 sec)	logL: -16746.586	Tol1: 0.03210	Tol2: 0.10485
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002206 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -25350.535
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -24707.650	Tol1: 0.02536	Tol2: 0.28093	Tol3: 0.04318
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24174.413	Tol1: 0.02158	Tol2: 0.13413	Tol3: 0.00402
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001139 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24426, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.21 sec)	logL: -20696.380
# Iter 2/3
# M step: done,  E step: done //  (in 0.27 sec)	logL: -19444.960	Tol1: 0.06047	Tol2: 0.24332
# Iter 3/3
# M step: done,  E step: done //  (in 0.29 sec)	logL: -18634.710	Tol1: 0.04167	Tol2: 0.21300
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001301 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24426, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.56 sec)	logL: -20042.587
# Iter 2/3
# M step: done,  E step: done //  (in 0.13 sec)	logL: -18914.243	Tol1: 0.05630	Tol2: 0.19943
# Iter 3/3
# M step: done,  E step: done //  (in 0.12 sec)	logL: -18049.867	Tol1: 0.04570	Tol2: 0.19628
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001138 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24426, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.20 sec)	logL: -27686.684
# Iter 2/3
# M step: done,  E step: done //  (in 0.32 sec)	logL: -22740.485	Tol1: 0.17865	Tol2: 2.18272
# Iter 3/3
# M step: done,  E step: done //  (in 0.30 sec)	logL: -21950.361	Tol1: 0.03475	Tol2: 0.13677
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 100us/step - loss: 1.0302
# Epoch 2/3
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9606
# Epoch 3/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9113
# Representation for DS in 0.059227 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18622.01986455975
# 2 	 -17329.983610508065 	0.3326	0.284820	0.069382
# 3 	 -17083.064565283923 	0.0772	0.209315	0.014248
# 4 	 -17035.73629833321 	0.0286	0.143694	0.002770
# Class marginals
# [0.37 0.33 0.3 ]
# Estimation for DS in 1.266400 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -18346.133
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -16650.035	Tol1: 0.09245	Tol2: 0.28539
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -16162.605	Tol1: 0.02927	Tol2: 0.09985
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002466 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.51 sec)	logL: -23811.155
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -22740.636	Tol1: 0.04496	Tol2: 0.47823	Tol3: 0.06110
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -22132.002	Tol1: 0.02676	Tol2: 0.25515	Tol3: 0.02847
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001170 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24661, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.14 sec)	logL: -20898.575
# Iter 2/3
# M step: done,  E step: done //  (in 0.29 sec)	logL: -19824.757	Tol1: 0.05138	Tol2: 0.17459
# Iter 3/3
# M step: done,  E step: done //  (in 0.31 sec)	logL: -18887.416	Tol1: 0.04728	Tol2: 0.18106
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001323 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24661, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.61 sec)	logL: -20562.938
# Iter 2/3
# M step: done,  E step: done //  (in 0.13 sec)	logL: -19519.437	Tol1: 0.05075	Tol2: 0.18170
# Iter 3/3
# M step: done,  E step: done //  (in 0.13 sec)	logL: -18591.379	Tol1: 0.04755	Tol2: 0.19050
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001188 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24661, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.11 sec)	logL: -26007.117
# Iter 2/3
# M step: done,  E step: done //  (in 0.26 sec)	logL: -21140.167	Tol1: 0.18714	Tol2: 1.36979
# Iter 3/3
# M step: done,  E step: done //  (in 0.25 sec)	logL: -20136.006	Tol1: 0.04750	Tol2: 0.05527
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 97us/step - loss: 1.1880
# Epoch 2/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 1.0836
# Epoch 3/3
# 2457/2457 [==============================] - 0s 29us/step - loss: 1.0022
# Representation for DS in 0.059878 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18547.766671955116
# 2 	 -17262.52533160395 	0.3555	0.282496	0.069294
# 3 	 -16991.552793368373 	0.0859	0.203879	0.015697
# 4 	 -16938.137008296253 	0.0327	0.139280	0.003144
# Class marginals
# [0.35 0.33 0.32]
# Estimation for DS in 1.232157 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.61 sec)	logL: -19582.682
# Iter 2/3
# M step: done,  E step: done //  (in 0.11 sec)	logL: -17877.209	Tol1: 0.08709	Tol2: 0.13638
# Iter 3/3
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17193.986	Tol1: 0.03822	Tol2: 0.05736
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002286 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.51 sec)	logL: -24278.934
# Iter 2/3
# M step: done,  E step: done //  (in 0.08 sec)	logL: -23433.521	Tol1: 0.03482	Tol2: 0.39624	Tol3: 0.05306
# Iter 3/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -22820.514	Tol1: 0.02616	Tol2: 0.22125	Tol3: 0.03235
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001372 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24425, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.45 sec)	logL: -21397.641
# Iter 2/3
# M step: done,  E step: done //  (in 0.40 sec)	logL: -20367.620	Tol1: 0.04814	Tol2: 0.22128
# Iter 3/3
# M step: done,  E step: done //  (in 0.44 sec)	logL: -19562.443	Tol1: 0.03953	Tol2: 0.20800
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001425 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24425, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.84 sec)	logL: -20092.194
# Iter 2/3
# M step: done,  E step: done //  (in 0.36 sec)	logL: -19188.856	Tol1: 0.04496	Tol2: 0.18039
# Iter 3/3
# M step: done,  E step: done //  (in 0.32 sec)	logL: -18337.870	Tol1: 0.04435	Tol2: 0.18798
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001188 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24425, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.15 sec)	logL: -18976.846
# Iter 2/3
# M step: done,  E step: done //  (in 0.26 sec)	logL: -17708.920	Tol1: 0.06681	Tol2: 0.28900
# Iter 3/3
# M step: done,  E step: done //  (in 0.25 sec)	logL: -16930.946	Tol1: 0.04393	Tol2: 0.24413
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 92us/step - loss: 1.0488
# Epoch 2/3
# 2457/2457 [==============================] - 0s 22us/step - loss: 0.9860
# Epoch 3/3
# 2457/2457 [==============================] - 0s 21us/step - loss: 0.9443
# Representation for DS in 0.074856 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15623.925162283396
# 2 	 -13320.788408577819 	0.3646	0.346088	0.147411
# 3 	 -12845.919787295523 	0.0406	0.281963	0.035649
# 4 	 -12712.45077435778 	0.0216	2963.114502	0.010390
# Class marginals
# [0.38 0.31 0.31]
# Estimation for DS in 7.185967 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.57 sec)	logL: -19597.803
# Iter 2/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17865.340	Tol1: 0.08840	Tol2: 0.13290
# Iter 3/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -17179.961	Tol1: 0.03836	Tol2: 0.05924
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002510 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.51 sec)	logL: -24935.120
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -23836.421	Tol1: 0.04406	Tol2: 0.42182	Tol3: 0.05589
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -23092.944	Tol1: 0.03119	Tol2: 0.20956	Tol3: 0.01387
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001369 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24721, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.37 sec)	logL: -22052.692
# Iter 2/3
# M step: done,  E step: done //  (in 0.42 sec)	logL: -20973.551	Tol1: 0.04893	Tol2: 0.20386
# Iter 3/3
# M step: done,  E step: done //  (in 0.42 sec)	logL: -20013.871	Tol1: 0.04576	Tol2: 0.20220
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001302 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24721, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.91 sec)	logL: -21596.821
# Iter 2/3
# M step: done,  E step: done //  (in 0.34 sec)	logL: -20950.507	Tol1: 0.02993	Tol2: 0.12777
# Iter 3/3
# M step: done,  E step: done //  (in 0.31 sec)	logL: -20334.588	Tol1: 0.02940	Tol2: 0.12090
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001160 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24721, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.17 sec)	logL: -19805.975
# Iter 2/3
# M step: done,  E step: done //  (in 0.28 sec)	logL: -18600.832	Tol1: 0.06085	Tol2: 0.26568
# Iter 3/3
# M step: done,  E step: done //  (in 0.30 sec)	logL: -17741.174	Tol1: 0.04622	Tol2: 0.23082
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 100us/step - loss: 1.0907
# Epoch 2/3
# 2457/2457 [==============================] - 0s 33us/step - loss: 1.0014
# Epoch 3/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9424
# Representation for DS in 0.093241 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15759.901988124813
# 2 	 -13472.7647088948 	0.3368	0.345239	0.145124
# 3 	 -13023.630629534917 	0.0347	0.281891	0.033336
# 4 	 -12900.251380438513 	0.0197	740.886902	0.009473
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 7.955796 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.60 sec)	logL: -19440.303
# Iter 2/3
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17727.590	Tol1: 0.08810	Tol2: 0.13292
# Iter 3/3
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17081.354	Tol1: 0.03645	Tol2: 0.05523
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002120 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -25288.296
# Iter 2/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -24203.851	Tol1: 0.04288	Tol2: 0.40210	Tol3: 0.05709
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23460.968	Tol1: 0.03069	Tol2: 0.19664	Tol3: 0.01191
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001356 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24374, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.59 sec)	logL: -20686.029
# Iter 2/3
# M step: done,  E step: done //  (in 0.45 sec)	logL: -19550.459	Tol1: 0.05490	Tol2: 0.23798
# Iter 3/3
# M step: done,  E step: done //  (in 0.43 sec)	logL: -18666.279	Tol1: 0.04523	Tol2: 0.23278
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001358 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24374, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.84 sec)	logL: -19559.954
# Iter 2/3
# M step: done,  E step: done //  (in 0.39 sec)	logL: -18514.514	Tol1: 0.05345	Tol2: 0.21614
# Iter 3/3
# M step: done,  E step: done //  (in 0.30 sec)	logL: -17682.144	Tol1: 0.04496	Tol2: 0.21314
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001339 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24374, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.16 sec)	logL: -19875.911
# Iter 2/3
# M step: done,  E step: done //  (in 0.25 sec)	logL: -18724.934	Tol1: 0.05791	Tol2: 0.25385
# Iter 3/3
# M step: done,  E step: done //  (in 0.28 sec)	logL: -17891.418	Tol1: 0.04451	Tol2: 0.22580
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 101us/step - loss: 0.9883
# Epoch 2/3
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9344
# Epoch 3/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.8941
# Representation for DS in 0.092476 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15647.4828003875
# 2 	 -13346.356765761053 	0.3527	0.350125	0.147060
# 3 	 -12885.019760526233 	0.0406	370.654480	0.034567
# 4 	 -12745.083229975417 	0.0183	3518.668945	0.010860
# Class marginals
# [0.38 0.31 0.31]
# Estimation for DS in 7.309828 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.70 sec)	logL: -19923.695
# Iter 2/3
# M step: done,  E step: done //  (in 0.11 sec)	logL: -18152.676	Tol1: 0.08889	Tol2: 0.13155
# Iter 3/3
# M step: done,  E step: done //  (in 0.10 sec)	logL: -17404.812	Tol1: 0.04120	Tol2: 0.05742
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002444 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.49 sec)	logL: -24220.309
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23273.183	Tol1: 0.03910	Tol2: 0.42810	Tol3: 0.08555
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -22611.978	Tol1: 0.02841	Tol2: 0.22400	Tol3: 0.03561
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001199 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24707, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.50 sec)	logL: -21526.605
# Iter 2/3
# M step: done,  E step: done //  (in 0.42 sec)	logL: -20402.363	Tol1: 0.05223	Tol2: 0.21719
# Iter 3/3
# M step: done,  E step: done //  (in 0.42 sec)	logL: -19505.663	Tol1: 0.04395	Tol2: 0.19141
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# ...
# Get init alphas in 0.001840 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24528, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 2.43 sec)	logL: -11969.341
# Iter 2/3
# M step: done,  E step: done //  (in 1.81 sec)	logL: -11305.586	Tol1: 0.05545	Tol2: 0.19161
# Iter 3/3
# M step: done,  E step: done //  (in 1.81 sec)	logL: -10827.667	Tol1: 0.04227	Tol2: 0.16356
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001827 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24528, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.13 sec)	logL: -11108.548
# Iter 2/3
# M step: done,  E step: done //  (in 0.26 sec)	logL: -8484.479	Tol1: 0.23622	Tol2: 0.50512
# Iter 3/3
# M step: done,  E step: done //  (in 0.32 sec)	logL: -7560.894	Tol1: 0.10886	Tol2: 0.38123
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 89us/step - loss: 1.1437
# Epoch 2/3
# 2457/2457 [==============================] - 0s 23us/step - loss: 1.0408
# Epoch 3/3
# 2457/2457 [==============================] - 0s 23us/step - loss: 0.9821
# Representation for DS in 0.226057 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3899.795489182111
# 2 	 -3156.546135363864 	0.1375	0.078547	0.190587
# 3 	 -2851.7696128480566 	0.0942	931.117371	0.096554
# 4 	 -2706.7980175063476 	0.0329	31677.304688	0.050836
# Class marginals
# [0.39 0.26 0.35]
# Estimation for DS in 56.452104 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.22 sec)	logL: -20668.482
# Iter 2/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -19703.918	Tol1: 0.04667	Tol2: 0.03569
# Iter 3/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -18853.344	Tol1: 0.04317	Tol2: 0.02674
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002354 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -25149.691
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -24155.234	Tol1: 0.03954	Tol2: 0.43411	Tol3: 0.07580
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23580.240	Tol1: 0.02380	Tol2: 0.19985	Tol3: 0.01517
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.002446 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24439, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 3.34 sec)	logL: -19776.851
# Iter 2/3
# M step: done,  E step: done //  (in 2.49 sec)	logL: -18745.933	Tol1: 0.05213	Tol2: 0.23143
# Iter 3/3
# M step: done,  E step: done //  (in 2.02 sec)	logL: -17884.739	Tol1: 0.04594	Tol2: 0.21571
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.002439 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24439, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 2.35 sec)	logL: -12345.914
# Iter 2/3
# M step: done,  E step: done //  (in 1.85 sec)	logL: -11689.704	Tol1: 0.05315	Tol2: 0.20768
# Iter 3/3
# M step: done,  E step: done //  (in 1.83 sec)	logL: -11250.345	Tol1: 0.03759	Tol2: 0.17228
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.002528 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24439, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.11 sec)	logL: -10974.437
# Iter 2/3
# M step: done,  E step: done //  (in 0.32 sec)	logL: -7967.585	Tol1: 0.27399	Tol2: 0.52665
# Iter 3/3
# M step: done,  E step: done //  (in 0.32 sec)	logL: -6969.418	Tol1: 0.12528	Tol2: 0.40308
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 97us/step - loss: 1.1062
# Epoch 2/3
# 2457/2457 [==============================] - 0s 32us/step - loss: 1.0226
# Epoch 3/3
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9606
# Representation for DS in 0.266717 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3898.115544168894
# 2 	 -3152.6073729654217 	0.1295	0.073620	0.191248
# 3 	 -2830.787040440875 	0.0920	283.476532	0.102081
# 4 	 -2690.4967798221055 	0.0292	34113.628906	0.049559
# Class marginals
# [0.39 0.25 0.36]
# Estimation for DS in 56.102172 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.20 sec)	logL: -20923.932
# Iter 2/3
# M step: done,  E step: done //  (in 0.43 sec)	logL: -19966.125	Tol1: 0.04578	Tol2: 0.03944
# Iter 3/3
# M step: done,  E step: done //  (in 0.43 sec)	logL: -19217.010	Tol1: 0.03752	Tol2: 0.02641
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002043 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.46 sec)	logL: -24790.476
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23675.889	Tol1: 0.04496	Tol2: 0.40851	Tol3: 0.07739
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -23066.444	Tol1: 0.02574	Tol2: 0.19922	Tol3: 0.01780
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001730 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24439, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 3.01 sec)	logL: -19973.437
# Iter 2/3
# M step: done,  E step: done //  (in 1.92 sec)	logL: -18840.662	Tol1: 0.05671	Tol2: 0.23395
# Iter 3/3
# M step: done,  E step: done //  (in 2.06 sec)	logL: -17903.989	Tol1: 0.04972	Tol2: 0.20981
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.002245 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24439, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 2.41 sec)	logL: -14053.782
# Iter 2/3
# M step: done,  E step: done //  (in 1.86 sec)	logL: -13172.868	Tol1: 0.06268	Tol2: 0.20976
# Iter 3/3
# M step: done,  E step: done //  (in 1.85 sec)	logL: -12533.427	Tol1: 0.04854	Tol2: 0.18832
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001770 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24439, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.13 sec)	logL: -13233.377
# Iter 2/3
# M step: done,  E step: done //  (in 0.33 sec)	logL: -9496.503	Tol1: 0.28238	Tol2: 0.50267
# Iter 3/3
# M step: done,  E step: done //  (in 0.34 sec)	logL: -8001.133	Tol1: 0.15747	Tol2: 0.40182
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 111us/step - loss: 1.0606
# Epoch 2/3
# 2457/2457 [==============================] - 0s 33us/step - loss: 0.9886
# Epoch 3/3
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9332
# Representation for DS in 0.385485 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3942.663334986279
# 2 	 -3175.4789817767924 	0.1290	0.081761	0.194585
# 3 	 -2853.8704228656657 	0.0931	975.652405	0.101279
# 4 	 -2710.4119093730474 	0.0328	35672.347656	0.050268
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 56.711731 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.25 sec)	logL: -20960.137
# Iter 2/3
# M step: done,  E step: done //  (in 0.44 sec)	logL: -20182.254	Tol1: 0.03711	Tol2: 0.03217
# Iter 3/3
# M step: done,  E step: done //  (in 0.43 sec)	logL: -19444.082	Tol1: 0.03658	Tol2: 0.02480
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002016 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.47 sec)	logL: -24062.641
# Iter 2/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -23241.784	Tol1: 0.03411	Tol2: 0.39601	Tol3: 0.06566
# Iter 3/3
# M step: done,  E step: done //  (in 0.06 sec)	logL: -22632.341	Tol1: 0.02622	Tol2: 0.20989	Tol3: 0.01393
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001789 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24466, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 2.79 sec)	logL: -18761.368
# Iter 2/3
# M step: done,  E step: done //  (in 1.77 sec)	logL: -17513.235	Tol1: 0.06653	Tol2: 0.25466
# Iter 3/3
# M step: done,  E step: done //  (in 2.26 sec)	logL: -16492.595	Tol1: 0.05828	Tol2: 0.23271
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001527 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24466, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 2.36 sec)	logL: -12736.577
# Iter 2/3
# M step: done,  E step: done //  (in 1.84 sec)	logL: -12097.785	Tol1: 0.05015	Tol2: 0.17605
# Iter 3/3
# M step: done,  E step: done //  (in 1.89 sec)	logL: -11661.179	Tol1: 0.03609	Tol2: 0.15271
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.001556 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24466, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.25 sec)	logL: -10876.210
# Iter 2/3
# M step: done,  E step: done //  (in 0.29 sec)	logL: -8050.263	Tol1: 0.25983	Tol2: 0.51419
# Iter 3/3
# M step: done,  E step: done //  (in 0.31 sec)	logL: -7098.240	Tol1: 0.11826	Tol2: 0.38009
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 88us/step - loss: 1.2783
# Epoch 2/3
# 2457/2457 [==============================] - 0s 22us/step - loss: 1.1143
# Epoch 3/3
# 2457/2457 [==============================] - 0s 22us/step - loss: 1.0067
# Representation for DS in 0.324707 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3915.006785014982
# 2 	 -3179.2260910596 	0.1214	0.085752	0.187939
# 3 	 -2852.350849163988 	0.1029	0.028999	0.102816
# 4 	 -2696.1599239185825 	0.0422	28818.705078	0.054759
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 56.247885 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.23 sec)	logL: -20708.002
# Iter 2/3
# M step: done,  E step: done //  (in 0.44 sec)	logL: -19602.852	Tol1: 0.05337	Tol2: 0.04013
# Iter 3/3
# M step: done,  E step: done //  (in 0.46 sec)	logL: -18826.869	Tol1: 0.03959	Tol2: 0.02496
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Doing clustering...Done!
# Get init alphas in 0.002060 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 0.48 sec)	logL: -26468.092
# Iter 2/3
# M step: done,  E step: done //  (in 0.09 sec)	logL: -25581.295	Tol1: 0.03350	Tol2: 0.35844	Tol3: 0.04397
# Iter 3/3
# M step: done,  E step: done //  (in 0.07 sec)	logL: -25043.873	Tol1: 0.02101	Tol2: 0.15064	Tol3: 0.00661
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.002569 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24700, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 2.75 sec)	logL: -20122.944
# Iter 2/3
# M step: done,  E step: done //  (in 1.79 sec)	logL: -19304.698	Tol1: 0.04066	Tol2: 0.19469
# Iter 3/3
# M step: done,  E step: done //  (in 1.77 sec)	logL: -18598.699	Tol1: 0.03657	Tol2: 0.19353
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.003045 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24700, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 2.50 sec)	logL: -12629.279
# Iter 2/3
# M step: done,  E step: done //  (in 2.01 sec)	logL: -11917.301	Tol1: 0.05638	Tol2: 0.20775
# Iter 3/3
# M step: done,  E step: done //  (in 1.97 sec)	logL: -11489.036	Tol1: 0.03594	Tol2: 0.15342
# Finished training!
# Needed params (units,deep,drop,BatchN?)
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# A = Son ortonormales / No fueron entregados!
# Doing clustering...Done!
# Get init alphas in 0.002634 mins
# Lambda by group:  [1. 1. 1. 1. 1.]
# Pre-train networks over *g* on 15 epochs... Done!
# Pre-train networks over *z* on 3 epochs... Done!
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (24700, 5, 3)
# Iter 1/3
# M step: done,  E step: done //  (in 1.24 sec)	logL: -11548.965
# Iter 2/3
# M step: done,  E step: done //  (in 0.29 sec)	logL: -8842.548	Tol1: 0.23434	Tol2: 0.51053
# Iter 3/3
# M step: done,  E step: done //  (in 0.29 sec)	logL: -7955.056	Tol1: 0.10037	Tol2: 0.36228
# Finished training!
# Epoch 1/3
# 2457/2457 [==============================] - 0s 92us/step - loss: 1.0899
# Epoch 2/3
# 2457/2457 [==============================] - 0s 31us/step - loss: 1.0011
# Epoch 3/3
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9522
# Representation for DS in 0.335525 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -4078.202822338915
# 2 	 -3296.998364796005 	0.1438	0.072557	0.191556
# 3 	 -2947.086865653484 	0.0984	362.843658	0.106130
# 4 	 -2789.361992116831 	0.0334	30415.675781	0.053519
# Class marginals
# [0.39 0.26 0.35]
# Estimation for DS in 58.097639 sec
# Done

# %%
import pandas as pd
df = pd.DataFrame({"Raykar exec": raykar_exec, "Raykar init": raykar_init, "Our exec": ourglobal_exec,
                  "Our init": ourglobal_init, "MV exec": mv_exec, "DS exec": ds_exec, 
                   "Our Indiv1 exec" : ourindiv1_exec,  "Our Indiv1 init" : ourindiv1_init,
                  "Our Indiv2 exec" : ourindiv2_exec,  "Our Indiv2 init" : ourindiv2_init,
                  "Our Indiv3 exec" : ourindiv3_exec,  "Our Indiv3 init" : ourindiv3_init,})
df.to_csv("time_comparison_plus.csv",index=False)
df.head()
# Out:
#     DS exec   MV exec  Our Indiv1 exec  Our Indiv1 init  Our Indiv2 exec  \
# 0  0.132291  0.065010         0.287486         3.736800         0.126463
# 1  0.975954  0.066954         0.406767         4.852425         0.319860
# 2  2.133536  0.068780         0.627257         5.851800         0.623293
# 3  3.827759  0.071789         0.915009         7.570264         0.993230
# 4  5.009330  0.067654         1.138357         8.517406         1.243152
#
#    Our Indiv2 init  Our Indiv3 exec  Our Indiv3 init  Our exec  Our init  \
# 0         0.969529         0.253214         3.230355  0.073996  0.149442
# 1         0.942847         0.259529         3.253575  0.069329  0.138835
# 2         0.997235         0.265707         3.238368  0.066072  0.142427
# 3         1.008135         0.282217         3.366431  0.069243  0.142879
# 4         0.974031         0.288356         3.276839  0.072832  0.147962
#
#    Raykar exec  Raykar init
# 0     0.058902     0.005458
# 1     0.107056     0.094697
# 2     0.176887     0.232963
# 3     0.273047     0.426669
# 4     0.347169     0.566788

# %%
import pandas as pd
aux = pd.read_csv("time_comparison_plus.csv")
raykar_exec = aux["Raykar exec"]
raykar_init = aux["Raykar init"]
ourglobal_exec = aux["Our exec"]
ourglobal_init = aux["Our init"]
mv_exec = aux["MV exec"]
ds_exec = aux["DS exec"]
ourindiv1_exec = aux["Our Indiv1 exec"]
ourindiv1_init = aux["Our Indiv1 init"]
ourindiv2_exec = aux["Our Indiv2 exec"]
ourindiv2_init = aux["Our Indiv2 init"]
ourindiv3_exec = aux["Our Indiv3 exec"]
ourindiv3_init = aux["Our Indiv3 init"]

# %% [markdown]
# ### Comparison between Ours Global (CMM) and Raykar

# %%
plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
#plt.plot(to_check,mv_exec,'cs-',label="MV iter exec", markersize=ms)
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
#plt.legend()
plt.show()

plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
plt.plot(to_check,mv_exec,'cs-',label="MV iter exec", markersize=ms)
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Comparison between Alls -- Ours Global (CMM), Ours Individual and Raykar

# %%
plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
plt.plot(to_check,mv_exec,'cs-',label="MV iter exec", markersize=ms)
plt.plot(to_check,ds_exec,'v-',label="DS inference iter exec", color='orange', markersize=ms)

plt.plot(to_check,ourindiv1_exec,'X-',label="Ours-Indiv (model-T) iter exec", color='purple', markersize=ms)
plt.plot(to_check,ourindiv2_exec,'X-',label="Ours-Indiv (param-T) iter exec", color='magenta',markersize=ms)
plt.plot(to_check,ourindiv3_exec,'X-',label="Ours-Indiv (model-K) iter exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()


plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)

plt.plot(to_check,ourindiv1_exec,'X-',label="Ours-Indiv (model-T) iter exec", color='purple', markersize=ms)
plt.plot(to_check,ourindiv2_exec,'X-',label="Ours-Indiv (param-T) iter exec", color='magenta',markersize=ms)
plt.plot(to_check,ourindiv3_exec,'X-',label="Ours-Indiv (model-K) iter exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()

plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar iter exec", markersize=ms)
plt.plot(to_check,ourglobal_exec,'g*-',label="Our-Global iter exec", markersize=ms)
plt.plot(to_check,ourindiv3_exec,'X-',label="Ours-Indiv (model-K) iter exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
#plt.legend()
plt.show()
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Initiation time Comparison

# %%
plt.figure(figsize=(10,7))
plt.plot(to_check,raykar_init,'bo-',label="Raykar init exec", markersize=ms)
plt.plot(to_check,ourglobal_init,'g*-',label="Our-Global init exec", markersize=ms)
plt.plot(to_check,ourindiv1_init,'X-',label="Ours-Indiv (model-T) init exec", color='purple', markersize=ms)
plt.plot(to_check,ourindiv2_init,'X-',label="Ours-Indiv (param-T) init exec", color='magenta', markersize=ms)
plt.plot(to_check,ourindiv3_init,'X-',label="Ours-Indiv (model-K) init exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()

plt.figure(figsize=(10,7))
plt.plot(to_check,raykar_init,'bo-',label="Raykar init exec", markersize=ms)
plt.plot(to_check,ourglobal_init,'g*-',label="Our-Global init exec", markersize=ms)
plt.plot(to_check,ourindiv2_init,'X-',label="Ours-Indiv (param-T) init exec", color='magenta', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# falta por el numero de iteraciones (El nuestro tiene mas)
R_iter = 15
Our_iter = 25
Our_iter2 = 20

plt.figure(figsize=(10,7))
plt.plot(to_check,raykar_init+raykar_exec*R_iter,'bo-',label="Raykar to conv", markersize=ms)
plt.plot(to_check,ourglobal_init+ourglobal_exec*Our_iter,'g*-',label="Our-Global to conv + groups", markersize=ms) 

plt.plot(to_check,ourindiv1_init+ourindiv1_exec*Our_iter2,'X-',label="Ours-Indiv (model-T) init exec", color='purple', markersize=ms)
plt.plot(to_check,ourindiv2_init+ourindiv2_exec*Our_iter2,'X-',label="Ours-Indiv (param-T) init exec", color='magenta', markersize=ms)
plt.plot(to_check,ourindiv3_init+ourindiv3_exec*Our_iter2,'X-',label="Ours-Indiv (model-K) init exec", color='hotpink', markersize=ms)

plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# falta por el numero de iteraciones (El nuestro tiene mas)
R_iter = 40
Our_iter = 40

plt.figure(figsize=(8,5))
plt.plot(to_check,raykar_init+raykar_exec*R_iter,'o-',label="Raykar init exec")
plt.plot(to_check,ourglobal_init+0.0021*60+ourglobal_exec*Our_iter,'o-',label="Our-Global init exec + groups")
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()

# %% [markdown]
# ### Future comparison
# ---

# %%
to_check = [100,500,2000,5000,10000,15000]
print("Simple Data")
N = 2500

T_data_test = np.arange(1,15,2)

plt.figure(figsize=(15,5))
for T_data in T_data_test:
    #fixint T_data
    D_t = [N*T_data/T for T in to_check]
    plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()

print("CIFAR Data")
N = 50000

T_data_test = np.arange(1,15,2)

plt.figure(figsize=(15,5))
for T_data in T_data_test:
    #fixint T_data
    D_t = [N*T_data/T for T in to_check]
    plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# Simple Data
# CIFAR Data

# %%
to_check = [100,500,1500,3500,6000,10000]
print("Simple Data")
N = 2500

plt.figure(figsize=(15,5))
T_data = 5 #5 para llegar solo a 10k o 10 para llegar a 15k
D_t = [N*T_data/T for T in to_check]
plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.ylim(0,20)

plt.show()

print("CIFAR Data")
N = 50000
T_data = 3 #para poder ver sparness factor mas bajos..
plt.figure(figsize=(15,5))
D_t = [N*T_data/T for T in to_check]
plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.ylim(0,100)
plt.show()
# Out:
# Simple Data
# CIFAR Data

# %%
np.linspace(100,10000,6)
# Out:
# array([  100.,  2080.,  4060.,  6040.,  8020., 10000.])

# %%
to_check = [25,100,500,2000,5000,10000]

# %%
N = Z_train.shape[0]
#fixing T_d
T_data = 5
print("T_d=",T_data)
D_t = np.asarray([N*T_data/T for T in to_check])

annot_acc = []
for Tmax in to_check:
    aux = []
    for _ in range(10):
        y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False,hard=True)
        aux.append(np.mean(GenerateData.yo_label == Z_train))
    annot_acc.append(np.mean(aux))
    
plt.figure(figsize=(8,5))
plt.plot(to_check,D_t/N,'o-',label="Sparseness factor")
plt.plot(to_check,annot_acc,'o-',label="Acc annotators")
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# T_d= 5
