# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras, time, sys, os, gc
from code.generate_data import SinteticData
from code.representation import *
from code.utils import *
from code.learning_models import *
from code.baseline import RaykarMC,LabelInference
from code.MixtureofGroups import GroupMixtureOpt

import matplotlib
font = {'family' : 'normal',
        'size'   : 15}
matplotlib.rc('font', **font)

matplotlib.rc('axes', titlesize=25)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=25)    # fontsize of the x and y labels
#plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
#plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

to_check = [100,2000,5000,10000,15000,25000,40000]
to_check
# Out:
# /home/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [100, 2000, 5000, 10000, 15000, 25000, 40000]

# %%
memory_cons = []
N = 50000
K = 10
for t in to_check:
    print(t)
    a = np.zeros((N,t,K),dtype='float32') #int8
    memory_cons.append(a.nbytes/(1024*1024)) #MB

plt.figure(figsize=(10,7))
ours_consume = np.zeros((N,K),dtype='float32').nbytes/(1024*1024)
print("CIFAR example 50k exaples, 10 classes")
plt.plot(to_check,memory_cons,'bo-',label="Repeat consume")
#plt.hlines(ours_consume,0,25000, 'g' , label="Global consume")
plt.plot(to_check,np.tile(ours_consume,len(to_check)),'g*-',label="Global consume")
plt.hlines(16000,0,to_check[-1], color='r', label="Our memory limit")

plt.xticks(to_check)
plt.ylabel("MB")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# 100
# 2000
# 5000
# 10000
# 15000
# 25000
# CIFAR example 50k exaples, 10 classes

# %%
folder = "."
X_train = np.loadtxt(folder+"/synthetic/simple/datasim_X_train.csv",delimiter=',')
Z_train = np.loadtxt(folder+"/synthetic/simple/datasim_Z_train.csv",dtype='int') #groudn truth

X_test = np.loadtxt(folder+"/synthetic/simple/datasim_X_test.csv",delimiter=',')
Z_test = np.loadtxt(folder+"/synthetic/simple/datasim_Z_test.csv",dtype='int') #groudn truth
N = Z_train.shape[0]
GenerateData = SinteticData(state=None)

#CONFUSION MATRIX CHOOSE
GenerateData.set_probas(asfile=True,file_matrix='./synthetic/simple/matrix_datasim_normal.csv',file_groups ='./synthetic/simple/groups_datasim_normal.csv')

#GenerateData.set_probas(asfile=True,file_matrix=path+'/synthetic/simple/matrix_datasim_badMV.csv',file_groups =path+'/synthetic/simple/groups_datasim_badMV.csv')

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
to_check = [100,2000,5000,10000,15000,25000,40000]
T_data = 10 

annot_acc = []
raykar_exec = []
raykar_init = []
ourglobal_exec = []
ourglobal_init = []
mv_exec = []
ds_exec = []
for Tmax in to_check:
    aux_annot_acc = []
    aux_raykar_exec = []
    aux_raykar_init = []
    aux_ourglobal_exec = []
    aux_ourglobal_init = []
    aux_mv_exec = []
    aux_ds_exec = []
    for _ in range(10):

        y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False,hard=True)

        #annot_acc.append(np.mean(GenerateData.yo_label == Z_train))

        #get representation needed for Raykar
        y_obs_categorical = set_representation(y_obs,'onehot') 

        raykarMC = RaykarMC(X_train.shape[1:],y_obs_categorical.shape[-1],Tmax,epochs=1)
        raykarMC.define_model("mlp",16,1,BatchN=False,drop=0.2)
        logL_hists,i = raykarMC.multiples_run(1,X_train,y_obs_categorical,max_iter=2)

        aux_raykar_exec.append(raykarMC.current_exectime)
        aux_raykar_init.append(raykarMC.init_exectime)

        del raykarMC
        gc.collect()
        keras.backend.clear_session()

        r_obs = set_representation(y_obs,"repeat")
        gMixture_Global = GroupMixtureOpt(X_train.shape[1:],Kl=r_obs.shape[1],M=5,epochs=1,pre_init=0) 
        gMixture_Global.define_model("mlp",16,1,BatchN=False,drop=0.2)
        gMixture_Global.lambda_random = True #with lambda random --necessary
        logL_hists,i_r = gMixture_Global.multiples_run(1,X_train,r_obs,max_iter=2,cluster=True)

        aux_ourglobal_exec.append(gMixture_Global.current_exectime)
        aux_ourglobal_init.append(gMixture_Global.init_exectime)
    
        del gMixture_Global
        gc.collect()
        keras.backend.clear_session()
        
        mv_soft = majority_voting(r_obs,repeats=True,probas=True) 
        time_callback = TimeHistory()
        model_mvsoft = MLP_Keras(X_train.shape[1:],mv_soft.shape[1],16,1,BN=False,drop=0.2)
        model_mvsoft.compile(loss='categorical_crossentropy',optimizer='adam')
        model_mvsoft.fit(X_train, mv_soft, epochs=2,batch_size=64,verbose=1,callbacks=[time_callback])
        times = time_callback.times
        aux_mv_exec.append(times[-1])
        
        #AND DS???????
        label_I = LabelInference(y_obs,1e-10, type_inf = 'ds', max_iter=3)
        ds_labels,ds_conf = label_I.DS_labels()
        aux_ds_exec.append(label_I.DS_current_exectime)
        
    raykar_exec.append(np.mean(aux_raykar_exec))
    raykar_init.append(np.mean(aux_raykar_init))
    ourglobal_exec.append(np.mean(aux_ourglobal_exec))
    ourglobal_init.append(np.mean(aux_ourglobal_init))
    mv_exec.append(np.mean(aux_mv_exec))
    ds_exec.append(np.mean(aux_ds_exec))
    
raykar_exec = np.asarray(raykar_exec)
raykar_init = np.asarray(raykar_init)
ourglobal_exec = np.asarray(ourglobal_exec)
ourglobal_init = np.asarray(ourglobal_init)
mv_exec = np.asarray(mv_exec)
ds_exec = np.asarray(ds_exec)
print("Done")
# Out:
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.64 sec)	logL: -18064.969
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -16563.195	Tol1: 0.08313	Tol2: 0.28646
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.006603 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.6121725  0.57657105 0.26334342 0.5951035  0.95249176]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.54 sec)	logL: -24830.978
# Iter 2/2
# M step: done,  E step: done //  (in 0.35 sec)	logL: -23789.535	Tol1: 0.04194	Tol2: 0.43851	Tol3: 0.06482
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 169us/step - loss: 1.0738
# Epoch 2/2
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9915
# Representation for DS in 0.878959 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18102.38024233045
# 2 	 -16869.633187710206 	0.4071	0.265678	0.068099
# 3 	 -16568.99247825827 	0.0934	0.199150	0.017821
# 4 	 -16481.17123135712 	0.0502	0.141290	0.005300
# Class marginals
# [0.38 0.33 0.29]
# Estimation for DS in 1.417337 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.84 sec)	logL: -17882.207
# Iter 2/2
# M step: done,  E step: done //  (in 0.17 sec)	logL: -16212.953	Tol1: 0.09335	Tol2: 0.28791
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003918 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.66 0.29 0.44 0.74 0.69]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.90 sec)	logL: -25116.194
# Iter 2/2
# M step: done,  E step: done //  (in 0.29 sec)	logL: -23745.121	Tol1: 0.05459	Tol2: 0.48034	Tol3: 0.09817
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 177us/step - loss: 1.1222
# Epoch 2/2
# 2457/2457 [==============================] - 0s 23us/step - loss: 1.0069
# Representation for DS in 0.826340 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18004.89494703969
# 2 	 -16726.017570189622 	0.3898	0.276342	0.071029
# 3 	 -16431.307822970793 	0.0887	0.202938	0.017620
# 4 	 -16352.270655476184 	0.0435	0.141100	0.004810
# Class marginals
# [0.38 0.33 0.29]
# Estimation for DS in 2.145400 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.17 sec)	logL: -18418.242
# Iter 2/2
# M step: done,  E step: done //  (in 0.25 sec)	logL: -16816.047	Tol1: 0.08699	Tol2: 0.28028
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.007922 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.76 0.05 0.63 0.08 0.31]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.07 sec)	logL: -26878.105
# Iter 2/2
# M step: done,  E step: done //  (in 0.25 sec)	logL: -24763.099	Tol1: 0.07869	Tol2: 0.61277	Tol3: 0.15180
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 95us/step - loss: 1.0238
# Epoch 2/2
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9316
# Representation for DS in 0.792380 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18706.268010683496
# 2 	 -17462.56642629876 	0.3233	0.283117	0.066486
# 3 	 -17226.642903286145 	0.0751	0.202018	0.013510
# 4 	 -17157.03353582227 	0.0370	0.144666	0.004041
# Class marginals
# [0.37 0.33 0.3 ]
# Estimation for DS in 2.207368 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.65 sec)	logL: -18562.340
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -16994.717	Tol1: 0.08445	Tol2: 0.27296
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.005209 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.64 0.4  0.13 0.59 0.42]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.12 sec)	logL: -23927.011
# Iter 2/2
# M step: done,  E step: done //  (in 0.33 sec)	logL: -22569.113	Tol1: 0.05675	Tol2: 0.62405	Tol3: 0.14612
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 148us/step - loss: 1.0642
# Epoch 2/2
# 2457/2457 [==============================] - 0s 29us/step - loss: 0.9782
# Representation for DS in 0.866973 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18683.35388244213
# 2 	 -17447.23867195452 	0.3548	0.278028	0.066161
# 3 	 -17186.826820661496 	0.0944	0.203242	0.014926
# 4 	 -17110.00582827095 	0.0361	0.147374	0.004470
# Class marginals
# [0.35 0.33 0.32]
# Estimation for DS in 2.236248 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.18 sec)	logL: -18812.281
# Iter 2/2
# M step: done,  E step: done //  (in 0.16 sec)	logL: -17193.867	Tol1: 0.08603	Tol2: 0.27836
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.006816 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.8  0.51 0.1  0.72 0.61]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.22 sec)	logL: -25540.906
# Iter 2/2
# M step: done,  E step: done //  (in 0.32 sec)	logL: -23985.569	Tol1: 0.06090	Tol2: 0.46807	Tol3: 0.05100
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 123us/step - loss: 1.2316
# Epoch 2/2
# 2457/2457 [==============================] - 0s 38us/step - loss: 1.0910
# Representation for DS in 0.866260 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18505.26919547843
# 2 	 -17256.516676494488 	0.3511	0.277601	0.067481
# 3 	 -16962.639950041335 	0.0867	0.206390	0.017030
# 4 	 -16887.062902774956 	0.0451	0.147062	0.004456
# Class marginals
# [0.37 0.34 0.3 ]
# Estimation for DS in 1.952707 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.86 sec)	logL: -18730.803
# Iter 2/2
# M step: done,  E step: done //  (in 0.24 sec)	logL: -17012.471	Tol1: 0.09174	Tol2: 0.28722
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.005538 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.23 0.98 0.06 0.35 0.73]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.05 sec)	logL: -25095.090
# Iter 2/2
# M step: done,  E step: done //  (in 0.28 sec)	logL: -24161.016	Tol1: 0.03722	Tol2: 0.39331	Tol3: 0.07269
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 159us/step - loss: 1.2107
# Epoch 2/2
# 2457/2457 [==============================] - 0s 35us/step - loss: 1.0902
# Representation for DS in 0.606305 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18943.35215745085
# 2 	 -17640.99340030692 	0.2900	0.302483	0.068750
# 3 	 -17447.591454669153 	0.0640	0.209272	0.010963
# 4 	 -17413.89674552882 	0.0249	0.146820	0.001931
# Class marginals
# [0.35 0.33 0.32]
# Estimation for DS in 2.197704 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.33 sec)	logL: -18415.883
# Iter 2/2
# M step: done,  E step: done //  (in 0.18 sec)	logL: -16680.184	Tol1: 0.09425	Tol2: 0.28435
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.005394 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.5  0.36 0.89 0.96 0.51]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.15 sec)	logL: -23633.195
# Iter 2/2
# M step: done,  E step: done //  (in 0.19 sec)	logL: -22278.641	Tol1: 0.05732	Tol2: 0.53693	Tol3: 0.14367
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 163us/step - loss: 1.1417
# Epoch 2/2
# 2457/2457 [==============================] - 0s 21us/step - loss: 1.0540
# Representation for DS in 0.906624 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18315.340874017995
# 2 	 -17076.352892603267 	0.3541	0.271842	0.067648
# 3 	 -16807.50549055137 	0.0844	0.200906	0.015744
# 4 	 -16738.24253418818 	0.0442	0.139201	0.004121
# Class marginals
# [0.37 0.33 0.3 ]
# Estimation for DS in 1.780845 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.73 sec)	logL: -18204.105
# Iter 2/2
# M step: done,  E step: done //  (in 0.08 sec)	logL: -16430.570	Tol1: 0.09743	Tol2: 0.29290
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.007739 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.94 0.31 0.05 0.18 0.15]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.38 sec)	logL: -25362.868
# Iter 2/2
# M step: done,  E step: done //  (in 0.34 sec)	logL: -23996.576	Tol1: 0.05387	Tol2: 0.51779	Tol3: 0.12551
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 180us/step - loss: 1.0280
# Epoch 2/2
# 2457/2457 [==============================] - 0s 39us/step - loss: 0.9526
# Representation for DS in 1.034237 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18598.222047273444
# 2 	 -17278.81877037685 	0.3337	0.286791	0.070942
# 3 	 -17030.97699804837 	0.0764	0.209068	0.014344
# 4 	 -16987.15135471967 	0.0340	0.136063	0.002573
# Class marginals
# [0.36 0.33 0.31]
# Estimation for DS in 2.332769 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.28 sec)	logL: -18644.098
# Iter 2/2
# M step: done,  E step: done //  (in 0.18 sec)	logL: -17137.660	Tol1: 0.08080	Tol2: 0.26101
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003824 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.29 0.   0.38 0.96 0.49]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.19 sec)	logL: -24386.494
# Iter 2/2
# M step: done,  E step: done //  (in 0.35 sec)	logL: -23281.358	Tol1: 0.04532	Tol2: 0.59050	Tol3: 0.09027
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 151us/step - loss: 1.0004
# Epoch 2/2
# 2457/2457 [==============================] - 0s 38us/step - loss: 0.9412
# Representation for DS in 0.606198 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18459.490022866485
# 2 	 -17286.425685732713 	0.3745	0.265329	0.063548
# 3 	 -16989.523261513936 	0.0995	0.206538	0.017175
# 4 	 -16899.37645963434 	0.0388	0.154228	0.005306
# Class marginals
# [0.36 0.33 0.31]
# Estimation for DS in 1.461020 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (100, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.73 sec)	logL: -18292.832
# Iter 2/2
# M step: done,  E step: done //  (in 0.18 sec)	logL: -16678.383	Tol1: 0.08826	Tol2: 0.28942
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003873 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.95 0.46 0.35 0.4  0.95]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.00 sec)	logL: -25924.663
# Iter 2/2
# M step: done,  E step: done //  (in 0.27 sec)	logL: -24431.989	Tol1: 0.05758	Tol2: 0.70642	Tol3: 0.11876
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 1s 204us/step - loss: 1.0141
# Epoch 2/2
# 2457/2457 [==============================] - 0s 34us/step - loss: 0.9633
# Representation for DS in 1.018862 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -18755.17144313365
# 2 	 -17403.38380866172 	0.3142	0.295278	0.072075
# 3 	 -17169.372504596045 	0.0698	0.215153	0.013446
# 4 	 -17132.222683742035 	0.0291	0.140075	0.002164
# Class marginals
# [0.35 0.34 0.31]
# Estimation for DS in 2.364257 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.48 sec)	logL: -19579.648
# Iter 2/2
# M step: done,  E step: done //  (in 0.34 sec)	logL: -17760.822	Tol1: 0.09289	Tol2: 0.13702
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.005280 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.44 0.33 0.72 0.58 0.21]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.84 sec)	logL: -27558.805
# Iter 2/2
# M step: done,  E step: done //  (in 0.35 sec)	logL: -25378.706	Tol1: 0.07911	Tol2: 0.56273	Tol3: 0.20016
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 163us/step - loss: 1.2474
# Epoch 2/2
# 2457/2457 [==============================] - 0s 23us/step - loss: 1.1212
# Representation for DS in 14.291887 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15761.268983534677
# 2 	 -13427.098001687023 	0.3622	0.340543	0.148095
# 3 	 -12930.432959364633 	0.0405	0.280143	0.036990
# 4 	 -12803.481241468791 	0.0184	2592.739014	0.009818
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 13.965108 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.47 sec)	logL: -19608.445
# Iter 2/2
# M step: done,  E step: done //  (in 0.25 sec)	logL: -17923.207	Tol1: 0.08594	Tol2: 0.12723
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.004628 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.   0.01 0.26 0.   0.84]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.22 sec)	logL: -25353.086
# Iter 2/2
# M step: done,  E step: done //  (in 0.30 sec)	logL: -23370.068	Tol1: 0.07822	Tol2: 0.86990	Tol3: 0.22673
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 124us/step - loss: 1.0231
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9356
# Representation for DS in 14.086612 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15677.733558312488
# 2 	 -13409.904390685278 	0.3538	0.339372	0.144653
# 3 	 -12928.943598622842 	0.0379	370.648071	0.035866
# 4 	 -12780.532405203277 	0.0200	2621.367676	0.011479
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 15.035070 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.22 sec)	logL: -19851.486
# Iter 2/2
# M step: done,  E step: done //  (in 0.30 sec)	logL: -18142.645	Tol1: 0.08608	Tol2: 0.14060
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003577 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.95 0.99 0.96 0.11 0.02]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.34 sec)	logL: -24412.970
# Iter 2/2
# M step: done,  E step: done //  (in 0.29 sec)	logL: -23604.122	Tol1: 0.03313	Tol2: 0.44497	Tol3: 0.05074
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 169us/step - loss: 1.0857
# Epoch 2/2
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9977
# Representation for DS in 13.461514 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15883.587612066072
# 2 	 -13499.168055416767 	0.3700	0.347610	0.150118
# 3 	 -12984.904878440295 	0.0431	0.288866	0.038096
# 4 	 -12855.755166753905 	0.0167	1296.457397	0.009946
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 12.610574 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.18 sec)	logL: -19793.785
# Iter 2/2
# M step: done,  E step: done //  (in 0.34 sec)	logL: -18127.389	Tol1: 0.08419	Tol2: 0.13083
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003609 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.59 0.54 0.93 0.67 0.16]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.90 sec)	logL: -24173.456
# Iter 2/2
# M step: done,  E step: done //  (in 0.26 sec)	logL: -23254.390	Tol1: 0.03802	Tol2: 0.42785	Tol3: 0.06486
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 151us/step - loss: 1.0394
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9599
# Representation for DS in 13.741067 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15851.878490593002
# 2 	 -13563.675890552426 	0.3556	0.340884	0.144349
# 3 	 -13070.600790406119 	0.0412	370.652100	0.036353
# 4 	 -12935.796462277067 	0.0168	2777.929443	0.010314
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 13.291768 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.96 sec)	logL: -19744.453
# Iter 2/2
# M step: done,  E step: done //  (in 0.30 sec)	logL: -18139.080	Tol1: 0.08131	Tol2: 0.13623
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003468 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.11 0.72 0.44 1.   0.02]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.03 sec)	logL: -25125.270
# Iter 2/2
# M step: done,  E step: done //  (in 0.27 sec)	logL: -23704.335	Tol1: 0.05655	Tol2: 0.62180	Tol3: 0.15902
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 147us/step - loss: 1.1265
# Epoch 2/2
# 2457/2457 [==============================] - 0s 20us/step - loss: 1.0160
# Representation for DS in 12.443247 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15837.970706746039
# 2 	 -13520.57031144879 	0.3589	0.347706	0.146319
# 3 	 -13039.709291643021 	0.0424	370.653656	0.035565
# 4 	 -12901.77615713494 	0.0231	1852.023071	0.010578
# Class marginals
# [0.37 0.3  0.32]
# Estimation for DS in 10.765194 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.34 sec)	logL: -19751.883
# Iter 2/2
# M step: done,  E step: done //  (in 0.24 sec)	logL: -18087.207	Tol1: 0.08428	Tol2: 0.12743
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.004041 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.98 0.37 0.52 0.13 0.88]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.31 sec)	logL: -24872.553
# Iter 2/2
# M step: done,  E step: done //  (in 0.26 sec)	logL: -23843.432	Tol1: 0.04138	Tol2: 0.43045	Tol3: 0.09752
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 173us/step - loss: 1.2402
# Epoch 2/2
# 2457/2457 [==============================] - 0s 33us/step - loss: 1.1041
# Representation for DS in 16.390605 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15940.23129724399
# 2 	 -13633.363233493848 	0.3357	0.345484	0.144720
# 3 	 -13146.245603946914 	0.0458	741.025452	0.035730
# 4 	 -13006.372014955496 	0.0203	740.903503	0.010640
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 12.289130 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.35 sec)	logL: -19768.908
# Iter 2/2
# M step: done,  E step: done //  (in 0.23 sec)	logL: -17949.861	Tol1: 0.09202	Tol2: 0.14025
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.004900 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.72 0.5  0.37 0.83 0.08]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.50 sec)	logL: -23902.882
# Iter 2/2
# M step: done,  E step: done //  (in 0.33 sec)	logL: -22945.882	Tol1: 0.04004	Tol2: 0.41554	Tol3: 0.04026
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 145us/step - loss: 1.0749
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9905
# Representation for DS in 14.281938 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15921.972328481028
# 2 	 -13586.641981763327 	0.3547	0.346779	0.146673
# 3 	 -13114.352796613006 	0.0386	0.281868	0.034761
# 4 	 -12979.023654758454 	0.0205	2592.741455	0.010319
# Class marginals
# [0.37 0.31 0.32]
# Estimation for DS in 12.499570 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.25 sec)	logL: -19874.422
# Iter 2/2
# M step: done,  E step: done //  (in 0.36 sec)	logL: -18199.908	Tol1: 0.08425	Tol2: 0.12587
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.007261 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.49 0.86 0.94 0.83 0.91]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.19 sec)	logL: -24506.613
# Iter 2/2
# M step: done,  E step: done //  (in 0.41 sec)	logL: -23537.955	Tol1: 0.03953	Tol2: 0.43689	Tol3: 0.05927
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 140us/step - loss: 1.1229
# Epoch 2/2
# 2457/2457 [==============================] - 0s 24us/step - loss: 1.0080
# Representation for DS in 14.720691 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15822.49634365327
# 2 	 -13506.792301857387 	0.3516	0.345092	0.146355
# 3 	 -13006.760168662106 	0.0400	370.656158	0.037021
# 4 	 -12877.131402382445 	0.0176	1481.636230	0.009966
# Class marginals
# [0.38 0.3  0.31]
# Estimation for DS in 11.598859 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.32 sec)	logL: -19564.285
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -17755.961	Tol1: 0.09243	Tol2: 0.13445
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.004704 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.04 0.84 0.36 0.01 0.18]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.98 sec)	logL: -25210.601
# Iter 2/2
# M step: done,  E step: done //  (in 0.26 sec)	logL: -23265.712	Tol1: 0.07715	Tol2: 0.56065	Tol3: 0.19000
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 172us/step - loss: 0.9796
# Epoch 2/2
# 2457/2457 [==============================] - 0s 37us/step - loss: 0.9245
# Representation for DS in 13.513997 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15900.029277538593
# 2 	 -13611.84371343186 	0.3522	0.345086	0.143911
# 3 	 -13146.016072998866 	0.0374	0.281760	0.034222
# 4 	 -12992.68466256572 	0.0185	1111.497070	0.011664
# Class marginals
# [0.38 0.31 0.31]
# Estimation for DS in 11.882696 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (2000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.47 sec)	logL: -20263.572
# Iter 2/2
# M step: done,  E step: done //  (in 0.23 sec)	logL: -18657.367	Tol1: 0.07927	Tol2: 0.11995
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.005402 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.84 0.54 0.08 0.7  0.83]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.25 sec)	logL: -28569.104
# Iter 2/2
# M step: done,  E step: done //  (in 0.27 sec)	logL: -26751.941	Tol1: 0.06361	Tol2: 0.56062	Tol3: 0.05011
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 178us/step - loss: 1.1625
# Epoch 2/2
# 2457/2457 [==============================] - 0s 21us/step - loss: 1.0446
# Representation for DS in 13.212873 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -15887.150163688186
# 2 	 -13583.490456036234 	0.3659	0.338508	0.145001
# 3 	 -13094.974328937025 	0.0429	0.275776	0.035964
# 4 	 -12952.495169812797 	0.0193	1296.557983	0.010880
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 12.480654 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.74 sec)	logL: -20428.451
# Iter 2/2
# M step: done,  E step: done //  (in 0.40 sec)	logL: -19116.961	Tol1: 0.06420	Tol2: 0.07587
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002190 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.77 0.97 0.41 0.22 0.08]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -26655.394
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -25298.483	Tol1: 0.05091	Tol2: 0.41863	Tol3: 0.10565
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 110us/step - loss: 1.2556
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 1.1239
# Representation for DS in 21.148200 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12369.688534349714
# 2 	 -9685.31413155399 	0.3422	0.270356	0.217012
# 3 	 -9130.312886201784 	0.0302	6488.787109	0.057303
# 4 	 -8969.694140215897 	0.0161	54987.382812	0.017592
# Class marginals
# [0.38 0.29 0.33]
# Estimation for DS in 17.370632 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.02 sec)	logL: -20209.854
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -18760.326	Tol1: 0.07172	Tol2: 0.08099
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002909 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.12 0.56 0.2  0.17 0.25]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -24015.361
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -22649.247	Tol1: 0.05688	Tol2: 0.48180	Tol3: 0.08711
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 107us/step - loss: 1.0535
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9701
# Representation for DS in 21.110473 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12342.102263276494
# 2 	 -9655.325905916618 	0.3749	0.264629	0.217692
# 3 	 -9088.778781430918 	0.0336	8292.119141	0.058677
# 4 	 -8927.048366963196 	0.0138	48171.636719	0.017795
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 17.372559 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.04 sec)	logL: -20459.709
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -19050.311	Tol1: 0.06889	Tol2: 0.07956
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002549 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.8  0.15 0.87 0.51 0.45]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.60 sec)	logL: -25286.593
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -24070.935	Tol1: 0.04808	Tol2: 0.44721	Tol3: 0.07458
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 93us/step - loss: 1.0437
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9810
# Representation for DS in 22.963749 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12413.115526034568
# 2 	 -9713.297092612982 	0.3539	0.271127	0.217497
# 3 	 -9080.107473892116 	0.0292	7710.041016	0.065188
# 4 	 -8913.661600828083 	0.0137	52811.785156	0.018331
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 17.187637 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.94 sec)	logL: -20421.322
# Iter 2/2
# M step: done,  E step: done //  (in 0.21 sec)	logL: -18794.830	Tol1: 0.07965	Tol2: 0.08728
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002466 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.43 0.06 0.58 0.33 0.61]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -24402.376
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23463.072	Tol1: 0.03849	Tol2: 0.39784	Tol3: 0.04423
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 104us/step - loss: 0.9508
# Epoch 2/2
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9100
# Representation for DS in 21.999463 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12489.091503738968
# 2 	 -9752.101978179113 	0.3590	0.278730	0.219150
# 3 	 -9195.821693504136 	0.0249	7605.982422	0.057042
# 4 	 -9035.61685112233 	0.0132	53344.328125	0.017421
# Class marginals
# [0.39 0.3  0.31]
# Estimation for DS in 17.574785 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.97 sec)	logL: -20384.344
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -18896.773	Tol1: 0.07298	Tol2: 0.08307
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002438 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.15 0.43 0.04 0.66 0.07]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.74 sec)	logL: -25114.586
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23422.366	Tol1: 0.06738	Tol2: 0.52199	Tol3: 0.12501
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 107us/step - loss: 1.1053
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.0174
# Representation for DS in 21.099285 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12475.612468238161
# 2 	 -9803.054942143173 	0.3510	0.272373	0.214223
# 3 	 -9205.666645634994 	0.0315	7714.053711	0.060939
# 4 	 -9022.07990516204 	0.0138	48568.757812	0.019943
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 16.870456 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.03 sec)	logL: -20690.904
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -19313.848	Tol1: 0.06655	Tol2: 0.07744
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002172 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.88 0.78 0.6  0.71 0.11]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.62 sec)	logL: -24585.882
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -23419.838	Tol1: 0.04743	Tol2: 0.54322	Tol3: 0.12155
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 89us/step - loss: 1.2170
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 1.1121
# Representation for DS in 21.437862 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12519.71917609718
# 2 	 -9778.66353681919 	0.3606	0.271473	0.218939
# 3 	 -9193.444703812573 	0.0359	6861.696777	0.059847
# 4 	 -9024.503362421396 	0.0157	48967.058594	0.018376
# Class marginals
# [0.38 0.31 0.32]
# Estimation for DS in 16.902971 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.03 sec)	logL: -20485.402
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -19196.328	Tol1: 0.06293	Tol2: 0.07312
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002710 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.14 0.58 0.78 0.48 0.16]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -26015.514
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23966.660	Tol1: 0.07876	Tol2: 0.54381	Tol3: 0.21916
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 95us/step - loss: 1.0568
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 0.9801
# Representation for DS in 23.342194 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12403.536758607872
# 2 	 -9737.81465649485 	0.3538	0.267106	0.214916
# 3 	 -9115.363577045979 	0.0331	4853.868652	0.063921
# 4 	 -8935.747984424755 	0.0150	48965.503906	0.019705
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 17.477551 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.94 sec)	logL: -20086.027
# Iter 2/2
# M step: done,  E step: done //  (in 0.21 sec)	logL: -18816.340	Tol1: 0.06321	Tol2: 0.07782
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002299 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.03 0.22 0.05 0.74 0.14]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -27667.809
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -24838.567	Tol1: 0.10226	Tol2: 0.79579	Tol3: 0.24818
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 93us/step - loss: 1.2410
# Epoch 2/2
# 2457/2457 [==============================] - 0s 31us/step - loss: 1.0828
# Representation for DS in 21.124240 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12218.406966599412
# 2 	 -9569.208056723259 	0.3494	0.266400	0.216820
# 3 	 -8953.135362756175 	0.0334	8806.127930	0.064381
# 4 	 -8773.626553079059 	0.0131	54816.128906	0.020050
# Class marginals
# [0.38 0.3  0.33]
# Estimation for DS in 16.679460 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.05 sec)	logL: -20305.344
# Iter 2/2
# M step: done,  E step: done //  (in 0.20 sec)	logL: -18784.924	Tol1: 0.07488	Tol2: 0.08536
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002568 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.96 0.05 0.99 0.22 0.67]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -24925.257
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23852.427	Tol1: 0.04304	Tol2: 0.44611	Tol3: 0.05570
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 92us/step - loss: 1.0139
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9525
# Representation for DS in 23.014491 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12653.449933485397
# 2 	 -9898.765692226018 	0.3558	0.270954	0.217702
# 3 	 -9275.663534188468 	0.0312	9272.575195	0.062947
# 4 	 -9106.278233304865 	0.0162	45795.597656	0.018261
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 17.456818 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (5000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.95 sec)	logL: -20054.566
# Iter 2/2
# M step: done,  E step: done //  (in 0.22 sec)	logL: -18659.299	Tol1: 0.06957	Tol2: 0.07883
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002170 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.65 0.26 0.55 0.07 0.05]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -24266.098
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23333.832	Tol1: 0.03842	Tol2: 0.37483	Tol3: 0.02709
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 90us/step - loss: 1.0118
# Epoch 2/2
# 2457/2457 [==============================] - 0s 23us/step - loss: 0.9488
# Representation for DS in 20.904650 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -12253.011791918085
# 2 	 -9595.10300517431 	0.3560	0.266378	0.216919
# 3 	 -9007.09074892566 	0.0349	5971.531738	0.061283
# 4 	 -8826.204518402905 	0.0200	54956.242188	0.020083
# Class marginals
# [0.37 0.3  0.32]
# Estimation for DS in 16.712295 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.11 sec)	logL: -20889.234
# Iter 2/2
# M step: done,  E step: done //  (in 0.32 sec)	logL: -19917.848	Tol1: 0.04650	Tol2: 0.04932
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002213 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.63 0.06 0.04 0.02 0.54]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.64 sec)	logL: -25425.403
# Iter 2/2
# M step: done,  E step: done //  (in 0.17 sec)	logL: -24075.823	Tol1: 0.05308	Tol2: 0.53063	Tol3: 0.12001
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 94us/step - loss: 1.1016
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 1.0168
# Representation for DS in 42.455841 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9071.665930934007
# 2 	 -6857.7766867122255 	0.3328	0.157154	0.244044
# 3 	 -6312.8884041865595 	0.0403	12599.409180	0.079456
# 4 	 -6145.373790019582 	0.0137	113932.539062	0.026535
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 31.127743 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.20 sec)	logL: -20884.457
# Iter 2/2
# M step: done,  E step: done //  (in 0.32 sec)	logL: -19745.715	Tol1: 0.05453	Tol2: 0.05370
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002605 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.8  0.83 0.23 0.86 0.92]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -24737.816
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23606.151	Tol1: 0.04575	Tol2: 0.49635	Tol3: 0.11883
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 112us/step - loss: 1.0650
# Epoch 2/2
# 2457/2457 [==============================] - 0s 32us/step - loss: 1.0030
# Representation for DS in 42.262872 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9164.505633048098
# 2 	 -6874.011464380672 	0.3412	0.160552	0.249931
# 3 	 -6340.405686796146 	0.0394	10321.802734	0.077627
# 4 	 -6158.6549430088535 	0.0195	116514.078125	0.028665
# Class marginals
# [0.38 0.3  0.32]
# Estimation for DS in 31.502769 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.16 sec)	logL: -20569.492
# Iter 2/2
# M step: done,  E step: done //  (in 0.29 sec)	logL: -19429.984	Tol1: 0.05540	Tol2: 0.05316
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002194 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.84 0.4  0.   0.64 0.72]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.58 sec)	logL: -25336.925
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -24025.328	Tol1: 0.05177	Tol2: 0.50044	Tol3: 0.07427
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 100us/step - loss: 1.2058
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 1.0698
# Representation for DS in 38.700601 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9156.662526846958
# 2 	 -6944.718648324761 	0.3445	0.156984	0.241567
# 3 	 -6389.394844661536 	0.0326	13732.626953	0.079963
# 4 	 -6183.283591951511 	0.0191	98096.000000	0.032258
# Class marginals
# [0.39 0.29 0.32]
# Estimation for DS in 29.906191 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.14 sec)	logL: -20832.430
# Iter 2/2
# M step: done,  E step: done //  (in 0.27 sec)	logL: -19840.496	Tol1: 0.04761	Tol2: 0.04915
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002163 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.   0.08 0.12 0.8  0.51]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.61 sec)	logL: -25934.541
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24533.169	Tol1: 0.05403	Tol2: 0.63671	Tol3: 0.11928
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 105us/step - loss: 1.0440
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9576
# Representation for DS in 38.017809 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9248.258872420336
# 2 	 -7033.442893267721 	0.3188	0.156175	0.239485
# 3 	 -6458.924614966036 	0.0440	10012.335938	0.081684
# 4 	 -6254.609917770953 	0.0196	111782.765625	0.031633
# Class marginals
# [0.37 0.3  0.33]
# Estimation for DS in 29.841952 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.18 sec)	logL: -20664.699
# Iter 2/2
# M step: done,  E step: done //  (in 0.27 sec)	logL: -19573.873	Tol1: 0.05279	Tol2: 0.05217
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002150 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.9  0.41 0.68 0.35 0.74]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.59 sec)	logL: -26563.356
# Iter 2/2
# M step: done,  E step: done //  (in 0.12 sec)	logL: -25179.418	Tol1: 0.05210	Tol2: 0.48195	Tol3: 0.11504
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 93us/step - loss: 1.0704
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9994
# Representation for DS in 42.742683 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9106.209883933307
# 2 	 -6880.167989405738 	0.3360	0.157043	0.244453
# 3 	 -6321.864754408265 	0.0377	14256.166992	0.081147
# 4 	 -6125.426201394767 	0.0168	108219.578125	0.031073
# Class marginals
# [0.38 0.29 0.33]
# Estimation for DS in 31.159029 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.28 sec)	logL: -20463.928
# Iter 2/2
# M step: done,  E step: done //  (in 0.30 sec)	logL: -19316.561	Tol1: 0.05607	Tol2: 0.05451
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002462 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.44 0.95 0.24 0.47 0.58]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -25256.767
# Iter 2/2
# M step: done,  E step: done //  (in 0.13 sec)	logL: -23475.557	Tol1: 0.07052	Tol2: 0.49974	Tol3: 0.12373
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 112us/step - loss: 1.0784
# Epoch 2/2
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9937
# Representation for DS in 37.928206 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9110.280746503016
# 2 	 -6893.449531027605 	0.3172	0.157026	0.243333
# 3 	 -6328.55588787496 	0.0297	9961.998047	0.081946
# 4 	 -6142.184184866725 	0.0171	102053.281250	0.029449
# Class marginals
# [0.38 0.28 0.34]
# Estimation for DS in 30.257841 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (10000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.25 sec)	logL: -20689.463
# Iter 2/2
# M step: done,  E step: done //  (in 0.33 sec)	logL: -19644.861	Tol1: 0.05049	Tol2: 0.04858
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003258 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.04 0.64 0.08 0.95 0.26]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -25230.563
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23690.787	Tol1: 0.06103	Tol2: 0.51393	Tol3: 0.12704
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 92us/step - loss: 0.9766
# Epoch 2/2
# 2457/2457 [==============================] - 0s 29us/step - loss: 0.9269
# Representation for DS in 38.345710 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -9035.410432013314
# ...
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -5460.3670057051395
# 2 	 -4223.0249588887855 	0.2145	0.080869	0.226604
# 3 	 -3757.903583064083 	0.0770	2982.332764	0.110139
# 4 	 -3577.172093283793 	0.0157	70135.132812	0.048094
# Class marginals
# [0.38 0.27 0.35]
# Estimation for DS in 51.190663 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (25000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.39 sec)	logL: -21089.113
# Iter 2/2
# M step: done,  E step: done //  (in 0.40 sec)	logL: -20155.223	Tol1: 0.04428	Tol2: 0.03703
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002237 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.12 0.37 0.44 0.92 0.55]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -25985.158
# Iter 2/2
# M step: done,  E step: done //  (in 0.16 sec)	logL: -24276.695	Tol1: 0.06575	Tol2: 0.48664	Tol3: 0.09059
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 88us/step - loss: 1.0486
# Epoch 2/2
# 2457/2457 [==============================] - 0s 24us/step - loss: 0.9824
# Representation for DS in 66.814986 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -5433.168429338466
# 2 	 -4223.996419399192 	0.2266	0.075066	0.222554
# 3 	 -3789.719170529243 	0.0715	3512.005371	0.102812
# 4 	 -3622.881976717818 	0.0158	67434.890625	0.044024
# Class marginals
# [0.37 0.28 0.35]
# Estimation for DS in 51.096811 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (25000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.74 sec)	logL: -20333.150
# Iter 2/2
# M step: done,  E step: done //  (in 0.42 sec)	logL: -19387.973	Tol1: 0.04648	Tol2: 0.03877
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.003292 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.35 0.26 0.2  0.16 0.32]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.64 sec)	logL: -23817.281
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -22611.567	Tol1: 0.05062	Tol2: 0.47071	Tol3: 0.10012
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 89us/step - loss: 0.9911
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 0.9252
# Representation for DS in 65.030233 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -5183.791189505567
# 2 	 -4080.676666928806 	0.1938	0.080237	0.212801
# 3 	 -3654.1297360834096 	0.0724	1868.551514	0.104528
# 4 	 -3482.542665459697 	0.0191	61494.902344	0.046957
# Class marginals
# [0.38 0.27 0.35]
# Estimation for DS in 50.138930 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.48 sec)	logL: -21016.746
# Iter 2/2
# M step: done,  E step: done //  (in 0.47 sec)	logL: -20217.873	Tol1: 0.03801	Tol2: 0.03221
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002790 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.33 0.13 0.92 0.65 0.15]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.69 sec)	logL: -26353.125
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24608.293	Tol1: 0.06621	Tol2: 0.54720	Tol3: 0.09621
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 93us/step - loss: 1.0220
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9539
# Representation for DS in 77.173717 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3984.571962679384
# 2 	 -3211.6363665940216 	0.1271	0.078592	0.193982
# 3 	 -2884.025033661983 	0.0920	0.030466	0.102008
# 4 	 -2742.0514787249763 	0.0307	31208.724609	0.049228
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 58.551922 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.41 sec)	logL: -20849.684
# Iter 2/2
# M step: done,  E step: done //  (in 0.45 sec)	logL: -20005.252	Tol1: 0.04050	Tol2: 0.03420
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002141 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.72 0.3  0.07 0.93 0.98]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.66 sec)	logL: -25672.269
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24018.295	Tol1: 0.06443	Tol2: 0.78027	Tol3: 0.16883
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 93us/step - loss: 1.0114
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9358
# Representation for DS in 80.157896 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3942.739015924878
# 2 	 -3160.320875382942 	0.1450	0.077554	0.198445
# 3 	 -2824.0445523000767 	0.0975	852.063538	0.106406
# 4 	 -2684.142622941899 	0.0377	29699.449219	0.049540
# Class marginals
# [0.38 0.27 0.35]
# Estimation for DS in 59.163325 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.50 sec)	logL: -21208.291
# Iter 2/2
# M step: done,  E step: done //  (in 0.45 sec)	logL: -20272.723	Tol1: 0.04411	Tol2: 0.03792
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002472 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.7  0.44 0.2  0.14 0.28]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.68 sec)	logL: -25194.920
# Iter 2/2
# M step: done,  E step: done //  (in 0.15 sec)	logL: -23546.486	Tol1: 0.06543	Tol2: 0.52565	Tol3: 0.15948
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 105us/step - loss: 1.0992
# Epoch 2/2
# 2457/2457 [==============================] - 0s 25us/step - loss: 1.0334
# Representation for DS in 82.144562 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -4057.945487434132
# 2 	 -3250.9979118720294 	0.1410	0.076039	0.198856
# 3 	 -2927.1234704602502 	0.0838	2408.684814	0.099623
# 4 	 -2781.094581379515 	0.0274	39629.414062	0.049888
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 60.008963 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.43 sec)	logL: -20913.047
# Iter 2/2
# M step: done,  E step: done //  (in 0.47 sec)	logL: -19899.910	Tol1: 0.04845	Tol2: 0.03833
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002465 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.39 0.16 0.63 0.02 0.87]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.63 sec)	logL: -26452.856
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -24195.659	Tol1: 0.08533	Tol2: 0.60274	Tol3: 0.21207
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 114us/step - loss: 1.0764
# Epoch 2/2
# 2457/2457 [==============================] - 0s 30us/step - loss: 0.9949
# Representation for DS in 79.231057 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3948.6292056718903
# 2 	 -3185.460324145862 	0.1165	0.083542	0.193274
# 3 	 -2844.7343568853485 	0.0871	724.904480	0.106963
# 4 	 -2684.3348013480368 	0.0323	27062.011719	0.056385
# Class marginals
# [0.37 0.25 0.37]
# Estimation for DS in 58.598449 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.38 sec)	logL: -20614.320
# Iter 2/2
# M step: done,  E step: done //  (in 0.47 sec)	logL: -19509.795	Tol1: 0.05358	Tol2: 0.04057
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002608 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.35 0.23 0.96 0.53 0.42]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -24959.028
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23746.292	Tol1: 0.04859	Tol2: 0.44807	Tol3: 0.07267
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 109us/step - loss: 1.0605
# Epoch 2/2
# 2457/2457 [==============================] - 0s 27us/step - loss: 0.9794
# Representation for DS in 77.376482 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3989.1456425180854
# 2 	 -3195.0609264340874 	0.1211	0.081309	0.199061
# 3 	 -2867.6489677802297 	0.0873	1860.578491	0.102474
# 4 	 -2731.151272907318 	0.0316	30193.488281	0.047599
# Class marginals
# [0.38 0.25 0.37]
# Estimation for DS in 58.451982 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.42 sec)	logL: -21275.859
# Iter 2/2
# M step: done,  E step: done //  (in 0.47 sec)	logL: -20485.182	Tol1: 0.03716	Tol2: 0.03282
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002159 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.72 0.74 0.28 0.04 0.75]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.57 sec)	logL: -24839.543
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -23408.199	Tol1: 0.05762	Tol2: 0.68125	Tol3: 0.15910
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 87us/step - loss: 1.0143
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9481
# Representation for DS in 79.368631 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3995.8061172329635
# 2 	 -3219.1842317421797 	0.1346	0.077350	0.194359
# 3 	 -2885.2849677113286 	0.0888	599.756348	0.103722
# 4 	 -2737.0369290006206 	0.0306	29287.015625	0.051381
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 60.299018 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.40 sec)	logL: -20932.820
# Iter 2/2
# M step: done,  E step: done //  (in 0.46 sec)	logL: -20143.498	Tol1: 0.03771	Tol2: 0.03291
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002614 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.66 0.04 0.75 0.23 0.13]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.65 sec)	logL: -26582.537
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -25174.387	Tol1: 0.05297	Tol2: 0.43217	Tol3: 0.09704
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 88us/step - loss: 1.0712
# Epoch 2/2
# 2457/2457 [==============================] - 0s 28us/step - loss: 0.9914
# Representation for DS in 77.414310 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3981.622668417396
# 2 	 -3182.2619309703973 	0.1375	0.079990	0.200763
# 3 	 -2856.008300123932 	0.1022	846.223755	0.102523
# 4 	 -2715.9812613866343 	0.0367	32779.921875	0.049029
# Class marginals
# [0.39 0.26 0.35]
# Estimation for DS in 58.324004 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.40 sec)	logL: -20945.742
# Iter 2/2
# M step: done,  E step: done //  (in 0.45 sec)	logL: -20044.277	Tol1: 0.04304	Tol2: 0.03692
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002182 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.09 0.33 0.17 0.53 0.25]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.57 sec)	logL: -24807.429
# Iter 2/2
# M step: done,  E step: done //  (in 0.12 sec)	logL: -22982.868	Tol1: 0.07355	Tol2: 0.75426	Tol3: 0.18061
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 102us/step - loss: 1.0211
# Epoch 2/2
# 2457/2457 [==============================] - 0s 26us/step - loss: 0.9542
# Representation for DS in 77.485945 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3942.2195401836902
# 2 	 -3183.655997143413 	0.1479	0.076852	0.192420
# 3 	 -2855.731437961512 	0.1012	282.263458	0.103003
# 4 	 -2709.16128545176 	0.0291	30179.474609	0.051325
# Class marginals
# [0.39 0.27 0.34]
# Estimation for DS in 58.233606 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.36 sec)	logL: -20779.117
# Iter 2/2
# M step: done,  E step: done //  (in 0.50 sec)	logL: -19781.754	Tol1: 0.04800	Tol2: 0.03829
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002444 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.65 0.62 0.73 0.29 0.01]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.67 sec)	logL: -25693.573
# Iter 2/2
# M step: done,  E step: done //  (in 0.17 sec)	logL: -23933.643	Tol1: 0.06850	Tol2: 0.72491	Tol3: 0.15529
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 107us/step - loss: 1.0871
# Epoch 2/2
# 2457/2457 [==============================] - 0s 31us/step - loss: 0.9865
# Representation for DS in 76.935329 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -4033.269228556083
# 2 	 -3226.038021923774 	0.1401	0.074488	0.200143
# 3 	 -2897.207913123128 	0.0904	1333.899048	0.101930
# 4 	 -2751.692318795428 	0.0254	36922.070312	0.050226
# Class marginals
# [0.4  0.25 0.35]
# Estimation for DS in 58.701891 sec
# Needed params (units,deep,drop,BatchN?)
# Initializing new EM...
# Betas shape:  (40000, 3, 3)
# Q estimate shape:  (2457, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 1.41 sec)	logL: -20502.395
# Iter 2/2
# M step: done,  E step: done //  (in 0.46 sec)	logL: -19633.402	Tol1: 0.04238	Tol2: 0.03484
# Finished training
# Needed params (units,deep,drop,BatchN?)
# Doing clustering...Done!
# Get init alphas in 0.002447 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.19 0.25 0.03 0.58 0.43]
# Alphas:  (5,)
# MV init:  (2457, 3)
# Betas:  (5, 3, 3)
# Q estimate:  (2457, 3, 5, 3)
# Iter 1/2
# M step: done,  E step: done //  (in 0.69 sec)	logL: -23768.370
# Iter 2/2
# M step: done,  E step: done //  (in 0.14 sec)	logL: -22515.801	Tol1: 0.05270	Tol2: 0.55590	Tol3: 0.13253
# Finished training!
# Epoch 1/2
# 2457/2457 [==============================] - 0s 91us/step - loss: 1.1011
# Epoch 2/2
# 2457/2457 [==============================] - 0s 24us/step - loss: 1.0052
# Representation for DS in 82.367305 sec
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -3891.3088819845607
# 2 	 -3108.983582079846 	0.1211	0.086276	0.201044
# 3 	 -2777.6808502335575 	0.0942	1062.025024	0.106563
# 4 	 -2627.7758704439048 	0.0349	31820.865234	0.053968
# Class marginals
# [0.38 0.26 0.36]
# Estimation for DS in 57.789325 sec
# Done

# %%
import pandas as pd
df = pd.DataFrame({"Raykar exec": raykar_exec, "Raykar init": raykar_init, "Our exec": ourglobal_exec,
                  "Our init": ourglobal_init, "MV exec": mv_exec, "DS exec": ds_exec})
df.to_csv("time_comparison.csv",index=False)
df.head()
# Out:
#     DS exec   MV exec  Our exec  Our init  Raykar exec  Raykar init
# 0  0.250600  0.079200  0.298502  0.009352     0.171685     0.010271
# 1  1.703965  0.067968  0.300040  0.009355     0.278917     0.170518
# 2  2.341949  0.067791  0.140558  0.004773     0.225573     0.282068
# 3  4.215937  0.069347  0.141013  0.004901     0.295861     0.479171
# 4  5.414651  0.068950  0.137257  0.004480     0.374893     0.638804

# %%
df = pd.read_csv("time_comparison.csv")
raykar_exec = df["Raykar exec"].values
raykar_init = df["Raykar init"].values
ourglobal_exec = df["Our exec"].values
ourglobal_init = df["Our init"].values
mv_exec = df["MV exec"].values
ds_exec = df["DS exec"].values

# %%
print("ITERATION TIME")
plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar time", markersize=8)
plt.plot(to_check,ourglobal_exec,'g*-',label="CMM time", markersize=8)
plt.xticks(to_check)

plt.ylabel("Seconds")
plt.xlabel("Annotators (T)")
#plt.legend()
plt.show()

plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_exec,'bo-',label="Raykar time", markersize=8)
plt.plot(to_check,ourglobal_exec,'g*-',label="CMM time", markersize=8)
plt.plot(to_check,mv_exec,'cs-',label="MV time", markersize=8)
plt.plot(to_check,ds_exec,'v-',label="DS time", color='orange', markersize=8)
#plt.plot(to_check,ds_exec+mv_exec,'p-',label="DS utility iter exec", color='orange')

plt.xticks(to_check)
plt.ylabel("Seconds")
plt.xlabel("Annotators (T)")
#plt.legend()
plt.show()
# Out:
# ITERATION TIME
# /home/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
print("INIT TIME")

plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_init,'bo-',label="Raykar time", markersize=8)
plt.plot(to_check,ourglobal_init,'g*-',label="CMM time", markersize=8)
plt.plot(to_check,ourglobal_init+0.0021*60,'m*-',label="CMM time + groups", markersize=8) #datacenter time
#plt.plot(to_check,ourglobal_init+0.0041*60,'m*-',label="Our-Global init exec + groups")# pc-casa time
plt.xticks(to_check)
plt.ylabel("sec")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# INIT TIME
# /home/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# falta por el numero de iteraciones (El nuestro tiene mas)
R_iter = 10
Our_iter = 25

plt.figure(figsize=(15,7))
plt.plot(to_check,raykar_init+raykar_exec*R_iter,'bo-',label="Raykar time", markersize=8)
#plt.plot(to_check,ourglobal_init+ourglobal_exec*Our_iter,'o-',label="Our-Global to conv")
plt.plot(to_check,ourglobal_init+0.0021*60+ourglobal_exec*Our_iter,'go-',label="CMM time", markersize=8)#datacenter
#plt.plot(to_check,ourglobal_init+0.0041*60+ourglobal_exec*Our_iter,'g*-',label="Our-Global to conv + groups")

plt.xticks(to_check)
plt.ylabel("Seconds")
plt.xlabel("Annotators (T)")
#plt.legend()
plt.show()
# Out:
# /home/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# falta por el numero de iteraciones (El nuestro tiene mas)
R_iter = 40
Our_iter = 40

plt.figure(figsize=(15,5))
plt.plot(to_check,raykar_init+raykar_exec*R_iter,'o-',label="Raykar time", markersize=8)
plt.plot(to_check,ourglobal_init+0.0021*60+ourglobal_exec*Our_iter,'o-',label="CMM time + groups", markersize=8)
plt.xticks(to_check)
plt.ylabel("Seconds")
plt.xlabel("Annotators (T)")
plt.legend()
plt.show()
# Out:
# /home/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Future comparison
# ---

# %%
to_check = [100,500,2000,5000,10000,15000]
print("Simple Data")
N = 2500

T_data_test = np.arange(1,15,2)

plt.figure(figsize=(15,5))
for T_data in T_data_test:
    #fixint T_data
    D_t = [N*T_data/T for T in to_check]
    plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()

print("CIFAR Data")
N = 50000

T_data_test = np.arange(1,15,2)

plt.figure(figsize=(15,5))
for T_data in T_data_test:
    #fixint T_data
    D_t = [N*T_data/T for T in to_check]
    plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# Simple Data
# CIFAR Data

# %%
to_check = [100,500,1500,3500,6000,10000]
print("Simple Data")
N = 2500

plt.figure(figsize=(15,5))
T_data = 5 #5 para llegar solo a 10k o 10 para llegar a 15k
D_t = [N*T_data/T for T in to_check]
plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))    
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.ylim(0,20)

plt.show()

print("CIFAR Data")
N = 50000
T_data = 3 #para poder ver sparness factor mas bajos..
plt.figure(figsize=(15,5))
D_t = [N*T_data/T for T in to_check]
plt.plot(to_check,D_t,'o-',label="Sparseness factor , T_d="+str(T_data))
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.ylim(0,100)
plt.show()
# Out:
# Simple Data
# CIFAR Data

# %%
np.linspace(100,10000,6)
# Out:
# array([  100.,  2080.,  4060.,  6040.,  8020., 10000.])

# %%
to_check = [25,100,500,2000,5000,10000]

# %%
N = Z_train.shape[0]
#fixing T_d
T_data = 5
print("T_d=",T_data)
D_t = np.asarray([N*T_data/T for T in to_check])

annot_acc = []
for Tmax in to_check:
    aux = []
    for _ in range(10):
        y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False,hard=True)
        aux.append(np.mean(GenerateData.yo_label == Z_train))
    annot_acc.append(np.mean(aux))
    
plt.figure(figsize=(8,5))
plt.plot(to_check,D_t/N,'o-',label="Sparseness factor")
plt.plot(to_check,annot_acc,'o-',label="Acc annotators")
plt.xticks(to_check)
plt.ylabel("value")
plt.xlabel("Annotators")
plt.legend()
plt.show()
# Out:
# T_d= 5
