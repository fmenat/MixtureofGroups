# %% [markdown]
# Experimentation on the CIFAR simmulated annotators
# * batch = 128
# * delta convergence = $3\cdot 10^{-2}$
# * Optimizer = ADAM
#
# * Our proposed: Pre-train base model with hard-MV (5 epochs?) as Rodrigues: https://github.com/fmpr/CrowdLayer/blob/master/demo-conll-ner-mturk.ipynb

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras, time, sys, os, gc

DTYPE_OP = 'float32'
keras.backend.set_floatx(DTYPE_OP)

if DTYPE_OP == 'float64':
    keras.backend.set_epsilon(np.finfo(np.float64).eps)
elif DTYPE_OP == 'float32':
    keras.backend.set_epsilon(np.finfo(np.float32).eps)
# Out:
# /home/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#GLOBAL Variables
BATCH_SIZE = 128
EPOCHS_BASE = 50
OPT = 'adam' #optimizer for neural network 
TOL = 3e-2 #tolerance for relative variation of parameters

# %% [markdown]
# ### Load Data and preprocess

# %%
from keras.datasets import cifar10
(X_train, Z_train), (X_test, Z_test) = cifar10.load_data()
print("Input shape:",X_train.shape)
# Out:
# Input shape: (50000, 32, 32, 3)

# %%
Xstd_train = X_train.astype(DTYPE_OP)/255
Xstd_test = X_test.astype(DTYPE_OP)/255
Z_train = Z_train[:,0]
Z_test = Z_test[:,0]
Xstd_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### Load annotations

# %%
scenario = 1
path = "."
state_sce = path+"/synthetic/CIFAR/state_CIFAR_s"+str(scenario)+".pickle"
#state_sce = None #random state

# %%
from code.generate_data import SinteticData

GenerateData = SinteticData(state=state_sce)

#CONFUSION MATRIX CHOOSE
if scenario == 1 or scenario == 3 or scenario == 4 or scenario ==5 or scenario==7:
    GenerateData.set_probas(asfile=True,file_matrix=path+'/synthetic/CIFAR/matrix_CIFAR_normal.csv',file_groups =path+'/synthetic/CIFAR/groups_CIFAR_normal.csv')

elif scenario == 2 or scenario == 6: #bad MV
    GenerateData.set_probas(asfile=True,file_matrix=path+'/synthetic/CIFAR/matrix_CIFAR_badMV.csv',file_groups =path+'/synthetic/CIFAR/groups_CIFAR_badMV.csv')

real_conf_matrix = GenerateData.conf_matrix.copy()

#ANNOTATOR DENSITY CHOOSE
if scenario == 1 or scenario ==2 or scenario == 3:
    Tmax = 100
    T_data = 10 
elif scenario == 4 or scenario == 6 or scenario ==7:
    Tmax = 2000
    T_data = 10 
elif scenario == 5:
    Tmax = 10000
    T_data = 20
    
print("New Synthetic data is being generated...",flush=True,end='')
if scenario == 3 or scenario==7: #soft
    y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False,hard=False)
else:
    y_obs, groups_annot = GenerateData.sintetic_annotate_data(Z_train,Tmax,T_data,deterministic=False)
print("Done! ")

if len(groups_annot.shape) ==1 or groups_annot.shape[1] ==  1: 
    groups_annot = keras.utils.to_categorical(groups_annot)  #only if it is hard clustering
confe_matrix = np.tensordot(groups_annot,real_conf_matrix, axes=[[1],[0]])

#print("Accuracy of MV on train: ",np.mean(majority_voting(y_obs,repeats=False,onehot=False) == Z_train))
print("Accuracy of MV on train: ",np.mean(GenerateData.yo_label == Z_train))

N,T = y_obs.shape
K = np.max(y_obs)+1 # asumiendo que estan ordenadas
print("Shape (data,annotators): ",(N,T))
print("Classes: ",K)
# Out:
# New Synthetic data is being generated...Done!
# Accuracy of MV on train:  0.73942
# Shape (data,annotators):  (50000, 100)
# Classes:  10

# %%
GenerateData.prob_groups
# Out:
# array([0.2 , 0.45, 0.1 , 0.25])

# %%
#save it
import pickle
new_state = GenerateData.init_state
with open('state_CIFAR_s'+str(scenario)+'.pickle', 'wb') as handle:
    pickle.dump(new_state, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# #### Delta Convergence criteria

# %%
from code.learning_models import LogisticRegression_Sklearn,LogisticRegression_Keras,MLP_Keras
#deep learning
from code.learning_models import default_CNN,default_RNN,default_RNNw_emb,CNN_simple, RNN_simple

from code.utils import EarlyStopRelative
ourCallback = EarlyStopRelative(monitor='loss',patience=1,min_delta=TOL)

# %% [markdown]
# ### Upper Bound Model -- ideal

# %%
Z_train_onehot = keras.utils.to_categorical(Z_train)

model_UB = default_CNN(Xstd_train.shape[1:],Z_train_onehot.shape[1])
model_UB.compile(loss='categorical_crossentropy',optimizer=keras.optimizers.rmsprop(1e-4))
hist=model_UB.fit(Xstd_train,Z_train_onehot,epochs=EPOCHS_BASE,batch_size=BATCH_SIZE,verbose=0,callbacks=[ourCallback])
print("Trained IDeal Model, Epochs to converge =",len(hist.epoch))
Z_train_pred = model_UB.predict_classes(Xstd_train)
Z_test_pred = model_UB.predict_classes(Xstd_test)
# Out:
# Trained IDeal Model, Epochs to converge = 9

# %%
from code.representation import *
from code.utils import *

# %% [markdown]
# ### Infer Labels (without predictive model)

# %%
from code.baseline import LabelInference

label_I = LabelInference(y_obs,TOL,type_inf = 'all')
#label_I = LabelInference(y_obs_categorical,TOL, type_inf = 'all')

mv_probas = label_I.mv_labels('probas')
mv_onehot = label_I.mv_labels('onehot')

if y_obs.shape[1] <= 3000:
    ds_labels,ds_conf = label_I.DS_labels()
# Out:
# Iter	log-likelihood	delta-CM	delta-ER	delta-LL
# 1 	 -757074.3072654587
# 2 	 -747955.7423568431 	0.1672	0.262116	0.012044
# 3 	 -746885.2579339432 	0.0408	0.083011	0.001431
# 4 	 -746695.4284392287 	0.0260	0.040855	0.000254
# 5 	 -746639.3976689416 	0.0171	0.025316	0.000075
# Class marginals
# [0.1  0.1  0.08 0.08 0.11 0.12 0.11 0.1  0.1  0.1 ]

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
print("ACC D&S on train:",np.mean(ds_labels.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.74872
# ACC D&S on train: 0.80782

# %%
model_mvsoft = default_CNN(Xstd_train.shape[1:],mv_probas.shape[1])
model_mvsoft.compile(loss='categorical_crossentropy',optimizer=OPT)
hist=model_mvsoft.fit(Xstd_train, mv_probas, epochs=EPOCHS_BASE,batch_size=BATCH_SIZE,verbose=0,callbacks=[ourCallback])
print("Trained model over soft-MV, Epochs to converge =",len(hist.epoch))
Z_train_pred = model_mvsoft.predict_classes(Xstd_train)
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
# Out:
# Trained model over soft-MV

# %%
model_mvhard = default_CNN(Xstd_train.shape[1:],mv_onehot.shape[1])
model_mvhard.compile(loss='categorical_crossentropy',optimizer=OPT)
hist=model_mvhard.fit(Xstd_train, mv_onehot, epochs=EPOCHS_BASE,batch_size=BATCH_SIZE,verbose=0,callbacks=[ourCallback])
print("Trained model over hard-MV, Epochs to converge =",len(hist.epoch))
Z_train_pred = model_mvhard.predict_classes(Xstd_train)
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
# Out:
# Trained model over hard-MV

# %%
model_ds = default_CNN(Xstd_train.shape[1:],ds_labels.shape[1])
model_ds.compile(loss='categorical_crossentropy',optimizer=OPT)
hist=model_ds.fit(Xstd_train, ds_labels, epochs=EPOCHS_BASE,batch_size=BATCH_SIZE,verbose=0,callbacks=[ourCallback])
print("Trained model over D&S, Epochs to converge =",len(hist.epoch))
Z_train_pred = model_ds.predict_classes(Xstd_train)
Z_test_pred = model_ds.predict_classes(Xstd_test)
# Out:
# Trained model over D&S

# %% [markdown]
# ### Raykar Model (joint predict model)

# %%
from code.baseline import RaykarMC
#get raykar represenstation
#y_obs_categorical = label_I.y_obs_categ
y_obs_categorical = set_representation(y_obs,'onehot') #for raykar
print("shape:",y_obs_categorical.shape)
# Out:
# shape: (50000, 100, 10)

# %% [markdown]
# from baseline import RaykarMC
#
# raykarMC = RaykarMC(Xstd_train.shape[1:],y_obs_categorical.shape[-1],T,epochs=1,optimizer=OPT,DTYPE_OP=DTYPE_OP)
# raykarMC.define_model("default cnn")
#
# raykarMC.define_priors(np.ones((T,K))) #cada observador dijo al menos un dato
# logL_hist = raykarMC.train(Xstd_train,y_obs_categorical,batch_size=BATCH_SIZE,iterations=EPOCHS_BASE,tolerance=TOL
#                            ,relative=True,val=False)

# %%
raykarMC = RaykarMC(Xstd_train.shape[1:],y_obs_categorical.shape[-1],T,epochs=1,optimizer=OPT,DTYPE_OP=DTYPE_OP)
raykarMC.define_model("default cnn")

logL_hists,i_r = raykarMC.multiples_run(10,Xstd_train,y_obs_categorical,batch_size=BATCH_SIZE,max_iter=EPOCHS_BASE,
                                     tolerance=TOL)
# Out:
# Initializing new EM...
# Betas shape:  (100, 10, 10)
# Q estimate shape:  (50000, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 16.45 sec)	logL: -740549.312
# Iter 2/50
# M step: done,  E step: done //  (in 15.61 sec)	logL: -701711.000	Tol1: 0.05245	Tol2: 0.30476
# Iter 3/50
# M step: done,  E step: done //  (in 15.65 sec)	logL: -694161.312	Tol1: 0.01076	Tol2: 0.10195
# Iter 4/50
# M step: done,  E step: done //  (in 15.56 sec)	logL: -691395.438	Tol1: 0.00398	Tol2: 0.04279
# Iter 5/50
# M step: done,  E step: done //  (in 14.17 sec)	logL: -690473.812	Tol1: 0.00133	Tol2: 0.02928
# Finished training
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               262272
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 552,874
# Trainable params: 551,722
# Non-trainable params: 1,152
# _________________________________________________________________
# None
# Initializing new EM...
# Betas shape:  (100, 10, 10)
# Q estimate shape:  (50000, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 15.96 sec)	logL: -740174.438
# Iter 2/50
# M step: done,  E step: done //  (in 13.92 sec)	logL: -702807.125	Tol1: 0.05048	Tol2: 0.30317
# Iter 3/50
# M step: done,  E step: done //  (in 14.62 sec)	logL: -698394.375	Tol1: 0.00628	Tol2: 0.10002
# Iter 4/50
# M step: done,  E step: done //  (in 14.01 sec)	logL: -692598.000	Tol1: 0.00830	Tol2: 0.04610
# Iter 5/50
# M step: done,  E step: done //  (in 15.20 sec)	logL: -690458.250	Tol1: 0.00309	Tol2: 0.05107
# Iter 6/50
# M step: done,  E step: done //  (in 14.82 sec)	logL: -689311.438	Tol1: 0.00166	Tol2: 0.02606
# Finished training
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               262272
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 552,874
# Trainable params: 551,722
# Non-trainable params: 1,152
# _________________________________________________________________
# None
# Multiples runs over Raykar, Epochs to converge=  5.5

# %%
Z_train_p = raykarMC.base_model.predict(Xstd_train)
Z_train_pred =Z_train_p.argmax(axis=-1)
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)

# %% [markdown]
# ### Our Proposed

# %%
from code.MixtureofGroups import GroupMixtureOpt
#get our representation 
#r_obs = set_representation(y_obs_categorical,"repeat")
#r_obs = set_representation(y_obs,"repeat")
r_obs = label_I.y_obs_repeat.copy()

print("vector of repeats:\n",r_obs)
print("shape:",r_obs.shape)
# Out:
# vector of repeats:
#  [[ 0  1  2 ...  2  0  0]
#  [ 0  8  1 ...  1  0  5]
#  [ 0  3  1 ...  3  2  7]
#  ...
#  [ 1  1  1 ...  1  1  5]
#  [ 0 12  1 ...  0  1  7]
#  [ 1  6  1 ...  0  1  5]]
# shape: (50000, 10)

# %%
M_seted = 4

# %%
gMixture_Global = GroupMixtureOpt(Xstd_train.shape[1:],Kl=r_obs.shape[1],M=M_seted,epochs=1,pre_init=0,optimizer=OPT,dtype_op=DTYPE_OP) 
gMixture_Global.define_model("default cnn")
gMixture_Global.lambda_random = True #with lambda random --necessary
logL_hists,i_r = gMixture_Global.multiples_run(10,Xstd_train,r_obs,batch_size=BATCH_SIZE,max_iter=EPOCHS_BASE,tolerance=TOL
                                   ,cluster=True)

# %%
Z_train_p = gMixture_Global.base_model.predict(Xstd_train)
Z_train_pred = Z_train_p.argmax(axis=-1)
Z_test_p = gMixture_Global.base_model.predict(Xstd_test)
Z_test_pred = Z_test_p.argmax(axis=-1)

# %%
# %%time

#pre analysis
from code.MixtureofGroups import project_and_cluster,clusterize_annotators
if y_obs_categorical.shape[1] > 3000:
    annotators_pca = project_and_cluster(y_obs_categorical,DTYPE_OP=DTYPE_OP,printed=False,mode_project="tpca")[0]
else:
    annotators_pca = project_and_cluster(y_obs_categorical,DTYPE_OP=DTYPE_OP,printed=False,mode_project="pca")[0]
print("Annotators PCA of annotations shape: ",annotators_pca.shape)

#mv_soft = majority_voting(r_obs,repeats=True,probas=True) 
#aux = []
#for example in mv_soft:
#    aux.append(entropy(example)/np.log(K))
#print("Normalized entropy (0-1) of repeats annotations:",np.mean(aux))
# Out:
# Annotators PCA of annotations shape:  (2000, 4)
# CPU times: user 37.1 s, sys: 21.5 s, total: 58.6 s
# Wall time: 44.2 s

# %%
#different M_seted?
M_seted = 4

# %%
gMixture1 = GroupMixtureOpt(Xstd_train.shape[1:],Kl=r_obs.shape[1],M=M_seted,epochs=1,pre_init=0,optimizer=OPT,dtype_op=DTYPE_OP) 
gMixture1.define_model("default cnn")
gMixture1.lambda_random = False #lambda=1     
logL_hists,i = gMixture1.multiples_run(10,Xstd_train,r_obs,batch_size=BATCH_SIZE,max_iter=EPOCHS_BASE,tolerance=TOL
                                   ,cluster=True,bulk_annotators=[y_obs_categorical,annotators_pca])
# Out:
# Clustering Done!
# Get init alphas in 0.180383 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 26.40 sec)	logL: -2151537.891
# Iter 2/50
# M step: done,  E step: done //  (in 17.34 sec)	logL: -2112877.307	Tol1: 0.01797	Tol2: 0.15108	Tol3: 0.00779
# Iter 3/50
# M step: done,  E step: done //  (in 17.15 sec)	logL: -2090958.396	Tol1: 0.01037	Tol2: 0.14332	Tol3: 0.00503
# Iter 4/50
# M step: done,  E step: done //  (in 17.30 sec)	logL: -2078924.365	Tol1: 0.00576	Tol2: 0.12423	Tol3: 0.00406
# Iter 5/50
# M step: done,  E step: done //  (in 17.53 sec)	logL: -2053857.284	Tol1: 0.01206	Tol2: 0.09834	Tol3: 0.00499
# Iter 6/50
# M step: done,  E step: done //  (in 17.47 sec)	logL: -2036155.225	Tol1: 0.00862	Tol2: 0.08051	Tol3: 0.00297
# Iter 7/50
# M step: done,  E step: done //  (in 17.38 sec)	logL: -2031571.968	Tol1: 0.00225	Tol2: 0.06349	Tol3: 0.00104
# Iter 8/50
# M step: done,  E step: done //  (in 17.37 sec)	logL: -2015805.160	Tol1: 0.00776	Tol2: 0.07053	Tol3: 0.00131
# Iter 9/50
# M step: done,  E step: done //  (in 17.38 sec)	logL: -2006491.761	Tol1: 0.00462	Tol2: 0.05839	Tol3: 0.00408
# Iter 10/50
# M step: done,  E step: done //  (in 17.31 sec)	logL: -2000102.236	Tol1: 0.00318	Tol2: 0.05686	Tol3: 0.00201
# Iter 11/50
# M step: done,  E step: done //  (in 17.34 sec)	logL: -2006063.995	Tol1: 0.00298	Tol2: 0.06739	Tol3: 0.00201
# Iter 12/50
# M step: done,  E step: done //  (in 17.33 sec)	logL: -1985907.517	Tol1: 0.01005	Tol2: 0.08717	Tol3: 0.00181
# Iter 13/50
# M step: done,  E step: done //  (in 17.27 sec)	logL: -1972472.913	Tol1: 0.00676	Tol2: 0.07766	Tol3: 0.00315
# Iter 14/50
# M step: done,  E step: done //  (in 17.47 sec)	logL: -1966221.597	Tol1: 0.00317	Tol2: 0.05989	Tol3: 0.00108
# Iter 15/50
# M step: done,  E step: done //  (in 17.45 sec)	logL: -1963686.111	Tol1: 0.00129	Tol2: 0.04185	Tol3: 0.00130
# Iter 16/50
# M step: done,  E step: done //  (in 17.44 sec)	logL: -1965909.286	Tol1: 0.00113	Tol2: 0.04713	Tol3: 0.00072
# Iter 17/50
# M step: done,  E step: done //  (in 17.41 sec)	logL: -1958634.669	Tol1: 0.00370	Tol2: 0.06429	Tol3: 0.00141
# Iter 18/50
# M step: done,  E step: done //  (in 17.27 sec)	logL: -1955760.774	Tol1: 0.00147	Tol2: 0.06918	Tol3: 0.00015
# Iter 19/50
# M step: done,  E step: done //  (in 17.12 sec)	logL: -1947454.175	Tol1: 0.00425	Tol2: 0.04378	Tol3: 0.00020
# Iter 20/50
# M step: done,  E step: done //  (in 17.42 sec)	logL: -1949139.837	Tol1: 0.00087	Tol2: 0.03839	Tol3: 0.00073
# Iter 21/50
# M step: done,  E step: done //  (in 17.32 sec)	logL: -1945482.830	Tol1: 0.00188	Tol2: 0.05657	Tol3: 0.00159
# Iter 22/50
# M step: done,  E step: done //  (in 17.35 sec)	logL: -1945659.923	Tol1: 0.00009	Tol2: 0.04741	Tol3: 0.00200
# Iter 23/50
# M step: done,  E step: done //  (in 17.38 sec)	logL: -1941289.082	Tol1: 0.00225	Tol2: 0.04927	Tol3: 0.00054
# Iter 24/50
# M step: done,  E step: done //  (in 17.26 sec)	logL: -1938780.833	Tol1: 0.00129	Tol2: 0.02785	Tol3: 0.00118
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 21.33 sec)	logL: -2154498.197
# Iter 2/50
# M step: done,  E step: done //  (in 17.20 sec)	logL: -2123015.533	Tol1: 0.01461	Tol2: 0.14714	Tol3: 0.00969
# Iter 3/50
# M step: done,  E step: done //  (in 17.33 sec)	logL: -2098769.465	Tol1: 0.01142	Tol2: 0.13553	Tol3: 0.00709
# Iter 4/50
# M step: done,  E step: done //  (in 17.45 sec)	logL: -2071211.780	Tol1: 0.01313	Tol2: 0.11961	Tol3: 0.00574
# Iter 5/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -2048560.620	Tol1: 0.01094	Tol2: 0.10065	Tol3: 0.00315
# Iter 6/50
# M step: done,  E step: done //  (in 17.26 sec)	logL: -2031309.502	Tol1: 0.00842	Tol2: 0.09309	Tol3: 0.00173
# Iter 7/50
# M step: done,  E step: done //  (in 17.28 sec)	logL: -2024303.474	Tol1: 0.00345	Tol2: 0.07162	Tol3: 0.00028
# Iter 8/50
# M step: done,  E step: done //  (in 17.17 sec)	logL: -2014995.743	Tol1: 0.00460	Tol2: 0.10411	Tol3: 0.00087
# Iter 9/50
# M step: done,  E step: done //  (in 17.15 sec)	logL: -2006273.258	Tol1: 0.00433	Tol2: 0.07112	Tol3: 0.00222
# Iter 10/50
# M step: done,  E step: done //  (in 17.32 sec)	logL: -1998200.931	Tol1: 0.00402	Tol2: 0.06473	Tol3: 0.00011
# Iter 11/50
# M step: done,  E step: done //  (in 17.23 sec)	logL: -2005229.262	Tol1: 0.00352	Tol2: 0.06442	Tol3: 0.00117
# Iter 12/50
# M step: done,  E step: done //  (in 17.16 sec)	logL: -1992474.499	Tol1: 0.00636	Tol2: 0.07127	Tol3: 0.00416
# Iter 13/50
# M step: done,  E step: done //  (in 17.38 sec)	logL: -1980886.865	Tol1: 0.00582	Tol2: 0.05661	Tol3: 0.00168
# Iter 14/50
# M step: done,  E step: done //  (in 17.46 sec)	logL: -1980782.426	Tol1: 0.00005	Tol2: 0.05114	Tol3: 0.00101
# Iter 15/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -1981192.029	Tol1: 0.00021	Tol2: 0.04482	Tol3: 0.00107
# Iter 16/50
# M step: done,  E step: done //  (in 17.32 sec)	logL: -1973098.121	Tol1: 0.00409	Tol2: 0.04236	Tol3: 0.00150
# Iter 17/50
# M step: done,  E step: done //  (in 17.37 sec)	logL: -1971194.645	Tol1: 0.00096	Tol2: 0.05293	Tol3: 0.00146
# Iter 18/50
# M step: done,  E step: done //  (in 17.32 sec)	logL: -1969405.572	Tol1: 0.00091	Tol2: 0.04289	Tol3: 0.00088
# Iter 19/50
# M step: done,  E step: done //  (in 17.24 sec)	logL: -1967749.013	Tol1: 0.00084	Tol2: 0.04014	Tol3: 0.00035
# Iter 20/50
# M step: done,  E step: done //  (in 17.50 sec)	logL: -1961940.638	Tol1: 0.00295	Tol2: 0.03969	Tol3: 0.00147
# Iter 21/50
# M step: done,  E step: done //  (in 17.24 sec)	logL: -1958836.508	Tol1: 0.00158	Tol2: 0.04718	Tol3: 0.00184
# Iter 22/50
# M step: done,  E step: done //  (in 17.19 sec)	logL: -1953931.556	Tol1: 0.00250	Tol2: 0.05030	Tol3: 0.00360
# Iter 23/50
# M step: done,  E step: done //  (in 17.23 sec)	logL: -1951910.700	Tol1: 0.00103	Tol2: 0.03505	Tol3: 0.00113
# Iter 24/50
# M step: done,  E step: done //  (in 17.36 sec)	logL: -1950297.782	Tol1: 0.00083	Tol2: 0.04020	Tol3: 0.00056
# Iter 25/50
# M step: done,  E step: done //  (in 17.40 sec)	logL: -1950232.302	Tol1: 0.00003	Tol2: 0.03745	Tol3: 0.00090
# Iter 26/50
# M step: done,  E step: done //  (in 17.35 sec)	logL: -1954741.012	Tol1: 0.00231	Tol2: 0.03865	Tol3: 0.00034
# Iter 27/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -1950760.161	Tol1: 0.00204	Tol2: 0.04282	Tol3: 0.00112
# Iter 28/50
# M step: done,  E step: done //  (in 17.15 sec)	logL: -1949281.463	Tol1: 0.00076	Tol2: 0.03827	Tol3: 0.00101
# Iter 29/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -1949206.061	Tol1: 0.00004	Tol2: 0.03875	Tol3: 0.00029
# Iter 30/50
# M step: done,  E step: done //  (in 17.21 sec)	logL: -1950234.209	Tol1: 0.00053	Tol2: 0.04428	Tol3: 0.00034
# Iter 31/50
# M step: done,  E step: done //  (in 17.32 sec)	logL: -1948945.030	Tol1: 0.00066	Tol2: 0.03420	Tol3: 0.00144
# Iter 32/50
# M step: done,  E step: done //  (in 17.37 sec)	logL: -1949624.674	Tol1: 0.00035	Tol2: 0.02751	Tol3: 0.00032
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 21.64 sec)	logL: -2160249.236
# Iter 2/50
# M step: done,  E step: done //  (in 17.34 sec)	logL: -2134593.305	Tol1: 0.01188	Tol2: 0.14611	Tol3: 0.01034
# Iter 3/50
# M step: done,  E step: done //  (in 17.36 sec)	logL: -2111624.197	Tol1: 0.01076	Tol2: 0.13698	Tol3: 0.00721
# Iter 4/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -2106346.458	Tol1: 0.00250	Tol2: 0.13178	Tol3: 0.00616
# Iter 5/50
# M step: done,  E step: done //  (in 17.38 sec)	logL: -2090720.568	Tol1: 0.00742	Tol2: 0.12228	Tol3: 0.00720
# Iter 6/50
# M step: done,  E step: done //  (in 17.20 sec)	logL: -2064590.434	Tol1: 0.01250	Tol2: 0.09897	Tol3: 0.00183
# Iter 7/50
# M step: done,  E step: done //  (in 17.26 sec)	logL: -2048004.588	Tol1: 0.00803	Tol2: 0.10596	Tol3: 0.00153
# Iter 8/50
# M step: done,  E step: done //  (in 17.23 sec)	logL: -2029014.410	Tol1: 0.00927	Tol2: 0.09367	Tol3: 0.00200
# Iter 9/50
# M step: done,  E step: done //  (in 17.24 sec)	logL: -2019388.866	Tol1: 0.00474	Tol2: 0.06877	Tol3: 0.00104
# Iter 10/50
# M step: done,  E step: done //  (in 17.31 sec)	logL: -2010735.145	Tol1: 0.00429	Tol2: 0.08041	Tol3: 0.00164
# Iter 11/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -2000548.516	Tol1: 0.00507	Tol2: 0.07750	Tol3: 0.00109
# Iter 12/50
# M step: done,  E step: done //  (in 17.36 sec)	logL: -1992712.498	Tol1: 0.00392	Tol2: 0.07083	Tol3: 0.00087
# Iter 13/50
# M step: done,  E step: done //  (in 17.33 sec)	logL: -1981763.058	Tol1: 0.00549	Tol2: 0.06698	Tol3: 0.00177
# Iter 14/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -1977151.787	Tol1: 0.00233	Tol2: 0.06393	Tol3: 0.00096
# Iter 15/50
# M step: done,  E step: done //  (in 17.13 sec)	logL: -1977451.419	Tol1: 0.00015	Tol2: 0.06843	Tol3: 0.00111
# Iter 16/50
# M step: done,  E step: done //  (in 17.33 sec)	logL: -1966268.546	Tol1: 0.00566	Tol2: 0.06455	Tol3: 0.00050
# Iter 17/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -1960338.244	Tol1: 0.00302	Tol2: 0.05758	Tol3: 0.00082
# Iter 18/50
# M step: done,  E step: done //  (in 17.30 sec)	logL: -1961218.295	Tol1: 0.00045	Tol2: 0.04204	Tol3: 0.00111
# Iter 19/50
# M step: done,  E step: done //  (in 17.17 sec)	logL: -1958519.166	Tol1: 0.00138	Tol2: 0.10595	Tol3: 0.00146
# Iter 20/50
# M step: done,  E step: done //  (in 17.18 sec)	logL: -1949156.182	Tol1: 0.00478	Tol2: 0.06094	Tol3: 0.00070
# Iter 21/50
# M step: done,  E step: done //  (in 17.10 sec)	logL: -1946041.295	Tol1: 0.00160	Tol2: 0.03836	Tol3: 0.00067
# Iter 22/50
# M step: done,  E step: done //  (in 17.15 sec)	logL: -1951036.530	Tol1: 0.00257	Tol2: 0.05270	Tol3: 0.00172
# Iter 23/50
# M step: done,  E step: done //  (in 17.10 sec)	logL: -1952691.174	Tol1: 0.00085	Tol2: 0.05043	Tol3: 0.00286
# Iter 24/50
# M step: done,  E step: done //  (in 17.19 sec)	logL: -1948539.288	Tol1: 0.00213	Tol2: 0.04523	Tol3: 0.00078
# Iter 25/50
# M step: done,  E step: done //  (in 17.06 sec)	logL: -1945391.043	Tol1: 0.00162	Tol2: 0.04057	Tol3: 0.00057
# Iter 26/50
# M step: done,  E step: done //  (in 17.17 sec)	logL: -1940746.805	Tol1: 0.00239	Tol2: 0.03803	Tol3: 0.00027
# Iter 27/50
# M step: done,  E step: done //  (in 17.10 sec)	logL: -1942074.456	Tol1: 0.00068	Tol2: 0.02640	Tol3: 0.00092
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 21.84 sec)	logL: -2172645.522
# Iter 2/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -2132093.271	Tol1: 0.01866	Tol2: 0.14167	Tol3: 0.01068
# Iter 3/50
# M step: done,  E step: done //  (in 17.22 sec)	logL: -2107693.744	Tol1: 0.01144	Tol2: 0.14876	Tol3: 0.00537
# Iter 4/50
# M step: done,  E step: done //  (in 17.36 sec)	logL: -2076788.462	Tol1: 0.01466	Tol2: 0.12991	Tol3: 0.00572
# Iter 5/50
# M step: done,  E step: done //  (in 17.26 sec)	logL: -2054486.552	Tol1: 0.01074	Tol2: 0.11284	Tol3: 0.00304
# Iter 6/50
# M step: done,  E step: done //  (in 17.33 sec)	logL: -2040116.470	Tol1: 0.00699	Tol2: 0.09773	Tol3: 0.00130
# Iter 7/50
# M step: done,  E step: done //  (in 17.33 sec)	logL: -2035603.283	Tol1: 0.00221	Tol2: 0.07200	Tol3: 0.00173
# Iter 8/50
# M step: done,  E step: done //  (in 17.13 sec)	logL: -2024707.386	Tol1: 0.00535	Tol2: 0.07911	Tol3: 0.00327
# Iter 9/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -2016523.781	Tol1: 0.00404	Tol2: 0.07744	Tol3: 0.00157
# Iter 10/50
# M step: done,  E step: done //  (in 17.30 sec)	logL: -2005584.609	Tol1: 0.00542	Tol2: 0.08830	Tol3: 0.00093
# Iter 11/50
# M step: done,  E step: done //  (in 17.25 sec)	logL: -1994186.945	Tol1: 0.00568	Tol2: 0.07487	Tol3: 0.00157
# Iter 12/50
# M step: done,  E step: done //  (in 17.11 sec)	logL: -1992236.520	Tol1: 0.00098	Tol2: 0.06802	Tol3: 0.00154
# Iter 13/50
# M step: done,  E step: done //  (in 17.28 sec)	logL: -1979843.329	Tol1: 0.00622	Tol2: 0.06771	Tol3: 0.00176
# Iter 14/50
# M step: done,  E step: done //  (in 17.27 sec)	logL: -1972724.210	Tol1: 0.00360	Tol2: 0.05044	Tol3: 0.00055
# Iter 15/50
# M step: done,  E step: done //  (in 17.07 sec)	logL: -1972195.802	Tol1: 0.00027	Tol2: 0.03945	Tol3: 0.00059
# Iter 16/50
# M step: done,  E step: done //  (in 17.25 sec)	logL: -1972701.705	Tol1: 0.00026	Tol2: 0.05823	Tol3: 0.00276
# Iter 17/50
# M step: done,  E step: done //  (in 17.19 sec)	logL: -1967134.504	Tol1: 0.00282	Tol2: 0.05821	Tol3: 0.00145
# Iter 18/50
# M step: done,  E step: done //  (in 17.22 sec)	logL: -1960496.397	Tol1: 0.00337	Tol2: 0.04169	Tol3: 0.00069
# Iter 19/50
# M step: done,  E step: done //  (in 17.11 sec)	logL: -1961827.267	Tol1: 0.00068	Tol2: 0.03529	Tol3: 0.00037
# Iter 20/50
# M step: done,  E step: done //  (in 17.22 sec)	logL: -1954297.759	Tol1: 0.00384	Tol2: 0.05742	Tol3: 0.00248
# Iter 21/50
# M step: done,  E step: done //  (in 17.20 sec)	logL: -1957863.653	Tol1: 0.00182	Tol2: 0.04332	Tol3: 0.00019
# Iter 22/50
# M step: done,  E step: done //  (in 17.17 sec)	logL: -1950653.593	Tol1: 0.00368	Tol2: 0.04783	Tol3: 0.00192
# Iter 23/50
# M step: done,  E step: done //  (in 17.22 sec)	logL: -1953430.942	Tol1: 0.00142	Tol2: 0.04545	Tol3: 0.00106
# Iter 24/50
# M step: done,  E step: done //  (in 17.21 sec)	logL: -1950598.491	Tol1: 0.00145	Tol2: 0.06149	Tol3: 0.00137
# Iter 25/50
# M step: done,  E step: done //  (in 17.19 sec)	logL: -1947267.104	Tol1: 0.00171	Tol2: 0.03694	Tol3: 0.00065
# Iter 26/50
# M step: done,  E step: done //  (in 17.35 sec)	logL: -1945500.252	Tol1: 0.00091	Tol2: 0.03851	Tol3: 0.00056
# Iter 27/50
# M step: done,  E step: done //  (in 17.22 sec)	logL: -1952680.517	Tol1: 0.00369	Tol2: 0.05206	Tol3: 0.00050
# Iter 28/50
# M step: done,  E step: done //  (in 17.02 sec)	logL: -1950832.646	Tol1: 0.00095	Tol2: 0.04941	Tol3: 0.00033
# Iter 29/50
# M step: done,  E step: done //  (in 17.09 sec)	logL: -1952479.086	Tol1: 0.00084	Tol2: 0.05307	Tol3: 0.00118
# Iter 30/50
# M step: done,  E step: done //  (in 17.19 sec)	logL: -1948962.558	Tol1: 0.00180	Tol2: 0.06049	Tol3: 0.00055
# Iter 31/50
# M step: done,  E step: done //  (in 17.21 sec)	logL: -1949030.985	Tol1: 0.00004	Tol2: 0.05248	Tol3: 0.00101
# Iter 32/50
# M step: done,  E step: done //  (in 17.27 sec)	logL: -1953288.218	Tol1: 0.00218	Tol2: 0.05511	Tol3: 0.00229
# Iter 33/50
# M step: done,  E step: done //  (in 17.19 sec)	logL: -1942841.474	Tol1: 0.00535	Tol2: 0.05757	Tol3: 0.00163
# Iter 34/50
# M step: done,  E step: done //  (in 17.18 sec)	logL: -1943332.985	Tol1: 0.00025	Tol2: 0.04855	Tol3: 0.00127
# Iter 35/50
# M step: done,  E step: done //  (in 17.07 sec)	logL: -1939977.997	Tol1: 0.00173	Tol2: 0.04019	Tol3: 0.00100
# Iter 36/50
# M step: done,  E step: done //  (in 17.10 sec)	logL: -1938467.685	Tol1: 0.00078	Tol2: 0.02709	Tol3: 0.00020
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 22.46 sec)	logL: -2171347.446
# Iter 2/50
# M step: done,  E step: done //  (in 17.43 sec)	logL: -2164581.544	Tol1: 0.00312	Tol2: 0.13691	Tol3: 0.01049
# Iter 3/50
# M step: done,  E step: done //  (in 17.50 sec)	logL: -2136720.421	Tol1: 0.01287	Tol2: 0.13256	Tol3: 0.00865
# Iter 4/50
# M step: done,  E step: done //  (in 17.51 sec)	logL: -2106118.460	Tol1: 0.01432	Tol2: 0.14973	Tol3: 0.00485
# Iter 5/50
# M step: done,  E step: done //  (in 17.32 sec)	logL: -2073196.268	Tol1: 0.01563	Tol2: 0.16442	Tol3: 0.00285
# Iter 6/50
# M step: done,  E step: done //  (in 17.43 sec)	logL: -2044064.396	Tol1: 0.01405	Tol2: 0.14354	Tol3: 0.00282
# Iter 7/50
# M step: done,  E step: done //  (in 17.44 sec)	logL: -2027207.200	Tol1: 0.00825	Tol2: 0.10607	Tol3: 0.00127
# Iter 8/50
# M step: done,  E step: done //  (in 17.51 sec)	logL: -2016583.295	Tol1: 0.00524	Tol2: 0.07780	Tol3: 0.00109
# Iter 9/50
# M step: done,  E step: done //  (in 17.47 sec)	logL: -2014249.654	Tol1: 0.00116	Tol2: 0.07706	Tol3: 0.00129
# Iter 10/50
# M step: done,  E step: done //  (in 17.53 sec)	logL: -2003359.746	Tol1: 0.00541	Tol2: 0.06532	Tol3: 0.00247
# Iter 11/50
# M step: done,  E step: done //  (in 17.35 sec)	logL: -1993317.125	Tol1: 0.00501	Tol2: 0.07533	Tol3: 0.00109
# Iter 12/50
# M step: done,  E step: done //  (in 17.61 sec)	logL: -1989557.967	Tol1: 0.00189	Tol2: 0.07611	Tol3: 0.00158
# Iter 13/50
# M step: done,  E step: done //  (in 17.41 sec)	logL: -1990680.159	Tol1: 0.00056	Tol2: 0.06760	Tol3: 0.00115
# Iter 14/50
# M step: done,  E step: done //  (in 17.64 sec)	logL: -1977547.839	Tol1: 0.00660	Tol2: 0.06711	Tol3: 0.00325
# Iter 15/50
# M step: done,  E step: done //  (in 17.40 sec)	logL: -1982161.855	Tol1: 0.00233	Tol2: 0.06310	Tol3: 0.00167
# Iter 16/50
# M step: done,  E step: done //  (in 17.44 sec)	logL: -1981987.856	Tol1: 0.00009	Tol2: 0.06354	Tol3: 0.00133
# Iter 17/50
# M step: done,  E step: done //  (in 17.41 sec)	logL: -1970166.975	Tol1: 0.00596	Tol2: 0.06374	Tol3: 0.00140
# Iter 18/50
# M step: done,  E step: done //  (in 17.54 sec)	logL: -1958408.007	Tol1: 0.00597	Tol2: 0.05605	Tol3: 0.00227
# Iter 19/50
# M step: done,  E step: done //  (in 17.57 sec)	logL: -1957754.297	Tol1: 0.00033	Tol2: 0.03791	Tol3: 0.00126
# Iter 20/50
# M step: done,  E step: done //  (in 17.43 sec)	logL: -1952072.920	Tol1: 0.00290	Tol2: 0.04803	Tol3: 0.00102
# Iter 21/50
# M step: done,  E step: done //  (in 17.52 sec)	logL: -1947756.286	Tol1: 0.00221	Tol2: 0.06330	Tol3: 0.00277
# Iter 22/50
# M step: done,  E step: done //  (in 17.45 sec)	logL: -1951236.460	Tol1: 0.00179	Tol2: 0.04642	Tol3: 0.00062
# Iter 23/50
# M step: done,  E step: done //  (in 17.59 sec)	logL: -1945791.928	Tol1: 0.00279	Tol2: 0.07250	Tol3: 0.00100
# Iter 24/50
# M step: done,  E step: done //  (in 17.34 sec)	logL: -1938611.858	Tol1: 0.00369	Tol2: 0.05419	Tol3: 0.00177
# Iter 25/50
# M step: done,  E step: done //  (in 17.54 sec)	logL: -1939502.408	Tol1: 0.00046	Tol2: 0.04446	Tol3: 0.00170
# Iter 26/50
# M step: done,  E step: done //  (in 17.52 sec)	logL: -1936609.844	Tol1: 0.00149	Tol2: 0.03642	Tol3: 0.00072
# Iter 27/50
# M step: done,  E step: done //  (in 17.35 sec)	logL: -1937117.051	Tol1: 0.00026	Tol2: 0.03865	Tol3: 0.00095
# Iter 28/50
# M step: done,  E step: done //  (in 17.52 sec)	logL: -1935741.020	Tol1: 0.00071	Tol2: 0.04065	Tol3: 0.00080
# Iter 29/50
# M step: done,  E step: done //  (in 17.39 sec)	logL: -1932821.426	Tol1: 0.00151	Tol2: 0.03895	Tol3: 0.00187
# Iter 30/50
# M step: done,  E step: done //  (in 17.47 sec)	logL: -1938902.213	Tol1: 0.00315	Tol2: 0.03107	Tol3: 0.00053
# Iter 31/50
# M step: done,  E step: done //  (in 17.38 sec)	logL: -1931347.600	Tol1: 0.00390	Tol2: 0.06022	Tol3: 0.00263
# Iter 32/50
# M step: done,  E step: done //  (in 17.43 sec)	logL: -1927862.503	Tol1: 0.00180	Tol2: 0.05555	Tol3: 0.00221
# Iter 33/50
# M step: done,  E step: done //  (in 17.41 sec)	logL: -1927550.847	Tol1: 0.00016	Tol2: 0.03305	Tol3: 0.00198
# Iter 34/50
# M step: done,  E step: done //  (in 17.40 sec)	logL: -1926620.490	Tol1: 0.00048	Tol2: 0.03851	Tol3: 0.00119
# Iter 35/50
# M step: done,  E step: done //  (in 17.22 sec)	logL: -1925643.342	Tol1: 0.00051	Tol2: 0.03126	Tol3: 0.00158
# Iter 36/50
# M step: done,  E step: done //  (in 17.54 sec)	logL: -1925599.820	Tol1: 0.00002	Tol2: 0.03984	Tol3: 0.00077
# Iter 37/50
# M step: done,  E step: done //  (in 17.31 sec)	logL: -1924033.514	Tol1: 0.00081	Tol2: 0.03872	Tol3: 0.00102
# Iter 38/50
# M step: done,  E step: done //  (in 17.51 sec)	logL: -1923491.738	Tol1: 0.00028	Tol2: 0.03817	Tol3: 0.00108
# Iter 39/50
# M step: done,  E step: done //  (in 17.35 sec)	logL: -1920963.927	Tol1: 0.00131	Tol2: 0.04334	Tol3: 0.00143
# Iter 40/50
# M step: done,  E step: done //  (in 17.37 sec)	logL: -1921728.704	Tol1: 0.00040	Tol2: 0.02697	Tol3: 0.00029
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 22.77 sec)	logL: -2141837.586
# Iter 2/50
# M step: done,  E step: done //  (in 17.56 sec)	logL: -2100055.778	Tol1: 0.01951	Tol2: 0.16327	Tol3: 0.00764
# Iter 3/50
# M step: done,  E step: done //  (in 17.78 sec)	logL: -2065989.454	Tol1: 0.01622	Tol2: 0.14388	Tol3: 0.00551
# Iter 4/50
# M step: done,  E step: done //  (in 17.68 sec)	logL: -2045978.637	Tol1: 0.00969	Tol2: 0.11088	Tol3: 0.00478
# Iter 5/50
# M step: done,  E step: done //  (in 17.63 sec)	logL: -2034166.011	Tol1: 0.00577	Tol2: 0.07857	Tol3: 0.00399
# Iter 6/50
# M step: done,  E step: done //  (in 17.55 sec)	logL: -2019099.994	Tol1: 0.00741	Tol2: 0.06948	Tol3: 0.00363
# Iter 7/50
# M step: done,  E step: done //  (in 17.52 sec)	logL: -2008145.574	Tol1: 0.00543	Tol2: 0.05188	Tol3: 0.00128
# Iter 8/50
# M step: done,  E step: done //  (in 17.47 sec)	logL: -1997434.265	Tol1: 0.00533	Tol2: 0.04735	Tol3: 0.00030
# Iter 9/50
# M step: done,  E step: done //  (in 17.63 sec)	logL: -1992537.980	Tol1: 0.00245	Tol2: 0.04657	Tol3: 0.00118
# Iter 10/50
# M step: done,  E step: done //  (in 17.62 sec)	logL: -1986843.015	Tol1: 0.00286	Tol2: 0.04737	Tol3: 0.00138
# Iter 11/50
# M step: done,  E step: done //  (in 17.62 sec)	logL: -1980503.255	Tol1: 0.00319	Tol2: 0.06077	Tol3: 0.00240
# Iter 12/50
# M step: done,  E step: done //  (in 17.76 sec)	logL: -1973427.087	Tol1: 0.00357	Tol2: 0.05945	Tol3: 0.00366
# Iter 13/50
# M step: done,  E step: done //  (in 17.67 sec)	logL: -1970385.897	Tol1: 0.00154	Tol2: 0.07064	Tol3: 0.00227
# Iter 14/50
# M step: done,  E step: done //  (in 17.72 sec)	logL: -1969203.529	Tol1: 0.00060	Tol2: 0.04652	Tol3: 0.00132
# Iter 15/50
# M step: done,  E step: done //  (in 17.54 sec)	logL: -1966882.227	Tol1: 0.00118	Tol2: 0.05931	Tol3: 0.00054
# Iter 16/50
# M step: done,  E step: done //  (in 17.56 sec)	logL: -1967596.715	Tol1: 0.00036	Tol2: 0.03728	Tol3: 0.00046
# Iter 17/50
# M step: done,  E step: done //  (in 17.60 sec)	logL: -1961815.913	Tol1: 0.00294	Tol2: 0.03671	Tol3: 0.00112
# Iter 18/50
# M step: done,  E step: done //  (in 17.47 sec)	logL: -1964047.120	Tol1: 0.00114	Tol2: 0.03321	Tol3: 0.00249
# Iter 19/50
# M step: done,  E step: done //  (in 17.75 sec)	logL: -1960025.127	Tol1: 0.00205	Tol2: 0.05034	Tol3: 0.00207
# Iter 20/50
# M step: done,  E step: done //  (in 17.46 sec)	logL: -1953594.833	Tol1: 0.00328	Tol2: 0.04200	Tol3: 0.00013
# Iter 21/50
# M step: done,  E step: done //  (in 17.47 sec)	logL: -1952740.262	Tol1: 0.00044	Tol2: 0.02472	Tol3: 0.00069
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 23.13 sec)	logL: -2157016.626
# Iter 2/50
# M step: done,  E step: done //  (in 17.50 sec)	logL: -2129159.341	Tol1: 0.01291	Tol2: 0.14997	Tol3: 0.00923
# Iter 3/50
# M step: done,  E step: done //  (in 17.45 sec)	logL: -2096838.450	Tol1: 0.01518	Tol2: 0.14368	Tol3: 0.00762
# Iter 4/50
# M step: done,  E step: done //  (in 17.62 sec)	logL: -2063559.558	Tol1: 0.01587	Tol2: 0.12946	Tol3: 0.00480
# Iter 5/50
# M step: done,  E step: done //  (in 17.27 sec)	logL: -2039119.876	Tol1: 0.01184	Tol2: 0.12651	Tol3: 0.00125
# Iter 6/50
# M step: done,  E step: done //  (in 17.57 sec)	logL: -2028366.083	Tol1: 0.00527	Tol2: 0.08655	Tol3: 0.00126
# Iter 7/50
# M step: done,  E step: done //  (in 17.52 sec)	logL: -2022390.857	Tol1: 0.00295	Tol2: 0.08019	Tol3: 0.00352
# Iter 8/50
# M step: done,  E step: done //  (in 17.69 sec)	logL: -2003945.489	Tol1: 0.00912	Tol2: 0.07676	Tol3: 0.00272
# Iter 9/50
# M step: done,  E step: done //  (in 17.67 sec)	logL: -2004347.104	Tol1: 0.00020	Tol2: 0.06588	Tol3: 0.00042
# Iter 10/50
# M step: done,  E step: done //  (in 17.57 sec)	logL: -2000622.081	Tol1: 0.00186	Tol2: 0.09358	Tol3: 0.00173
# Iter 11/50
# M step: done,  E step: done //  (in 17.56 sec)	logL: -1986439.463	Tol1: 0.00709	Tol2: 0.05831	Tol3: 0.00089
# Iter 12/50
# M step: done,  E step: done //  (in 17.48 sec)	logL: -1985467.946	Tol1: 0.00049	Tol2: 0.05727	Tol3: 0.00100
# Iter 13/50
# M step: done,  E step: done //  (in 17.52 sec)	logL: -1977268.869	Tol1: 0.00413	Tol2: 0.04950	Tol3: 0.00140
# Iter 14/50
# M step: done,  E step: done //  (in 17.44 sec)	logL: -1973888.782	Tol1: 0.00171	Tol2: 0.06214	Tol3: 0.00276
# Iter 15/50
# M step: done,  E step: done //  (in 17.29 sec)	logL: -1967607.320	Tol1: 0.00318	Tol2: 0.06399	Tol3: 0.00145
# Iter 16/50
# M step: done,  E step: done //  (in 17.40 sec)	logL: -1963401.530	Tol1: 0.00214	Tol2: 0.03124	Tol3: 0.00035
# Iter 17/50
# M step: done,  E step: done //  (in 17.52 sec)	logL: -1960426.010	Tol1: 0.00152	Tol2: 0.06849	Tol3: 0.00289
# Iter 18/50
# M step: done,  E step: done //  (in 17.64 sec)	logL: -1959818.957	Tol1: 0.00031	Tol2: 0.04091	Tol3: 0.00104
# Iter 19/50
# M step: done,  E step: done //  (in 17.63 sec)	logL: -1974842.389	Tol1: 0.00767	Tol2: 0.04080	Tol3: 0.00304
# Iter 20/50
# M step: done,  E step: done //  (in 17.54 sec)	logL: -1958113.116	Tol1: 0.00847	Tol2: 0.06245	Tol3: 0.00433
# Iter 21/50
# M step: done,  E step: done //  (in 17.60 sec)	logL: -1954376.518	Tol1: 0.00191	Tol2: 0.04786	Tol3: 0.00145
# Iter 22/50
# M step: done,  E step: done //  (in 17.47 sec)	logL: -1950887.491	Tol1: 0.00179	Tol2: 0.03134	Tol3: 0.00130
# Iter 23/50
# M step: done,  E step: done //  (in 17.47 sec)	logL: -1947217.288	Tol1: 0.00188	Tol2: 0.03338	Tol3: 0.00221
# Iter 24/50
# M step: done,  E step: done //  (in 17.41 sec)	logL: -1945734.138	Tol1: 0.00076	Tol2: 0.02602	Tol3: 0.00061
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 23.43 sec)	logL: -2159344.537
# Iter 2/50
# M step: done,  E step: done //  (in 17.52 sec)	logL: -2124327.259	Tol1: 0.01622	Tol2: 0.15121	Tol3: 0.00619
# Iter 3/50
# M step: done,  E step: done //  (in 17.54 sec)	logL: -2094938.749	Tol1: 0.01383	Tol2: 0.14439	Tol3: 0.00426
# Iter 4/50
# M step: done,  E step: done //  (in 17.54 sec)	logL: -2083409.058	Tol1: 0.00550	Tol2: 0.12775	Tol3: 0.00628
# Iter 5/50
# M step: done,  E step: done //  (in 17.69 sec)	logL: -2056765.886	Tol1: 0.01279	Tol2: 0.11392	Tol3: 0.00607
# Iter 6/50
# M step: done,  E step: done //  (in 17.50 sec)	logL: -2034247.478	Tol1: 0.01095	Tol2: 0.08163	Tol3: 0.00489
# Iter 7/50
# M step: done,  E step: done //  (in 17.58 sec)	logL: -2015908.494	Tol1: 0.00902	Tol2: 0.11260	Tol3: 0.00180
# Iter 8/50
# M step: done,  E step: done //  (in 17.50 sec)	logL: -2004422.819	Tol1: 0.00570	Tol2: 0.06491	Tol3: 0.00119
# Iter 9/50
# M step: done,  E step: done //  (in 17.45 sec)	logL: -1996109.289	Tol1: 0.00415	Tol2: 0.06059	Tol3: 0.00203
# Iter 10/50
# M step: done,  E step: done //  (in 17.79 sec)	logL: -1988551.085	Tol1: 0.00379	Tol2: 0.05100	Tol3: 0.00050
# Iter 11/50
# M step: done,  E step: done //  (in 17.55 sec)	logL: -1983308.715	Tol1: 0.00264	Tol2: 0.05049	Tol3: 0.00100
# Iter 12/50
# M step: done,  E step: done //  (in 17.77 sec)	logL: -1981918.731	Tol1: 0.00070	Tol2: 0.07107	Tol3: 0.00287
# Iter 13/50
# M step: done,  E step: done //  (in 17.57 sec)	logL: -1976286.063	Tol1: 0.00284	Tol2: 0.06421	Tol3: 0.00189
# Iter 14/50
# M step: done,  E step: done //  (in 17.76 sec)	logL: -1980699.707	Tol1: 0.00223	Tol2: 0.06697	Tol3: 0.00267
# Iter 15/50
# M step: done,  E step: done //  (in 17.64 sec)	logL: -1985813.802	Tol1: 0.00258	Tol2: 0.06637	Tol3: 0.00351
# Iter 16/50
# M step: done,  E step: done //  (in 17.53 sec)	logL: -1969660.365	Tol1: 0.00813	Tol2: 0.06280	Tol3: 0.00151
# Iter 17/50
# M step: done,  E step: done //  (in 17.50 sec)	logL: -1970978.392	Tol1: 0.00067	Tol2: 0.06154	Tol3: 0.00302
# Iter 18/50
# M step: done,  E step: done //  (in 17.62 sec)	logL: -1969393.020	Tol1: 0.00080	Tol2: 0.04105	Tol3: 0.00121
# Iter 19/50
# M step: done,  E step: done //  (in 17.72 sec)	logL: -1969837.927	Tol1: 0.00023	Tol2: 0.03547	Tol3: 0.00059
# Iter 20/50
# M step: done,  E step: done //  (in 17.69 sec)	logL: -1961582.906	Tol1: 0.00419	Tol2: 0.03790	Tol3: 0.00303
# Iter 21/50
# M step: done,  E step: done //  (in 17.46 sec)	logL: -1959208.568	Tol1: 0.00121	Tol2: 0.03129	Tol3: 0.00156
# Iter 22/50
# M step: done,  E step: done //  (in 17.50 sec)	logL: -1955305.738	Tol1: 0.00199	Tol2: 0.02318	Tol3: 0.00123
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 23.88 sec)	logL: -2170262.665
# Iter 2/50
# M step: done,  E step: done //  (in 17.90 sec)	logL: -2136062.035	Tol1: 0.01576	Tol2: 0.13373	Tol3: 0.00878
# Iter 3/50
# M step: done,  E step: done //  (in 18.04 sec)	logL: -2105736.664	Tol1: 0.01420	Tol2: 0.14014	Tol3: 0.00552
# Iter 4/50
# M step: done,  E step: done //  (in 17.91 sec)	logL: -2092866.199	Tol1: 0.00611	Tol2: 0.12309	Tol3: 0.00541
# Iter 5/50
# M step: done,  E step: done //  (in 18.02 sec)	logL: -2075615.841	Tol1: 0.00824	Tol2: 0.09814	Tol3: 0.00512
# Iter 6/50
# M step: done,  E step: done //  (in 17.94 sec)	logL: -2064766.767	Tol1: 0.00523	Tol2: 0.10084	Tol3: 0.00489
# Iter 7/50
# M step: done,  E step: done //  (in 17.87 sec)	logL: -2057835.722	Tol1: 0.00336	Tol2: 0.09116	Tol3: 0.00333
# Iter 8/50
# M step: done,  E step: done //  (in 17.86 sec)	logL: -2051308.219	Tol1: 0.00317	Tol2: 0.08731	Tol3: 0.00372
# Iter 9/50
# M step: done,  E step: done //  (in 18.01 sec)	logL: -2022560.154	Tol1: 0.01401	Tol2: 0.08717	Tol3: 0.00175
# Iter 10/50
# M step: done,  E step: done //  (in 18.05 sec)	logL: -2008788.666	Tol1: 0.00681	Tol2: 0.08348	Tol3: 0.00199
# Iter 11/50
# M step: done,  E step: done //  (in 18.15 sec)	logL: -2003274.367	Tol1: 0.00275	Tol2: 0.08364	Tol3: 0.00293
# Iter 12/50
# M step: done,  E step: done //  (in 17.95 sec)	logL: -1988110.450	Tol1: 0.00757	Tol2: 0.07831	Tol3: 0.00340
# Iter 13/50
# M step: done,  E step: done //  (in 17.89 sec)	logL: -1986416.089	Tol1: 0.00085	Tol2: 0.04175	Tol3: 0.00070
# Iter 14/50
# M step: done,  E step: done //  (in 17.99 sec)	logL: -1979821.534	Tol1: 0.00332	Tol2: 0.06721	Tol3: 0.00210
# Iter 15/50
# M step: done,  E step: done //  (in 17.79 sec)	logL: -1974999.536	Tol1: 0.00244	Tol2: 0.08634	Tol3: 0.00294
# Iter 16/50
# M step: done,  E step: done //  (in 17.96 sec)	logL: -1965875.841	Tol1: 0.00462	Tol2: 0.06136	Tol3: 0.00208
# Iter 17/50
# M step: done,  E step: done //  (in 17.84 sec)	logL: -1959119.568	Tol1: 0.00344	Tol2: 0.07181	Tol3: 0.00106
# Iter 18/50
# M step: done,  E step: done //  (in 17.79 sec)	logL: -1956876.269	Tol1: 0.00115	Tol2: 0.04340	Tol3: 0.00051
# Iter 19/50
# M step: done,  E step: done //  (in 17.92 sec)	logL: -1954771.489	Tol1: 0.00108	Tol2: 0.06883	Tol3: 0.00092
# Iter 20/50
# M step: done,  E step: done //  (in 17.86 sec)	logL: -1949017.539	Tol1: 0.00294	Tol2: 0.04969	Tol3: 0.00184
# Iter 21/50
# M step: done,  E step: done //  (in 17.73 sec)	logL: -1949707.306	Tol1: 0.00035	Tol2: 0.05145	Tol3: 0.00158
# Iter 22/50
# M step: done,  E step: done //  (in 17.94 sec)	logL: -1948698.830	Tol1: 0.00052	Tol2: 0.06356	Tol3: 0.00202
# Iter 23/50
# M step: done,  E step: done //  (in 18.02 sec)	logL: -1942145.811	Tol1: 0.00336	Tol2: 0.05203	Tol3: 0.00170
# Iter 24/50
# M step: done,  E step: done //  (in 17.82 sec)	logL: -1939214.274	Tol1: 0.00151	Tol2: 0.04147	Tol3: 0.00064
# Iter 25/50
# M step: done,  E step: done //  (in 17.80 sec)	logL: -1937830.333	Tol1: 0.00071	Tol2: 0.03574	Tol3: 0.00063
# Iter 26/50
# M step: done,  E step: done //  (in 17.86 sec)	logL: -1934971.440	Tol1: 0.00148	Tol2: 0.03605	Tol3: 0.00012
# Iter 27/50
# M step: done,  E step: done //  (in 17.93 sec)	logL: -1935851.132	Tol1: 0.00045	Tol2: 0.04947	Tol3: 0.00118
# Iter 28/50
# M step: done,  E step: done //  (in 17.89 sec)	logL: -1931665.560	Tol1: 0.00216	Tol2: 0.05751	Tol3: 0.00072
# Iter 29/50
# M step: done,  E step: done //  (in 17.91 sec)	logL: -1930637.203	Tol1: 0.00053	Tol2: 0.03283	Tol3: 0.00072
# Iter 30/50
# M step: done,  E step: done //  (in 17.90 sec)	logL: -1930577.690	Tol1: 0.00003	Tol2: 0.02840	Tol3: 0.00088
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [1. 1. 1. 1.]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 24.46 sec)	logL: -2149952.541
# Iter 2/50
# M step: done,  E step: done //  (in 18.06 sec)	logL: -2116554.308	Tol1: 0.01553	Tol2: 0.15595	Tol3: 0.00776
# Iter 3/50
# M step: done,  E step: done //  (in 17.94 sec)	logL: -2094339.619	Tol1: 0.01050	Tol2: 0.14039	Tol3: 0.00799
# Iter 4/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -2065078.823	Tol1: 0.01397	Tol2: 0.12525	Tol3: 0.00644
# Iter 5/50
# M step: done,  E step: done //  (in 18.05 sec)	logL: -2049560.386	Tol1: 0.00751	Tol2: 0.10656	Tol3: 0.00241
# Iter 6/50
# M step: done,  E step: done //  (in 17.88 sec)	logL: -2036288.359	Tol1: 0.00648	Tol2: 0.07474	Tol3: 0.00390
# Iter 7/50
# M step: done,  E step: done //  (in 18.01 sec)	logL: -2020795.620	Tol1: 0.00761	Tol2: 0.06742	Tol3: 0.00137
# Iter 8/50
# M step: done,  E step: done //  (in 18.07 sec)	logL: -2010063.784	Tol1: 0.00531	Tol2: 0.06291	Tol3: 0.00109
# Iter 9/50
# M step: done,  E step: done //  (in 17.74 sec)	logL: -2003151.176	Tol1: 0.00344	Tol2: 0.05762	Tol3: 0.00074
# Iter 10/50
# M step: done,  E step: done //  (in 18.05 sec)	logL: -2006095.439	Tol1: 0.00147	Tol2: 0.05359	Tol3: 0.00134
# Iter 11/50
# M step: done,  E step: done //  (in 18.06 sec)	logL: -1995030.571	Tol1: 0.00552	Tol2: 0.07973	Tol3: 0.00428
# Iter 12/50
# M step: done,  E step: done //  (in 18.14 sec)	logL: -1984156.461	Tol1: 0.00545	Tol2: 0.06563	Tol3: 0.00139
# Iter 13/50
# M step: done,  E step: done //  (in 18.14 sec)	logL: -1985253.145	Tol1: 0.00055	Tol2: 0.08444	Tol3: 0.00457
# Iter 14/50
# M step: done,  E step: done //  (in 17.88 sec)	logL: -1986476.549	Tol1: 0.00062	Tol2: 0.07231	Tol3: 0.00138
# Iter 15/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -1982647.666	Tol1: 0.00193	Tol2: 0.05935	Tol3: 0.00253
# Iter 16/50
# M step: done,  E step: done //  (in 18.07 sec)	logL: -1981356.898	Tol1: 0.00065	Tol2: 0.06177	Tol3: 0.00126
# Iter 17/50
# M step: done,  E step: done //  (in 17.91 sec)	logL: -1972434.985	Tol1: 0.00450	Tol2: 0.07541	Tol3: 0.00191
# Iter 18/50
# M step: done,  E step: done //  (in 18.07 sec)	logL: -1966881.541	Tol1: 0.00282	Tol2: 0.04904	Tol3: 0.00045
# Iter 19/50
# M step: done,  E step: done //  (in 17.92 sec)	logL: -1964318.838	Tol1: 0.00130	Tol2: 0.05297	Tol3: 0.00103
# Iter 20/50
# M step: done,  E step: done //  (in 17.93 sec)	logL: -1963975.812	Tol1: 0.00017	Tol2: 0.04506	Tol3: 0.00127
# Iter 21/50
# M step: done,  E step: done //  (in 18.02 sec)	logL: -1964635.821	Tol1: 0.00034	Tol2: 0.05469	Tol3: 0.00077
# Iter 22/50
# M step: done,  E step: done //  (in 18.05 sec)	logL: -1958007.777	Tol1: 0.00337	Tol2: 0.04798	Tol3: 0.00059
# Iter 23/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -1962541.921	Tol1: 0.00232	Tol2: 0.04242	Tol3: 0.00085
# Iter 24/50
# M step: done,  E step: done //  (in 18.11 sec)	logL: -1957082.401	Tol1: 0.00278	Tol2: 0.05339	Tol3: 0.00257
# Iter 25/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -1952313.195	Tol1: 0.00244	Tol2: 0.04256	Tol3: 0.00101
# Iter 26/50
# M step: done,  E step: done //  (in 18.01 sec)	logL: -1949585.439	Tol1: 0.00140	Tol2: 0.03992	Tol3: 0.00069
# Iter 27/50
# M step: done,  E step: done //  (in 18.09 sec)	logL: -1947908.356	Tol1: 0.00086	Tol2: 0.04370	Tol3: 0.00059
# Iter 28/50
# M step: done,  E step: done //  (in 17.95 sec)	logL: -1944196.155	Tol1: 0.00191	Tol2: 0.03357	Tol3: 0.00058
# Iter 29/50
# M step: done,  E step: done //  (in 18.05 sec)	logL: -1945684.928	Tol1: 0.00077	Tol2: 0.04984	Tol3: 0.00328
# Iter 30/50
# M step: done,  E step: done //  (in 17.95 sec)	logL: -1948950.953	Tol1: 0.00168	Tol2: 0.04120	Tol3: 0.00063
# Iter 31/50
# M step: done,  E step: done //  (in 17.92 sec)	logL: -1946216.213	Tol1: 0.00140	Tol2: 0.03094	Tol3: 0.00089
# Iter 32/50
# M step: done,  E step: done //  (in 17.90 sec)	logL: -1941349.103	Tol1: 0.00250	Tol2: 0.02455	Tol3: 0.00027
# Finished training!

# %%
gMixture2 = GroupMixtureOpt(Xstd_train.shape[1:],Kl=r_obs.shape[1],M=M_seted,epochs=1,pre_init=0,optimizer=OPT,dtype_op=DTYPE_OP) 
gMixture2.define_model("default cnn")
gMixture2.lambda_random = True #lambda random
logL_hists,i = gMixture2.multiples_run(10,Xstd_train,r_obs,batch_size=BATCH_SIZE,max_iter=EPOCHS_BASE,tolerance=TOL
                                   ,cluster=True,bulk_annotators=[y_obs_categorical,annotators_pca])
# Out:
# Clustering Done!
# Get init alphas in 0.172200 mins
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.40299946 0.12263902 0.701242   0.8247606 ]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 25.26 sec)	logL: -2097684.727
# Iter 2/50
# M step: done,  E step: done //  (in 18.04 sec)	logL: -2074380.664	Tol1: 0.01111	Tol2: 0.11931	Tol3: 0.01513
# Iter 3/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -2038685.008	Tol1: 0.01721	Tol2: 0.12335	Tol3: 0.00228
# Iter 4/50
# M step: done,  E step: done //  (in 18.20 sec)	logL: -2011585.085	Tol1: 0.01329	Tol2: 0.08470	Tol3: 0.00449
# Iter 5/50
# M step: done,  E step: done //  (in 18.27 sec)	logL: -1999069.526	Tol1: 0.00622	Tol2: 0.05509	Tol3: 0.00377
# Iter 6/50
# M step: done,  E step: done //  (in 18.18 sec)	logL: -1988086.950	Tol1: 0.00549	Tol2: 0.08792	Tol3: 0.00365
# Iter 7/50
# M step: done,  E step: done //  (in 18.21 sec)	logL: -1986311.535	Tol1: 0.00089	Tol2: 0.04551	Tol3: 0.00312
# Iter 8/50
# M step: done,  E step: done //  (in 18.20 sec)	logL: -1979837.466	Tol1: 0.00326	Tol2: 0.07234	Tol3: 0.00636
# Iter 9/50
# M step: done,  E step: done //  (in 18.08 sec)	logL: -1969690.738	Tol1: 0.00513	Tol2: 0.10441	Tol3: 0.01127
# Iter 10/50
# M step: done,  E step: done //  (in 18.21 sec)	logL: -1964052.155	Tol1: 0.00286	Tol2: 0.06665	Tol3: 0.00369
# Iter 11/50
# M step: done,  E step: done //  (in 18.25 sec)	logL: -1956414.747	Tol1: 0.00389	Tol2: 0.05165	Tol3: 0.00924
# Iter 12/50
# M step: done,  E step: done //  (in 18.17 sec)	logL: -1957803.454	Tol1: 0.00071	Tol2: 0.03993	Tol3: 0.00516
# Iter 13/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -1963565.162	Tol1: 0.00294	Tol2: 0.05159	Tol3: 0.00818
# Iter 14/50
# M step: done,  E step: done //  (in 17.95 sec)	logL: -1952036.266	Tol1: 0.00587	Tol2: 0.06314	Tol3: 0.00558
# Iter 15/50
# M step: done,  E step: done //  (in 18.22 sec)	logL: -1948638.336	Tol1: 0.00174	Tol2: 0.05645	Tol3: 0.00643
# Iter 16/50
# M step: done,  E step: done //  (in 18.20 sec)	logL: -1944216.809	Tol1: 0.00227	Tol2: 0.05822	Tol3: 0.00423
# Iter 17/50
# M step: done,  E step: done //  (in 18.29 sec)	logL: -1946766.512	Tol1: 0.00131	Tol2: 0.04990	Tol3: 0.00448
# Iter 18/50
# M step: done,  E step: done //  (in 17.98 sec)	logL: -1946448.699	Tol1: 0.00016	Tol2: 0.08421	Tol3: 0.00895
# Iter 19/50
# M step: done,  E step: done //  (in 18.04 sec)	logL: -1945925.638	Tol1: 0.00027	Tol2: 0.04994	Tol3: 0.00156
# Iter 20/50
# M step: done,  E step: done //  (in 18.24 sec)	logL: -1942440.718	Tol1: 0.00179	Tol2: 0.04585	Tol3: 0.00122
# Iter 21/50
# M step: done,  E step: done //  (in 18.30 sec)	logL: -1938837.075	Tol1: 0.00186	Tol2: 0.03876	Tol3: 0.00563
# Iter 22/50
# M step: done,  E step: done //  (in 18.21 sec)	logL: -1933645.054	Tol1: 0.00268	Tol2: 0.04152	Tol3: 0.00159
# Iter 23/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -1933913.549	Tol1: 0.00014	Tol2: 0.03665	Tol3: 0.00262
# Iter 24/50
# M step: done,  E step: done //  (in 18.20 sec)	logL: -1941955.806	Tol1: 0.00416	Tol2: 0.03626	Tol3: 0.00780
# Iter 25/50
# M step: done,  E step: done //  (in 18.24 sec)	logL: -1936264.262	Tol1: 0.00293	Tol2: 0.04238	Tol3: 0.00590
# Iter 26/50
# M step: done,  E step: done //  (in 18.00 sec)	logL: -1931744.214	Tol1: 0.00233	Tol2: 0.02790	Tol3: 0.00089
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.19469997 0.8033384  0.29134047 0.6037571 ]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 24.93 sec)	logL: -2080813.304
# Iter 2/50
# M step: done,  E step: done //  (in 17.98 sec)	logL: -2047826.886	Tol1: 0.01585	Tol2: 0.11487	Tol3: 0.01937
# Iter 3/50
# M step: done,  E step: done //  (in 18.02 sec)	logL: -2022495.353	Tol1: 0.01237	Tol2: 0.10148	Tol3: 0.01421
# Iter 4/50
# M step: done,  E step: done //  (in 17.88 sec)	logL: -2037006.384	Tol1: 0.00717	Tol2: 0.08185	Tol3: 0.00626
# Iter 5/50
# M step: done,  E step: done //  (in 17.96 sec)	logL: -2025368.862	Tol1: 0.00571	Tol2: 0.12116	Tol3: 0.01784
# Iter 6/50
# M step: done,  E step: done //  (in 17.87 sec)	logL: -1999727.125	Tol1: 0.01266	Tol2: 0.10808	Tol3: 0.01410
# Iter 7/50
# M step: done,  E step: done //  (in 18.06 sec)	logL: -1992177.510	Tol1: 0.00378	Tol2: 0.09607	Tol3: 0.00755
# Iter 8/50
# M step: done,  E step: done //  (in 17.85 sec)	logL: -1988609.542	Tol1: 0.00179	Tol2: 0.07094	Tol3: 0.00905
# Iter 9/50
# M step: done,  E step: done //  (in 17.94 sec)	logL: -1994449.853	Tol1: 0.00294	Tol2: 0.06601	Tol3: 0.01283
# Iter 10/50
# M step: done,  E step: done //  (in 17.82 sec)	logL: -1985941.236	Tol1: 0.00427	Tol2: 0.08270	Tol3: 0.01274
# Iter 11/50
# M step: done,  E step: done //  (in 17.94 sec)	logL: -1991171.875	Tol1: 0.00263	Tol2: 0.08679	Tol3: 0.00228
# Iter 12/50
# M step: done,  E step: done //  (in 18.09 sec)	logL: -1977853.614	Tol1: 0.00669	Tol2: 0.14643	Tol3: 0.00762
# Iter 13/50
# M step: done,  E step: done //  (in 17.94 sec)	logL: -1970933.121	Tol1: 0.00350	Tol2: 0.07255	Tol3: 0.00621
# Iter 14/50
# M step: done,  E step: done //  (in 17.76 sec)	logL: -1961323.859	Tol1: 0.00488	Tol2: 0.06828	Tol3: 0.00319
# Iter 15/50
# M step: done,  E step: done //  (in 17.88 sec)	logL: -1960684.023	Tol1: 0.00033	Tol2: 0.04908	Tol3: 0.00189
# Iter 16/50
# M step: done,  E step: done //  (in 17.95 sec)	logL: -1976012.774	Tol1: 0.00782	Tol2: 0.04978	Tol3: 0.00402
# Iter 17/50
# M step: done,  E step: done //  (in 17.93 sec)	logL: -1967982.627	Tol1: 0.00406	Tol2: 0.10838	Tol3: 0.01055
# Iter 18/50
# M step: done,  E step: done //  (in 17.97 sec)	logL: -1960347.280	Tol1: 0.00388	Tol2: 0.06307	Tol3: 0.00588
# Iter 19/50
# M step: done,  E step: done //  (in 18.04 sec)	logL: -1956881.683	Tol1: 0.00177	Tol2: 0.06586	Tol3: 0.00345
# Iter 20/50
# M step: done,  E step: done //  (in 18.04 sec)	logL: -1949585.276	Tol1: 0.00373	Tol2: 0.05635	Tol3: 0.00104
# Iter 21/50
# M step: done,  E step: done //  (in 17.84 sec)	logL: -1946175.600	Tol1: 0.00175	Tol2: 0.05749	Tol3: 0.00384
# Iter 22/50
# M step: done,  E step: done //  (in 17.90 sec)	logL: -1943323.714	Tol1: 0.00147	Tol2: 0.05073	Tol3: 0.00234
# Iter 23/50
# M step: done,  E step: done //  (in 17.87 sec)	logL: -1941680.896	Tol1: 0.00085	Tol2: 0.03858	Tol3: 0.00182
# Iter 24/50
# M step: done,  E step: done //  (in 18.09 sec)	logL: -1940102.808	Tol1: 0.00081	Tol2: 0.03989	Tol3: 0.00120
# Iter 25/50
# M step: done,  E step: done //  (in 17.85 sec)	logL: -1939116.039	Tol1: 0.00051	Tol2: 0.04148	Tol3: 0.00221
# Iter 26/50
# M step: done,  E step: done //  (in 17.89 sec)	logL: -1939357.831	Tol1: 0.00012	Tol2: 0.03132	Tol3: 0.00027
# Iter 27/50
# M step: done,  E step: done //  (in 17.75 sec)	logL: -1934705.500	Tol1: 0.00240	Tol2: 0.05079	Tol3: 0.00361
# Iter 28/50
# M step: done,  E step: done //  (in 17.88 sec)	logL: -1932849.207	Tol1: 0.00096	Tol2: 0.03862	Tol3: 0.00077
# Iter 29/50
# M step: done,  E step: done //  (in 17.75 sec)	logL: -1930745.437	Tol1: 0.00109	Tol2: 0.03991	Tol3: 0.00216
# Iter 30/50
# M step: done,  E step: done //  (in 17.89 sec)	logL: -1932551.608	Tol1: 0.00094	Tol2: 0.04614	Tol3: 0.00352
# Iter 31/50
# M step: done,  E step: done //  (in 17.69 sec)	logL: -1930288.397	Tol1: 0.00117	Tol2: 0.06213	Tol3: 0.00411
# Iter 32/50
# M step: done,  E step: done //  (in 17.72 sec)	logL: -1929169.159	Tol1: 0.00058	Tol2: 0.03914	Tol3: 0.00191
# Iter 33/50
# M step: done,  E step: done //  (in 17.86 sec)	logL: -1933230.932	Tol1: 0.00211	Tol2: 0.04221	Tol3: 0.00391
# Iter 34/50
# M step: done,  E step: done //  (in 17.79 sec)	logL: -1933112.814	Tol1: 0.00006	Tol2: 0.04479	Tol3: 0.00477
# Iter 35/50
# M step: done,  E step: done //  (in 17.48 sec)	logL: -1925464.875	Tol1: 0.00396	Tol2: 0.04049	Tol3: 0.00072
# Iter 36/50
# M step: done,  E step: done //  (in 17.76 sec)	logL: -1926623.705	Tol1: 0.00060	Tol2: 0.03099	Tol3: 0.00316
# Iter 37/50
# M step: done,  E step: done //  (in 17.87 sec)	logL: -1926996.104	Tol1: 0.00019	Tol2: 0.02624	Tol3: 0.00363
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.5712446  0.76758605 0.7331849  0.58540297]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 25.46 sec)	logL: -2137801.182
# Iter 2/50
# M step: done,  E step: done //  (in 18.10 sec)	logL: -2086342.253	Tol1: 0.02407	Tol2: 0.15455	Tol3: 0.01569
# Iter 3/50
# M step: done,  E step: done //  (in 18.20 sec)	logL: -2070744.512	Tol1: 0.00748	Tol2: 0.12401	Tol3: 0.00942
# Iter 4/50
# M step: done,  E step: done //  (in 18.15 sec)	logL: -2045792.530	Tol1: 0.01205	Tol2: 0.12753	Tol3: 0.00907
# Iter 5/50
# M step: done,  E step: done //  (in 18.07 sec)	logL: -2042529.605	Tol1: 0.00159	Tol2: 0.11759	Tol3: 0.00567
# Iter 6/50
# M step: done,  E step: done //  (in 18.11 sec)	logL: -2013667.578	Tol1: 0.01413	Tol2: 0.11615	Tol3: 0.00421
# Iter 7/50
# M step: done,  E step: done //  (in 17.96 sec)	logL: -2002582.076	Tol1: 0.00551	Tol2: 0.08231	Tol3: 0.00233
# Iter 8/50
# M step: done,  E step: done //  (in 18.18 sec)	logL: -1986237.654	Tol1: 0.00816	Tol2: 0.07163	Tol3: 0.00104
# Iter 9/50
# M step: done,  E step: done //  (in 18.07 sec)	logL: -1982655.471	Tol1: 0.00180	Tol2: 0.05934	Tol3: 0.00211
# Iter 10/50
# M step: done,  E step: done //  (in 18.17 sec)	logL: -1979862.150	Tol1: 0.00141	Tol2: 0.06548	Tol3: 0.00257
# Iter 11/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -1970246.755	Tol1: 0.00486	Tol2: 0.10717	Tol3: 0.00179
# Iter 12/50
# M step: done,  E step: done //  (in 18.05 sec)	logL: -1974003.732	Tol1: 0.00191	Tol2: 0.05091	Tol3: 0.00096
# Iter 13/50
# M step: done,  E step: done //  (in 18.05 sec)	logL: -1971278.381	Tol1: 0.00138	Tol2: 0.07497	Tol3: 0.00314
# Iter 14/50
# M step: done,  E step: done //  (in 18.14 sec)	logL: -1957195.770	Tol1: 0.00714	Tol2: 0.08319	Tol3: 0.00127
# Iter 15/50
# M step: done,  E step: done //  (in 17.97 sec)	logL: -1986049.490	Tol1: 0.01474	Tol2: 0.04592	Tol3: 0.00071
# Iter 16/50
# M step: done,  E step: done //  (in 18.10 sec)	logL: -1956287.654	Tol1: 0.01499	Tol2: 0.10895	Tol3: 0.00323
# Iter 17/50
# M step: done,  E step: done //  (in 18.31 sec)	logL: -1955941.945	Tol1: 0.00018	Tol2: 0.04678	Tol3: 0.00176
# Iter 18/50
# M step: done,  E step: done //  (in 18.09 sec)	logL: -1957127.320	Tol1: 0.00061	Tol2: 0.05209	Tol3: 0.00147
# Iter 19/50
# M step: done,  E step: done //  (in 18.15 sec)	logL: -1952017.654	Tol1: 0.00261	Tol2: 0.06170	Tol3: 0.00284
# Iter 20/50
# M step: done,  E step: done //  (in 18.11 sec)	logL: -1953260.184	Tol1: 0.00064	Tol2: 0.03976	Tol3: 0.00066
# Iter 21/50
# M step: done,  E step: done //  (in 18.06 sec)	logL: -1948360.209	Tol1: 0.00251	Tol2: 0.05405	Tol3: 0.00113
# Iter 22/50
# M step: done,  E step: done //  (in 18.21 sec)	logL: -1945367.776	Tol1: 0.00154	Tol2: 0.06385	Tol3: 0.00082
# Iter 23/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -1939649.381	Tol1: 0.00294	Tol2: 0.05924	Tol3: 0.00160
# Iter 24/50
# M step: done,  E step: done //  (in 17.96 sec)	logL: -1940432.658	Tol1: 0.00040	Tol2: 0.05022	Tol3: 0.00144
# Iter 25/50
# M step: done,  E step: done //  (in 18.19 sec)	logL: -1938086.192	Tol1: 0.00121	Tol2: 0.06957	Tol3: 0.00347
# Iter 26/50
# M step: done,  E step: done //  (in 18.16 sec)	logL: -1935078.496	Tol1: 0.00155	Tol2: 0.04464	Tol3: 0.00142
# Iter 27/50
# M step: done,  E step: done //  (in 18.12 sec)	logL: -1934772.166	Tol1: 0.00016	Tol2: 0.05061	Tol3: 0.00160
# Iter 28/50
# M step: done,  E step: done //  (in 18.06 sec)	logL: -1931083.982	Tol1: 0.00191	Tol2: 0.04673	Tol3: 0.00115
# Iter 29/50
# M step: done,  E step: done //  (in 18.31 sec)	logL: -1928734.265	Tol1: 0.00122	Tol2: 0.03125	Tol3: 0.00083
# Iter 30/50
# M step: done,  E step: done //  (in 18.20 sec)	logL: -1927103.546	Tol1: 0.00085	Tol2: 0.03727	Tol3: 0.00093
# Iter 31/50
# M step: done,  E step: done //  (in 18.08 sec)	logL: -1926487.010	Tol1: 0.00032	Tol2: 0.04121	Tol3: 0.00063
# Iter 32/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -1923400.473	Tol1: 0.00160	Tol2: 0.03974	Tol3: 0.00077
# Iter 33/50
# M step: done,  E step: done //  (in 17.91 sec)	logL: -1924101.259	Tol1: 0.00036	Tol2: 0.02605	Tol3: 0.00081
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.79389966 0.11049712 0.8249825  0.98159146]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 25.77 sec)	logL: -2117998.602
# Iter 2/50
# M step: done,  E step: done //  (in 18.19 sec)	logL: -2070898.332	Tol1: 0.02224	Tol2: 0.14714	Tol3: 0.02800
# Iter 3/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -2038685.642	Tol1: 0.01555	Tol2: 0.13405	Tol3: 0.02342
# Iter 4/50
# M step: done,  E step: done //  (in 18.09 sec)	logL: -2020654.232	Tol1: 0.00884	Tol2: 0.09285	Tol3: 0.01177
# Iter 5/50
# M step: done,  E step: done //  (in 18.08 sec)	logL: -2000769.036	Tol1: 0.00984	Tol2: 0.10089	Tol3: 0.00394
# Iter 6/50
# M step: done,  E step: done //  (in 18.17 sec)	logL: -1993136.420	Tol1: 0.00381	Tol2: 0.05282	Tol3: 0.00691
# Iter 7/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -1996202.763	Tol1: 0.00154	Tol2: 0.06296	Tol3: 0.00147
# Iter 8/50
# M step: done,  E step: done //  (in 18.26 sec)	logL: -1990018.426	Tol1: 0.00310	Tol2: 0.08194	Tol3: 0.01330
# Iter 9/50
# M step: done,  E step: done //  (in 18.43 sec)	logL: -1982270.765	Tol1: 0.00389	Tol2: 0.05898	Tol3: 0.00930
# Iter 10/50
# M step: done,  E step: done //  (in 18.34 sec)	logL: -1978538.496	Tol1: 0.00188	Tol2: 0.06861	Tol3: 0.00773
# Iter 11/50
# M step: done,  E step: done //  (in 18.20 sec)	logL: -1968749.026	Tol1: 0.00495	Tol2: 0.05498	Tol3: 0.01001
# Iter 12/50
# M step: done,  E step: done //  (in 18.11 sec)	logL: -1970702.760	Tol1: 0.00099	Tol2: 0.04733	Tol3: 0.00191
# Iter 13/50
# M step: done,  E step: done //  (in 18.15 sec)	logL: -1967264.822	Tol1: 0.00174	Tol2: 0.06735	Tol3: 0.00718
# Iter 14/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -1957489.998	Tol1: 0.00497	Tol2: 0.07306	Tol3: 0.00379
# Iter 15/50
# M step: done,  E step: done //  (in 18.18 sec)	logL: -1954565.643	Tol1: 0.00149	Tol2: 0.04595	Tol3: 0.00225
# Iter 16/50
# M step: done,  E step: done //  (in 18.27 sec)	logL: -1952149.069	Tol1: 0.00124	Tol2: 0.06111	Tol3: 0.00341
# Iter 17/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -1956425.894	Tol1: 0.00219	Tol2: 0.04974	Tol3: 0.00979
# Iter 18/50
# M step: done,  E step: done //  (in 18.14 sec)	logL: -1953228.677	Tol1: 0.00163	Tol2: 0.06776	Tol3: 0.01532
# Iter 19/50
# M step: done,  E step: done //  (in 18.19 sec)	logL: -1953476.266	Tol1: 0.00013	Tol2: 0.04710	Tol3: 0.00579
# Iter 20/50
# M step: done,  E step: done //  (in 18.12 sec)	logL: -1950336.484	Tol1: 0.00161	Tol2: 0.04460	Tol3: 0.00492
# Iter 21/50
# M step: done,  E step: done //  (in 18.25 sec)	logL: -1945107.693	Tol1: 0.00268	Tol2: 0.04548	Tol3: 0.00122
# Iter 22/50
# M step: done,  E step: done //  (in 18.07 sec)	logL: -1945259.107	Tol1: 0.00008	Tol2: 0.03858	Tol3: 0.00197
# Iter 23/50
# M step: done,  E step: done //  (in 18.27 sec)	logL: -1942057.356	Tol1: 0.00165	Tol2: 0.04768	Tol3: 0.00209
# Iter 24/50
# M step: done,  E step: done //  (in 18.19 sec)	logL: -1938624.603	Tol1: 0.00177	Tol2: 0.03990	Tol3: 0.00412
# Iter 25/50
# M step: done,  E step: done //  (in 18.34 sec)	logL: -1936747.564	Tol1: 0.00097	Tol2: 0.03688	Tol3: 0.00071
# Iter 26/50
# M step: done,  E step: done //  (in 18.25 sec)	logL: -1934360.674	Tol1: 0.00123	Tol2: 0.04066	Tol3: 0.00152
# Iter 27/50
# M step: done,  E step: done //  (in 18.24 sec)	logL: -1933148.043	Tol1: 0.00063	Tol2: 0.03282	Tol3: 0.00396
# Iter 28/50
# M step: done,  E step: done //  (in 18.02 sec)	logL: -1933831.523	Tol1: 0.00035	Tol2: 0.03659	Tol3: 0.00073
# Iter 29/50
# M step: done,  E step: done //  (in 18.11 sec)	logL: -1934589.926	Tol1: 0.00039	Tol2: 0.02690	Tol3: 0.00441
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.43178257 0.17448145 0.38108206 0.00104866]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 26.13 sec)	logL: -2075098.069
# Iter 2/50
# M step: done,  E step: done //  (in 18.22 sec)	logL: -2043491.454	Tol1: 0.01523	Tol2: 0.14642	Tol3: 0.00418
# Iter 3/50
# M step: done,  E step: done //  (in 18.30 sec)	logL: -2023593.004	Tol1: 0.00974	Tol2: 0.12420	Tol3: 0.00090
# Iter 4/50
# M step: done,  E step: done //  (in 18.27 sec)	logL: -2025607.176	Tol1: 0.00100	Tol2: 0.11244	Tol3: 0.00331
# Iter 5/50
# M step: done,  E step: done //  (in 18.39 sec)	logL: -2001072.077	Tol1: 0.01211	Tol2: 0.11437	Tol3: 0.00930
# Iter 6/50
# M step: done,  E step: done //  (in 18.51 sec)	logL: -2010108.728	Tol1: 0.00452	Tol2: 0.09773	Tol3: 0.00614
# Iter 7/50
# M step: done,  E step: done //  (in 18.26 sec)	logL: -1992003.773	Tol1: 0.00901	Tol2: 0.12277	Tol3: 0.01327
# Iter 8/50
# M step: done,  E step: done //  (in 18.21 sec)	logL: -1986188.502	Tol1: 0.00292	Tol2: 0.08618	Tol3: 0.00950
# Iter 9/50
# M step: done,  E step: done //  (in 18.38 sec)	logL: -1970954.674	Tol1: 0.00767	Tol2: 0.09546	Tol3: 0.01028
# Iter 10/50
# M step: done,  E step: done //  (in 18.30 sec)	logL: -1972609.267	Tol1: 0.00084	Tol2: 0.10924	Tol3: 0.00320
# Iter 11/50
# M step: done,  E step: done //  (in 18.21 sec)	logL: -1960494.731	Tol1: 0.00614	Tol2: 0.10891	Tol3: 0.00737
# Iter 12/50
# M step: done,  E step: done //  (in 18.21 sec)	logL: -1957341.760	Tol1: 0.00161	Tol2: 0.08060	Tol3: 0.00867
# Iter 13/50
# M step: done,  E step: done //  (in 18.38 sec)	logL: -1951635.838	Tol1: 0.00292	Tol2: 0.08858	Tol3: 0.00305
# Iter 14/50
# M step: done,  E step: done //  (in 18.33 sec)	logL: -1949760.101	Tol1: 0.00096	Tol2: 0.07318	Tol3: 0.00737
# Iter 15/50
# M step: done,  E step: done //  (in 18.30 sec)	logL: -1948849.089	Tol1: 0.00047	Tol2: 0.06754	Tol3: 0.00719
# Iter 16/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -1943670.754	Tol1: 0.00266	Tol2: 0.07521	Tol3: 0.00929
# Iter 17/50
# M step: done,  E step: done //  (in 18.14 sec)	logL: -1939193.844	Tol1: 0.00230	Tol2: 0.07663	Tol3: 0.00044
# Iter 18/50
# M step: done,  E step: done //  (in 18.36 sec)	logL: -1937197.391	Tol1: 0.00103	Tol2: 0.06370	Tol3: 0.00121
# Iter 19/50
# M step: done,  E step: done //  (in 18.33 sec)	logL: -1933247.228	Tol1: 0.00204	Tol2: 0.05679	Tol3: 0.00435
# Iter 20/50
# M step: done,  E step: done //  (in 18.19 sec)	logL: -1934967.046	Tol1: 0.00089	Tol2: 0.04835	Tol3: 0.00104
# Iter 21/50
# M step: done,  E step: done //  (in 18.51 sec)	logL: -1929929.480	Tol1: 0.00260	Tol2: 0.05772	Tol3: 0.00660
# Iter 22/50
# M step: done,  E step: done //  (in 18.32 sec)	logL: -1932679.589	Tol1: 0.00142	Tol2: 0.05005	Tol3: 0.00200
# Iter 23/50
# M step: done,  E step: done //  (in 18.21 sec)	logL: -1925054.723	Tol1: 0.00395	Tol2: 0.05491	Tol3: 0.00233
# Iter 24/50
# M step: done,  E step: done //  (in 18.42 sec)	logL: -1925068.087	Tol1: 0.00001	Tol2: 0.04201	Tol3: 0.00134
# Iter 25/50
# M step: done,  E step: done //  (in 18.28 sec)	logL: -1922697.798	Tol1: 0.00123	Tol2: 0.03677	Tol3: 0.00150
# Iter 26/50
# M step: done,  E step: done //  (in 18.44 sec)	logL: -1921005.316	Tol1: 0.00088	Tol2: 0.04153	Tol3: 0.00593
# Iter 27/50
# M step: done,  E step: done //  (in 18.25 sec)	logL: -1920370.057	Tol1: 0.00033	Tol2: 0.02857	Tol3: 0.00171
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.24490452 0.5321268  0.01844724 0.8212078 ]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 26.64 sec)	logL: -2087410.538
# Iter 2/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -2046167.972	Tol1: 0.01976	Tol2: 0.10282	Tol3: 0.02065
# Iter 3/50
# M step: done,  E step: done //  (in 17.97 sec)	logL: -2016773.242	Tol1: 0.01437	Tol2: 0.07510	Tol3: 0.01403
# Iter 4/50
# M step: done,  E step: done //  (in 18.24 sec)	logL: -2001236.119	Tol1: 0.00770	Tol2: 0.05205	Tol3: 0.00962
# Iter 5/50
# M step: done,  E step: done //  (in 18.18 sec)	logL: -2024338.803	Tol1: 0.01154	Tol2: 0.05826	Tol3: 0.00208
# Iter 6/50
# M step: done,  E step: done //  (in 18.01 sec)	logL: -1992374.102	Tol1: 0.01579	Tol2: 0.11604	Tol3: 0.01103
# Iter 7/50
# M step: done,  E step: done //  (in 18.24 sec)	logL: -1981851.245	Tol1: 0.00528	Tol2: 0.08332	Tol3: 0.00827
# Iter 8/50
# M step: done,  E step: done //  (in 18.29 sec)	logL: -1971128.964	Tol1: 0.00541	Tol2: 0.08328	Tol3: 0.00602
# Iter 9/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -1968305.832	Tol1: 0.00143	Tol2: 0.06874	Tol3: 0.00402
# Iter 10/50
# M step: done,  E step: done //  (in 18.23 sec)	logL: -1959708.701	Tol1: 0.00437	Tol2: 0.06361	Tol3: 0.00571
# Iter 11/50
# M step: done,  E step: done //  (in 18.11 sec)	logL: -1959012.699	Tol1: 0.00036	Tol2: 0.05859	Tol3: 0.00612
# Iter 12/50
# M step: done,  E step: done //  (in 18.19 sec)	logL: -1952854.859	Tol1: 0.00314	Tol2: 0.06837	Tol3: 0.00510
# Iter 13/50
# M step: done,  E step: done //  (in 18.11 sec)	logL: -1949736.030	Tol1: 0.00160	Tol2: 0.05729	Tol3: 0.00425
# Iter 14/50
# M step: done,  E step: done //  (in 18.25 sec)	logL: -1946740.878	Tol1: 0.00154	Tol2: 0.06913	Tol3: 0.00879
# Iter 15/50
# M step: done,  E step: done //  (in 18.24 sec)	logL: -1943817.986	Tol1: 0.00150	Tol2: 0.05402	Tol3: 0.00923
# Iter 16/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -1944426.490	Tol1: 0.00031	Tol2: 0.06174	Tol3: 0.00915
# Iter 17/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -1939780.346	Tol1: 0.00239	Tol2: 0.05562	Tol3: 0.01012
# Iter 18/50
# M step: done,  E step: done //  (in 18.23 sec)	logL: -1940896.294	Tol1: 0.00058	Tol2: 0.05337	Tol3: 0.00893
# Iter 19/50
# M step: done,  E step: done //  (in 18.03 sec)	logL: -1934534.004	Tol1: 0.00328	Tol2: 0.06032	Tol3: 0.01144
# Iter 20/50
# M step: done,  E step: done //  (in 18.14 sec)	logL: -1932036.761	Tol1: 0.00129	Tol2: 0.03565	Tol3: 0.00502
# Iter 21/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -1931542.966	Tol1: 0.00026	Tol2: 0.03441	Tol3: 0.00407
# Iter 22/50
# M step: done,  E step: done //  (in 18.18 sec)	logL: -1928697.558	Tol1: 0.00147	Tol2: 0.04047	Tol3: 0.00665
# Iter 23/50
# M step: done,  E step: done //  (in 18.22 sec)	logL: -1932671.700	Tol1: 0.00206	Tol2: 0.04593	Tol3: 0.00427
# Iter 24/50
# M step: done,  E step: done //  (in 18.22 sec)	logL: -1929722.596	Tol1: 0.00153	Tol2: 0.05598	Tol3: 0.00737
# Iter 25/50
# M step: done,  E step: done //  (in 18.17 sec)	logL: -1936004.392	Tol1: 0.00326	Tol2: 0.04117	Tol3: 0.00904
# Iter 26/50
# M step: done,  E step: done //  (in 18.13 sec)	logL: -1933642.013	Tol1: 0.00122	Tol2: 0.07108	Tol3: 0.00909
# Iter 27/50
# M step: done,  E step: done //  (in 18.17 sec)	logL: -1927062.771	Tol1: 0.00340	Tol2: 0.04766	Tol3: 0.00382
# Iter 28/50
# M step: done,  E step: done //  (in 18.07 sec)	logL: -1925911.583	Tol1: 0.00060	Tol2: 0.03130	Tol3: 0.00235
# Iter 29/50
# M step: done,  E step: done //  (in 18.22 sec)	logL: -1924143.071	Tol1: 0.00092	Tol2: 0.02428	Tol3: 0.00162
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.51068616 0.02415647 0.23069401 0.67228127]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 26.79 sec)	logL: -2083965.396
# Iter 2/50
# M step: done,  E step: done //  (in 18.47 sec)	logL: -2049981.229	Tol1: 0.01631	Tol2: 0.10290	Tol3: 0.01049
# Iter 3/50
# M step: done,  E step: done //  (in 18.33 sec)	logL: -2029012.092	Tol1: 0.01023	Tol2: 0.06915	Tol3: 0.00484
# Iter 4/50
# M step: done,  E step: done //  (in 18.33 sec)	logL: -2016573.265	Tol1: 0.00613	Tol2: 0.09570	Tol3: 0.00276
# Iter 5/50
# M step: done,  E step: done //  (in 18.23 sec)	logL: -2005820.216	Tol1: 0.00533	Tol2: 0.09023	Tol3: 0.00330
# Iter 6/50
# M step: done,  E step: done //  (in 18.50 sec)	logL: -1991471.925	Tol1: 0.00715	Tol2: 0.08227	Tol3: 0.00109
# Iter 7/50
# M step: done,  E step: done //  (in 18.28 sec)	logL: -1980370.793	Tol1: 0.00557	Tol2: 0.06252	Tol3: 0.00066
# Iter 8/50
# M step: done,  E step: done //  (in 18.39 sec)	logL: -1984098.484	Tol1: 0.00188	Tol2: 0.06842	Tol3: 0.00892
# Iter 9/50
# M step: done,  E step: done //  (in 18.31 sec)	logL: -1972775.531	Tol1: 0.00571	Tol2: 0.10481	Tol3: 0.00924
# Iter 10/50
# M step: done,  E step: done //  (in 18.30 sec)	logL: -1967396.467	Tol1: 0.00273	Tol2: 0.08772	Tol3: 0.01031
# Iter 11/50
# M step: done,  E step: done //  (in 18.36 sec)	logL: -1963323.243	Tol1: 0.00207	Tol2: 0.09584	Tol3: 0.00642
# Iter 12/50
# M step: done,  E step: done //  (in 18.39 sec)	logL: -1958162.072	Tol1: 0.00263	Tol2: 0.08648	Tol3: 0.01343
# Iter 13/50
# M step: done,  E step: done //  (in 18.33 sec)	logL: -1951508.702	Tol1: 0.00340	Tol2: 0.07208	Tol3: 0.00660
# Iter 14/50
# M step: done,  E step: done //  (in 18.48 sec)	logL: -1951318.873	Tol1: 0.00010	Tol2: 0.03815	Tol3: 0.00541
# Iter 15/50
# M step: done,  E step: done //  (in 18.18 sec)	logL: -1946487.967	Tol1: 0.00248	Tol2: 0.06355	Tol3: 0.00477
# Iter 16/50
# M step: done,  E step: done //  (in 18.47 sec)	logL: -1954821.975	Tol1: 0.00428	Tol2: 0.07606	Tol3: 0.00225
# Iter 17/50
# M step: done,  E step: done //  (in 18.32 sec)	logL: -1948853.026	Tol1: 0.00305	Tol2: 0.08940	Tol3: 0.00562
# Iter 18/50
# M step: done,  E step: done //  (in 18.22 sec)	logL: -1940849.056	Tol1: 0.00411	Tol2: 0.06420	Tol3: 0.00950
# Iter 19/50
# M step: done,  E step: done //  (in 18.35 sec)	logL: -1935811.426	Tol1: 0.00260	Tol2: 0.07750	Tol3: 0.00268
# Iter 20/50
# M step: done,  E step: done //  (in 18.35 sec)	logL: -1937312.944	Tol1: 0.00078	Tol2: 0.02747	Tol3: 0.00088
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.6028608  0.45614398 0.9655196  0.96819216]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 27.46 sec)	logL: -2114793.848
# Iter 2/50
# M step: done,  E step: done //  (in 18.60 sec)	logL: -2075929.367	Tol1: 0.01838	Tol2: 0.13092	Tol3: 0.02485
# Iter 3/50
# M step: done,  E step: done //  (in 18.72 sec)	logL: -2044714.798	Tol1: 0.01504	Tol2: 0.11552	Tol3: 0.01788
# Iter 4/50
# M step: done,  E step: done //  (in 18.78 sec)	logL: -2026002.076	Tol1: 0.00915	Tol2: 0.09361	Tol3: 0.01282
# Iter 5/50
# M step: done,  E step: done //  (in 18.57 sec)	logL: -2007301.366	Tol1: 0.00923	Tol2: 0.07023	Tol3: 0.00550
# Iter 6/50
# M step: done,  E step: done //  (in 18.69 sec)	logL: -2002836.292	Tol1: 0.00222	Tol2: 0.07656	Tol3: 0.00296
# Iter 7/50
# M step: done,  E step: done //  (in 18.57 sec)	logL: -1991843.465	Tol1: 0.00549	Tol2: 0.07489	Tol3: 0.00485
# Iter 8/50
# M step: done,  E step: done //  (in 18.64 sec)	logL: -1984868.964	Tol1: 0.00350	Tol2: 0.05754	Tol3: 0.00272
# Iter 9/50
# M step: done,  E step: done //  (in 18.69 sec)	logL: -1977317.146	Tol1: 0.00380	Tol2: 0.05214	Tol3: 0.00341
# Iter 10/50
# M step: done,  E step: done //  (in 18.52 sec)	logL: -1970068.101	Tol1: 0.00367	Tol2: 0.06380	Tol3: 0.00150
# Iter 11/50
# M step: done,  E step: done //  (in 18.63 sec)	logL: -1969241.669	Tol1: 0.00042	Tol2: 0.04379	Tol3: 0.00572
# Iter 12/50
# M step: done,  E step: done //  (in 18.65 sec)	logL: -1963297.121	Tol1: 0.00302	Tol2: 0.05762	Tol3: 0.00209
# Iter 13/50
# M step: done,  E step: done //  (in 18.63 sec)	logL: -1957244.639	Tol1: 0.00308	Tol2: 0.04204	Tol3: 0.00385
# Iter 14/50
# M step: done,  E step: done //  (in 18.67 sec)	logL: -1958600.769	Tol1: 0.00069	Tol2: 0.03322	Tol3: 0.00290
# Iter 15/50
# M step: done,  E step: done //  (in 18.72 sec)	logL: -1952800.834	Tol1: 0.00296	Tol2: 0.06550	Tol3: 0.00159
# Iter 16/50
# M step: done,  E step: done //  (in 18.78 sec)	logL: -1947445.252	Tol1: 0.00274	Tol2: 0.05313	Tol3: 0.00234
# Iter 17/50
# M step: done,  E step: done //  (in 18.67 sec)	logL: -1954693.024	Tol1: 0.00372	Tol2: 0.04028	Tol3: 0.00260
# Iter 18/50
# M step: done,  E step: done //  (in 18.50 sec)	logL: -1956421.185	Tol1: 0.00088	Tol2: 0.04648	Tol3: 0.00593
# Iter 19/50
# M step: done,  E step: done //  (in 18.60 sec)	logL: -1954378.938	Tol1: 0.00104	Tol2: 0.05494	Tol3: 0.00415
# Iter 20/50
# M step: done,  E step: done //  (in 18.66 sec)	logL: -1953328.060	Tol1: 0.00054	Tol2: 0.05425	Tol3: 0.00344
# Iter 21/50
# M step: done,  E step: done //  (in 18.56 sec)	logL: -1942656.814	Tol1: 0.00546	Tol2: 0.03764	Tol3: 0.00500
# Iter 22/50
# M step: done,  E step: done //  (in 18.51 sec)	logL: -1943484.436	Tol1: 0.00043	Tol2: 0.03832	Tol3: 0.00451
# Iter 23/50
# M step: done,  E step: done //  (in 18.60 sec)	logL: -1937918.605	Tol1: 0.00286	Tol2: 0.03599	Tol3: 0.00206
# Iter 24/50
# M step: done,  E step: done //  (in 18.44 sec)	logL: -1937514.927	Tol1: 0.00021	Tol2: 0.04692	Tol3: 0.00347
# Iter 25/50
# M step: done,  E step: done //  (in 18.60 sec)	logL: -1934541.202	Tol1: 0.00153	Tol2: 0.03601	Tol3: 0.00094
# Iter 26/50
# M step: done,  E step: done //  (in 18.70 sec)	logL: -1931956.680	Tol1: 0.00134	Tol2: 0.02595	Tol3: 0.00056
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.3735149 0.6834001 0.6669375 0.9547164]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 28.15 sec)	logL: -2136855.779
# Iter 2/50
# M step: done,  E step: done //  (in 18.91 sec)	logL: -2104841.809	Tol1: 0.01498	Tol2: 0.15993	Tol3: 0.01010
# Iter 3/50
# M step: done,  E step: done //  (in 18.77 sec)	logL: -2066778.481	Tol1: 0.01808	Tol2: 0.14592	Tol3: 0.00786
# Iter 4/50
# M step: done,  E step: done //  (in 18.46 sec)	logL: -2034793.154	Tol1: 0.01548	Tol2: 0.11771	Tol3: 0.00626
# Iter 5/50
# M step: done,  E step: done //  (in 18.75 sec)	logL: -2027809.754	Tol1: 0.00343	Tol2: 0.08964	Tol3: 0.00756
# Iter 6/50
# M step: done,  E step: done //  (in 18.68 sec)	logL: -2027587.395	Tol1: 0.00011	Tol2: 0.08247	Tol3: 0.00035
# Iter 7/50
# M step: done,  E step: done //  (in 18.78 sec)	logL: -2009330.199	Tol1: 0.00900	Tol2: 0.10002	Tol3: 0.00442
# Iter 8/50
# M step: done,  E step: done //  (in 18.69 sec)	logL: -2003187.046	Tol1: 0.00306	Tol2: 0.07297	Tol3: 0.00303
# Iter 9/50
# M step: done,  E step: done //  (in 18.64 sec)	logL: -1987217.507	Tol1: 0.00797	Tol2: 0.07740	Tol3: 0.00166
# Iter 10/50
# M step: done,  E step: done //  (in 18.75 sec)	logL: -1980769.216	Tol1: 0.00324	Tol2: 0.06620	Tol3: 0.00200
# Iter 11/50
# M step: done,  E step: done //  (in 18.71 sec)	logL: -1973181.921	Tol1: 0.00383	Tol2: 0.07478	Tol3: 0.00301
# Iter 12/50
# M step: done,  E step: done //  (in 18.88 sec)	logL: -1970185.793	Tol1: 0.00152	Tol2: 0.05060	Tol3: 0.00133
# Iter 13/50
# M step: done,  E step: done //  (in 18.63 sec)	logL: -1975575.301	Tol1: 0.00274	Tol2: 0.06912	Tol3: 0.00279
# Iter 14/50
# M step: done,  E step: done //  (in 18.79 sec)	logL: -1965315.418	Tol1: 0.00519	Tol2: 0.07670	Tol3: 0.00394
# Iter 15/50
# M step: done,  E step: done //  (in 18.90 sec)	logL: -1961873.332	Tol1: 0.00175	Tol2: 0.05982	Tol3: 0.00147
# Iter 16/50
# M step: done,  E step: done //  (in 18.81 sec)	logL: -1957694.905	Tol1: 0.00213	Tol2: 0.06280	Tol3: 0.00245
# Iter 17/50
# M step: done,  E step: done //  (in 18.80 sec)	logL: -1949884.621	Tol1: 0.00399	Tol2: 0.06449	Tol3: 0.00173
# Iter 18/50
# M step: done,  E step: done //  (in 18.49 sec)	logL: -1951911.150	Tol1: 0.00104	Tol2: 0.04464	Tol3: 0.00321
# Iter 19/50
# M step: done,  E step: done //  (in 18.89 sec)	logL: -1949532.934	Tol1: 0.00122	Tol2: 0.07294	Tol3: 0.00339
# Iter 20/50
# M step: done,  E step: done //  (in 18.65 sec)	logL: -1942331.930	Tol1: 0.00369	Tol2: 0.07262	Tol3: 0.00250
# Iter 21/50
# M step: done,  E step: done //  (in 18.81 sec)	logL: -1940878.534	Tol1: 0.00075	Tol2: 0.04399	Tol3: 0.00130
# Iter 22/50
# M step: done,  E step: done //  (in 18.79 sec)	logL: -1943704.535	Tol1: 0.00146	Tol2: 0.04808	Tol3: 0.00403
# Iter 23/50
# M step: done,  E step: done //  (in 18.64 sec)	logL: -1937958.591	Tol1: 0.00296	Tol2: 0.05904	Tol3: 0.00121
# Iter 24/50
# M step: done,  E step: done //  (in 18.71 sec)	logL: -1935404.582	Tol1: 0.00132	Tol2: 0.03481	Tol3: 0.00174
# Iter 25/50
# M step: done,  E step: done //  (in 18.72 sec)	logL: -1936045.638	Tol1: 0.00033	Tol2: 0.03095	Tol3: 0.00063
# Iter 26/50
# M step: done,  E step: done //  (in 18.75 sec)	logL: -1932386.707	Tol1: 0.00189	Tol2: 0.03967	Tol3: 0.00428
# Iter 27/50
# M step: done,  E step: done //  (in 18.79 sec)	logL: -1929052.339	Tol1: 0.00173	Tol2: 0.02907	Tol3: 0.00139
# Finished training!
# Initializing new EM...
# Pre-train network on 0 epochs... Done!
# Lambda by group:  [0.9382292  0.4833804  0.01457971 0.50637287]
# Alphas:  (4,)
# MV init:  (50000, 10)
# Betas:  (4, 10, 10)
# Q estimate:  (50000, 10, 4, 10)
# Iter 1/50
# M step: done,  E step: done //  (in 28.49 sec)	logL: -2096411.642
# Iter 2/50
# M step: done,  E step: done //  (in 18.88 sec)	logL: -2063666.421	Tol1: 0.01562	Tol2: 0.13390	Tol3: 0.02344
# Iter 3/50
# M step: done,  E step: done //  (in 18.91 sec)	logL: -2035186.066	Tol1: 0.01380	Tol2: 0.11018	Tol3: 0.01518
# Iter 4/50
# M step: done,  E step: done //  (in 18.87 sec)	logL: -2038931.251	Tol1: 0.00184	Tol2: 0.08773	Tol3: 0.00341
# Iter 5/50
# M step: done,  E step: done //  (in 18.81 sec)	logL: -2008682.646	Tol1: 0.01484	Tol2: 0.11707	Tol3: 0.01736
# Iter 6/50
# M step: done,  E step: done //  (in 18.96 sec)	logL: -2017958.223	Tol1: 0.00462	Tol2: 0.05757	Tol3: 0.00147
# Iter 7/50
# M step: done,  E step: done //  (in 18.86 sec)	logL: -1998865.324	Tol1: 0.00946	Tol2: 0.10041	Tol3: 0.01240
# Iter 8/50
# M step: done,  E step: done //  (in 18.98 sec)	logL: -1997748.240	Tol1: 0.00056	Tol2: 0.10318	Tol3: 0.00386
# Iter 9/50
# M step: done,  E step: done //  (in 18.71 sec)	logL: -1983150.772	Tol1: 0.00731	Tol2: 0.08573	Tol3: 0.01552
# Iter 10/50
# M step: done,  E step: done //  (in 18.87 sec)	logL: -1978817.969	Tol1: 0.00218	Tol2: 0.07340	Tol3: 0.00407
# Iter 11/50
# M step: done,  E step: done //  (in 18.94 sec)	logL: -1975581.796	Tol1: 0.00164	Tol2: 0.08225	Tol3: 0.00179
# Iter 12/50
# M step: done,  E step: done //  (in 18.95 sec)	logL: -1968369.807	Tol1: 0.00365	Tol2: 0.06465	Tol3: 0.00439
# Iter 13/50
# M step: done,  E step: done //  (in 18.97 sec)	logL: -1963061.859	Tol1: 0.00270	Tol2: 0.06425	Tol3: 0.00827
# Iter 14/50
# M step: done,  E step: done //  (in 18.92 sec)	logL: -1960173.387	Tol1: 0.00147	Tol2: 0.05106	Tol3: 0.00572
# Iter 15/50
# M step: done,  E step: done //  (in 18.80 sec)	logL: -1961225.630	Tol1: 0.00054	Tol2: 0.06673	Tol3: 0.00597
# Iter 16/50
# M step: done,  E step: done //  (in 18.82 sec)	logL: -1954095.270	Tol1: 0.00364	Tol2: 0.07698	Tol3: 0.00310
# Iter 17/50
# M step: done,  E step: done //  (in 18.83 sec)	logL: -1955328.082	Tol1: 0.00063	Tol2: 0.07753	Tol3: 0.00512
# Iter 18/50
# M step: done,  E step: done //  (in 18.63 sec)	logL: -1946624.405	Tol1: 0.00445	Tol2: 0.07186	Tol3: 0.00641
# Iter 19/50
# M step: done,  E step: done //  (in 18.79 sec)	logL: -1946072.064	Tol1: 0.00028	Tol2: 0.04862	Tol3: 0.00221
# Iter 20/50
# M step: done,  E step: done //  (in 18.86 sec)	logL: -1941379.873	Tol1: 0.00241	Tol2: 0.04579	Tol3: 0.00541
# Iter 21/50
# M step: done,  E step: done //  (in 18.90 sec)	logL: -1951972.922	Tol1: 0.00546	Tol2: 0.05021	Tol3: 0.00296
# Iter 22/50
# M step: done,  E step: done //  (in 18.88 sec)	logL: -1939904.031	Tol1: 0.00618	Tol2: 0.07116	Tol3: 0.00520
# Iter 23/50
# M step: done,  E step: done //  (in 18.90 sec)	logL: -1936911.682	Tol1: 0.00154	Tol2: 0.05892	Tol3: 0.00211
# Iter 24/50
# M step: done,  E step: done //  (in 18.81 sec)	logL: -1937027.994	Tol1: 0.00006	Tol2: 0.04126	Tol3: 0.00048
# Iter 25/50
# M step: done,  E step: done //  (in 18.84 sec)	logL: -1935474.334	Tol1: 0.00080	Tol2: 0.06422	Tol3: 0.00485
# Iter 26/50
# M step: done,  E step: done //  (in 18.76 sec)	logL: -1934183.339	Tol1: 0.00067	Tol2: 0.03439	Tol3: 0.00149
# Iter 27/50
# M step: done,  E step: done //  (in 18.75 sec)	logL: -1934342.984	Tol1: 0.00008	Tol2: 0.04194	Tol3: 0.00093
# Iter 28/50
# M step: done,  E step: done //  (in 18.93 sec)	logL: -1929517.566	Tol1: 0.00249	Tol2: 0.05564	Tol3: 0.00660
# Iter 29/50
# M step: done,  E step: done //  (in 18.76 sec)	logL: -1935508.542	Tol1: 0.00310	Tol2: 0.03302	Tol3: 0.00336
# Iter 30/50
# M step: done,  E step: done //  (in 18.91 sec)	logL: -1934692.904	Tol1: 0.00042	Tol2: 0.05995	Tol3: 0.01246
# Iter 31/50
# M step: done,  E step: done //  (in 18.82 sec)	logL: -1928871.816	Tol1: 0.00301	Tol2: 0.03095	Tol3: 0.00495
# Iter 32/50
# M step: done,  E step: done //  (in 18.67 sec)	logL: -1926884.803	Tol1: 0.00103	Tol2: 0.05237	Tol3: 0.00527
# Iter 33/50
# M step: done,  E step: done //  (in 18.82 sec)	logL: -1925780.882	Tol1: 0.00057	Tol2: 0.03234	Tol3: 0.00280
# Iter 34/50
# M step: done,  E step: done //  (in 19.00 sec)	logL: -1925500.776	Tol1: 0.00015	Tol2: 0.04019	Tol3: 0.00200
# Iter 35/50
# M step: done,  E step: done //  (in 18.73 sec)	logL: -1922625.888	Tol1: 0.00149	Tol2: 0.04534	Tol3: 0.00164
# Iter 36/50
# M step: done,  E step: done //  (in 18.68 sec)	logL: -1922100.163	Tol1: 0.00027	Tol2: 0.03722	Tol3: 0.00101
# Iter 37/50
# M step: done,  E step: done //  (in 18.64 sec)	logL: -1921335.438	Tol1: 0.00040	Tol2: 0.03382	Tol3: 0.00368
# Iter 38/50
# M step: done,  E step: done //  (in 18.93 sec)	logL: -1924508.642	Tol1: 0.00165	Tol2: 0.04965	Tol3: 0.00147
# Iter 39/50
# M step: done,  E step: done //  (in 18.72 sec)	logL: -1922341.707	Tol1: 0.00113	Tol2: 0.03324	Tol3: 0.00498
# Iter 40/50
# M step: done,  E step: done //  (in 18.92 sec)	logL: -1921781.624	Tol1: 0.00029	Tol2: 0.02946	Tol3: 0.00074
# Finished training!

# %%
plt.figure(figsize=(15,7))
for a, value in enumerate(logL_hists): #logL_hists
    if a != i_r:
        plt.plot(range(len(value)),value,'.-')
plt.plot(range(len(logL_hists[i_r])),logL_hists[i_r],'o-',markersize=10,label="Selected run")
plt.legend()
plt.show()

# %% [markdown]
# ### Compare trained models

# %%
#Import it:
from code.evaluation import Evaluation_metrics
from sklearn.metrics import confusion_matrix

# %%
evaluate = Evaluation_metrics(model_UB,'keras',Xstd_train.shape[0])
print("*** Upper bound -- Ideal (Train with GT) ***")

print("Train")
Z_train_pred = model_UB.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred)

print("Test")
Z_test_pred = model_UB.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Upper bound -- Ideal (Train with GT) ***
# Train
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global     0.98012       0.98012
# ====  ======  ==========  ============
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.8428        0.8428
# ====  ======  ==========  ============

# %% [markdown]
# #### 1st configuration: Normal ($T$ = 100, $T_{max}$ = 10 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.80502

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Soft-Majority (Train with softMV) ***
# Train
# KL divergence: 0.0337	Pearson Correlation between diagonals: 0.9897
# KL divergence: 0.1448	Pearson Correlation between diagonals: 0.9125
# KL divergence: 0.0339	Pearson Correlation between diagonals: 0.9902
# KL divergence: 0.1404	Pearson Correlation between diagonals: 0.9465
# KL divergence: 0.5742	Pearson Correlation between diagonals: 0.8865
# KL divergence: 0.5965	Pearson Correlation between diagonals: 0.8789
# KL divergence: 0.1436	Pearson Correlation between diagonals: 0.9151
# KL divergence: 0.5766	Pearson Correlation between diagonals: 0.8843
# KL divergence: 0.1409	Pearson Correlation between diagonals: 0.9335
# KL divergence: 0.5835	Pearson Correlation between diagonals: 0.8601
# KL divergence: 0.1455	Pearson Correlation between diagonals: 0.9242
# KL divergence: 0.0336	Pearson Correlation between diagonals: 0.9857
# KL divergence: 0.1426	Pearson Correlation between diagonals: 0.9372
# KL divergence: 0.1422	Pearson Correlation between diagonals: 0.9118
# KL divergence: 0.5813	Pearson Correlation between diagonals: 0.9213
# A result
#  ====  ======  ==========  ============  =========  =========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  =========  ==================
#    0  Global     0.58618       0.58618   0.254549  0.0635741             0.93283
# ====  ======  ==========  ============  =========  =========  ==================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.5773        0.5773
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Hard-Majority (Train with hardMV) ***
# Train
# KL divergence: 0.0348	Pearson Correlation between diagonals: 0.9844
# KL divergence: 0.0316	Pearson Correlation between diagonals: 0.9722
# KL divergence: 0.0118	Pearson Correlation between diagonals: 0.9935
# KL divergence: 0.0344	Pearson Correlation between diagonals: 0.9528
# KL divergence: 0.1567	Pearson Correlation between diagonals: 0.9276
# KL divergence: 0.1489	Pearson Correlation between diagonals: 0.9326
# KL divergence: 0.0303	Pearson Correlation between diagonals: 0.9864
# KL divergence: 0.0341	Pearson Correlation between diagonals: 0.9470
# KL divergence: 0.0289	Pearson Correlation between diagonals: 0.9849
# KL divergence: 0.0338	Pearson Correlation between diagonals: 0.9882
# KL divergence: 0.1470	Pearson Correlation between diagonals: 0.9433
# KL divergence: 0.1497	Pearson Correlation between diagonals: 0.9343
# KL divergence: 0.0339	Pearson Correlation between diagonals: 0.9923
# KL divergence: 0.0385	Pearson Correlation between diagonals: 0.9795
# KL divergence: 0.0389	Pearson Correlation between diagonals: 0.9523
# A result
#  ====  ======  ==========  ============  =========  =========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  =========  ==================
#    0  Global      0.7782        0.7782  0.0655332  0.0172189            0.962909
# ====  ======  ==========  ============  =========  =========  ==================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7425        0.7425
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Dawid and Skene model (Train with D&S) ***
# Train
# KL divergence: 0.0118	Pearson Correlation between diagonals: 0.9706
# KL divergence: 0.0069	Pearson Correlation between diagonals: 0.9955
# KL divergence: 0.0102	Pearson Correlation between diagonals: 0.9646
# KL divergence: 0.0079	Pearson Correlation between diagonals: 0.9926
# KL divergence: 0.0134	Pearson Correlation between diagonals: 0.9536
# KL divergence: 0.0099	Pearson Correlation between diagonals: 0.9911
# KL divergence: 0.0235	Pearson Correlation between diagonals: 0.9876
# KL divergence: 0.0122	Pearson Correlation between diagonals: 0.9460
# KL divergence: 0.0106	Pearson Correlation between diagonals: 0.9587
# KL divergence: 0.0166	Pearson Correlation between diagonals: 0.9971
# KL divergence: 0.0167	Pearson Correlation between diagonals: 0.9886
# KL divergence: 0.0248	Pearson Correlation between diagonals: 0.9874
# KL divergence: 0.0103	Pearson Correlation between diagonals: 0.9940
# KL divergence: 0.0081	Pearson Correlation between diagonals: 0.9860
# KL divergence: 0.0219	Pearson Correlation between diagonals: 0.9643
# A result
#  ====  ======  ==========  ============  =========  ==========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL     Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  ==========  ==================
#    0  Global     0.80854       0.80854  0.0137832  0.00272482            0.980567
# ====  ======  ==========  ============  =========  ==========  ==================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7557        0.7557
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.0098	Pearson Correlation between diagonals: 0.9635
# KL divergence: 0.0093	Pearson Correlation between diagonals: 0.9848
# KL divergence: 0.0084	Pearson Correlation between diagonals: 0.9886
# KL divergence: 0.0113	Pearson Correlation between diagonals: 0.9893
# KL divergence: 0.0092	Pearson Correlation between diagonals: 0.9779
# KL divergence: 0.0082	Pearson Correlation between diagonals: 0.9883
# KL divergence: 0.0097	Pearson Correlation between diagonals: 0.9614
# KL divergence: 0.0085	Pearson Correlation between diagonals: 0.9877
# KL divergence: 0.0122	Pearson Correlation between diagonals: 0.9902
# KL divergence: 0.0119	Pearson Correlation between diagonals: 0.9771
# KL divergence: 0.0120	Pearson Correlation between diagonals: 0.9766
# KL divergence: 0.0122	Pearson Correlation between diagonals: 0.9895
# KL divergence: 0.0088	Pearson Correlation between diagonals: 0.9941
# KL divergence: 0.0105	Pearson Correlation between diagonals: 0.9825
# KL divergence: 0.0113	Pearson Correlation between diagonals: 0.9850
# A result
#  ====  ======  ==========  ============  ==========  ==========  ==================  ==============
#   ..            Accuracy    F1 (micro)     Mean KL     Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  ==========  ==========  ==================  ==============
#    0  Global     0.80704       0.80704  0.00996929  0.00260587            0.983005       0.0631678
# ====  ======  ==========  ============  ==========  ==========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.418503                 1.66684
# ====  =======================  ======================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7754        0.7754
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(gMixture_Global,'our1') 
aux = gMixture_Global.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours Global multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture_Global.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture_Global.get_confusionM()
y_o_groups = gMixture_Global.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture_Global.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (1) multiples runs***
# Train
# KL divergence: 0.6291	Pearson Correlation between diagonals: 0.2931
# KL divergence: 0.7560	Pearson Correlation between diagonals: 0.5607
# KL divergence: 0.7560	Pearson Correlation between diagonals: 0.5607
# KL divergence: 0.3824	Pearson Correlation between diagonals: 0.0042
# KL divergence: 0.3824	Pearson Correlation between diagonals: 0.0042
# KL divergence: 0.2739	Pearson Correlation between diagonals: -0.0884
# KL divergence: 0.2739	Pearson Correlation between diagonals: -0.0884
# KL divergence: 0.3824	Pearson Correlation between diagonals: 0.0042
# KL divergence: 0.3824	Pearson Correlation between diagonals: 0.0042
# KL divergence: 0.2739	Pearson Correlation between diagonals: -0.0884
# KL divergence: 0.2739	Pearson Correlation between diagonals: -0.0884
# KL divergence: 0.3824	Pearson Correlation between diagonals: 0.0042
# KL divergence: 0.7560	Pearson Correlation between diagonals: 0.5607
# KL divergence: 0.6291	Pearson Correlation between diagonals: 0.2931
# KL divergence: 0.3824	Pearson Correlation between diagonals: 0.0042
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global     0.81508       0.81508   0.426638  0.0669812           0.0814631       0.0284352
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                  0.43138                 1.70306
# ====  =======================  ======================
# Test
# Inertia: 0.025814110830348607
# A result
#  ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.300979      30    1.19376     0.675612   0.397962       0.813326   0.575612      0.785         0.785
#    1         1  0.227161      22    1.49506     0.544456   0.628835       0.717767   0.444456      0.7849        0.7849
#    2         2  0.292713      29    1.50925     0.533428   0.646549       0.710046   0.433428      0.7788        0.7788
#    3         3  0.179148      17    1.57089     0.474265   0.805266       0.655534   0.374265      0.645         0.645
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7531        0.7531
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (2) multiples runs***
# Train
# KL divergence: 0.7503	Pearson Correlation between diagonals: -0.3583
# KL divergence: 0.3166	Pearson Correlation between diagonals: -0.3823
# KL divergence: 0.8380	Pearson Correlation between diagonals: -0.3117
# KL divergence: 0.3166	Pearson Correlation between diagonals: -0.3823
# KL divergence: 0.2239	Pearson Correlation between diagonals: -0.3048
# KL divergence: 0.2239	Pearson Correlation between diagonals: -0.3048
# KL divergence: 0.2047	Pearson Correlation between diagonals: -0.3518
# KL divergence: 0.2239	Pearson Correlation between diagonals: -0.3048
# KL divergence: 0.2239	Pearson Correlation between diagonals: -0.3048
# KL divergence: 0.3166	Pearson Correlation between diagonals: -0.3823
# KL divergence: 0.3166	Pearson Correlation between diagonals: -0.3823
# KL divergence: 0.3166	Pearson Correlation between diagonals: -0.3823
# KL divergence: 0.2239	Pearson Correlation between diagonals: -0.3048
# KL divergence: 0.2239	Pearson Correlation between diagonals: -0.3048
# KL divergence: 0.2239	Pearson Correlation between diagonals: -0.3048
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global     0.81666       0.81666   0.406988   0.072578           -0.349296       0.0211964
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.424882                 1.73912
# ====  =======================  ======================
# Test
# Inertia: 0.0627941859420389
# A result
#  ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.27152       27   1.25199      0.666439   0.412113       0.807155   0.566439      0.78          0.78
#    1         1  0.236346      23   1.58009      0.518576   0.682384       0.696873   0.418576      0.7778        0.7778
#    2         2  0.317873      31   1.70526      0.441275   0.849152       0.633445   0.341275      0.7551        0.7551
#    3         3  0.174262      17   0.519652     0.900076   0.106705       0.94766    0.800076      0.7396        0.7396
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global       0.747         0.747
# ====  ======  ==========  ============

# %% [markdown]
# #### 2) configuration: very bad MV ($T$ = 100, $T_{max}$ = 10 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.64792

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Soft-Majority (Train with softMV) ***
# Train
# KL divergence: 0.1026	Pearson Correlation between diagonals: 0.8301
# KL divergence: 0.4456	Pearson Correlation between diagonals: 0.8095
# KL divergence: 0.1002	Pearson Correlation between diagonals: 0.8531
# KL divergence: 0.0989	Pearson Correlation between diagonals: 0.9786
# KL divergence: 0.1012	Pearson Correlation between diagonals: 0.8800
# KL divergence: 0.0914	Pearson Correlation between diagonals: 0.9787
# KL divergence: 0.0976	Pearson Correlation between diagonals: 0.9913
# KL divergence: 0.0937	Pearson Correlation between diagonals: 0.9753
# KL divergence: 0.0229	Pearson Correlation between diagonals: 0.9951
# KL divergence: 0.0903	Pearson Correlation between diagonals: 0.9864
# KL divergence: 0.1019	Pearson Correlation between diagonals: 0.8731
# KL divergence: 0.1001	Pearson Correlation between diagonals: 0.9081
# KL divergence: 0.0964	Pearson Correlation between diagonals: 0.9745
# KL divergence: 0.0911	Pearson Correlation between diagonals: 0.9763
# KL divergence: 0.0227	Pearson Correlation between diagonals: 0.9958
# A result
#  ====  ======  ==========  ============  =========  =========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  =========  ==================
#    0  Global      0.7337        0.7337   0.115996  0.0302268              0.9273
# ====  ======  ==========  ============  =========  =========  ==================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.6466        0.6466
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Hard-Majority (Train with hardMV) ***
# Train
# KL divergence: 0.0223	Pearson Correlation between diagonals: 0.7796
# KL divergence: 0.0662	Pearson Correlation between diagonals: 0.8142
# KL divergence: 0.0215	Pearson Correlation between diagonals: 0.7884
# KL divergence: 0.0204	Pearson Correlation between diagonals: 0.8693
# KL divergence: 0.0224	Pearson Correlation between diagonals: 0.9609
# KL divergence: 0.0225	Pearson Correlation between diagonals: 0.9574
# KL divergence: 0.0197	Pearson Correlation between diagonals: 0.9031
# KL divergence: 0.0237	Pearson Correlation between diagonals: 0.8659
# KL divergence: 0.0137	Pearson Correlation between diagonals: 0.9871
# KL divergence: 0.0222	Pearson Correlation between diagonals: 0.8387
# KL divergence: 0.0680	Pearson Correlation between diagonals: 0.8278
# KL divergence: 0.0198	Pearson Correlation between diagonals: 0.9711
# KL divergence: 0.0194	Pearson Correlation between diagonals: 0.9818
# KL divergence: 0.0205	Pearson Correlation between diagonals: 0.9708
# KL divergence: 0.0736	Pearson Correlation between diagonals: 0.8028
# A result
#  ====  ======  ==========  ============  =========  ==========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL     Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  ==========  ==================
#    0  Global     0.69506       0.69506  0.0236947  0.00643257            0.916895
# ====  ======  ==========  ============  =========  ==========  ==================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.6615        0.6615
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Dawid and Skene model (Train with D&S) ***
# Train
# KL divergence: 0.0189	Pearson Correlation between diagonals: 0.9310
# KL divergence: 0.0194	Pearson Correlation between diagonals: 0.9836
# KL divergence: 0.0184	Pearson Correlation between diagonals: 0.9852
# KL divergence: 0.0212	Pearson Correlation between diagonals: 0.9855
# KL divergence: 0.0137	Pearson Correlation between diagonals: 0.9933
# KL divergence: 0.0113	Pearson Correlation between diagonals: 0.9938
# KL divergence: 0.0137	Pearson Correlation between diagonals: 0.9935
# KL divergence: 0.0165	Pearson Correlation between diagonals: 0.9846
# KL divergence: 0.0171	Pearson Correlation between diagonals: 0.9732
# KL divergence: 0.0134	Pearson Correlation between diagonals: 0.9649
# KL divergence: 0.0114	Pearson Correlation between diagonals: 0.9868
# KL divergence: 0.0161	Pearson Correlation between diagonals: 0.9804
# KL divergence: 0.0181	Pearson Correlation between diagonals: 0.9933
# KL divergence: 0.0159	Pearson Correlation between diagonals: 0.9950
# KL divergence: 0.0101	Pearson Correlation between diagonals: 0.9959
# A result
#  ====  ======  ==========  ============  =========  =========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  =========  ==================
#    0  Global     0.85014       0.85014  0.0173186  0.0039099             0.97567
# ====  ======  ==========  ============  =========  =========  ==================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7635        0.7635
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.0133	Pearson Correlation between diagonals: 0.9747
# KL divergence: 0.0126	Pearson Correlation between diagonals: 0.9897
# KL divergence: 0.0166	Pearson Correlation between diagonals: 0.9772
# KL divergence: 0.0118	Pearson Correlation between diagonals: 0.9909
# KL divergence: 0.0101	Pearson Correlation between diagonals: 0.9745
# KL divergence: 0.0076	Pearson Correlation between diagonals: 0.9908
# KL divergence: 0.0105	Pearson Correlation between diagonals: 0.9676
# KL divergence: 0.0120	Pearson Correlation between diagonals: 0.9919
# KL divergence: 0.0098	Pearson Correlation between diagonals: 0.9940
# KL divergence: 0.0160	Pearson Correlation between diagonals: 0.9953
# KL divergence: 0.0133	Pearson Correlation between diagonals: 0.9973
# KL divergence: 0.0149	Pearson Correlation between diagonals: 0.9512
# KL divergence: 0.0135	Pearson Correlation between diagonals: 0.9789
# KL divergence: 0.0111	Pearson Correlation between diagonals: 0.9906
# KL divergence: 0.0140	Pearson Correlation between diagonals: 0.9694
# A result
#  ====  ======  ==========  ============  =========  ==========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL     Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  ==========  ==================  ==============
#    0  Global      0.8306        0.8306    0.01203  0.00313822            0.981699       0.0420443
# ====  ======  ==========  ============  =========  ==========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.362311                 1.77246
# ====  =======================  ======================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7842        0.7842
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(gMixture_Global,'our1') 
aux = gMixture_Global.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours Global multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture_Global.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture_Global.get_confusionM()
y_o_groups = gMixture_Global.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture_Global.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (1) multiples runs***
# Train
# KL divergence: 0.3404	Pearson Correlation between diagonals: -0.5527
# KL divergence: 0.5683	Pearson Correlation between diagonals: 0.0536
# KL divergence: 0.2141	Pearson Correlation between diagonals: -0.0711
# KL divergence: 0.3404	Pearson Correlation between diagonals: -0.5527
# KL divergence: 0.5683	Pearson Correlation between diagonals: 0.0536
# KL divergence: 0.4532	Pearson Correlation between diagonals: 0.8817
# KL divergence: 0.4532	Pearson Correlation between diagonals: 0.8817
# KL divergence: 0.5683	Pearson Correlation between diagonals: 0.0536
# KL divergence: 0.3404	Pearson Correlation between diagonals: -0.5527
# KL divergence: 0.4532	Pearson Correlation between diagonals: 0.8817
# KL divergence: 0.5683	Pearson Correlation between diagonals: 0.0536
# KL divergence: 0.4532	Pearson Correlation between diagonals: 0.8817
# KL divergence: 0.2141	Pearson Correlation between diagonals: -0.0711
# KL divergence: 0.5683	Pearson Correlation between diagonals: 0.0536
# KL divergence: 0.3404	Pearson Correlation between diagonals: -0.5527
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global      0.7374        0.7374   0.421299  0.0785778           -0.113281       0.0320025
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.363928                 1.82554
# ====  =======================  ======================
# Test
# Inertia: 0.05040133614481116
# A result
#  ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.238282      23    1.39624     0.600767   0.523214       0.760413   0.500767      0.7467        0.7467
#    1         1  0.289336      28    1.43254     0.577405   0.568707       0.742365   0.477405      0.7172        0.7172
#    2         2  0.134411      13    1.50003     0.420322   1.14833        0.577639   0.320322      0.4772        0.4772
#    3         3  0.33797       33    1.41388     0.58382    0.55205        0.748275   0.48382       0.7539        0.7539
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.6775        0.6775
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (2) multiples runs***
# Train
# KL divergence: 1.0616	Pearson Correlation between diagonals: -0.3561
# KL divergence: 0.5130	Pearson Correlation between diagonals: -0.2264
# KL divergence: 1.0616	Pearson Correlation between diagonals: -0.3561
# KL divergence: 0.5130	Pearson Correlation between diagonals: -0.2264
# KL divergence: 1.0616	Pearson Correlation between diagonals: -0.3561
# KL divergence: 1.0616	Pearson Correlation between diagonals: -0.3561
# KL divergence: 0.5130	Pearson Correlation between diagonals: -0.2264
# KL divergence: 0.6999	Pearson Correlation between diagonals: 0.8176
# KL divergence: 0.5130	Pearson Correlation between diagonals: -0.2264
# KL divergence: 0.6999	Pearson Correlation between diagonals: 0.8176
# KL divergence: 1.0616	Pearson Correlation between diagonals: -0.3561
# KL divergence: 0.5130	Pearson Correlation between diagonals: -0.2264
# KL divergence: 0.5130	Pearson Correlation between diagonals: -0.2264
# KL divergence: 0.5130	Pearson Correlation between diagonals: -0.2264
# KL divergence: 1.0616	Pearson Correlation between diagonals: -0.3561
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global      0.6207        0.6207   0.700682   0.111706           -0.134835       0.0348903
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.370462                 1.81062
# ====  =======================  ======================
# Test
# Inertia: 0.05967068419946978
# A result
#  ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.221254      22    1.03016     0.737744   0.315529       0.851119   0.637744      0.7051        0.7051
#    1         1  0.276479      27    1.09635     0.707429   0.360402       0.831317   0.607429      0.6784        0.6784
#    2         2  0.141442      14    1.3968      0.44516    1.06145        0.602652   0.34516       0.4811        0.4811
#    3         3  0.360825      36    1.29462     0.605902   0.5426         0.756727   0.505902      0.7532        0.7532
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.5555        0.5555
# ====  ======  ==========  ============

# %% [markdown]
# #### 3) configuration: normal soft ($T$ = 100, $T_{max}$ = 10, soft clustering )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))
# Out:
# ACC MV on train: 0.74872

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Soft-Majority (Train with softMV) ***
# Train
# KL divergence: 0.1079	Pearson Correlation between diagonals: 0.9526
# KL divergence: 0.2284	Pearson Correlation between diagonals: 0.9304
# KL divergence: 0.2080	Pearson Correlation between diagonals: 0.9166
# KL divergence: 0.1704	Pearson Correlation between diagonals: 0.9271
# KL divergence: 0.0922	Pearson Correlation between diagonals: 0.9501
# KL divergence: 0.1824	Pearson Correlation between diagonals: 0.9008
# KL divergence: 0.0825	Pearson Correlation between diagonals: 0.9735
# KL divergence: 0.3415	Pearson Correlation between diagonals: 0.8837
# KL divergence: 0.1156	Pearson Correlation between diagonals: 0.9220
# KL divergence: 0.1769	Pearson Correlation between diagonals: 0.8952
# KL divergence: 0.2835	Pearson Correlation between diagonals: 0.9050
# KL divergence: 0.2239	Pearson Correlation between diagonals: 0.9582
# KL divergence: 0.2514	Pearson Correlation between diagonals: 0.8406
# KL divergence: 0.1298	Pearson Correlation between diagonals: 0.9840
# KL divergence: 0.4014	Pearson Correlation between diagonals: 0.8142
# A result
#  ====  ======  ==========  ============  =========  =========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  =========  ==================
#    0  Global     0.38434       0.38434   0.223482  0.0533009            0.907651
# ====  ======  ==========  ============  =========  =========  ==================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.3774        0.3774
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Hard-Majority (Train with hardMV) ***
# Train
# KL divergence: 0.0301	Pearson Correlation between diagonals: 0.9589
# KL divergence: 0.0622	Pearson Correlation between diagonals: 0.9231
# KL divergence: 0.0489	Pearson Correlation between diagonals: 0.9184
# KL divergence: 0.0509	Pearson Correlation between diagonals: 0.9368
# KL divergence: 0.0259	Pearson Correlation between diagonals: 0.9911
# KL divergence: 0.0632	Pearson Correlation between diagonals: 0.9400
# KL divergence: 0.0951	Pearson Correlation between diagonals: 0.9321
# KL divergence: 0.0244	Pearson Correlation between diagonals: 0.9869
# KL divergence: 0.0469	Pearson Correlation between diagonals: 0.9095
# KL divergence: 0.0830	Pearson Correlation between diagonals: 0.8988
# KL divergence: 0.0663	Pearson Correlation between diagonals: 0.9045
# KL divergence: 0.0632	Pearson Correlation between diagonals: 0.8942
# KL divergence: 0.0734	Pearson Correlation between diagonals: 0.9154
# KL divergence: 0.0157	Pearson Correlation between diagonals: 0.9931
# KL divergence: 0.0841	Pearson Correlation between diagonals: 0.8860
# A result
#  ====  ======  ==========  ============  =========  =========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  =========  ==================
#    0  Global     0.68952       0.68952  0.0650525  0.0162586            0.928238
# ====  ======  ==========  ============  =========  =========  ==================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.6694        0.6694
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Dawid and Skene model (Train with D&S) ***
# Train
# KL divergence: 0.0163	Pearson Correlation between diagonals: 0.9692
# KL divergence: 0.0104	Pearson Correlation between diagonals: 0.9695
# KL divergence: 0.0109	Pearson Correlation between diagonals: 0.9912
# KL divergence: 0.0139	Pearson Correlation between diagonals: 0.9711
# KL divergence: 0.0157	Pearson Correlation between diagonals: 0.9672
# KL divergence: 0.0117	Pearson Correlation between diagonals: 0.9852
# KL divergence: 0.0135	Pearson Correlation between diagonals: 0.9748
# KL divergence: 0.0113	Pearson Correlation between diagonals: 0.9927
# KL divergence: 0.0125	Pearson Correlation between diagonals: 0.9633
# KL divergence: 0.0123	Pearson Correlation between diagonals: 0.9657
# KL divergence: 0.0186	Pearson Correlation between diagonals: 0.9825
# KL divergence: 0.0137	Pearson Correlation between diagonals: 0.9485
# KL divergence: 0.0090	Pearson Correlation between diagonals: 0.9945
# KL divergence: 0.0141	Pearson Correlation between diagonals: 0.9774
# KL divergence: 0.0151	Pearson Correlation between diagonals: 0.9073
# A result
#  ====  ======  ==========  ============  =========  ==========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL     Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  ==========  ==================
#    0  Global     0.75908       0.75908  0.0143272  0.00338183            0.963204
# ====  ======  ==========  ============  =========  ==========  ==================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7331        0.7331
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.0109	Pearson Correlation between diagonals: 0.9707
# KL divergence: 0.0103	Pearson Correlation between diagonals: 0.9737
# KL divergence: 0.0094	Pearson Correlation between diagonals: 0.9890
# KL divergence: 0.0108	Pearson Correlation between diagonals: 0.9753
# KL divergence: 0.0099	Pearson Correlation between diagonals: 0.9703
# KL divergence: 0.0103	Pearson Correlation between diagonals: 0.9761
# KL divergence: 0.0111	Pearson Correlation between diagonals: 0.9322
# KL divergence: 0.0104	Pearson Correlation between diagonals: 0.9450
# KL divergence: 0.0138	Pearson Correlation between diagonals: 0.9703
# KL divergence: 0.0106	Pearson Correlation between diagonals: 0.9699
# KL divergence: 0.0113	Pearson Correlation between diagonals: 0.9479
# KL divergence: 0.0085	Pearson Correlation between diagonals: 0.9902
# KL divergence: 0.0130	Pearson Correlation between diagonals: 0.9784
# KL divergence: 0.0136	Pearson Correlation between diagonals: 0.9626
# KL divergence: 0.0088	Pearson Correlation between diagonals: 0.9932
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global     0.82314       0.82314  0.0111718  0.0027915            0.969676       0.0386291
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.374174                 1.82648
# ====  =======================  ======================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7808        0.7808
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(gMixture_Global,'our1') 
aux = gMixture_Global.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours Global multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture_Global.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture_Global.get_confusionM()
y_o_groups = gMixture_Global.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture_Global.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (1) multiples runs***
# Train
# KL divergence: 0.4026	Pearson Correlation between diagonals: -0.1576
# KL divergence: 0.2886	Pearson Correlation between diagonals: -0.2170
# KL divergence: 0.2715	Pearson Correlation between diagonals: -0.1856
# KL divergence: 0.4052	Pearson Correlation between diagonals: -0.3519
# KL divergence: 0.2707	Pearson Correlation between diagonals: -0.1941
# KL divergence: 0.2580	Pearson Correlation between diagonals: -0.2147
# KL divergence: 0.2622	Pearson Correlation between diagonals: -0.1064
# KL divergence: 0.1825	Pearson Correlation between diagonals: -0.1698
# KL divergence: 0.4795	Pearson Correlation between diagonals: -0.2397
# KL divergence: 0.2171	Pearson Correlation between diagonals: -0.2257
# KL divergence: 0.2257	Pearson Correlation between diagonals: -0.1347
# KL divergence: 0.3262	Pearson Correlation between diagonals: -0.2204
# KL divergence: 0.2285	Pearson Correlation between diagonals: -0.3345
# KL divergence: 0.1870	Pearson Correlation between diagonals: -0.1704
# KL divergence: 0.2119	Pearson Correlation between diagonals: -0.2074
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global     0.81248       0.81248   0.295512  0.0539347           -0.227553       0.0216622
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.382421                 1.85387
# ====  =======================  ======================
# Test
# Inertia: 0.0005347140759113245
# A result
#  ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.286319      28    1.51423     0.54974    0.608889       0.724331   0.44974       0.7527        0.7527
#    1         1  0.231767      23    1.48149     0.568243   0.573222       0.738611   0.468243      0.7524        0.7524
#    2         2  0.260179      26    1.50028     0.559112   0.590886       0.731538   0.459112      0.7545        0.7545
#    3         3  0.221736      22    1.48903     0.566845   0.576534       0.737372   0.466845      0.7571        0.7571
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7509        0.7509
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (2) multiples runs***
# Train
# KL divergence: 0.3647	Pearson Correlation between diagonals: -0.4020
# KL divergence: 0.2542	Pearson Correlation between diagonals: -0.3839
# KL divergence: 0.3251	Pearson Correlation between diagonals: -0.3872
# KL divergence: 0.3609	Pearson Correlation between diagonals: -0.4660
# KL divergence: 0.3801	Pearson Correlation between diagonals: -0.3386
# KL divergence: 0.3257	Pearson Correlation between diagonals: -0.4443
# KL divergence: 0.3712	Pearson Correlation between diagonals: -0.4378
# KL divergence: 0.3292	Pearson Correlation between diagonals: -0.4171
# KL divergence: 0.3414	Pearson Correlation between diagonals: -0.4197
# KL divergence: 0.3920	Pearson Correlation between diagonals: -0.4048
# KL divergence: 0.2627	Pearson Correlation between diagonals: -0.4015
# KL divergence: 0.2423	Pearson Correlation between diagonals: -0.3919
# KL divergence: 0.4379	Pearson Correlation between diagonals: -0.4897
# KL divergence: 0.3767	Pearson Correlation between diagonals: -0.3828
# KL divergence: 0.2272	Pearson Correlation between diagonals: -0.3866
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global     0.82004       0.82004   0.339203  0.0634644           -0.389461       0.0134439
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.391196                  1.8353
# ====  =======================  ======================
# Test
# Inertia: 0.024489921813559096
# A result
#  ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.291269      29   1.41898      0.595017   0.536267       0.755367   0.495017      0.7801        0.7801
#    1         1  0.244392      24   1.65061      0.474456   0.775785       0.660955   0.374456      0.7697        0.7697
#    2         2  0.239811      23   0.850557     0.809616   0.214002       0.896667   0.709616      0.7726        0.7726
#    3         3  0.224528      22   1.47136      0.57344    0.57562        0.739278   0.47344       0.783         0.783
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7446        0.7446
# ====  ======  ==========  ============

# %% [markdown]
# #### 4) configuration: Manny annot v1 ($T$ = 2000, $T_{max}$ = 20 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.0717	Pearson Correlation between diagonals: 0.8312
# KL divergence: 0.1001	Pearson Correlation between diagonals: 0.9188
# KL divergence: 0.0825	Pearson Correlation between diagonals: 0.9391
# KL divergence: 0.0608	Pearson Correlation between diagonals: 0.7944
# KL divergence: 0.0783	Pearson Correlation between diagonals: 0.6312
# KL divergence: 0.0915	Pearson Correlation between diagonals: 0.7020
# KL divergence: 0.0994	Pearson Correlation between diagonals: 0.9708
# KL divergence: 0.0717	Pearson Correlation between diagonals: 0.6392
# KL divergence: 0.0784	Pearson Correlation between diagonals: 0.9106
# KL divergence: 0.0649	Pearson Correlation between diagonals: 0.5959
# KL divergence: 0.0780	Pearson Correlation between diagonals: 0.8639
# KL divergence: 0.0921	Pearson Correlation between diagonals: 0.8447
# KL divergence: 0.0694	Pearson Correlation between diagonals: 0.7584
# KL divergence: 0.0767	Pearson Correlation between diagonals: 0.9510
# KL divergence: 0.1005	Pearson Correlation between diagonals: 0.9390
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global     0.78094       0.78094  0.0821774  0.0220737            0.874822       0.0714281
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.395359                 1.70213
# ====  =======================  ======================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7529        0.7529
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(gMixture_Global,'our1') 
aux = gMixture_Global.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours Global multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture_Global.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture_Global.get_confusionM()
y_o_groups = gMixture_Global.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture_Global.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=False)
predictions_m,prob_Gt,prob_Yzt,_ =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (1) multiples runs***
# Train
# KL divergence: 0.8418	Pearson Correlation between diagonals: 0.5230
# KL divergence: 0.4268	Pearson Correlation between diagonals: 0.0037
# KL divergence: 1.0828	Pearson Correlation between diagonals: -0.2596
# KL divergence: 0.4270	Pearson Correlation between diagonals: -0.0012
# KL divergence: 0.4268	Pearson Correlation between diagonals: 0.0038
# KL divergence: 0.2662	Pearson Correlation between diagonals: 0.1571
# KL divergence: 0.8418	Pearson Correlation between diagonals: 0.5230
# KL divergence: 0.4268	Pearson Correlation between diagonals: 0.0037
# KL divergence: 0.2662	Pearson Correlation between diagonals: 0.1571
# KL divergence: 0.8418	Pearson Correlation between diagonals: 0.5230
# KL divergence: 1.0828	Pearson Correlation between diagonals: -0.2596
# KL divergence: 0.4268	Pearson Correlation between diagonals: 0.0037
# KL divergence: 0.4442	Pearson Correlation between diagonals: -0.0807
# KL divergence: 0.2662	Pearson Correlation between diagonals: 0.1571
# KL divergence: 0.4386	Pearson Correlation between diagonals: -0.0651
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global     0.70006       0.70006   0.578327  0.0910167           0.0946688       0.0390093
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.390257                 1.80474
# ====  =======================  ======================
# Test
# Inertia: 0.019846756472058285
# A result
#  ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    T(g)    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.183276     366    1.378       0.595919   0.538698       0.755053   0.49592       0.7604        0.7604
#    1         1  0.434119     868    1.39975     0.562944   0.59875        0.730605   0.462944      0.7514        0.7514
#    2         2  0.203404     406    1.51432     0.484186   0.773092       0.665336   0.384186      0.5978        0.5978
#    3         3  0.179201     358    1.33732     0.615444   0.504554       0.769194   0.515444      0.7574        0.7574
# ====  ========  ========  ======  =========  ===========  =========  =============  =========  ==========  ============
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.6398        0.6398
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=False)
predictions_m,prob_Gt,prob_Yzt,_ =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# *** Ours (2) multiples runs***
# Train
# KL divergence: 0.4397	Pearson Correlation between diagonals: 0.0130
# KL divergence: 1.1442	Pearson Correlation between diagonals: -0.4612
# KL divergence: 0.2651	Pearson Correlation between diagonals: -0.5007
# KL divergence: 0.4397	Pearson Correlation between diagonals: 0.0130
# KL divergence: 1.1442	Pearson Correlation between diagonals: -0.4612
# KL divergence: 0.4391	Pearson Correlation between diagonals: 0.0130
# KL divergence: 0.4397	Pearson Correlation between diagonals: 0.0130
# KL divergence: 0.4387	Pearson Correlation between diagonals: 0.0129
# KL divergence: 0.2651	Pearson Correlation between diagonals: -0.5007
# KL divergence: 0.4397	Pearson Correlation between diagonals: 0.0130
# KL divergence: 0.2651	Pearson Correlation between diagonals: -0.5007
# KL divergence: 0.4397	Pearson Correlation between diagonals: 0.0130
# KL divergence: 1.1442	Pearson Correlation between diagonals: -0.4612
# KL divergence: 0.4380	Pearson Correlation between diagonals: 0.0129
# KL divergence: 0.4391	Pearson Correlation between diagonals: 0.0130
# A result
#  ====  ======  ==========  ============  =========  =========  ==================
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr
# ====  ======  ==========  ============  =========  =========  ==================
#    0  Global     0.79336       0.79336    0.64309   0.109905           -0.285686
# ====  ======  ==========  ============  =========  =========  ==================
# Test
# Inertia: 0.06194681334697331
# A result
#  ====  ========  ========  =========  ===========  =========  =============  =========  ==========  ============
#   ..    Groups      Prob    Entropy    Diag Mean    KL to I    I sim %(JS)    Spammer    Accuracy    F1 (micro)
# ====  ========  ========  =========  ===========  =========  =============  =========  ==========  ============
#    0         0  0.173399   1.26417      0.646478  0.454921        0.790512   0.546478      0.7963        0.7963
#    1         1  0.485392   1.63423      0.431333  0.891875        0.621121   0.331333      0.7374        0.7374
#    2         2  0.181743   0.439609     0.916978  0.0877133       0.956838   0.816978      0.7177        0.7177
#    3         3  0.159466   1.10377      0.716151  0.343336        0.838288   0.616151      0.7847        0.7847
# ====  ========  ========  =========  ===========  =========  =============  =========  ==========  ============
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global       0.719         0.719
# ====  ======  ==========  ============

# %% [markdown]
# #### 5) configuration: Manny annot v2 ($T$ = 10000, $T_{max}$ = 40 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(gMixture_Global,'our1') 
aux = gMixture_Global.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=False)
predictions_m,prob_Gt,prob_Yzt,_ =  aux #to evaluate...
print("*** Ours Global multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture_Global.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
c_M = gMixture_Global.get_confusionM()
y_o_groups = gMixture_Global.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture_Global.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)

# %% [markdown]
# #### 6) configuration: Manny annot v1 + bad MV ($T$ = 2000, $T_{max}$ = 20 )

# %%
print("ACC MV on train:",np.mean(mv_onehot.argmax(axis=1)==Z_train))

# %%
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)
# Out:
# *** Raykar model multiples runs***
# Train
# KL divergence: 0.0805	Pearson Correlation between diagonals: 0.9365
# KL divergence: 0.1010	Pearson Correlation between diagonals: 0.9308
# KL divergence: 0.0745	Pearson Correlation between diagonals: 0.7718
# KL divergence: 0.0877	Pearson Correlation between diagonals: 0.8609
# KL divergence: 0.0876	Pearson Correlation between diagonals: 0.8168
# KL divergence: 0.0861	Pearson Correlation between diagonals: 0.9615
# KL divergence: 0.0604	Pearson Correlation between diagonals: 0.8140
# KL divergence: 0.0935	Pearson Correlation between diagonals: 0.9819
# KL divergence: 0.0708	Pearson Correlation between diagonals: 0.9268
# KL divergence: 0.0628	Pearson Correlation between diagonals: 0.9652
# KL divergence: 0.0745	Pearson Correlation between diagonals: 0.6372
# KL divergence: 0.0959	Pearson Correlation between diagonals: 0.9426
# KL divergence: 0.0744	Pearson Correlation between diagonals: 0.7761
# KL divergence: 0.1002	Pearson Correlation between diagonals: 0.9359
# KL divergence: 0.0809	Pearson Correlation between diagonals: 0.8072
# A result
#  ====  ======  ==========  ============  =========  =========  ==================  ==============
#   ..            Accuracy    F1 (micro)    Mean KL    Mean JS    Mean PearsonCorr    Average RMSE
# ====  ======  ==========  ============  =========  =========  ==================  ==============
#    0  Global     0.77382       0.77382  0.0853959   0.022828            0.870939       0.0626477
# ====  ======  ==========  ============  =========  =========  ==================  ==============
# A result
#  ====  =======================  ======================
#   ..    ACC imiting Annotator    CE imiting Annotator
# ====  =======================  ======================
#    0                 0.370616                 1.74988
# ====  =======================  ======================
# Test
# A result
#  ====  ======  ==========  ============
#   ..            Accuracy    F1 (micro)
# ====  ======  ==========  ============
#    0  Global      0.7428        0.7428
# ====  ======  ==========  ============

# %%
evaluate = Evaluation_metrics(gMixture_Global,'our1') 
aux = gMixture_Global.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours Global multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture_Global.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture_Global.get_confusionM()
y_o_groups = gMixture_Global.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture_Global.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)

# %%
evaluate = Evaluation_metrics(gMixture1,'our1') 
aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=False)
predictions_m,prob_Gt,prob_Yzt,_ =  aux #to evaluate...
print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture1.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
c_M = gMixture1.get_confusionM()
y_o_groups = gMixture1.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture1.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-674b9f6b0be1> in <module>()
#       1 evaluate = Evaluation_metrics(gMixture1,'our1')
# ----> 2 aux = gMixture1.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
#       3 predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
#       4 print("*** Ours (1) multiples runs***") #--with tol *2 aka detenerlo antes
#       5
#
# ~/MixtureofGroups/code/MixtureofGroups.py in calculate_extra_components(self, X, y_o, T, calculate_pred_annotator)
#     463
#     464         if calculate_pred_annotator:
# --> 465             prob_Yxt = np.tensordot(predictions_m, prob_Gt, axes=[[1],[1]]).transpose(0,2,1) #p(y^o|x,t) = sum_g p(g|t) *p(yo|x,g)
#     466         else:
#     467             prob_Yxt = None
#
# ~/.local/lib/python3.5/site-packages/numpy/core/numeric.py in tensordot(a, b, axes)
#    1303     at = a.transpose(newaxes_a).reshape(newshape_a)
#    1304     bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1305     res = dot(at, bt)
#    1306     return res.reshape(olda + oldb)
#    1307
#
# MemoryError:

# %%
evaluate = Evaluation_metrics(gMixture2,'our1') 
aux = gMixture2.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=False)
predictions_m,prob_Gt,prob_Yzt,_ =  aux #to evaluate...
print("*** Ours (2) multiples runs***") #--with tol *2 aka detenerlo antes

print("Train")
Z_train_pred = gMixture2.base_model.predict_classes(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
c_M = gMixture2.get_confusionM()
y_o_groups = gMixture2.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture2.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)

# %% [markdown]
# #### 7) configuration: Manny annot v1 + soft ($T$ = 2000, $T_{max}$ = 20 )

# %%
#soft mv one
evaluate = Evaluation_metrics(model_mvsoft,'keras',Xstd_train.shape[0])
print("*** Soft-Majority (Train with softMV) ***")

print("Train")
Z_train_p = model_mvsoft.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvsoft.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(model_mvhard,'keras',Xstd_train.shape[0])
print("*** Hard-Majority (Train with hardMV) ***")

print("Train")
Z_train_p = model_mvhard.predict(Xstd_train)
#prob_Yzt = get_confusionM(Z_train_p,y_obs_categorical)
Z_train_pred = Z_train_p.argmax(axis=1)
prob_Yzt = np.tile(confusion_matrix(y_true=Z_train,y_pred=Z_train_pred), (T,1,1) )
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_mvhard.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(model_ds,'keras',Xstd_train.shape[0])
print("*** Dawid and Skene model (Train with D&S) ***")

print("Train")
Z_train_pred = model_ds.predict_classes(Xstd_train)
results1 = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=ds_conf,conf_true=confe_matrix)

print("Test")
Z_test_pred = model_ds.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(raykarMC,'raykar')
print("*** Raykar model multiples runs***")

print("Train")
Z_train_pred = raykarMC.base_model.predict_classes(Xstd_train)
prob_Yzt = raykarMC.get_confusionM()
prob_Yxt = raykarMC.get_predictions_annot(Xstd_train)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
Z_test_pred = raykarMC.base_model.predict_classes(Xstd_test)
results2 = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred)

# %%
evaluate = Evaluation_metrics(gMixture_Global,'our1') 
aux = gMixture_Global.calculate_extra_components(Xstd_train,y_obs,T=T,calculate_pred_annotator=True)
predictions_m,prob_Gt,prob_Yzt,prob_Yxt =  aux #to evaluate...
print("*** Ours Global multiples runs***") #lambda = random

print("Train")
Z_train_pred = gMixture_Global.base_model.predict_classes(Xstd_train)
y_o_groups = predictions_m.argmax(axis=-1)
results = evaluate.calculate_metrics(Z=Z_train,Z_pred=Z_train_pred,conf_pred=prob_Yzt,conf_true=confe_matrix,y_o=y_obs,yo_pred=prob_Yxt, y_o_groups=y_o_groups)

results = evaluate.calculate_metrics(y_o=y_obs,yo_pred=prob_Yxt)

print("Test")
c_M = gMixture_Global.get_confusionM()
y_o_groups = gMixture_Global.get_predictions_groups(Xstd_test).argmax(axis=-1) #obtain p(y^o|x,g=m) and then argmax
Z_test_pred = gMixture_Global.base_model.predict_classes(Xstd_test)
results = evaluate.calculate_metrics(Z=Z_test,Z_pred=Z_test_pred,conf_pred=c_M, y_o_groups=y_o_groups)
